# %%
######################################### IMPORTING PACAKGES #############################
# Basic ML Packages
from scipy import spatial
import pandas as pd
import math
import os
import json
import numpy as np
import string

import warnings
warnings.filterwarnings("ignore")

# PDF text extraction
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import PDFPageAggregator
from pdfminer3.converter import TextConverter

# Others
import string
import re
from pprint import pprint
from tqdm.notebook import tqdm
import io

# Text pre-processing (Tokenization, Stemming, Lemmatization)
import nltk
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('omw-1.4')

# Pdf Extraction Model
import spacy
spacy.cli.download("en_core_web_sm")
nlp = spacy.load("en_core_web_sm", disable=['ner'])

#Gensim stopwords
import gensim
from gensim.parsing.preprocessing import remove_stopwords
stopwords = gensim.parsing.preprocessing.STOPWORDS

# Train Test Split
from sklearn.model_selection import train_test_split

# Tf-Idf Vectorization
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

DATA_FOLDER = "dataset/"
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Chen
# [nltk_data]     Wei\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Chen
# [nltk_data]     Wei\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Chen
# [nltk_data]     Wei\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
def extract_pdf(file_path):
    """
    Process raw PDF text to structured and processed PDF text to be worked on in Python.
    Parameters
    ----------
    file_path : Relative Location of File
    Return
    ------
    text : str
        processed PDF text if no error is throw
    """   

    try:
        resource_manager = PDFResourceManager()
        fake_file_handle = io.StringIO()
        codec = 'utf-8'
        laparams = LAParams()

        converter = TextConverter(resource_manager, fake_file_handle, codec=codec, laparams=laparams)
        page_interpreter = PDFPageInterpreter(resource_manager, converter)
        
        password = ""
        maxpages = 0
        caching = True
        pagenos = set()

        content = []

        with open(file_path, 'rb') as file:
            for page in PDFPage.get_pages(file,
                                        pagenos, 
                                        maxpages=maxpages,
                                        password=password,
                                        caching=True,
                                        check_extractable=False):

                page_interpreter.process_page(page)

                content.append(fake_file_handle.getvalue())

                fake_file_handle.truncate(0)
                fake_file_handle.seek(0)        

        text = '##PAGE_BREAK##'.join(content)

        # close open handles
        converter.close()
        fake_file_handle.close()
        
        return text

    except Exception as e:
        print(e)

        # close open handles
        converter.close()
        fake_file_handle.close()

        return ""

# %%
# nlp preprocessing
def preprocess_lines(line_input):
    """
    Helper Function to preprocess and clean sentences from raw PDF text 
    Parameters
    ----------
    line_input : str
        String that contains a sentence to be cleaned
    Return
    ------
    line : str
        Cleaned sentence
    ----------
    Sub: Substitute regular expression
    Split: Remove blank space from front and rear 
    """  
    # removing header number
    line = re.sub(r'^\s?\d+(.*)$', r'\1', line_input)
    # removing trailing spaces
    line = line.strip()
    # words may be split between lines, ensure we link them back together
    line = re.sub(r'\s?-\s?', '-', line)
    # remove space prior to punctuation
    line = re.sub(r'\s?([,:;\.])', r'\1', line)
    # ESG contains a lot of figures that are not relevant to grammatical structure
    line = re.sub(r'\d{5,}', r' ', line)
    # remove emails
    line = re.sub(r'\S*@\S*\s?', '', line)
    # remove mentions of URLs
    line = re.sub(r'((http|https)\:\/\/)?[a-zA-Z0-9\.\/\?\:@\-_=#]+\.([a-zA-Z]){2,6}([a-zA-Z0-9\.\&\/\?\:@\-_=#])*', r' ', line)
    # remove multiple spaces
    line = re.sub(r'\s+', ' ', line)
    # join next line with space
    line = re.sub(r' \n', ' ', line)
    line = re.sub(r'.\n', '. ', line)
    line = re.sub(r'\x0c', ' ', line)
    
    return line

# %%
def remove_non_ascii(text):
    """
    Helper Function to remove non ascii characters from text
    Printable will 
    """
    printable = set(string.printable) #Convert iterable to set
    return ''.join(filter(lambda x: x in printable, text))

def not_header(line):
    """
    Helper Function to remove headers
    Check if all the characters are in upper case
    """
    return not line.isupper()

# %%
def extract_pages_sentences(nlp, text):    
    """
    Extracting text from raw PDF text and store them by pages and senteces. Raw text is also cleand by removing junk, URLs, etc.
    Consecutive lines are also grouped into paragraphs and spacy is used to parse sentences.
    Parameters
    ----------
    nlp: spacy nlp model
        NLP model to parse sentences
    text : str
        Raw PDF text
    Return
    ------
    pages_content : list of str
        A list containing text from each page of the PDF report. Page number is the index of list + 1
    
    pages_sentences : list of list
        A list containing lists. Page number is the index of outer list + 1. Inner list contains sentences from each page
 
    """  
    
    pages = text.split('##PAGE_BREAK##')
    #print('Number of Pages: {}'.format(len(pages)))

    lines = []
    for i in range(len(pages)):
        page_number = i + 1
        page = pages[i]
        
        # remove non ASCII characters
        text = remove_non_ascii(page)
        
        # if len(text.split(' ')) < MIN_WORDS_PER_PAGE:
        #     print(f'Skipped Page: {page_number}')
        #     continue
        
        prev = ""
        for line in text.split('\n\n'):
            # aggregate consecutive lines where text may be broken down
            # only if next line starts with a space or previous does not end with dot.
            if(line.startswith(' ') or not prev.endswith('.')):
                prev = prev + ' ' + line
            else:
                # new paragraph
                lines.append(prev)
                prev = line

        # don't forget left-over paragraph
        lines.append(prev)
        lines.append('##SAME_PAGE##')
        
    lines = '  '.join(lines).split('##SAME_PAGE##')
    
    # clean paragraphs from extra space, unwanted characters, urls, etc.
    # best effort clean up, consider a more versatile cleaner
    
    pages_content = []
    pages_sentences = []
    all_sentences = []

    for line in lines[:-1]: # looping through each page
        
        line = preprocess_lines(line)       
        pages_content.append(str(line).strip())

        sentences = []
        # split paragraphs into well defined sentences using spacy
        for part in list(nlp(line).sents):
            sentences.append(str(part).strip())

        #sentences += nltk.sent_tokenize(line)
            
        # Only interested in full sentences and sentences with 10 to 100 words. --> filter out first page/content page
        sentences = [s for s in sentences if re.match('^[A-Z][^?!.]*[?.!]$', s) is not None]
        sentences = [s.replace('\n', ' ') for s in sentences]
        
        pages_sentences.append(sentences)
        all_sentences.extend(sentences)
    return pages_content, pages_sentences, all_sentences #list, list of list where page is index of outer list, list of sentences

# %%
def extract_sentences(nlp, text):
    pages = text.split('##PAGE_BREAK##')
    #print('Number of Pages: {}'.format(len(pages)))

    lines = []
    for i in range(len(pages)):
        page_number = i + 1
        page = pages[i]
        
        # remove non ASCII characters
        text = remove_non_ascii(page)
 
        prev = ""
        for line in text.split('\n\n'):
            # aggregate consecutive lines where text may be broken down
            # only if next line starts with a space or previous does not end with dot.
            if(line.startswith(' ') or not prev.endswith('.')):
                prev = prev + ' ' + line
            else:
                # new paragraph
                lines.append(prev)
                prev = line

        # don't forget left-over paragraph
        lines.append(prev)
        lines.append('##SAME_PAGE##')
        
    lines = '  '.join(lines).split('##SAME_PAGE##')
    
    # clean paragraphs from extra space, unwanted characters, urls, etc.
    # best effort clean up, consider a more versatile cleaner
    
    pages_content = []
    pages_sentences = []
    all_sentences = []

    for line in lines[:-1]: # looping through each page
        
        line = preprocess_lines(line)       
        pages_content.append(str(line).strip())

        sentences = []
        # split paragraphs into well defined sentences using spacy
        for part in list(nlp(line).sents):
            sentences.append(str(part).strip())

        #sentences += nltk.sent_tokenize(line)
            
        # Only interested in full sentences and sentences with 10 to 100 words. --> filter out first page/content page
        sentences = [s for s in sentences if re.match('^[A-Z][^?!.]*[?.!]$', s) is not None]
        sentences = [s.replace('\n', ' ') for s in sentences]
        
        pages_sentences.append(sentences)
        all_sentences.extend(sentences)
    return all_sentences #list of sentences

# %%
# Corpus has already been extract to corpus.txt, take around 15 mins to extract 24 reports
spacy_model = spacy.load("en_core_web_sm")
list_dataset = os.listdir(DATA_FOLDER)
corpus = []
#for file in list_dataset: ##clean loop
pages_content, pages_sentences, all_sentences = extract_pages_sentences(spacy_model,extract_pdf("british-land-sustainability-accounts-2022.pdf"))
corpus.extend(all_sentences)
np.shape(corpus)
# Out:
# (988,)

# %%
#Store corpus in text file
with open("bl_corpus.txt", "w") as fp:
    json.dump(corpus, fp)

# %%
corpus_data = open('bl_corpus.txt')
corpus = json.load(corpus_data)
corpus
# Out:
# ['Our ESG journey Our 2030 commitments Performance overview (KPIs) Net Zero carbon Place based approach Responsible business Performance data 2022 EPRA index SASB index Reporting criteria Assurance Reports 2 3 4 5 9 17 24 27 61 64 66 85 Read more about our TCFD disclosures in our 2022 Annual Report Against a challenging backdrop, our teams have done a fantastic job this year, working with our customers and partners to support local communities.',
#  'As we go into a new year, with new uncertainties on the horizon, their dedication will be more vital than ever.',
#  'Introduction This year we celebrate 20 years of sustainability reporting, and never has our environmental and social focus been more integral to the way we do business.',
#  'The climate emergency is high on everyones agenda; we face a cost of living crisis and the impact of Covid 19 continues to reverberate throughout our communities.',
#  'This means progressing our pathway to net zero and making a positive impact at our places is more important than ever.',
#  'We have continued to deliver strong progress this year.',
#  'At 1 Triton Square, we completed our second net zero carbon development and we are now on site at Canada Water, where we are piloting some of the most innovative building materials and technologies to deliver market leading, highly sustainable buildings.',
#  'Our approach is not only right in terms of the environment, but it also reflects what our customers increasingly expect.',
#  'The strong business case for sustainable buildings was underlined this year by our leasing success at 1 Broadgate, which will be one of the most sustainable buildings in London and is fully let (or under option) four years ahead of completion.',
#  'On the standing portfolio, we completed our net zero audits and are working with our customers to invest into the energy efficient interventions that programme has identified.',
#  'One outcome will be to raise EPC ratings across our portfolio to A or B by 2030 in line with expected MEES legislation.',
#  'We were delighted that our efforts have again been recognised by GRESB, the Global Real Estate Sustainability Benchmark where we achieved a 5* rating for both developments and standing investments.',
#  'On the social side, our Place Based approach and our strong local relationships allow us to adapt to emerging needs and opportunities at each place to make the biggest impact.',
#  'This year our community activities benefitted nearly 24,000 people.',
#  'Our lasting collaboration with Capital City Partnership at Fort Kinnaird, where together we help people who face barriers move into employment, is a powerful example of that (see p23).',
#  'This year marked ten years of our partnership with the National Literacy Trust.',
#  'Against a challenging backdrop, our teams have done a fantastic job, working with our customers and partners to support local communities.',
#  'I would like to thank them for all their hard work and for their huge contribution to making our places vibrant and successful.',
#  'As we go into a new year, with new uncertainties, their dedication will be more vital than ever.',
#  'Overview Overview Broadgate Places People Prefer Our purpose is to create and manage outstanding places which deliver positive outcomes for all our stakeholders on a long term, sustainable basis.',
#  'We do this by understanding the evolving needs ofthe people and the organisations who use our places and the communities who live around them.',
#  'The deep connections we have created between our customers, communities, partners and people have never been more important as we emerge from the pandemic.',
#  'Second net zero carbon development completed Embodied carbon at 1 Triton Square was below our 2030 target at 436 kg CO2e per sqm and was offset through certified schemes including a teak afforestation project in Mexico and a community reforestation project in Ghana.',
#  'Net zero asset audits completed Working with third party experts, we completed 29 audits across the portfolio identifying opportunities to improve the energy efficiency of our standing portfolio.',
#  'Awarded two BRE4 innovation credits For a heat exchange system, recycling waste heat from offices to residential at Canada Water and for introducing a Materials Passport, facilitating materials re-use at 1 Broadgate.',
#  'Offices development pipeline, including completed developments 2.',
#  'Whole building operational energy intensity improvement vs 2019 baseline for offices 3.',
#  'Impacted by Covid-19 restrictions requiring assets to close or operate at lower capacity 4.',
#  'Building Research Establishment, parent organisation of BREEAM certification framework Launched NDT Broadgate Together with New Diorama Theatre we launched NDT Broadgate to support the recovery of the arts post-pandemic.',
#  'One of Londons biggest rehearsal and artist development complexes.',
#  'This year we celebrate 20 years of sustainability reporting and our environmental and social focus has never been more integral to our business.',
#  'Launched Sustainability Brief for Developments.',
#  'Founding member of the UK Green Building Council.',
#  'Launched Community Investment Fund.',
#  'Signatory to the UN Global Compact.',
#  'Delivered first BREEAM Excellent projects.',
#  'Introduced smart energy management system.',
#  'Completed first whole life carbon assessments.',
#  'Our Sustainability Brief established the social and environmental requirements for our developments.',
#  'The UKGBC works to promote sustainability within the built environment.',
#  'Supported 56,000 children to read since our partnership with the National Literacy Trust began.',
#  'Launched Community Charter, laying the foundation for todays Local Charter.',
#  'Started Young Readers Programme partnership.',
#  'Queens Award for lasting economic, social and environmental achievements Launched Regents Place Customer Community Fund an industry first.',
#  'Launched Bright Lights, our skills and employment programme.',
#  'Worked with Happy City to establish seven core principles which guide our placemaking activities.',
#  'Launched 2030 sustainability strategy commitment to be net zero by 2030.',
#  'Introduced internal carbon levy of 60 per tonne on embodied carbon in developments.',
#  'Launched Transition Vehicle to fund energy efficient improvements.',
#  'Our Bright Lights skills and employment programme Science Based Targets initiative validated our carbon reduction targets.',
#  'Our Net Zero Pathway* sets out the ways in which we will reduce our carbon emissions.',
#  'We already offset embodied carbon in developments and from 2030 will offset operational carbon.',
#  'Overview Overview Our 2030 commitments Net zero carbon Environmental leadership Place Based approach We have committed to achieving a net zero carbon portfolio by 2030 and have set out clear targets to reduce both the embodied carbon in our developments and the operational carbon across our portfolio.',
#  'We demonstrate the strong progress we are delivering by participating in leading international benchmarks.',
#  'Our target is to achieve a 5* GRESB rating by 2022 and we are pleased to have achieved this two years ahead of target.',
#  'Top 81st percentile Science Based Targets: approval in 2021 Our Place Based approach means understanding the most important issues and opportunities in the communities around each of our places and focusing our efforts collaboratively to make the biggest impact at each place.',
#  'To deliver on this, we work directly with our community partners and we collaborate with our customers to identify key local issues where they can make an impact.',
#  'Connect: connecting customers, suppliers and community partners around priority local issues and opportunities.',
#  'Our Community Funds at Broadgate, Paddington and Regents Place are an example of this approach Education: needs-based initiatives at our places and working with long term partner the National Literacy Trust Employment: needs-based initiatives at our places.',
#  'Recent focus has been on supporting those impacted by Covid 19, for example through virtual employment training Supporting local business: supporting local business through the provision of affordable workspace, such as Thrive at Canada Water Wellbeing: putting our Wellbeing Principles into practice, which this year included a new park at Exchange Square, Broadgate.',
#  'Responsible business We advocate responsible business practices across British Land and throughout our supply chain.',
#  'Our key areas of focus are set out below.',
#  'Proportion of units with EPCs rated A or B across Assets Under Management 2030 Target 5-star by 2022 100% 50% by 2025 5% reduction in operational water consumption vs 2020 Operational waste from managed assets that is re-used, composted, or recycled Development and operational waste diverted from landfill New construction and major renovation projects designed to achieve a 10% net gain in biodiversity % of managed assets with Biodiversity Action Plans % of managed assets and major developments which have undergone a flood risk assessment 5% Offices: 80% Retail: 70% 100% 100% 100% 1.',
#  'From 2021, the 2030 strategy upgraded our BREEAM targets to Outstanding for Offices (from Excellent) and Excellent for Retail (from Very Good) 2.',
#  'Excludes residential FY22 Performance 5-star 70% 44% 28% 36% 13% Offices: 76% Retail: 48% 96% On track 15% 100% 2021 5-star 73% 27% 25% 24% 20% 71% 47% 100% nr 18% 100% 2020 4-star 24% 21% 25% 72% 54% 99% nr nr 100% BREEAM certifications To date, we have pursued BREEAM certificates at 44% of our standing portfolio.',
#  'While we target best-in-class certifications for new developments and major refurbishments, the majority of our portfolio was built prior to the BRE certification schemes and therefore the route for certifying these assets is through operational certifications, primarily BREEAM In Use.',
#  'We are currently pursuing a multi-stage rollout of BREEAM In Use certifications including first-time pilots at retail assets.',
#  'Likewise, as Committed and Near Term developments complete, their entry into the standing portfolio will increase the proportion of highly-rated assets.',
#  'Following socio-economic assessments, business plans have been created for all sites FY23 Priorities Report on social value generated Develop social value target 5 year target To be reported from FY23 Place Based initiatives identified at all priority assets.',
#  'We will use the priority assets tables on pages 21-23 to report progress against this.',
#  'Overview Net Zero Carbon Net Zero Carbon We have committed to achieving a net zero carbon portfolio by 2030 and have set out clear targets to reduce both the embodied carbon in our developments and the operational carbon across our portfolio.',
#  'We have a long track record of delivering sustainable space and this a clear competitive advantage for our business as more and more of our customers prioritise sustainability.',
#  'Overview Net Zero Carbon Net Zero delivering on our Pathway Last year we set out our Pathway to Net Zero.',
#  'We have delivered on our commitments for this year and are well advanced on those for the coming year.',
#  'Overview Net Zero Carbon Blossom Yard & Studios, Norton Folgate Net Zero carbon Reducing embodied carbon in developments To progress our target of 500 kg CO2e per sqm of embodied carbon on office developments from 2030, we committed to undertaking whole life carbon assessments on all our developments and major refurbishments.',
#  'To do this, we have adopted One Click LCA life cycle assessment software for all our developments.',
#  'This enables us to consolidate data so together with our consultants, we can benchmark performance and monitor progress.',
#  'This is helping to identify which designs, materials and techniques generate the most significant carbon savings.',
#  'Norton Folgate case study We focus on reusing existing materials and structures as far as possible.',
#  'At Blossom Studios, one of the buildings within the Norton Folgate development we retained almost all of the existing faade and 80% of the floors, and all the timber joists were individually assessed with most being re-used.',
#  'We rebuilt some internal walls re-using reclaimed bricks from the original building and retained original features such as iron columns and glazed bricks to preserve the original character of the building.',
#  'New materials focused on responsibly sourced and low carbon alternatives; we are using 100% FSC (Forest Stewardship Council) wood and all the concrete used has 40% cement replacement.',
#  'As a result we currently expect embodied carbon to be 403 kg CO2e per sqm (434 kg CO2e per sqm for the whole redevelopment), ahead of our 2030 target.',
#  'To drive operational performance we are adding roof top solar panels and using air source heat pumps to deliver all electric offices with 100% green power, so operational energy intensity is expected to be in line with our trajectory to 2030.',
#  'Overview Net Zero Carbon Reducing embodied carbon in developments continued Canada Water case study Unlike Norton Folgate, where we have greater capacity to reuse existing materials, Canada Water is a ground up redevelopment.',
#  'This means that to minimise embodied carbon emissions, our focus is on piloting more sustainable materials and processes.',
#  'At A1, a mixed use building which includes 186 residential units and 120,000 sq ft of workspace, we are using more sustainable materials in the superstructure.',
#  'This includes GGBS (ground granulated blast-furnace slag), a waste product from the blast furnaces used to make iron which can be repurposed as a cement replacement.',
#  'We are using post tensioned concrete slabs which are stronger and thinner, requiring less concrete, more cross laminated timber reducing the number of steel beams required and electric arc furnace steel.',
#  'These innovations are in line with the commitment to pilot low carbon materials in our Net Zero Pathway.',
#  'Our current projections are for embodied carbon to be 682 kg CO2e per sqm which is above our 2030 target of 500kg CO2e per sqm, but below the glidepath to 2030.',
#  'WELL Gold Certifications targeted Outdoor space Offsetting strategy We prioritise the re-use of existing materials to minimise embodied carbon as far as possible.',
#  'Where residual embodied carbon cannot be avoided by design and material choice, we offset this through certified emission reduction projects.',
#  'We use nature based offset credits and where possible, we select projects which also support biodiversity or have economic benefits for local communities.',
#  'Project works closely with local farmers, some of whom are employed on the project and others are able to grow crops.',
#  'Aim is to expand by 1,000 hectares each year.',
#  'Supporting the planting of 23,000 trees through the Woodland Carbon Code.',
#  'This was an additional commitment and not part of our formal offset at 1 Triton Square.',
#  'Overview Net Zero Carbon Reducing operational carbon The chart below sets out the key opportunities we have to reduce carbon emissions across our portfolio over the coming eight years.',
#  'On our standing portfolio these focus on renewable power and energy saving initiatives in our buildings.',
#  'Renewable power (grid, onsite and offsite) Residual emissons to be offset from 2030 2030 Energy saving initiatives New developments present the greatest opportunity to deliver best in class buildings which are operationally, highly energy efficient.',
#  'The chart below illustrates the improvement at 1 Broadgate, where energy intensity is just one sixth of the previous building.',
#  'Relatively recent developments, such as 4 Kingdom Street, are already among the most efficient in our portfolio and thoughtful asset management can deliver a significant improvement at relatively low cost.',
#  'In this case, the key intervention is a heat pump accounting for over 70% of the retrofit cost, which altogether represents less than 1% of the buildings value.',
#  'Older buildings such as Broadgate Tower require more comprehensive retrofitting.',
#  'This year we completed 29 net zero audits of buildings across our portfolio identifying initiatives which would deliver at least a 25% improvement in whole building energy efficiency.',
#  'A case study of Exchange House is shown over the page.',
#  'Indicative view which assumes developments are built out per development pipeline and excludes any capital activity We already offset residual embodied carbon on our developments and from 2030, will offset operational carbon across our standing portfolio but will seek to minimise this as far as possible in the following ways.',
#  'The decarbonisation of the National Grid will play a key role in the switch to renewable power across the UK.',
#  'We will supplement this by investing in onsite and offsite renewable energy sources.',
#  'Already we have 2 mega watts of capacity across our portfolio (of which half is at Meadowhall) and are now undertaking feasibility studies to identify further opportunities for rooftop and solar car port possibilities.',
#  'Detailed studies are now underway at two retail sites and the car park at Meadowhall shopping centre.',
#  'We are also exploring opportunities for offsite renewables which would increase the relative contribution of Renewable Power to our overall Pathway.',
#  'Overview Net Zero Carbon Reducing operational carbon continued Increasing energy efficiency on the standing portfolio This year, third party consultants completed net zero audits covering 29 of our major assets.',
#  'These have identified initiatives on the standing portfolio, which if actioned would deliver a 25% improvement in whole building energy efficiency in line with our target.',
#  'Some of these initiatives have already been delivered, reducing energy use by 23% and saving occupiers 340,000 annually.',
#  'One of the most effective interventions we have already delivered is introducing CO2 controls; sensors were installed on all office floors enabling us to monitor fresh air levels and adjust ventilation as needed.',
#  'This relatively low cost measure has significantly cut demand for heating and cooling.',
#  'We are also installing dedicated chillers for out of hours cooling, reducing the requirement to run the main chillers which are more intensive.',
#  'The most significant interventions are LED lighting and heat pumps.',
#  'The improvements will deliver savings which payback the investment over 5 years and we expect that around two-thirds of the cost will be funded through the service charge or covered directly by occupiers.',
#  'These interventions will also improve the buildings EPC rating to a B from an E, making the building fully compliant with expected MEES legislation.',
#  'Overview Place Based approach Our Place Based approach A Place Based approach means understanding the most important issues and opportunities in the communities around each of our places and focusing our efforts collaboratively to make the biggest impact.',
#  'Overview Place Based approach Place Based approach to Social Impact We invest directly into local community organisations, support them in a range of ways, including through the use of our space and work with our occupiers to deliver a positive social impact across our areas of focus.',
#  'Our Local Charter focuses on five key areas where we can create a lasting positive legacy for those who work, shop and live in and around our places.',
#  'Connect We connect with local communities bringing our customers, suppliers and community partners together around a common goal at each place.',
#  'Connecting customers and community partners is one of our strongest social contributions.',
#  'Following the success of the Regents Place Community Fund, this year we worked with our customers to launch funds at Broadgate and Paddington Central.',
#  'Together, we agree priority local themes, pledge funds and award grants to community organisations working locally.',
#  'In the first year, 15 customers and local stakeholders pledged over 150,000 to our Broadgate and Paddington Central Community Funds.',
#  'We support educational initiatives for local people helping them discover their potential, developing skills and raising awareness of career opportunities in our sectors.',
#  'This year, we delivered 58 education initiatives.',
#  'These ranged from primary school projects and secondary school workshops to college events and university challenges.',
#  'We continued our partnership with the National Literacy Trust across 29 of our places, working collaboratively with our customers and local schools to encourage an additional 7,800 children to read for pleasure and improve their literacy skills.',
#  'Together, we have reached 56,000 children since our partnership began.',
#  'Employment We support local training and jobs through Bright Lights, our skills and employment programme, working with customers, suppliers and local partners.',
#  'Recognising the impact of Covid-19 and the emerging cost of living crisis, we have refocused Bright Lights to support some of those most affected, including individuals who have lost their livelihoods.',
#  'These initiatives run across our portfolio.',
#  'We reached over 135 people through virtual employment training and one-to-one support designed to give local residents the skills to achieve lasting employment.',
#  'The programme included ringfenced opportunities with businesses at our places.',
#  'On average over 60% of candidates have already gained employment, in a range of sectors and at Glasgow Fort this rises to 75%.',
#  'Supporting local business = affordable space We support local businesses opening opportunities to local independents, social enterprises and start-ups to support their future success.',
#  'We provided affordable space at five of the eight priority assets and identified opportunities at the remaining three.',
#  'This includes affordable work space, affordable retail space and community and arts space.',
#  'Following the success of New Diorama Theatre (NDT) at Regents Place, together we launched NDT Broadgate to support the recovery of the arts post-pandemic.',
#  'The first project of its kind in the world, NDT Broadgate has attracted a footfall of 80,000 creatives, engaged over 600,000 people and supported the creation of highly successful productions.',
#  'New Diorama Theatre at Regents Place also won The Stages Fringe Theatre of the Year 2022 Award.',
#  'We create places that support health and wellbeing for our customers, colleagues and communities.',
#  'We develop partnerships in our communities which support the wellbeing of the people who work, visit and live in and around our places.',
#  'In 2022 our range of wellbeing initiatives, with community partners such as Darnall United and Global Generation, supported over 2,700 beneficiaries.',
#  'We are on track to achieve WELL Platinum, at 1 Broadgate, the highest level of certification on this globally-recognised benchmark for health and wellbeing.',
#  'Working closely with occupier JLL and architect AHMM, we are targeting industry leading standards for air quality, water and light.',
#  'We continue to align developments to the WELL standard.',
#  'Our first two office developments at Canada Water, A1 and A2, will both be WELL-ready.',
#  'This pre-certification supports us in delivering outstanding workspaces for our customers and opens up the opportunity for customers to partner with us in pursuing full WELL certification for employee health and wellbeing.',
#  'Our social reporting on the subsequent pages focuses on our priority assets and details our specific activities from 2022 and commitments for 2023.',
#  'However, our Place Based approach goes far beyond those assets with programmes delivered across our portfolio.',
#  'The reach of our biggest community initiatives, our partnership with The National Literacy Trust and our Bright Lights Employment initiative can be seen on the map.',
#  'Supporting Ukraine To support those affected by the war in Ukraine we donated 25,000 to the Disaster Emergency Committee which included matching personal donations from our people.',
#  'We also donated 5,000 to the Ukrainian Cathedral in Marylebone, close to our head office.',
#  'At Paddington Central, we pledged 30,000 funding for a scheme to support the Ukrainian Institute setting up an English Language School for refugees and have donated space to host classrooms at Storey Club.',
#  'At a number of assets, we have rolled out specific QR codes to enable people to make donations to the British Red Cross easily.',
#  'Cost of living crisis During FY23 we will be collaborating with our long term partners to support the excellent work they are already doing to help those struggling with the cost of living crisis.',
#  'Our Bright Lights initiatives will focus many of their activities on those most affected.',
#  'Overview Place Based approach Delivering Place Based Working with local partners, we are focusing on a core theme at each asset, to make the biggest social impact.',
#  'We appreciate the interest and respect British Land have for what we do.',
#  'They have a long term vision and were part of that, its like weve been brought into the subsoil and its wonderful to be part of the conversation around how this place comes together.',
#  'Jane Riddiford, Global Generation Canada Water At Canada Water, our partnership with environmental education charity Global Generation continues to grow.',
#  'This year, Global Generation engaged over 600 local primary schoolchildren through workshops and worked with Generator youth leaders.',
#  'Constructed using circular economy principles, the new facility will provide a fantastic community resource for years to come.',
#  'Paddington Central At Paddington Central, we are connecting customers and local partners around inclusive opportunities and this year launched our new Community Fund in collaboration with our occupiers where we will partner with them to address key local issues.',
#  'In April 2021, we unveiled a community garden, supported by occupiers Wipro and Kingfisher.',
#  'Local schoolchildren were among the first visitors to the garden and in the first year, customers volunteered and over 300 people took part in workshops on gardening and food growing with urban farming experts, Square Mile Farms.',
#  'Customers also volunteered 60 hours to help adults with learning disabilities run a fruit and smoothie stall on the campus, through our partnership with local non-profit Pursuing Independent Paths.',
#  'Representatives from businesses on the campus continue to connect through our diversity and inclusion network, with activities this year including a session with activist, TED speaker and author Nova Reid to mark Black History Month.',
#  'Overview Place Based approach Our Place Based approach in action Education Supporting local business = affordable space Wellbeing Broadgate At Broadgate, we are partnering to open access to educational opportunities across the age spectrum from primary school to university.',
#  'This year alone, we engaged 47 schoolchildren local to Broadgate through our collaboration with the National Literacy Trust and customers.',
#  'A further 9 local students completed our virtual work experience programme.',
#  'Our partnership with the University of East London continued to grow, students worked collaboratively on designs for the campus through the Broadgate Prize.',
#  'Canada Water At Canada Water, we continue to partner with Tree Shepherd to deliver Thrive, affordable workspace and business support for entrepreneurs, prioritising SE16 residents.',
#  'Through this project, we aim to create a self-sustaining local business network, growing a pipeline of successful enterprises for future opportunities at Canada Water.',
#  'This year, we supported 72 entrepreneurs with business advice of which five have gone on to set up businesses or become self-employed.',
#  'We provided low-cost workspace, including offices, meeting rooms and makerspace.',
#  'British Land authentically supports people in the community.',
#  'Together, were working to create a place where local people run businesses and are supported to be successful.',
#  'Its people who make a place meaningful.',
#  'Sandra Ferguson, Tree Shepherd Regents Place At Regents Place, we are providing 10,000 sq ft of affordable workspace at 1 Triton Square and donated space at the Triton Caf for community uses.',
#  'This included meeting space for local non-profit Camden Giving and occupier New Diorama Theatre.',
#  'We also provided space to BlackOut UK to run five monthly events across six months that supported peer learning, debates, networking and meaningful connections for 75 black queer men.',
#  'There are tens of thousands of plants, including many native species and flowering varieties good for bees, butterflies and other insects.',
#  'Mature birch trees will offer homes for birds.',
#  'This will all enhance biodiversity and open up access to nature, which studies show boosts wellbeing and productivity.',
#  'The park is also a valuable community space, designed for accessibility.',
#  'We will host events for customers and local people, including talks on gardening led by our Head Gardener.',
#  'To help create a network of green spaces for wildlife in central London, we are now working on roof gardens at Exchange House and nearby 1 Appold Street.',
#  'What nature loves above all things is mixture and change, and thats mirrored in the environments and planting at Exchange Square.',
#  'British Land was exceptionally supportive about us taking a different approach to urban planting.',
#  'The reason our recruitment and skills partnership works so well is because theres a real family feel at Fort Kinnaird.',
#  'At Fort Kinnaird, our strong relationship with Capital City Partnership has enabled us to respond rapidly as retailers and communities have faced shifts in Covid and sudden recruitment needs.',
#  'Together, we have supported nearly 90 people into jobs this year and delivered employability sessions to almost 130 young people.',
#  'As well as developing the confidence and skills of candidates who face barriers to employment, Capital City Partnership is on site every day, so retailers know vulnerable candidates have a network of resources to draw on.',
#  'As part of our focus on providing affordable retail space at Ealing Broadway we worked to find an opportunity for Curated Collective, a family business which supports independent artists and makers.',
#  'The team identified a unit in a good location with supportive terms.',
#  'Curative Collective was also able to use a pre-existing shop fit to avoid extra costs.',
#  'I cant thank Andrew, the Ealing Broadway team and British Land enough for getting behind this placemaking initiative and being so supportive.',
#  'Weve been able to work with 25 local creative partners.',
#  'People in Ealing love being able to interact with the people who made the items they are buying.',
#  'Weve gone from a market stall to thinking about five year leases and we couldnt have done that without the support of British Land.',
#  'Overview Responsible business Responsible business We advocate responsible business practices across British Land and throughout our supply chain.',
#  'Our key areas of focus are Responsible Employment, Diversity, Equality & Inclusion and Responsible Procurement.',
#  'Our people are our competitive advantage.',
#  'We invest in them and seek to create an environment where they can achieve their potential.',
#  'We apply this approach across our supply chain.',
#  'Overview Responsible business Responsible Business We advocate responsible business practices across British Land and throughout our supply chain.',
#  'Our key areas of focus are set out here.',
#  'Responsible Employment Invest in our people We recognise the importance of growing talent internally.',
#  'This year, we invested 440,000 in training and qualifications for our people (380,000 in FY21), developing leadership talent within the business.',
#  'Employees completed over 7,000 hours of training and we are supporting 14 colleagues to gain professional qualifications.',
#  'To support career development we run an internal mentorship scheme, which includes senior leaders and we also partner with Circl Coaching, pairing our people with local students, growing our coaching culture and supporting local talent.',
#  'Connect with our people We ran an in-depth employee engagement survey in early 2022, completed by 87% of our people.',
#  'Topics included leadership, engagement, learning and development, social connection and wellbeing, Diversity Equality & Inclusion (DE&I), and our response to Covid.',
#  'Our overall engagement score was 69%.',
#  'Some very positive messages emerged with 90% of staff reporting that they were proud to work for British Land and 85% confirming that they would recommend British Land as a great place to work.',
#  'The survey also highlighted areas for improvement and our ambition is to increase our overall engagement score.',
#  'To do this, our leadership teams are having detailed sessions across their departments and working collaboratively with their teams to create an action plan addressing the key points raised.',
#  'Provide a safe working environment We maintained our excellent standards for health and safety to ensure our people and places are safe.',
#  'Our health and safety management system is accredited to the international ISO standard and our accident frequency rates remain substantially below the national average.',
#  'Families need flexibility, and opportunities should be equal.',
#  'Thats why British Land offers up to six months of shared parental leave on full pay.',
#  'They support employees to live our lives and careers in ways that work for us, reflecting modern lifestyles through their benefits.',
#  'Michael and Olivia Head of Planning (Michael), Team Assistant (Olivia) Diversity, Equality & Inclusion In early 2022 we launched our Diversity, Equality & Inclusion Strategy, approved by our CSR Committee.',
#  'Aligned with the United Nations Sustainable Development Goals, this sets out our commitments to improve the diversity, equality and inclusivity of our business by 2030, ensuring that we reflect and understand the people who work, shop, live and spend time at our places.',
#  'All our employee feedback channels, including exit interviews and engagement surveys, include diversity demographics to help us understand where employees of different backgrounds, ethnicities and experiences encounter challenges, so we can improve.',
#  'To attract a more diverse workforce, we ensure hiring managers complete anti-bias training and receive blind CVs at the selection for interview stage which have removed the ethnicity and gender indicators.',
#  'We also work with agencies such as BAME Recruitment and London Works to reach candidates from varied backgrounds.',
#  'We have taken a lead role in the 10,000 Black Interns initiative, as real estate sector chair, and continue to support the Change 100 programme, offering paid internships to university students or recent graduates with disabilities or long-term conditions.',
#  'Our ten employee-led networks continue to drive progress on diversity, equality and inclusion.',
#  'These include our ability network enaBLe, REACH (Race Ethnicity and Celebrating Heritage), Parents & Carers, Pride and Womens Network, recently rebranded as equitaBLe.',
#  'Overview Responsible business NextGen, to represent and support the next generation of property professionals.',
#  'Improve gender diversity at all levels In 2022, we exceeded our commitment to maintain a minimum of 35% female representation on the Board, with 36% women on the Board and 37% of senior management female.',
#  'Improve ethnic diversity at all levels We fulfilled our commitment to maintain a minimum of two Directors from an ethnic minority background, ahead of the Parker Review recommendations for ethnic diversity at Board level.',
#  'This reduction was ahead of our target to reduce the pay gap by 2% year on year.',
#  'Responsible Procurement A strong relationship with our suppliers plays a key role in the successful delivery of our strategy which is governed by our Supplier Code of Conduct.',
#  'This sets out clear social, ethical and environmental obligations for our supply chain and promotes safe and fair working conditions.',
#  'Compliance is mandatory for all suppliers.',
#  'We pay at least the Real Living Wage to all British Land employees and we strongly encourage all suppliers to pay their UK employees at or above the Real Living Wage.',
#  'Our London Campuses are accredited Living Wage Places and also comply with the Mayors Good Work Standard.',
#  'Our Slavery and Human Trafficking Statement can be found on our website governance/modern-slavery-act Mandating prompt payment Paying suppliers and partners promptly and within the agreed payment terms is not only an ethical responsibility but also economically beneficial for all parties and the wider economy.',
#  'We have been a signatory to the UK Governments Prompt Payment Code since 2010 and aim to pay 95% of suppliers within 30 days.',
#  'Group invoices are settled within 18 days on average.',
#  'Responsible procurement standards This year, we introduced our Contractor Framework, identifying key sustainability performance indicators that we will monitor for new contractors employed on asset management initiatives.',
#  'We also launched our Supplier Excellence Awards to celebrate and showcase the best suppliers contributions in a range of categories including responsible business.',
#  'Active against modern slavery We uphold the human rights of our employees and throughout the supply chain.',
#  'This year, we provided anti-modern slavery training to all employees.',
#  'Through our partnership with anti-modern slavery charity Unseen, we also undertook independent audits of 10 of our suppliers operating in higher risk areas (with 11 more scheduled), reviewing compliance on 12 key areas of our Supplier Code of Conduct.',
#  'These included human rights, health and safety, equal opportunities, fair reward, working hours, staff development and worker representation.',
#  'Informed by risk and impact assessments, audits prioritised property management service providers at our assets and construction contractors on our developments.',
#  'All suppliers scored above 77% and by working with these suppliers improvement opportunities will be identified and agreed.',
#  'We continue to be a member of Unseens business helpline portal, which allows people to report a potential modern slavery occurrence anonymously.',
#  'Our Supplier Excellence Awards We are delighted to be recognised by British Land in their first supplier awards it felt so rewarding to be recognised by one of our clients in this way.',
#  'I can also confirm that having been in the FM industry for the last 12 years I havent seen any other client take this approach to service partner recognition trailblazing springs to mind.',
#  'Overview British Land Sustainability Accounts 2022 Net zero carbon Carbon emissions Fig.',
#  'Please see pages 85-87 for the full Assurance Reports from Korn Ferry (paygap data)and DNV.',
#  'Selected datahas been independently assured since 2007 (see earlier reports).',
#  'SBTi, Net Zero targets and greenhouse gas intensity For the second consecutive year, COVID-19 and related government restrictions has significantly affected our portfolios carbon intensity, representing the majority of the reduction.',
#  'However, we have also delivered initiatives which enhance energy efficiency over the last year, notably at Exchange House (see p6).',
#  'Overview Carbon emissions (continued) Fig.',
#  'The embodied emissions are offset after the project achieves the practical completion.',
#  'Until the UK Government specifies the long-term strategy for low-carbon heating (including the role of hydrogen and all-electric buildings), Y will include the use of renewable bio-gas.',
#  'Office and A1 units are all electric.',
#  'Exploring all electric option targeting <80.',
#  'N/A project has not undertaken the full NABERS accreditation.',
#  'TBC data will be available in future years as projects progress Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'In 2021/22, our estimated energy consumption in retail units assumes regular operations.',
#  'This will show a significant rise vs last year, where we assumed only 50% operation in retail units.',
#  'This years totals also include the embodied carbon of 1 Triton Square following its practical completion.',
#  'Location based: Our use of the 2021 UK greenhouse gas conversion factors reflect a +3% increase in the GHG intensity of gas (vs 2020) and a +1% increase in the GHG intensity of electricity (vs 2020).',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'While our proportion of renewable gas rose to 85% this year, renewable power dropped to 93%.',
#  'This reduced from last year primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Retail: direct use in retail units (occupier procured) FRI or non-landlord obtained energy at non-BL managed assets Upstream emissions from landlord obtained water use Indirect value chain greenhouse gas emissions In 2021/22, our estimated energy consumption in retail units assumes regular operations.',
#  'This will show a significant rise vs last year, where we assumed only 50% operation in retail units.',
#  'This years totals also include the embodied carbon of 1 Triton Square following its practical completion.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Fig.',
#  'However, we have also delivered initiatives which enhance energy efficiency over the last year, notably at Exchange House (see p16).',
#  'Other energy intensity measures Group occupied floors kWh per sqm * Common parts baseline.',
#  'Overview Carbon emissions (continued) Fig.',
#  'The committed development figures are provisional and amounts will be adjusted if they differ from the completed values.',
#  'These figures are proportionally disclosed at share.',
#  'This figure excludes funds allocated to offsets and funds already invested in projects to improve energy efficiency.',
#  'Investment this year included a chiller replacement at Broadwalk House with a total capex of 552,000.',
#  'This is expected to deliver annual cost savings of 65,000 which will be repaid through the service charge.',
#  'Our Net Zero and energy auditsassessed major assets representing 90% of landlord procured power.',
#  'Overview Energy use Fig.',
#  'Renewable Non-renewable Purchased Purchased Managed portfolio Offices: common parts Offices: shared services Offices: direct use in occupier space Sub-total Retail: common parts Retail: direct use in occupier space (landlord procured) Residential: common parts Scope (managed properties) Corporate Group offices Overall Total Proportion of purchased electricity from renewable sources Proportion of total electricity from renewable sources 110 110 1,150 18,635 20,283 59,974 98,891 14,351 2,584 2,958 999 3,793 7,749 547 300 570 21,703 21,282 63,766 106,751 16,047 2,883 570 109/111 49 49 1,210 20,148 16,375 66,178 102,701 14,722 2 947 821 891 279 332 1,502 196 93 1,084 21,087 16,654 66,510 104,252 16,129 1,040 1,087 108/112 821 46 46 1,274 24 22,618 17,838 83,496 123,952 18,151 1,827 143 240 3,216 3,599 661 16 984 22,808 18,078 86,712 127,598 20,086 1,843 1,008 102/106 971 971 1,260 116,535 9,166 126,960 1,261 119,192 2,875 123,328 1,344 144,901 5,259 151,504 93% 93% 98% 98% 96% 97% Total electricity consumption This year, our proportion of renewable power dropped to 93%.',
#  'This reduction from last year is primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff.',
#  'Overview Energy use (continued) Fig.',
#  'Managed portfolio Offices: common parts Offices: shared services Offices: direct use in occupier space Sub-total Retail: common parts Retail: direct use in occupier space (landlord procured) Residential: common parts Sub-total All property types: on-site vehicles Fuel consumption from service providers on-site vehicles and equipment Corporate Group offices Overall Total Proportion of purchased fuel from renewable sources Proportion of total fuel from renewable sources Fig.',
#  'Overview Energy use (continued) Fig.',
#  'Managed portfolio Offices: common parts Offices: shared services Offices: direct use in occupier space Sub-total Retail: common parts Retail: direct use in occupier space Residential: common parts All property types: on-site vehicles Fuel consumption from service providers on-site vehicles and equipment All property types: district heating and cooling Sub-total Corporate Group offices Overall Total Proportion of purchased energy from renewable sources Proportion of total energy from renewable sources Solar PV (including energy exported to the grid) CHP (electricity generated) CHP (heat generated) Total generated Proportion of energy use in common parts andsharedservices Proportion of all energy use Total energy consumed and generated on site This year, 90% of landlord procured energy was from renewable sources.',
#  'While our proportion of renewable gas rose to 85% this year, renewable power dropped to 93%.',
#  'This reduced from last year primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff.',
#  'Overview Environmental leadership Building certifications Fig.',
#  'The Revolving Credit Facility KPIs exclude residential properties.',
#  'Despite the disposal of some BREEAM-rated assets in recent years, our overall proportion of BREEAM certified assets continues to rise.',
#  'Likewise, 10 Exchange Square completed its first assessment this year, with a BREEAM In Use rating of Very Good.',
#  'This year, we also piloted BREEAM In Use (Part 2) assessments at a number of our retail sites.',
#  'As we have not traditionally procured energy and water on behalf of retail occupiers, we understood upfront that this lack of unit consumption data would limit the assessment rating to Pass.',
#  'However, the process has served as a useful benchmark of our alignment with BREEAMs management criteria and incentivises us to prioritise the collection of retailer consumption data, which will enable us to significantly improve these ratings in future.',
#  'Overview Building certifications (continued) Fig.',
#  'We expect the total cost for retrofitting the portfolio to be in the region of 100m and that two-thirds of this will be funded through the service charge or by customers directly.',
#  'These are typically low cost interventions with an attractive payback period and support occupiers in achieving their own sustainability ambitions.',
#  'Overview Water use Fig.',
#  'Fig.',
#  'At retail, water consumption returned to familiar levels in 2021/22, following a significant increase in the previous year due to a leak at Nugent Shopping Park.',
#  'Overview Water use (continued) Fig.',
#  'Overview Overview Waste and materials Fig.',
#  'Overview Waste and materials (continued) Fig.',
#  'Overview Waste and materials (continued) Fig.',
#  'Assurance excludes waste diverted from landfill through re-use on site and landfilled tax costs ().',
#  'Fig.',
#  'Proportion from sustainable sources 2020 58% 2021 88% 12% 100% 34/36 42% 100% 49/52 2022 56% 39% 95% 35/36 Waste management developments During excavation works at one of our Canada Water projects, it was discovered that some of the soil contained historic land contamination, and whilst not classified as hazardous waste, it would be unsuitable for repurposing due to the existing ground conditions.',
# ...
#  'Non-executive directors are included in this table to reflect any new joiners to the Board within the year.',
#  'Fig.',
#  'Employees who left under TUPE or at the end of their agreed fixed term employment contract are excluded.',
#  'Turnover rates are based on the number of leavers divided by the total number of number of employees at the end of the year (as reported in Fig.',
#  'Proportion of leavers by gender, employment level and age is based on the number of leavers in each category divided by total number of leavers within the year.',
#  'Non-executive directors are included in this table to reflect any leavers to the Board within the year.',
#  'Figures include salary, discretionary performance bonuses, car allowance, board fees and private medical insurance.',
#  'Remuneration related to share schemes is not included.',
#  'The bonus element is based on the prior year bonus paid, as current year bonuses will be paid after 31 March 2022 and had not been determined when data was compiled.',
#  'Salary and bonus payment data for part time employees has been pro-rated to their FTE data.',
#  'Non-executive directors are not included in this table, only executive directors employed permanently by British Land are included.',
#  'Fig.',
#  'Full details and previous years of gender pay gap reporting can be found on We are reporting on the 2022 pay gap ahead of the 2023 deadline set by the government.',
#  'All employees employed on 5 April 2022 are included in the data.',
#  'Fig.',
#  'Ethnicity pay gap British Land and Broadgate Estates Ltd comply with the mandatory government criteria for gender pay gap reporting, our ethnicity pay gap has followed the same methodology.',
#  'All employees employed on 5 April 2022 and who have voluntarily disclosed their ethnicity are included in the data.',
#  'Any bonus received in the year preceding 5 April 2022 is included in the bonus calculations.',
#  'Due to the small population size and to ensure anonymity, employees have been split into BAME (Black, Asian and minority ethnic) and non-BAME to report the ethnicity pay gap.',
#  'Fig.',
#  'In line with recommendations from the Global Reporting Initiative (GRI), this is the fourth year we are reporting on the median employee to CEO pay ratio.',
#  'CEO pay data includes salary, benefits, pension, annual incentives, long term incentives and other items in nature of compensation.',
#  'It is consistent with the single figure reported in our 2022 Annual Report and Accounts.',
#  'The data follows method A of the governments reporting criteria, therefore showing full time equivalent total remuneration of all UK employees for the financial year April 2021 to March 2022.',
#  'From 2016, ethnicity data has been captured through the human resources systems upon request from human resources.',
#  'All data has been given voluntarily by employees.',
#  'For reporting purposes, we use the Office of National Statistics ethnicity categories, shown in Table 11.',
#  'Other White Not disclosed Includes Asian Bangladeshi Asian Chinese Asian Indian Asian Pakistani Asian Other Black African Black Caribbean Black Other Mixed Other Mixed White and Asian Mixed White and Black African Mixed White and Black Caribbean Arab Other Ethnic Groups White English/Welsh/Scottish/Northern Irish White Gipsy or Irish Traveller White Irish White Other Includes employees who have actively chosen not to disclose and employees who did not respond at all Fig 51: Employee Diversity Sexual Orientation Proportion of employees voluntarily recording on our HR system whether they identify as LGBT+.',
#  'This data excludes non-executive directors.',
#  'Fig 52: Employee Diversity Disability Proportion of employees voluntarily recording on our HR system whether they have a disability or long-term condition.',
#  'Employees can select from one of the categories when disclosing their disability: This data excludes non-executive directors.',
#  'None Hidden Disability Hearing Disability Visual Disability Mobility and Physical Impairment Mental Health Condition Prefer not to say Fig 53: Employee Diversity Social Mobility Proportion of employees voluntarily recording on our HR system whether while at school received free school meal, were the first generation in their family to attend university or attended a non-selective state run or state funded school.',
#  'This data excludes non-executive directors.',
#  'Fig.',
#  'It excludes new starters, who have six weeks to complete the training, and are therefore reported in the next financial year.',
#  'Anti-corruption and bribery, information security and health and safety training are mandatory training modules.',
#  'All employees complete these training modules while employed at British Land Group.',
#  'This data excludes non-executive directors.',
#  'Fig.',
#  'This proportion is calculated for employees employed by British Land Group since the beginning of the performance review year.',
#  'This data excludes non-executive directors.',
#  'The British Land Company PLC (British Land) engaged Korn Ferry (UK) Limited (Korn Ferry) to conduct a limited assurance engagement of the British Land and Broadgate Estates 2022 Gender and Ethnicity pay gaps.',
#  'Conclusion Based on the review Korn Ferry has undertaken of the British Land and Broadgate Estates Gender and Ethnicity pay gaps, nothing has come to our attention that causes us to believe that the calculations and resultant gender and ethnicity pay gap figures are not fairly stated and have not been prepared, in all material respects, in accordance with the applicable criteria.',
#  'The scope of the review is based on the 2022 data presented in the following figures in the Gender and Ethnicity pay gap reports, based on the snapshot date of 5 April 2022.',
#  'Proportion of employees receiving a bonus Number of male and female employees by quartile Basis for our conclusion Korn Ferry were asked to review the Gender pay gap calculations against the Government regulations for Gender pay gap calculations, and relevant guidance.',
#  'The Ethnicity pay gap calculations were also reviewed on the same basis.',
#  'A review of the allocation of male and females by employee band and final calculation A review of the method to calculate the proportion of employees receiving bonus pay During the review process, our observations and questions relating to methodology were raised with British Land.',
#  'Korn Ferry confirms these were resolved or confirmed as appropriate by British Land.',
#  'Our competence, independence and quality control Korn Ferry is the independent adviser to the Remuneration Committee of British Land which does not conflict with the scope of this work.',
#  'Korn Ferry policies and procedures are designed to ensure the provision of objective and independent advice.',
#  'This independent review was carried out by a team of Pay and Governance specialists who are experienced in the review of the relevant regulations.',
#  'Inherent limitations of assurance All assurance engagements are subject to inherent limitations such as data sampling and may not detect errors, fraud or other irregularities.',
#  'Furthermore, our assurance relies on the premise that the data and information provided to us by British Land have been provided in good faith.',
#  'Korn Ferry expressly disclaims any liability or co-responsibility for any decision a person or an entity may make based on this report.',
#  'Overview Independent Limited Assurance Report to the Board of Directors of The British Land Company Plc The British Land Company Plc (British Land) commissioned DNV Business Assurance Services UK Limited (DNV, us or we) to conduct a limited assurance engagement over Selected Information presented in the Sustainability Accounts 2022 (the Report) for the reporting year ended 31 March 2022.',
#  'Our Conclusion: Based on the procedures we have performed and the evidence we have obtained, nothing has come to our attention that causes us to believe that the Selected Information is not fairly stated and has not been prepared, in all material respects, in accordance with the Criteria.',
#  'This conclusion relates only to the Selected Information, and is to be read in the context of this Independent Limited Assurance Report, in particular the inherent limitations explained overleaf.',
#  'Our observations and areas for improvement will be raised in a separate report to British Lands Management.',
#  'The scope and boundary of our work is restricted to the 2022 data presented in Figures marked with A (the Selected Information) in the Report.',
#  'A summary of these Figures is listed below: 1.',
#  'SBTi NZC targets greenhouse gas intensity 2.',
#  'Net Zero Carbon Developments 4.',
#  'Total direct and indirect (Scopes 1 2 & 3) GHG emissions Location and market based 5.',
#  'Like-for-like total direct and indirect (Scopes 1, 2 and 3) landlord-influenced greenhouse gas emissions 6.',
#  'Indirect (Scope 3) value chain greenhouse gas emissions 7.',
#  'Total greenhouse gas emissions by gas 8.',
#  'Building energy target and intensity 9.',
#  'Internal carbon levy and Transition Vehicle 10.',
#  'Total electricity consumption 11.',
#  'Total fuel consumption 12.',
#  'Like-for-like total electricity and fuel consumption 13.',
#  'Total energy consumed and generated on-site 14.',
#  'Sustainability ratings 15.',
#  'Energy Performance Certificates (EPC) 16.',
#  'Total water consumption 17.',
#  'Like-for-like total water consumption 18.',
#  'Building water target and intensity 19.',
#  'Waste management-managed portfolio and corporate 20.',
#  'Like for like waste management-managed portfolio 21.',
#  'Waste management-developments 23.',
#  'Environmental compliance 32 Community contributions through planning and development 37 Accidents-managed portfolio and corporate 38 Accidents-developments 39 Health and safety-compliance 40 Lost working days 41 Employment 42 New employees 43 Employee turnover 44 Salary and remuneration 48 Employee diversity-gender Our competence, independence and quality control DNV established policies and procedures are designed to ensure that DNV, its personnel and, where applicable, others are subject to independence requirements (including personnel of other entities of DNV) and maintain independence where required by relevant ethical requirements.',
#  'This engagement work was carried out by an independent team of sustainability assurance professionals.',
#  'DNV has held other audit and assurance contracts with British Land, none of which conflict with the scope of this work.',
#  'Our multi-disciplinary team consisted of professionals with a combination of environmental and sustainability assurance experience.',
#  'To assess the Selected Information, which includes an assessment of the risk of material misstatement in the Report, we have used British Lands Reporting Criteria (the Criteria), which can be found from page 66 of the Report.',
#  'We have not performed any work, and do not express any conclusion, on any other information that may be published in the Report or on British Lands website for the current reporting period or for previous periods.',
#  'Overview Standard and level of assurance We performed a limited assurance engagement in accordance with the International Standard on Assurance Engagements (ISAE) 3000 revised Assurance Engagements other than Audits and Reviews of Historical Financial Information (revised), issued by the International Auditing and Assurance Standards Board.',
#  'This standard requires that we comply with ethical requirements and plan and perform the assurance engagement to obtain limited assurance.',
#  'DNV applies its own management standards and compliance policies for quality control, in accordance with ISO/IEC -1:2015-Conformity Assessment Requirements for bodies providing audit and certification of management systems, and accordingly maintains a comprehensive system of quality control including documented policies and procedures regarding compliance with ethical requirements, professional standards and applicable legal and regulatory requirements.',
#  'The procedures performed in a limited assurance engagement vary in nature and timing from, and are less in extent than for, a reasonable assurance engagement; and the level of assurance obtained is substantially lower than the assurance that would have been obtained had a reasonable assurance engagement been performed.',
#  'We planned and performed our work to obtain the evidence we considered sufficient to provide a basis for our opinion, so that the risk of this conclusion being in error is reduced but not reduced to very low.',
#  'Basis of our conclusion We are required to plan and perform our work in order to consider the risk of material misstatement of the Selected Information; our work included, but was not restricted to: Conducting interviews with British Land management and data owners to obtain an understanding of the key processes, systems and controls in place to generate, aggregate and report the Selected Information; Performing limited substantive testing on a selective basis of the Selected Information to check that data had been appropriately measured, recorded, collated and reported; Reviewing that the evidence, measurements and their scope provided to us by British Land for the Selected Information is prepared in line with the Criteria; A remote visit to Head Office to test the consolidation of data at Group level; A remote site visit to Canada Water (Waste) and Norton Folgate (H&S) in the Development portfolio to review the processes and systems for preparing site level data consolidated at Group level.',
#  'DNV were free to choose the site on the basis of materiality to the Group level figures; Assessing the appropriateness of the Criteria for the Selected Information; and Reading the Report and narrative accompanying the Selected Information within it with regard to the Criteria.',
#  'DNV Business Assurance Services UK Limited London, UK 09 June 2022 Inherent limitations All assurance engagements are subject to inherent limitations as selective testing (sampling) may not detect errors, fraud or other irregularities.',
#  'Non-financial data may be subject to greater inherent uncertainty than financial data, given the nature and methods used for calculating, estimating and determining such data.',
#  'The selection of different, but acceptable, measurement techniques may result in different quantifications between different entities.',
#  'Our assurance relies on the premise that the data and information provided to us by British Land have been provided in good faith.',
#  'DNV expressly disclaims any liability or co-responsibility for any decision a person or an entity may make based on this Independent Limited Assurance Report.',
#  'Responsibilities of the Board of Directors of British Land and DNV The Directors of British Land have sole responsibility for: Preparing and presenting the Selected information in accordance with the Criteria; Designing, implementing and maintaining effective internal controls over the information and data, resulting in the preparation of the Selected Information that is free from material misstatements; Measuring and reporting the Selected Information based on their established Criteria; and Contents and statements contained within the Report and the Criteria.',
#  'Our responsibility is to plan and perform our work to obtain limited assurance about whether the Selected Information has been prepared in accordance with the Criteria and to report to British Land in the form of an independent limited assurance conclusion, based on the work performed and the evidence obtained.',
#  'We have not been responsible for the preparation of the Report.',
#  'DNV Business Assurance DNV Business Assurance Services UK Limited is part of DNV Business Assurance, a global provider of certification, verification, assessment and training services, helping customers to build sustainable business performance.']

# %%
from tabulate import tabulate

def stemming(corpus):
    stemmer = SnowballStemmer(language='english')
    revisions = [stemmer.stem(line) for line in corpus]
    return revisions

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer 

def lemmatization(corpus):
    lemmatizer = WordNetLemmatizer()
    revisions = [lemmatizer.lemmatize(line) for line in corpus]
    return revisions
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Chen
# [nltk_data]     Wei\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
tokenizer = TreebankWordTokenizer()
tokenize_output = tokenizer.tokenize(corpus[15])
stemming(tokenize_output)
# Out:
# ['this',
#  'year',
#  'mark',
#  'ten',
#  'year',
#  'of',
#  'our',
#  'partnership',
#  'with',
#  'the',
#  'nation',
#  'literaci',
#  'trust',
#  '.']

# %%
lemmatization(stemming(tokenize_output))
# Out:
# ['this',
#  'year',
#  'mark',
#  'ten',
#  'year',
#  'of',
#  'our',
#  'partnership',
#  'with',
#  'the',
#  'nation',
#  'literaci',
#  'trust',
#  '.']

# %%
def remove_stop_words(corpus):
    revisions = [remove_stopwords(line) for line in corpus]
    return revisions

# %%
remove_stop_words(corpus)
# Out:
# ['Our ESG journey Our 2030 commitments Performance overview (KPIs) Net Zero carbon Place based approach Responsible business Performance data 2022 EPRA index SASB index Reporting criteria Assurance Reports 2 3 4 5 9 17 24 27 61 64 66 85 Read TCFD disclosures 2022 Annual Report Against challenging backdrop, teams fantastic job year, working customers partners support local communities.',
#  'As new year, new uncertainties horizon, dedication vital ever.',
#  'Introduction This year celebrate 20 years sustainability reporting, environmental social focus integral way business.',
#  'The climate emergency high everyones agenda; face cost living crisis impact Covid 19 continues reverberate communities.',
#  'This means progressing pathway net zero making positive impact places important ever.',
#  'We continued deliver strong progress year.',
#  'At 1 Triton Square, completed second net zero carbon development site Canada Water, piloting innovative building materials technologies deliver market leading, highly sustainable buildings.',
#  'Our approach right terms environment, reflects customers increasingly expect.',
#  'The strong business case sustainable buildings underlined year leasing success 1 Broadgate, sustainable buildings London fully let (or option) years ahead completion.',
#  'On standing portfolio, completed net zero audits working customers invest energy efficient interventions programme identified.',
#  'One outcome raise EPC ratings portfolio A B 2030 line expected MEES legislation.',
#  'We delighted efforts recognised GRESB, Global Real Estate Sustainability Benchmark achieved 5* rating developments standing investments.',
#  'On social side, Place Based approach strong local relationships allow adapt emerging needs opportunities place biggest impact.',
#  'This year community activities benefitted nearly 24,000 people.',
#  'Our lasting collaboration Capital City Partnership Fort Kinnaird, help people face barriers employment, powerful example (see p23).',
#  'This year marked years partnership National Literacy Trust.',
#  'Against challenging backdrop, teams fantastic job, working customers partners support local communities.',
#  'I like thank hard work huge contribution making places vibrant successful.',
#  'As new year, new uncertainties, dedication vital ever.',
#  'Overview Overview Broadgate Places People Prefer Our purpose create manage outstanding places deliver positive outcomes stakeholders long term, sustainable basis.',
#  'We understanding evolving needs ofthe people organisations use places communities live them.',
#  'The deep connections created customers, communities, partners people important emerge pandemic.',
#  'Second net zero carbon development completed Embodied carbon 1 Triton Square 2030 target 436 CO2e sqm offset certified schemes including teak afforestation project Mexico community reforestation project Ghana.',
#  'Net zero asset audits completed Working party experts, completed 29 audits portfolio identifying opportunities improve energy efficiency standing portfolio.',
#  'Awarded BRE4 innovation credits For heat exchange system, recycling waste heat offices residential Canada Water introducing Materials Passport, facilitating materials re-use 1 Broadgate.',
#  'Offices development pipeline, including completed developments 2.',
#  'Whole building operational energy intensity improvement vs 2019 baseline offices 3.',
#  'Impacted Covid-19 restrictions requiring assets close operate lower capacity 4.',
#  'Building Research Establishment, parent organisation BREEAM certification framework Launched NDT Broadgate Together New Diorama Theatre launched NDT Broadgate support recovery arts post-pandemic.',
#  'One Londons biggest rehearsal artist development complexes.',
#  'This year celebrate 20 years sustainability reporting environmental social focus integral business.',
#  'Launched Sustainability Brief Developments.',
#  'Founding member UK Green Building Council.',
#  'Launched Community Investment Fund.',
#  'Signatory UN Global Compact.',
#  'Delivered BREEAM Excellent projects.',
#  'Introduced smart energy management system.',
#  'Completed life carbon assessments.',
#  'Our Sustainability Brief established social environmental requirements developments.',
#  'The UKGBC works promote sustainability built environment.',
#  'Supported 56,000 children read partnership National Literacy Trust began.',
#  'Launched Community Charter, laying foundation todays Local Charter.',
#  'Started Young Readers Programme partnership.',
#  'Queens Award lasting economic, social environmental achievements Launched Regents Place Customer Community Fund industry first.',
#  'Launched Bright Lights, skills employment programme.',
#  'Worked Happy City establish seven core principles guide placemaking activities.',
#  'Launched 2030 sustainability strategy commitment net zero 2030.',
#  'Introduced internal carbon levy 60 tonne embodied carbon developments.',
#  'Launched Transition Vehicle fund energy efficient improvements.',
#  'Our Bright Lights skills employment programme Science Based Targets initiative validated carbon reduction targets.',
#  'Our Net Zero Pathway* sets ways reduce carbon emissions.',
#  'We offset embodied carbon developments 2030 offset operational carbon.',
#  'Overview Overview Our 2030 commitments Net zero carbon Environmental leadership Place Based approach We committed achieving net zero carbon portfolio 2030 set clear targets reduce embodied carbon developments operational carbon portfolio.',
#  'We demonstrate strong progress delivering participating leading international benchmarks.',
#  'Our target achieve 5* GRESB rating 2022 pleased achieved years ahead target.',
#  'Top 81st percentile Science Based Targets: approval 2021 Our Place Based approach means understanding important issues opportunities communities places focusing efforts collaboratively biggest impact place.',
#  'To deliver this, work directly community partners collaborate customers identify key local issues impact.',
#  'Connect: connecting customers, suppliers community partners priority local issues opportunities.',
#  'Our Community Funds Broadgate, Paddington Regents Place example approach Education: needs-based initiatives places working long term partner National Literacy Trust Employment: needs-based initiatives places.',
#  'Recent focus supporting impacted Covid 19, example virtual employment training Supporting local business: supporting local business provision affordable workspace, Thrive Canada Water Wellbeing: putting Wellbeing Principles practice, year included new park Exchange Square, Broadgate.',
#  'Responsible business We advocate responsible business practices British Land supply chain.',
#  'Our key areas focus set below.',
#  'Proportion units EPCs rated A B Assets Under Management 2030 Target 5-star 2022 100% 50% 2025 5% reduction operational water consumption vs 2020 Operational waste managed assets re-used, composted, recycled Development operational waste diverted landfill New construction major renovation projects designed achieve 10% net gain biodiversity % managed assets Biodiversity Action Plans % managed assets major developments undergone flood risk assessment 5% Offices: 80% Retail: 70% 100% 100% 100% 1.',
#  'From 2021, 2030 strategy upgraded BREEAM targets Outstanding Offices (from Excellent) Excellent Retail (from Very Good) 2.',
#  'Excludes residential FY22 Performance 5-star 70% 44% 28% 36% 13% Offices: 76% Retail: 48% 96% On track 15% 100% 2021 5-star 73% 27% 25% 24% 20% 71% 47% 100% nr 18% 100% 2020 4-star 24% 21% 25% 72% 54% 99% nr nr 100% BREEAM certifications To date, pursued BREEAM certificates 44% standing portfolio.',
#  'While target best-in-class certifications new developments major refurbishments, majority portfolio built prior BRE certification schemes route certifying assets operational certifications, primarily BREEAM In Use.',
#  'We currently pursuing multi-stage rollout BREEAM In Use certifications including first-time pilots retail assets.',
#  'Likewise, Committed Near Term developments complete, entry standing portfolio increase proportion highly-rated assets.',
#  'Following socio-economic assessments, business plans created sites FY23 Priorities Report social value generated Develop social value target 5 year target To reported FY23 Place Based initiatives identified priority assets.',
#  'We use priority assets tables pages 21-23 report progress this.',
#  'Overview Net Zero Carbon Net Zero Carbon We committed achieving net zero carbon portfolio 2030 set clear targets reduce embodied carbon developments operational carbon portfolio.',
#  'We long track record delivering sustainable space clear competitive advantage business customers prioritise sustainability.',
#  'Overview Net Zero Carbon Net Zero delivering Pathway Last year set Pathway Net Zero.',
#  'We delivered commitments year advanced coming year.',
#  'Overview Net Zero Carbon Blossom Yard & Studios, Norton Folgate Net Zero carbon Reducing embodied carbon developments To progress target 500 CO2e sqm embodied carbon office developments 2030, committed undertaking life carbon assessments developments major refurbishments.',
#  'To this, adopted One Click LCA life cycle assessment software developments.',
#  'This enables consolidate data consultants, benchmark performance monitor progress.',
#  'This helping identify designs, materials techniques generate significant carbon savings.',
#  'Norton Folgate case study We focus reusing existing materials structures far possible.',
#  'At Blossom Studios, buildings Norton Folgate development retained existing faade 80% floors, timber joists individually assessed re-used.',
#  'We rebuilt internal walls re-using reclaimed bricks original building retained original features iron columns glazed bricks preserve original character building.',
#  'New materials focused responsibly sourced low carbon alternatives; 100% FSC (Forest Stewardship Council) wood concrete 40% cement replacement.',
#  'As result currently expect embodied carbon 403 CO2e sqm (434 CO2e sqm redevelopment), ahead 2030 target.',
#  'To drive operational performance adding roof solar panels air source heat pumps deliver electric offices 100% green power, operational energy intensity expected line trajectory 2030.',
#  'Overview Net Zero Carbon Reducing embodied carbon developments continued Canada Water case study Unlike Norton Folgate, greater capacity reuse existing materials, Canada Water ground redevelopment.',
#  'This means minimise embodied carbon emissions, focus piloting sustainable materials processes.',
#  'At A1, mixed use building includes 186 residential units 120,000 sq ft workspace, sustainable materials superstructure.',
#  'This includes GGBS (ground granulated blast-furnace slag), waste product blast furnaces iron repurposed cement replacement.',
#  'We post tensioned concrete slabs stronger thinner, requiring concrete, cross laminated timber reducing number steel beams required electric arc furnace steel.',
#  'These innovations line commitment pilot low carbon materials Net Zero Pathway.',
#  'Our current projections embodied carbon 682 CO2e sqm 2030 target 500kg CO2e sqm, glidepath 2030.',
#  'WELL Gold Certifications targeted Outdoor space Offsetting strategy We prioritise re-use existing materials minimise embodied carbon far possible.',
#  'Where residual embodied carbon avoided design material choice, offset certified emission reduction projects.',
#  'We use nature based offset credits possible, select projects support biodiversity economic benefits local communities.',
#  'Project works closely local farmers, employed project able grow crops.',
#  'Aim expand 1,000 hectares year.',
#  'Supporting planting 23,000 trees Woodland Carbon Code.',
#  'This additional commitment formal offset 1 Triton Square.',
#  'Overview Net Zero Carbon Reducing operational carbon The chart sets key opportunities reduce carbon emissions portfolio coming years.',
#  'On standing portfolio focus renewable power energy saving initiatives buildings.',
#  'Renewable power (grid, onsite offsite) Residual emissons offset 2030 2030 Energy saving initiatives New developments present greatest opportunity deliver best class buildings operationally, highly energy efficient.',
#  'The chart illustrates improvement 1 Broadgate, energy intensity sixth previous building.',
#  'Relatively recent developments, 4 Kingdom Street, efficient portfolio thoughtful asset management deliver significant improvement relatively low cost.',
#  'In case, key intervention heat pump accounting 70% retrofit cost, altogether represents 1% buildings value.',
#  'Older buildings Broadgate Tower require comprehensive retrofitting.',
#  'This year completed 29 net zero audits buildings portfolio identifying initiatives deliver 25% improvement building energy efficiency.',
#  'A case study Exchange House shown page.',
#  'Indicative view assumes developments built development pipeline excludes capital activity We offset residual embodied carbon developments 2030, offset operational carbon standing portfolio seek minimise far possible following ways.',
#  'The decarbonisation National Grid play key role switch renewable power UK.',
#  'We supplement investing onsite offsite renewable energy sources.',
#  'Already 2 mega watts capacity portfolio (of half Meadowhall) undertaking feasibility studies identify opportunities rooftop solar car port possibilities.',
#  'Detailed studies underway retail sites car park Meadowhall shopping centre.',
#  'We exploring opportunities offsite renewables increase relative contribution Renewable Power overall Pathway.',
#  'Overview Net Zero Carbon Reducing operational carbon continued Increasing energy efficiency standing portfolio This year, party consultants completed net zero audits covering 29 major assets.',
#  'These identified initiatives standing portfolio, actioned deliver 25% improvement building energy efficiency line target.',
#  'Some initiatives delivered, reducing energy use 23% saving occupiers 340,000 annually.',
#  'One effective interventions delivered introducing CO2 controls; sensors installed office floors enabling monitor fresh air levels adjust ventilation needed.',
#  'This relatively low cost measure significantly cut demand heating cooling.',
#  'We installing dedicated chillers hours cooling, reducing requirement run main chillers intensive.',
#  'The significant interventions LED lighting heat pumps.',
#  'The improvements deliver savings payback investment 5 years expect two-thirds cost funded service charge covered directly occupiers.',
#  'These interventions improve buildings EPC rating B E, making building fully compliant expected MEES legislation.',
#  'Overview Place Based approach Our Place Based approach A Place Based approach means understanding important issues opportunities communities places focusing efforts collaboratively biggest impact.',
#  'Overview Place Based approach Place Based approach Social Impact We invest directly local community organisations, support range ways, including use space work occupiers deliver positive social impact areas focus.',
#  'Our Local Charter focuses key areas create lasting positive legacy work, shop live places.',
#  'Connect We connect local communities bringing customers, suppliers community partners common goal place.',
#  'Connecting customers community partners strongest social contributions.',
#  'Following success Regents Place Community Fund, year worked customers launch funds Broadgate Paddington Central.',
#  'Together, agree priority local themes, pledge funds award grants community organisations working locally.',
#  'In year, 15 customers local stakeholders pledged 150,000 Broadgate Paddington Central Community Funds.',
#  'We support educational initiatives local people helping discover potential, developing skills raising awareness career opportunities sectors.',
#  'This year, delivered 58 education initiatives.',
#  'These ranged primary school projects secondary school workshops college events university challenges.',
#  'We continued partnership National Literacy Trust 29 places, working collaboratively customers local schools encourage additional 7,800 children read pleasure improve literacy skills.',
#  'Together, reached 56,000 children partnership began.',
#  'Employment We support local training jobs Bright Lights, skills employment programme, working customers, suppliers local partners.',
#  'Recognising impact Covid-19 emerging cost living crisis, refocused Bright Lights support affected, including individuals lost livelihoods.',
#  'These initiatives run portfolio.',
#  'We reached 135 people virtual employment training one-to-one support designed local residents skills achieve lasting employment.',
#  'The programme included ringfenced opportunities businesses places.',
#  'On average 60% candidates gained employment, range sectors Glasgow Fort rises 75%.',
#  'Supporting local business = affordable space We support local businesses opening opportunities local independents, social enterprises start-ups support future success.',
#  'We provided affordable space priority assets identified opportunities remaining three.',
#  'This includes affordable work space, affordable retail space community arts space.',
#  'Following success New Diorama Theatre (NDT) Regents Place, launched NDT Broadgate support recovery arts post-pandemic.',
#  'The project kind world, NDT Broadgate attracted footfall 80,000 creatives, engaged 600,000 people supported creation highly successful productions.',
#  'New Diorama Theatre Regents Place won The Stages Fringe Theatre Year 2022 Award.',
#  'We create places support health wellbeing customers, colleagues communities.',
#  'We develop partnerships communities support wellbeing people work, visit live places.',
#  'In 2022 range wellbeing initiatives, community partners Darnall United Global Generation, supported 2,700 beneficiaries.',
#  'We track achieve WELL Platinum, 1 Broadgate, highest level certification globally-recognised benchmark health wellbeing.',
#  'Working closely occupier JLL architect AHMM, targeting industry leading standards air quality, water light.',
#  'We continue align developments WELL standard.',
#  'Our office developments Canada Water, A1 A2, WELL-ready.',
#  'This pre-certification supports delivering outstanding workspaces customers opens opportunity customers partner pursuing WELL certification employee health wellbeing.',
#  'Our social reporting subsequent pages focuses priority assets details specific activities 2022 commitments 2023.',
#  'However, Place Based approach goes far assets programmes delivered portfolio.',
#  'The reach biggest community initiatives, partnership The National Literacy Trust Bright Lights Employment initiative seen map.',
#  'Supporting Ukraine To support affected war Ukraine donated 25,000 Disaster Emergency Committee included matching personal donations people.',
#  'We donated 5,000 Ukrainian Cathedral Marylebone, close head office.',
#  'At Paddington Central, pledged 30,000 funding scheme support Ukrainian Institute setting English Language School refugees donated space host classrooms Storey Club.',
#  'At number assets, rolled specific QR codes enable people donations British Red Cross easily.',
#  'Cost living crisis During FY23 collaborating long term partners support excellent work help struggling cost living crisis.',
#  'Our Bright Lights initiatives focus activities affected.',
#  'Overview Place Based approach Delivering Place Based Working local partners, focusing core theme asset, biggest social impact.',
#  'We appreciate respect British Land do.',
#  'They long term vision that, like weve brought subsoil wonderful conversation place comes together.',
#  'Jane Riddiford, Global Generation Canada Water At Canada Water, partnership environmental education charity Global Generation continues grow.',
#  'This year, Global Generation engaged 600 local primary schoolchildren workshops worked Generator youth leaders.',
#  'Constructed circular economy principles, new facility provide fantastic community resource years come.',
#  'Paddington Central At Paddington Central, connecting customers local partners inclusive opportunities year launched new Community Fund collaboration occupiers partner address key local issues.',
#  'In April 2021, unveiled community garden, supported occupiers Wipro Kingfisher.',
#  'Local schoolchildren visitors garden year, customers volunteered 300 people took workshops gardening food growing urban farming experts, Square Mile Farms.',
#  'Customers volunteered 60 hours help adults learning disabilities run fruit smoothie stall campus, partnership local non-profit Pursuing Independent Paths.',
#  'Representatives businesses campus continue connect diversity inclusion network, activities year including session activist, TED speaker author Nova Reid mark Black History Month.',
#  'Overview Place Based approach Our Place Based approach action Education Supporting local business = affordable space Wellbeing Broadgate At Broadgate, partnering open access educational opportunities age spectrum primary school university.',
#  'This year alone, engaged 47 schoolchildren local Broadgate collaboration National Literacy Trust customers.',
#  'A 9 local students completed virtual work experience programme.',
#  'Our partnership University East London continued grow, students worked collaboratively designs campus Broadgate Prize.',
#  'Canada Water At Canada Water, continue partner Tree Shepherd deliver Thrive, affordable workspace business support entrepreneurs, prioritising SE16 residents.',
#  'Through project, aim create self-sustaining local business network, growing pipeline successful enterprises future opportunities Canada Water.',
#  'This year, supported 72 entrepreneurs business advice gone set businesses self-employed.',
#  'We provided low-cost workspace, including offices, meeting rooms makerspace.',
#  'British Land authentically supports people community.',
#  'Together, working create place local people run businesses supported successful.',
#  'Its people place meaningful.',
#  'Sandra Ferguson, Tree Shepherd Regents Place At Regents Place, providing 10,000 sq ft affordable workspace 1 Triton Square donated space Triton Caf community uses.',
#  'This included meeting space local non-profit Camden Giving occupier New Diorama Theatre.',
#  'We provided space BlackOut UK run monthly events months supported peer learning, debates, networking meaningful connections 75 black queer men.',
#  'There tens thousands plants, including native species flowering varieties good bees, butterflies insects.',
#  'Mature birch trees offer homes birds.',
#  'This enhance biodiversity open access nature, studies boosts wellbeing productivity.',
#  'The park valuable community space, designed accessibility.',
#  'We host events customers local people, including talks gardening led Head Gardener.',
#  'To help create network green spaces wildlife central London, working roof gardens Exchange House nearby 1 Appold Street.',
#  'What nature loves things mixture change, thats mirrored environments planting Exchange Square.',
#  'British Land exceptionally supportive taking different approach urban planting.',
#  'The reason recruitment skills partnership works theres real family feel Fort Kinnaird.',
#  'At Fort Kinnaird, strong relationship Capital City Partnership enabled respond rapidly retailers communities faced shifts Covid sudden recruitment needs.',
#  'Together, supported nearly 90 people jobs year delivered employability sessions 130 young people.',
#  'As developing confidence skills candidates face barriers employment, Capital City Partnership site day, retailers know vulnerable candidates network resources draw on.',
#  'As focus providing affordable retail space Ealing Broadway worked opportunity Curated Collective, family business supports independent artists makers.',
#  'The team identified unit good location supportive terms.',
#  'Curative Collective able use pre-existing shop fit avoid extra costs.',
#  'I thank Andrew, Ealing Broadway team British Land getting placemaking initiative supportive.',
#  'Weve able work 25 local creative partners.',
#  'People Ealing love able interact people items buying.',
#  'Weve gone market stall thinking year leases support British Land.',
#  'Overview Responsible business Responsible business We advocate responsible business practices British Land supply chain.',
#  'Our key areas focus Responsible Employment, Diversity, Equality & Inclusion Responsible Procurement.',
#  'Our people competitive advantage.',
#  'We invest seek create environment achieve potential.',
#  'We apply approach supply chain.',
#  'Overview Responsible business Responsible Business We advocate responsible business practices British Land supply chain.',
#  'Our key areas focus set here.',
#  'Responsible Employment Invest people We recognise importance growing talent internally.',
#  'This year, invested 440,000 training qualifications people (380,000 FY21), developing leadership talent business.',
#  'Employees completed 7,000 hours training supporting 14 colleagues gain professional qualifications.',
#  'To support career development run internal mentorship scheme, includes senior leaders partner Circl Coaching, pairing people local students, growing coaching culture supporting local talent.',
#  'Connect people We ran in-depth employee engagement survey early 2022, completed 87% people.',
#  'Topics included leadership, engagement, learning development, social connection wellbeing, Diversity Equality & Inclusion (DE&I), response Covid.',
#  'Our overall engagement score 69%.',
#  'Some positive messages emerged 90% staff reporting proud work British Land 85% confirming recommend British Land great place work.',
#  'The survey highlighted areas improvement ambition increase overall engagement score.',
#  'To this, leadership teams having detailed sessions departments working collaboratively teams create action plan addressing key points raised.',
#  'Provide safe working environment We maintained excellent standards health safety ensure people places safe.',
#  'Our health safety management accredited international ISO standard accident frequency rates remain substantially national average.',
#  'Families need flexibility, opportunities equal.',
#  'Thats British Land offers months shared parental leave pay.',
#  'They support employees live lives careers ways work us, reflecting modern lifestyles benefits.',
#  'Michael Olivia Head Planning (Michael), Team Assistant (Olivia) Diversity, Equality & Inclusion In early 2022 launched Diversity, Equality & Inclusion Strategy, approved CSR Committee.',
#  'Aligned United Nations Sustainable Development Goals, sets commitments improve diversity, equality inclusivity business 2030, ensuring reflect understand people work, shop, live spend time places.',
#  'All employee feedback channels, including exit interviews engagement surveys, include diversity demographics help understand employees different backgrounds, ethnicities experiences encounter challenges, improve.',
#  'To attract diverse workforce, ensure hiring managers complete anti-bias training receive blind CVs selection interview stage removed ethnicity gender indicators.',
#  'We work agencies BAME Recruitment London Works reach candidates varied backgrounds.',
#  'We taken lead role 10,000 Black Interns initiative, real estate sector chair, continue support Change 100 programme, offering paid internships university students recent graduates disabilities long-term conditions.',
#  'Our employee-led networks continue drive progress diversity, equality inclusion.',
#  'These include ability network enaBLe, REACH (Race Ethnicity Celebrating Heritage), Parents & Carers, Pride Womens Network, recently rebranded equitaBLe.',
#  'Overview Responsible business NextGen, represent support generation property professionals.',
#  'Improve gender diversity levels In 2022, exceeded commitment maintain minimum 35% female representation Board, 36% women Board 37% senior management female.',
#  'Improve ethnic diversity levels We fulfilled commitment maintain minimum Directors ethnic minority background, ahead Parker Review recommendations ethnic diversity Board level.',
#  'This reduction ahead target reduce pay gap 2% year year.',
#  'Responsible Procurement A strong relationship suppliers plays key role successful delivery strategy governed Supplier Code Conduct.',
#  'This sets clear social, ethical environmental obligations supply chain promotes safe fair working conditions.',
#  'Compliance mandatory suppliers.',
#  'We pay Real Living Wage British Land employees strongly encourage suppliers pay UK employees Real Living Wage.',
#  'Our London Campuses accredited Living Wage Places comply Mayors Good Work Standard.',
#  'Our Slavery Human Trafficking Statement website governance/modern-slavery-act Mandating prompt payment Paying suppliers partners promptly agreed payment terms ethical responsibility economically beneficial parties wider economy.',
#  'We signatory UK Governments Prompt Payment Code 2010 aim pay 95% suppliers 30 days.',
#  'Group invoices settled 18 days average.',
#  'Responsible procurement standards This year, introduced Contractor Framework, identifying key sustainability performance indicators monitor new contractors employed asset management initiatives.',
#  'We launched Supplier Excellence Awards celebrate showcase best suppliers contributions range categories including responsible business.',
#  'Active modern slavery We uphold human rights employees supply chain.',
#  'This year, provided anti-modern slavery training employees.',
#  'Through partnership anti-modern slavery charity Unseen, undertook independent audits 10 suppliers operating higher risk areas (with 11 scheduled), reviewing compliance 12 key areas Supplier Code Conduct.',
#  'These included human rights, health safety, equal opportunities, fair reward, working hours, staff development worker representation.',
#  'Informed risk impact assessments, audits prioritised property management service providers assets construction contractors developments.',
#  'All suppliers scored 77% working suppliers improvement opportunities identified agreed.',
#  'We continue member Unseens business helpline portal, allows people report potential modern slavery occurrence anonymously.',
#  'Our Supplier Excellence Awards We delighted recognised British Land supplier awards felt rewarding recognised clients way.',
#  'I confirm having FM industry 12 years I havent seen client approach service partner recognition trailblazing springs mind.',
#  'Overview British Land Sustainability Accounts 2022 Net zero carbon Carbon emissions Fig.',
#  'Please pages 85-87 Assurance Reports Korn Ferry (paygap data)and DNV.',
#  'Selected datahas independently assured 2007 (see earlier reports).',
#  'SBTi, Net Zero targets greenhouse gas intensity For second consecutive year, COVID-19 related government restrictions significantly affected portfolios carbon intensity, representing majority reduction.',
#  'However, delivered initiatives enhance energy efficiency year, notably Exchange House (see p6).',
#  'Overview Carbon emissions (continued) Fig.',
#  'The embodied emissions offset project achieves practical completion.',
#  'Until UK Government specifies long-term strategy low-carbon heating (including role hydrogen all-electric buildings), Y include use renewable bio-gas.',
#  'Office A1 units electric.',
#  'Exploring electric option targeting <80.',
#  'N/A project undertaken NABERS accreditation.',
#  'TBC data available future years projects progress Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'In 2021/22, estimated energy consumption retail units assumes regular operations.',
#  'This significant rise vs year, assumed 50% operation retail units.',
#  'This years totals include embodied carbon 1 Triton Square following practical completion.',
#  'Location based: Our use 2021 UK greenhouse gas conversion factors reflect +3% increase GHG intensity gas (vs 2020) +1% increase GHG intensity electricity (vs 2020).',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'While proportion renewable gas rose 85% year, renewable power dropped 93%.',
#  'This reduced year primarily impact onboarding new assets time transfer assets renewable tariff.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Retail: direct use retail units (occupier procured) FRI non-landlord obtained energy non-BL managed assets Upstream emissions landlord obtained water use Indirect value chain greenhouse gas emissions In 2021/22, estimated energy consumption retail units assumes regular operations.',
#  'This significant rise vs year, assumed 50% operation retail units.',
#  'This years totals include embodied carbon 1 Triton Square following practical completion.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Fig.',
#  'However, delivered initiatives enhance energy efficiency year, notably Exchange House (see p16).',
#  'Other energy intensity measures Group occupied floors kWh sqm * Common parts baseline.',
#  'Overview Carbon emissions (continued) Fig.',
#  'The committed development figures provisional amounts adjusted differ completed values.',
#  'These figures proportionally disclosed share.',
#  'This figure excludes funds allocated offsets funds invested projects improve energy efficiency.',
#  'Investment year included chiller replacement Broadwalk House total capex 552,000.',
#  'This expected deliver annual cost savings 65,000 repaid service charge.',
#  'Our Net Zero energy auditsassessed major assets representing 90% landlord procured power.',
#  'Overview Energy use Fig.',
#  'Renewable Non-renewable Purchased Purchased Managed portfolio Offices: common parts Offices: shared services Offices: direct use occupier space Sub-total Retail: common parts Retail: direct use occupier space (landlord procured) Residential: common parts Scope (managed properties) Corporate Group offices Overall Total Proportion purchased electricity renewable sources Proportion total electricity renewable sources 110 110 1,150 18,635 20,283 59,974 98,891 14,351 2,584 2,958 999 3,793 7,749 547 300 570 21,703 21,282 63,766 106,751 16,047 2,883 570 109/111 49 49 1,210 20,148 16,375 66,178 102,701 14,722 2 947 821 891 279 332 1,502 196 93 1,084 21,087 16,654 66,510 104,252 16,129 1,040 1,087 108/112 821 46 46 1,274 24 22,618 17,838 83,496 123,952 18,151 1,827 143 240 3,216 3,599 661 16 984 22,808 18,078 86,712 127,598 20,086 1,843 1,008 102/106 971 971 1,260 116,535 9,166 126,960 1,261 119,192 2,875 123,328 1,344 144,901 5,259 151,504 93% 93% 98% 98% 96% 97% Total electricity consumption This year, proportion renewable power dropped 93%.',
#  'This reduction year primarily impact onboarding new assets time transfer assets renewable tariff.',
#  'Overview Energy use (continued) Fig.',
#  'Managed portfolio Offices: common parts Offices: shared services Offices: direct use occupier space Sub-total Retail: common parts Retail: direct use occupier space (landlord procured) Residential: common parts Sub-total All property types: on-site vehicles Fuel consumption service providers on-site vehicles equipment Corporate Group offices Overall Total Proportion purchased fuel renewable sources Proportion total fuel renewable sources Fig.',
#  'Overview Energy use (continued) Fig.',
#  'Managed portfolio Offices: common parts Offices: shared services Offices: direct use occupier space Sub-total Retail: common parts Retail: direct use occupier space Residential: common parts All property types: on-site vehicles Fuel consumption service providers on-site vehicles equipment All property types: district heating cooling Sub-total Corporate Group offices Overall Total Proportion purchased energy renewable sources Proportion total energy renewable sources Solar PV (including energy exported grid) CHP (electricity generated) CHP (heat generated) Total generated Proportion energy use common parts andsharedservices Proportion energy use Total energy consumed generated site This year, 90% landlord procured energy renewable sources.',
#  'While proportion renewable gas rose 85% year, renewable power dropped 93%.',
#  'This reduced year primarily impact onboarding new assets time transfer assets renewable tariff.',
#  'Overview Environmental leadership Building certifications Fig.',
#  'The Revolving Credit Facility KPIs exclude residential properties.',
#  'Despite disposal BREEAM-rated assets recent years, overall proportion BREEAM certified assets continues rise.',
#  'Likewise, 10 Exchange Square completed assessment year, BREEAM In Use rating Very Good.',
#  'This year, piloted BREEAM In Use (Part 2) assessments number retail sites.',
#  'As traditionally procured energy water behalf retail occupiers, understood upfront lack unit consumption data limit assessment rating Pass.',
#  'However, process served useful benchmark alignment BREEAMs management criteria incentivises prioritise collection retailer consumption data, enable significantly improve ratings future.',
#  'Overview Building certifications (continued) Fig.',
#  'We expect total cost retrofitting portfolio region 100m two-thirds funded service charge customers directly.',
#  'These typically low cost interventions attractive payback period support occupiers achieving sustainability ambitions.',
#  'Overview Water use Fig.',
#  'Fig.',
#  'At retail, water consumption returned familiar levels 2021/22, following significant increase previous year leak Nugent Shopping Park.',
#  'Overview Water use (continued) Fig.',
#  'Overview Overview Waste materials Fig.',
#  'Overview Waste materials (continued) Fig.',
#  'Overview Waste materials (continued) Fig.',
#  'Assurance excludes waste diverted landfill re-use site landfilled tax costs ().',
#  'Fig.',
#  'Proportion sustainable sources 2020 58% 2021 88% 12% 100% 34/36 42% 100% 49/52 2022 56% 39% 95% 35/36 Waste management developments During excavation works Canada Water projects, discovered soil contained historic land contamination, whilst classified hazardous waste, unsuitable repurposing existing ground conditions.',
#  'The team reviewed options including cleaning soil, onsite attendance dedicated waste supplier groundworks programme test segregate soil, possible landfill site capping/topper.',
#  'Despite efforts, sizable proportion sent landfill.',
#  'Sustainable Timber At refurbishment Exchange House, existing raised access floors poor condition; instead replacing brand new floors, opted install reclaimed tiles supplier takes raised floor tiles, tests provides new warranties.',
#  'Whilst originally FSC certified, flooring supplier purchased hold FSC certification, breaking chain custody certification.',
#  'Chain custody important choosing report non-certified.',
#  'Installing reclaimed tiles keeps good quality materials circulation, saves virgin materials carbon emissions.',
#  'Overview Waste materials (continued) Fig.',
#  'The non-compliance incident reported happened Broadgate campus excavator strike occurred gas pipe utility diversion works 1 Broadgate.',
#  'As precautionary measure, surrounding area evacuated London Fire Brigade, assisted onsite team campus staff, established gas dispersed pose risk neighbouring buildings.',
#  'The pipe quickly repaired Cadent changes method statements implemented Contractor, following review lessons learnt.',
#  'Overview Biodiversity Fig.',
#  'Fig.',
#  'Overview Community Fig.',
#  'Fig.',
#  'We work partnership customers, suppliers local partners develop skills local people empower access opportunities places supply chain.',
#  'Initiatives include pre-employment training, virtual programmes, mentoring, work placements, graduate schemes, internships, apprenticeships job fairs.',
#  'Overview Contributions investment Fig.',
#  'Key supplier workforce (and British Land employees outside working hours) time Total Beneficiaries Total individuals directly benefitting community investment programme 2022 1,813,909 58,833 56,720 1,929,462 635,904 159,732 795,636 Direct community investment () 2020 1,619,646 313,612 238,804 2,172,062 2021 1,475,171 102,474 53,509 1,631,154 170,367 973,188 29,663 200,030 84,547 1,057,735 23,949 23,024 40,076 Long term space Value space provided community organisations 2,861,454 nr nr Volunteering Fig.',
#  'Community investment For year reporting value space provide community organisations.',
#  'This value reflects cost organisations bear space provided British Land.',
#  'Fig.',
#  'This spend associated planning consents.',
#  'Our development activity varies significantly year year figure fluctuate.',
#  'Overview Considerate Constructors Fig.',
#  'Considerate Constructors Scheme Scoring Considerate Constructors Scheme updated FY22, details here: Fig.',
#  'The British Land Company PLC (Company number: ) signatory Prompt Payment Code sets standards payment practices best practice administered Chartered Institute Credit Management behalf Department Business, Energy Industrial Strategy (BEIS).',
#  'Regulations section 3 Small Business, Enterprise Employment Act 2015 (and, limited liability partnerships (LLPs), Limited Liability Partnerships Act 2000), introduce duty UKs largest companies LLPs report half-yearly basis payment practices, policies performance.',
#  'Overview Health safety Fig.',
#  'Overview Health safety (continued) Fig.',
#  'In system, risks classed classed substantial, requiring resolution shorter timeframe previous compliance partner.',
#  'The significant dip 2020 resolved percentages indication transition new service provider subsequent work required integrate new classifications processes.',
#  'Fig.',
#  'It includes lost days work-related accidents.',
#  'The absentee rate calculated total days lost, relative total number days scheduled worked employees.',
#  'Group employment Fig.',
#  'All numbers include maternity paternity leave, long term sick leave sabbatical.',
#  'Overview Group employment (continued) Fig.',
#  'Turnover rates based number leavers divided total number employees 31 March 2022.',
#  'Overview Group employment (continued) Fig.',
#  'This compare gender pay ratios employees employment level.',
#  'Please page 83 elements remuneration.',
#  'Overview Group employment (continued) Fig.',
#  'Overview Group employment (continued) Fig.',
#  'Overview Group employment (continued) Fig.',
#  'Overview Group employment (continued) Fig.',
#  'Not mandatory training.',
#  'Fig.',
#  'Employee training proportion category DSE Assessment Training (previously referred Health Safety training), fell significantly year alternative focus working home returning office assessments.',
#  'DSE assessment mandatory year employees undertake assessments appropriate.',
#  'Participation levels DSE assessment Training expecting return higher rate 2023.',
#  'We launched new Cyber Security Awareness training year; mandatory course IT team target reaching 85% trained, exceeded.',
#  'As EPRA best practice recommendations, total energy water data covers energy water procured British Land.',
#  'Energy carbon intensity data covers building Offices common parts Retail.',
#  'Water intensity data covers buildings Offices common parts Retail.',
#  'Per m2 comprises net internal areas Offices common parts Retail.',
#  'Overview EPRA Index (continued) Social performance1 Area Health & Safety EPRA code H&S-Emp Indicator GRI code 403-2 Employee health safety H&S-Asset 416-1 Asset health safety H&S-Comp Comty-Eng Community engagement 416-2 413-1 Proportion managed portfolio (floor area) community activity implemented Governance Governance Gov-Board 102-22 Composition highest governance body Gov-Select 102-23 Nominating selecting highest governance body Gov-Col 102-25 Process managing conflicts 1.',
#  'Employee data restated headcount FTE.',
#  'Overview SASB table This British Lands Sustainability Accounts references indicators set Sustainability Accounting Standards Board (SASB) framework.',
#  'This index highlights existing reporting aligns framework provides limited data certain indicators previously reported against.',
#  'We continue consider reporting develop meet needs stakeholders.',
#  'Area Energy Management Units kWhe sqm SASB Code IF-RE-130a 1 Location Figure 8, p36 GRI code 302-1 IF-RE-130a 2 302-1 IF-RE-130a 3 302-1 IF-RE-130a 4 IF-RE-130a 5 103-2 Activity Metric Energy consumption data coverage percentage floor area, property subsector Total energy consumed portfolio area data coverage, percentage grid electricity, percentage renewable, property subsector LFL change energy consumption portfolio area data coverage, property subsector Percentage eligible portfolio (1) obtained energy rating (2) certified ENERGY STAR, property subsector Description building energy management consideration integrated property investment analysis operational strategy MWh Figure 13, p40 MWh Figure 12, p39 % floor area (sqm) Figure 14, p41 Discussion analysis Energy carbon management integrated policies procedures.',
#  'Details Pathway net zero1, Sustainability Brief developments operations2 Sustainability brief acquisitions3 Figure 18, p44 By floor area, 48%4 assets management located areas high water stress.',
#  'Of office assets account 51% floor area areas high water stress retail assets account 22%.',
#  'Figure 16, p43 Water Management IF-RE-140a 1 Water withdrawal data coverage percentage total floor area percentage regions High Extremely High Baseline Water Stress, property sector % floor area (ft2) IF-RE-140a 2 IF-RE-140a 3 IF-RE-140a 4 Total water withdrawn portfolio area data coverage percentage regions High Extremely High Baseline Water Stress, property subsector LFL change water withdrawn portfolio area data coverage, property subsector Discussion water management risks description strategies practices mitigate risks.',
#  'In 2022 undertook number independent water audits order identify existing potential issues.',
#  'Our Pathway Net Zero, transition plan, available online 2.',
#  'Our Sustainability Brief Developments Operations available online 3.',
#  'Overview SASB table (continued) Area Management Tenant Sustainability Impacts SASB Code IF-RE-410a 1 GRI code Activity Metric Percentage new leases contain cost recovery clause resource efficiency-related capital improvements associated leased floor area, property subsector Units IF-RE-410a 2 Percentage tenants separately metered submetered (1) grid electricity consumption (2) water withdrawals, property sector % floor area (ft2) IF-RE-410a 3 Description approach measuring, incentivizing, improving sustainability impacts tenants.',
#  'Our leases include sustainability clauses cost recovery clauses.',
#  'Where lifecycle replacement requires replacement plant engage tenants encourage selection efficient option.',
#  'Our service charge agreement allows like-for-lie replacement plant equipment, use Transition Vehicle fund gaps efficient equipment installed.',
#  'Electricity Figure 10, p38 Water-Our Sustainability Brief requires tenant sub-meters water new developments.',
#  'Following Net Zero Audits programme pathway major asset.',
#  'These pathways arebeing presented occupiers.',
#  'Collaboration andcontribution occupiers essential.',
#  'Sustainability impacts standing agenda item property management forums.',
#  'All tenants access data.',
#  'The following section provides specific explanations data figures above.',
#  'It sets overall principles, boundaries, scope methodologies applied reporting sustainability data 2022 Annual Report Accounts, Sustainability Accounts corporate website.',
#  'The following sets overall principles, boundaries, scope methodologies applied reporting sustainability data 2022 Annual Report Accounts, Sustainability Accounts (The Report) corporate website.',
#  'Further explanations provided section Reporting Criteria.',
#  'We report data issues relevant sustainability strategy.',
#  'Data reported meaningful consistent DNVs assurance report included Report Assurance Statement section.',
#  'Data included scope DNVs assurance outlined section.',
#  'This DNVs year assurance partner.',
#  'The explanatory notes.',
#  'Data presented transparently aid reader making judgements decisions performance confidence Report.',
# ...
#  'Data total people working office building calculated average FTE period.',
#  'Occupiers provided data email differences reporting methodologies; accept 10% variance reported FTE data.',
#  'Retail total reportable accidents period divided total footfall period x 100,000.',
#  'Group offices total reportable accidents period divided total number British Land employees period x 100,000.',
#  'Does include dangerous occurrences.',
#  'Injury Frequency Rate calculated total reportable accidents period divided total time worked British Land employees period 100,000 hours worked.',
#  'Rates calculated number incidents involving British Land employees only.',
#  'Fig.',
#  'Injury Frequency Rate refers number RIDDOR reportable incidents (this calculated combined total fatalities, specified injuries seven-day absent incident totals) 100,000 hours worked (that is, RIDDOR reportable injuries x 100,000/Number hours worked).',
#  'Number hours worked data estimated developments digital security record hours: (average number personnel day) x (hours worked) x (days worked month).',
#  'Fig.',
#  'Within system, objectives managed portfolio, group offices developments.',
#  'Incidents non-compliance number HSE Prohibition Notices Improvement Notices served.',
#  'Managed portfolio group offices For managed portfolio sites group offices, key metrics monitor health safety management are: Risks controlled annual audit: risks identified classified.',
#  'We target management agents ensure 90% risks deemed control annual assessment.',
#  'Uncontrolled risks resolved: monitor time takes managing agents complete actions required convert risk requires action control.',
#  'Statutory document compliance: require documents required statute British Lands standards available site valid.',
#  'This includes lift inspection reports legionella risk assessments.',
#  'Where new property acquired British Land management responsibility, risk assessment audit undertaken weeks.',
#  'This risk assessment based HSEs Five Steps approach adopts scoring methodology PAS 79 guidance issued BSI.',
#  'Developments Incidents non-compliance number HSE Prohibition notices Improvement notices served.',
#  'It includes lost days work-related accidents.',
#  'The absentee rate calculated total days lost, relative total number days scheduled worked employees.',
#  'Lost day rate specifically covers lost days work-related accidents diseases.',
#  'Lost day rate calculated total lost days RIDDOR reportable injuries occupational diseases 100,000 hours worked (that is, Lost days x 100,000/Number hours worked).',
#  'All lost days calculated moment employee leaves work (half day, example) arrive work.',
#  'Overview Group employment Figs.',
#  'Includes maternity paternity leave, long-term sick leave sabbatical.',
#  'Unless stated, data excludes internships, temporary employees, contractors consultants.',
#  'Employment type defined shown Table 10 stated.',
#  'Table 10: Employment levels Employment type Executive Directors Senior management Middle management non-management Employees British Land Group Permanent fixed term employees British Land Board Directors.',
#  'Where applicable includes Non-Executive Directors.',
#  'Executive Committee level I, levels II III employees British Land Leadership Team.',
#  'All employees, excluding Executive Directors Senior management.',
#  'All permanent fixed term employees.',
#  'Fig.',
#  'New hires includes permanent FTCs joined year left year.',
#  'Non-executive directors included table reflect new joiners Board year.',
#  'Fig.',
#  'Employees left TUPE end agreed fixed term employment contract excluded.',
#  'Turnover rates based number leavers divided total number number employees end year (as reported Fig.',
#  'Proportion leavers gender, employment level age based number leavers category divided total number leavers year.',
#  'Non-executive directors included table reflect leavers Board year.',
#  'Figures include salary, discretionary performance bonuses, car allowance, board fees private medical insurance.',
#  'Remuneration related share schemes included.',
#  'The bonus element based prior year bonus paid, current year bonuses paid 31 March 2022 determined data compiled.',
#  'Salary bonus payment data time employees pro-rated FTE data.',
#  'Non-executive directors included table, executive directors employed permanently British Land included.',
#  'Fig.',
#  'Full details previous years gender pay gap reporting We reporting 2022 pay gap ahead 2023 deadline set government.',
#  'All employees employed 5 April 2022 included data.',
#  'Fig.',
#  'Ethnicity pay gap British Land Broadgate Estates Ltd comply mandatory government criteria gender pay gap reporting, ethnicity pay gap followed methodology.',
#  'All employees employed 5 April 2022 voluntarily disclosed ethnicity included data.',
#  'Any bonus received year preceding 5 April 2022 included bonus calculations.',
#  'Due small population size ensure anonymity, employees split BAME (Black, Asian minority ethnic) non-BAME report ethnicity pay gap.',
#  'Fig.',
#  'In line recommendations Global Reporting Initiative (GRI), fourth year reporting median employee CEO pay ratio.',
#  'CEO pay data includes salary, benefits, pension, annual incentives, long term incentives items nature compensation.',
#  'It consistent single figure reported 2022 Annual Report Accounts.',
#  'The data follows method A governments reporting criteria, showing time equivalent total remuneration UK employees financial year April 2021 March 2022.',
#  'From 2016, ethnicity data captured human resources systems request human resources.',
#  'All data given voluntarily employees.',
#  'For reporting purposes, use Office National Statistics ethnicity categories, shown Table 11.',
#  'Other White Not disclosed Includes Asian Bangladeshi Asian Chinese Asian Indian Asian Pakistani Asian Other Black African Black Caribbean Black Other Mixed Other Mixed White Asian Mixed White Black African Mixed White Black Caribbean Arab Other Ethnic Groups White English/Welsh/Scottish/Northern Irish White Gipsy Irish Traveller White Irish White Other Includes employees actively chosen disclose employees respond Fig 51: Employee Diversity Sexual Orientation Proportion employees voluntarily recording HR identify LGBT+.',
#  'This data excludes non-executive directors.',
#  'Fig 52: Employee Diversity Disability Proportion employees voluntarily recording HR disability long-term condition.',
#  'Employees select categories disclosing disability: This data excludes non-executive directors.',
#  'None Hidden Disability Hearing Disability Visual Disability Mobility Physical Impairment Mental Health Condition Prefer Fig 53: Employee Diversity Social Mobility Proportion employees voluntarily recording HR school received free school meal, generation family attend university attended non-selective state run state funded school.',
#  'This data excludes non-executive directors.',
#  'Fig.',
#  'It excludes new starters, weeks complete training, reported financial year.',
#  'Anti-corruption bribery, information security health safety training mandatory training modules.',
#  'All employees complete training modules employed British Land Group.',
#  'This data excludes non-executive directors.',
#  'Fig.',
#  'This proportion calculated employees employed British Land Group beginning performance review year.',
#  'This data excludes non-executive directors.',
#  'The British Land Company PLC (British Land) engaged Korn Ferry (UK) Limited (Korn Ferry) conduct limited assurance engagement British Land Broadgate Estates 2022 Gender Ethnicity pay gaps.',
#  'Conclusion Based review Korn Ferry undertaken British Land Broadgate Estates Gender Ethnicity pay gaps, come attention causes believe calculations resultant gender ethnicity pay gap figures fairly stated prepared, material respects, accordance applicable criteria.',
#  'The scope review based 2022 data presented following figures Gender Ethnicity pay gap reports, based snapshot date 5 April 2022.',
#  'Proportion employees receiving bonus Number male female employees quartile Basis conclusion Korn Ferry asked review Gender pay gap calculations Government regulations Gender pay gap calculations, relevant guidance.',
#  'The Ethnicity pay gap calculations reviewed basis.',
#  'A review allocation male females employee band final calculation A review method calculate proportion employees receiving bonus pay During review process, observations questions relating methodology raised British Land.',
#  'Korn Ferry confirms resolved confirmed appropriate British Land.',
#  'Our competence, independence quality control Korn Ferry independent adviser Remuneration Committee British Land conflict scope work.',
#  'Korn Ferry policies procedures designed ensure provision objective independent advice.',
#  'This independent review carried team Pay Governance specialists experienced review relevant regulations.',
#  'Inherent limitations assurance All assurance engagements subject inherent limitations data sampling detect errors, fraud irregularities.',
#  'Furthermore, assurance relies premise data information provided British Land provided good faith.',
#  'Korn Ferry expressly disclaims liability co-responsibility decision person entity based report.',
#  'Overview Independent Limited Assurance Report Board Directors The British Land Company Plc The British Land Company Plc (British Land) commissioned DNV Business Assurance Services UK Limited (DNV, we) conduct limited assurance engagement Selected Information presented Sustainability Accounts 2022 (the Report) reporting year ended 31 March 2022.',
#  'Our Conclusion: Based procedures performed evidence obtained, come attention causes believe Selected Information fairly stated prepared, material respects, accordance Criteria.',
#  'This conclusion relates Selected Information, read context Independent Limited Assurance Report, particular inherent limitations explained overleaf.',
#  'Our observations areas improvement raised separate report British Lands Management.',
#  'The scope boundary work restricted 2022 data presented Figures marked A (the Selected Information) Report.',
#  'A summary Figures listed below: 1.',
#  'SBTi NZC targets greenhouse gas intensity 2.',
#  'Net Zero Carbon Developments 4.',
#  'Total direct indirect (Scopes 1 2 & 3) GHG emissions Location market based 5.',
#  'Like-for-like total direct indirect (Scopes 1, 2 3) landlord-influenced greenhouse gas emissions 6.',
#  'Indirect (Scope 3) value chain greenhouse gas emissions 7.',
#  'Total greenhouse gas emissions gas 8.',
#  'Building energy target intensity 9.',
#  'Internal carbon levy Transition Vehicle 10.',
#  'Total electricity consumption 11.',
#  'Total fuel consumption 12.',
#  'Like-for-like total electricity fuel consumption 13.',
#  'Total energy consumed generated on-site 14.',
#  'Sustainability ratings 15.',
#  'Energy Performance Certificates (EPC) 16.',
#  'Total water consumption 17.',
#  'Like-for-like total water consumption 18.',
#  'Building water target intensity 19.',
#  'Waste management-managed portfolio corporate 20.',
#  'Like like waste management-managed portfolio 21.',
#  'Waste management-developments 23.',
#  'Environmental compliance 32 Community contributions planning development 37 Accidents-managed portfolio corporate 38 Accidents-developments 39 Health safety-compliance 40 Lost working days 41 Employment 42 New employees 43 Employee turnover 44 Salary remuneration 48 Employee diversity-gender Our competence, independence quality control DNV established policies procedures designed ensure DNV, personnel and, applicable, subject independence requirements (including personnel entities DNV) maintain independence required relevant ethical requirements.',
#  'This engagement work carried independent team sustainability assurance professionals.',
#  'DNV held audit assurance contracts British Land, conflict scope work.',
#  'Our multi-disciplinary team consisted professionals combination environmental sustainability assurance experience.',
#  'To assess Selected Information, includes assessment risk material misstatement Report, British Lands Reporting Criteria (the Criteria), page 66 Report.',
#  'We performed work, express conclusion, information published Report British Lands website current reporting period previous periods.',
#  'Overview Standard level assurance We performed limited assurance engagement accordance International Standard Assurance Engagements (ISAE) 3000 revised Assurance Engagements Audits Reviews Historical Financial Information (revised), issued International Auditing Assurance Standards Board.',
#  'This standard requires comply ethical requirements plan perform assurance engagement obtain limited assurance.',
#  'DNV applies management standards compliance policies quality control, accordance ISO/IEC -1:2015-Conformity Assessment Requirements bodies providing audit certification management systems, accordingly maintains comprehensive quality control including documented policies procedures compliance ethical requirements, professional standards applicable legal regulatory requirements.',
#  'The procedures performed limited assurance engagement vary nature timing from, extent for, reasonable assurance engagement; level assurance obtained substantially lower assurance obtained reasonable assurance engagement performed.',
#  'We planned performed work obtain evidence considered sufficient provide basis opinion, risk conclusion error reduced reduced low.',
#  'Basis conclusion We required plan perform work order consider risk material misstatement Selected Information; work included, restricted to: Conducting interviews British Land management data owners obtain understanding key processes, systems controls place generate, aggregate report Selected Information; Performing limited substantive testing selective basis Selected Information check data appropriately measured, recorded, collated reported; Reviewing evidence, measurements scope provided British Land Selected Information prepared line Criteria; A remote visit Head Office test consolidation data Group level; A remote site visit Canada Water (Waste) Norton Folgate (H&S) Development portfolio review processes systems preparing site level data consolidated Group level.',
#  'DNV free choose site basis materiality Group level figures; Assessing appropriateness Criteria Selected Information; Reading Report narrative accompanying Selected Information regard Criteria.',
#  'DNV Business Assurance Services UK Limited London, UK 09 June 2022 Inherent limitations All assurance engagements subject inherent limitations selective testing (sampling) detect errors, fraud irregularities.',
#  'Non-financial data subject greater inherent uncertainty financial data, given nature methods calculating, estimating determining data.',
#  'The selection different, acceptable, measurement techniques result different quantifications different entities.',
#  'Our assurance relies premise data information provided British Land provided good faith.',
#  'DNV expressly disclaims liability co-responsibility decision person entity based Independent Limited Assurance Report.',
#  'Responsibilities Board Directors British Land DNV The Directors British Land sole responsibility for: Preparing presenting Selected information accordance Criteria; Designing, implementing maintaining effective internal controls information data, resulting preparation Selected Information free material misstatements; Measuring reporting Selected Information based established Criteria; Contents statements contained Report Criteria.',
#  'Our responsibility plan perform work obtain limited assurance Selected Information prepared accordance Criteria report British Land form independent limited assurance conclusion, based work performed evidence obtained.',
#  'We responsible preparation Report.',
#  'DNV Business Assurance DNV Business Assurance Services UK Limited DNV Business Assurance, global provider certification, verification, assessment training services, helping customers build sustainable business performance.']

# %%
def pre_processing(corpus):
    return lemmatization(stemming(remove_stop_words(corpus)))

# %%
def label_relevancy(corpus, related_words):
    related_words = pre_processing(related_words)
    corpus = pre_processing(corpus)
    related_sentences = [line for line in corpus if any(word in line for word in related_words)]
    unrelated_sentences = [line for line in corpus if (line not in related_sentences)]
    all_sentences = related_sentences + unrelated_sentences
    all_data = pd.DataFrame(all_sentences, columns=['corpus'])
    all_data['have_transition_plan'] = all_data['corpus'].isin(related_sentences)
    return related_sentences, unrelated_sentences, all_data

# %%
related_words = ['ghg', 'sbti', 'tcfd', 'sasb']
related_sentences, unrelated_sentences, all_data = label_relevancy(corpus, related_words)
all_data
# Out:
#                                                 corpus  have_transition_plan
# 0    our esg journey our 2030 commitments performan...                  True
# 1    sbti, net zero targets greenhouse gas intensit...                  True
# 2    location based: our use 2021 uk greenhouse gas...                  True
# 3    overview sasb table this british lands sustain...                  True
# 4    area energy management units kwhe sqm sasb cod...                  True
# ..                                                 ...                   ...
# 983  dnv expressly disclaims liability co-responsib...                 False
# 984  responsibilities board directors british land ...                 False
# 985  our responsibility plan perform work obtain li...                 False
# 986                 we responsible preparation report.                 False
# 987  dnv business assurance dnv business assurance ...                 False
#
# [988 rows x 2 columns]

# %%
all_data.to_csv('bl_ratios.csv')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test= train_test_split(related_sentences, test_size=0.5)
X_train[:5]
# Out:
# ['this includes seven main ghg emissions covered kyoto greenhouse gas protocols, line common practice: carbon dioxide (co2), methane (ch4), hydrofluorocarbons (hfcs), nitrous oxide (n2o), perfluorocarbons (pfcs), sulphur hexafluoride (sf6) nitrogen trifluoride (nf3).',
#  'total direct indirect (scopes 1 2 & 3) ghg emissions location market based 5.',
#  'scope 1 2 ghg emissions intensities epra reporting reported fig.',
#  'our esg journey our 2030 commitments performance overview (kpis) net zero carbon place based approach responsible business performance data 2022 epra index sasb index reporting criteria assurance reports 2 3 4 5 9 17 24 27 61 64 66 85 read tcfd disclosures 2022 annual report against challenging backdrop, teams fantastic job year, working customers partners support local communities.',
#  'table 4 shows combined carbon-equivalent emission factors different ghgs considered.']

# %%
vectorizer = TfidfVectorizer()
tf_idf_matrix = vectorizer.fit_transform(X_train)

# %%
tf_idf_matrix.shape
# Out:
# (13, 209)

# %%
feature_names = vectorizer.get_feature_names()
corpus_index = [n for n in X_train]
df = pd.DataFrame(tf_idf_matrix.T.todense(), index=feature_names, columns=corpus_index)
df
# Out:
#          this includes seven main ghg emissions covered kyoto greenhouse gas protocols, line common practice: carbon dioxide (co2), methane (ch4), hydrofluorocarbons (hfcs), nitrous oxide (n2o), perfluorocarbons (pfcs), sulphur hexafluoride (sf6) nitrogen trifluoride (nf3).  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          total direct indirect (scopes 1 2 & 3) ghg emissions location market based 5.  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          scope 1 2 ghg emissions intensities epra reporting reported fig.  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          our esg journey our 2030 commitments performance overview (kpis) net zero carbon place based approach responsible business performance data 2022 epra index sasb index reporting criteria assurance reports 2 3 4 5 9 17 24 27 61 64 66 85 read tcfd disclosures 2022 annual report against challenging backdrop, teams fantastic job year, working customers partners support local communities.  \
# 100                                               0.000000
# 103                                               0.000000
# 12                                                0.000000
# 13                                                0.000000
# 130a                                              0.000000
# ...                                                    ...
# water                                             0.000000
# working                                           0.130515
# year                                              0.130515
# years                                             0.000000
# zero                                              0.130515
#
#          table 4 shows combined carbon-equivalent emission factors different ghgs considered.  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          financial intensity ratio expresses absolute scope 1 2 ghg emissions relation gross rental income properties managed portfolio.  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          absolute scope 1 2 ghg emissions relate managed portfolio electricity, gas use refrigerant loss air conditioning, fuel use british land owned vehicles.  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          a1-a5 emissions (embodied carbon construction stages new developments refurbishments carbon levy applies): includes ghg emissions new developments refurbishments, carbon levy applies, completed 2020 construction (stage 5).  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          location based: our use 2021 uk greenhouse gas conversion factors reflect +3% increase ghg intensity gas (vs 2020) +1% increase ghg intensity electricity (vs 2020).  \
# 100                                                    0.0
# 103                                                    0.0
# 12                                                     0.0
# 13                                                     0.0
# 130a                                                   0.0
# ...                                                    ...
# water                                                  0.0
# working                                                0.0
# year                                                   0.0
# years                                                  0.0
# zero                                                   0.0
#
#          the reporting years total scope 1 2 ghg emissions prepared sourced figure 4.  \
# 100                                               0.000000
# 103                                               0.000000
# 12                                                0.000000
# 13                                                0.000000
# 130a                                              0.000000
# ...                                                    ...
# water                                             0.000000
# working                                           0.000000
# year                                              0.000000
# years                                             0.386629
# zero                                              0.000000
#
#          includes 100% ghg emissions developments, joint venture developments developments undertaken funding.  \
# 100                                               0.282267
# 103                                               0.000000
# 12                                                0.000000
# 13                                                0.000000
# 130a                                              0.000000
# ...                                                    ...
# water                                             0.000000
# working                                           0.000000
# year                                              0.000000
# years                                             0.000000
# zero                                              0.000000
#
#          area energy management units kwhe sqm sasb code if-re-130a 1 location figure 8, p36 gri code 302-1 if-re-130a 2 302-1 if-re-130a 3 302-1 if-re-130a 4 if-re-130a 5 103-2 activity metric energy consumption data coverage percentage floor area, property subsector total energy consumed portfolio area data coverage, percentage grid electricity, percentage renewable, property subsector lfl change energy consumption portfolio area data coverage, property subsector percentage eligible portfolio (1) obtained energy rating (2) certified energy star, property subsector description building energy management consideration integrated property investment analysis operational strategy mwh figure 13, p40 mwh figure 12, p39 % floor area (sqm) figure 14, p41 discussion analysis energy carbon management integrated policies procedures.  \
# 100                                               0.000000
# 103                                               0.056371
# 12                                                0.056371
# 13                                                0.056371
# 130a                                              0.281857
# ...                                                    ...
# water                                             0.000000
# working                                           0.000000
# year                                              0.000000
# years                                             0.000000
# zero                                              0.000000
#
#          carbon intensity includes scope 1, 2 3 ghg emissions related energy sources plus emissions building sources waste disposal management water consumption.
# 100                                               0.000000
# 103                                               0.000000
# 12                                                0.000000
# 13                                                0.000000
# 130a                                              0.000000
# ...                                                    ...
# water                                             0.260303
# working                                           0.000000
# year                                              0.000000
# years                                             0.000000
# zero                                              0.000000
#
# [209 rows x 13 columns]

# %%
df.T
# Out:
#                                                          100       103  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.000000  0.000000
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.000000
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.282267  0.000000
# area energy management units kwhe sqm sasb code...  0.000000  0.056371
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
#                                                           12        13  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.000000  0.000000
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.000000
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.000000  0.000000
# area energy management units kwhe sqm sasb code...  0.056371  0.056371
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
#                                                         130a        14  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.000000  0.000000
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.000000
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.000000  0.000000
# area energy management units kwhe sqm sasb code...  0.281857  0.056371
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
#                                                           17      2020  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.130515  0.000000
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.147533
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.344313
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.000000  0.000000
# area energy management units kwhe sqm sasb code...  0.000000  0.000000
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
#                                                         2021     2022  ...  \
# this includes seven main ghg emissions covered ...  0.000000  0.00000  ...
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.00000  ...
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.00000  ...
# our esg journey our 2030 commitments performanc...  0.000000  0.26103  ...
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.00000  ...
# financial intensity ratio expresses absolute sc...  0.000000  0.00000  ...
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.00000  ...
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.00000  ...
# location based: our use 2021 uk greenhouse gas ...  0.199633  0.00000  ...
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.00000  ...
# includes 100% ghg emissions developments, joint...  0.000000  0.00000  ...
# area energy management units kwhe sqm sasb code...  0.000000  0.00000  ...
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.00000  ...
#
#                                                          use  vehicles  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.000000  0.000000
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.418395  0.242586
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.172156  0.000000
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.000000  0.000000
# area energy management units kwhe sqm sasb code...  0.000000  0.000000
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
#                                                      venture        vs  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.000000  0.000000
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.399266
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.282267  0.000000
# area energy management units kwhe sqm sasb code...  0.000000  0.000000
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
#                                                        waste     water  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.000000  0.000000
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.000000
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.000000  0.000000
# area energy management units kwhe sqm sasb code...  0.000000  0.000000
# carbon intensity includes scope 1, 2 3 ghg emis...  0.260303  0.260303
#
#                                                      working      year  \
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.130515  0.130515
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.000000
# the reporting years total scope 1 2 ghg emissio...  0.000000  0.000000
# includes 100% ghg emissions developments, joint...  0.000000  0.000000
# area energy management units kwhe sqm sasb code...  0.000000  0.000000
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
#                                                        years      zero
# this includes seven main ghg emissions covered ...  0.000000  0.000000
# total direct indirect (scopes 1 2 & 3) ghg emis...  0.000000  0.000000
# scope 1 2 ghg emissions intensities epra report...  0.000000  0.000000
# our esg journey our 2030 commitments performanc...  0.000000  0.130515
# table 4 shows combined carbon-equivalent emissi...  0.000000  0.000000
# financial intensity ratio expresses absolute sc...  0.000000  0.000000
# absolute scope 1 2 ghg emissions relate managed...  0.000000  0.000000
# a1-a5 emissions (embodied carbon construction s...  0.000000  0.000000
# location based: our use 2021 uk greenhouse gas ...  0.000000  0.000000
# the reporting years total scope 1 2 ghg emissio...  0.386629  0.000000
# includes 100% ghg emissions developments, joint...  0.000000  0.000000
# area energy management units kwhe sqm sasb code...  0.000000  0.000000
# carbon intensity includes scope 1, 2 3 ghg emis...  0.000000  0.000000
#
# [13 rows x 209 columns]

# %%
import math

def find_related_sentences(file_path):
    spacy_model = spacy.load("en_core_web_sm")
    im = extract_sentences(spacy_model, extract_pdf(file_path)) #Get list of corpus
    im = pre_processing(im)
    input_len = len(im)
    input_vec = vectorizer.transform(im)
    cosine_similarities = []
    angles = []
    for i in range(tf_idf_matrix.shape[0]):
        cosine = cosine_similarity(tf_idf_matrix[i], input_vec)[0]
        angle_list = np.rad2deg(np.arccos(cosine))
        cosine_similarities.append(cosine)
        angles.extend(angle_list)
    min_angle = min(angles)
    threshold_value = 30
    index1 = math.ceil(np.argmin(angles) / input_len)
    index2 = np.argmin(angles) % input_len
    new_line = '\n'
    if min_angle <= threshold_value:
        print(f"Low carbon transition plan found: {new_line} Sentence in input report: {im[index2]} {new_line} Sentence in training dataset: {corpus[index1]}")
        return True
    else:
        print(f"No low carbon transition plan found {new_line} Closest sentences: {im[index2]}")
        return False

# %%
find_related_sentences("british-land-sustainability-accounts-2022.pdf")
# Out:
# Low carbon transition plan found:
#  Sentence in input report: scope 1 2 ghg emissions intensities epra reporting reported fig.
#  Sentence in training dataset: The climate emergency is high on everyones agenda; we face a cost of living crisis and the impact of Covid 19 continues to reverberate throughout our communities.
# True

# %%
def check_relevancy(sentence):
    sentence = pre_processing(sentence)
    input_vec = vectorizer.transform(sentence) 
    cosine_similarities = []
    angles = []
    for i in range(tf_idf_matrix.shape[0]):
        cosine = cosine_similarity(tf_idf_matrix[i], input_vec)[0]
        angle_list = np.rad2deg(np.arccos(cosine))
        cosine_similarities.append(cosine)
        angles.extend(angle_list)
        
    min_angle = min(angles)
    threshold_value = 60
    return min_angle <= threshold_value

# %%
unrelated_sentences
# Out:
# ['as new year, new uncertainties horizon, dedication vital ever.',
#  'introduction this year celebrate 20 years sustainability reporting, environmental social focus integral way business.',
#  'the climate emergency high everyones agenda; face cost living crisis impact covid 19 continues reverberate communities.',
#  'this means progressing pathway net zero making positive impact places important ever.',
#  'we continued deliver strong progress year.',
#  'at 1 triton square, completed second net zero carbon development site canada water, piloting innovative building materials technologies deliver market leading, highly sustainable buildings.',
#  'our approach right terms environment, reflects customers increasingly expect.',
#  'the strong business case sustainable buildings underlined year leasing success 1 broadgate, sustainable buildings london fully let (or option) years ahead completion.',
#  'on standing portfolio, completed net zero audits working customers invest energy efficient interventions programme identified.',
#  'one outcome raise epc ratings portfolio a b 2030 line expected mees legislation.',
#  'we delighted efforts recognised gresb, global real estate sustainability benchmark achieved 5* rating developments standing investments.',
#  'on social side, place based approach strong local relationships allow adapt emerging needs opportunities place biggest impact.',
#  'this year community activities benefitted nearly 24,000 people.',
#  'our lasting collaboration capital city partnership fort kinnaird, help people face barriers employment, powerful example (see p23).',
#  'this year marked years partnership national literacy trust.',
#  'against challenging backdrop, teams fantastic job, working customers partners support local communities.',
#  'i like thank hard work huge contribution making places vibrant successful.',
#  'as new year, new uncertainties, dedication vital ever.',
#  'overview overview broadgate places people prefer our purpose create manage outstanding places deliver positive outcomes stakeholders long term, sustainable basis.',
#  'we understanding evolving needs ofthe people organisations use places communities live them.',
#  'the deep connections created customers, communities, partners people important emerge pandemic.',
#  'second net zero carbon development completed embodied carbon 1 triton square 2030 target 436 co2e sqm offset certified schemes including teak afforestation project mexico community reforestation project ghana.',
#  'net zero asset audits completed working party experts, completed 29 audits portfolio identifying opportunities improve energy efficiency standing portfolio.',
#  'awarded bre4 innovation credits for heat exchange system, recycling waste heat offices residential canada water introducing materials passport, facilitating materials re-use 1 broadgate.',
#  'offices development pipeline, including completed developments 2.',
#  'whole building operational energy intensity improvement vs 2019 baseline offices 3.',
#  'impacted covid-19 restrictions requiring assets close operate lower capacity 4.',
#  'building research establishment, parent organisation breeam certification framework launched ndt broadgate together new diorama theatre launched ndt broadgate support recovery arts post-pandemic.',
#  'one londons biggest rehearsal artist development complexes.',
#  'this year celebrate 20 years sustainability reporting environmental social focus integral business.',
#  'launched sustainability brief developments.',
#  'founding member uk green building council.',
#  'launched community investment fund.',
#  'signatory un global compact.',
#  'delivered breeam excellent projects.',
#  'introduced smart energy management system.',
#  'completed life carbon assessments.',
#  'our sustainability brief established social environmental requirements developments.',
#  'the ukgbc works promote sustainability built environment.',
#  'supported 56,000 children read partnership national literacy trust began.',
#  'launched community charter, laying foundation todays local charter.',
#  'started young readers programme partnership.',
#  'queens award lasting economic, social environmental achievements launched regents place customer community fund industry first.',
#  'launched bright lights, skills employment programme.',
#  'worked happy city establish seven core principles guide placemaking activities.',
#  'launched 2030 sustainability strategy commitment net zero 2030.',
#  'introduced internal carbon levy 60 tonne embodied carbon developments.',
#  'launched transition vehicle fund energy efficient improvements.',
#  'our bright lights skills employment programme science based targets initiative validated carbon reduction targets.',
#  'our net zero pathway* sets ways reduce carbon emissions.',
#  'we offset embodied carbon developments 2030 offset operational carbon.',
#  'overview overview our 2030 commitments net zero carbon environmental leadership place based approach we committed achieving net zero carbon portfolio 2030 set clear targets reduce embodied carbon developments operational carbon portfolio.',
#  'we demonstrate strong progress delivering participating leading international benchmarks.',
#  'our target achieve 5* gresb rating 2022 pleased achieved years ahead target.',
#  'top 81st percentile science based targets: approval 2021 our place based approach means understanding important issues opportunities communities places focusing efforts collaboratively biggest impact place.',
#  'to deliver this, work directly community partners collaborate customers identify key local issues impact.',
#  'connect: connecting customers, suppliers community partners priority local issues opportunities.',
#  'our community funds broadgate, paddington regents place example approach education: needs-based initiatives places working long term partner national literacy trust employment: needs-based initiatives places.',
#  'recent focus supporting impacted covid 19, example virtual employment training supporting local business: supporting local business provision affordable workspace, thrive canada water wellbeing: putting wellbeing principles practice, year included new park exchange square, broadgate.',
#  'responsible business we advocate responsible business practices british land supply chain.',
#  'our key areas focus set below.',
#  'proportion units epcs rated a b assets under management 2030 target 5-star 2022 100% 50% 2025 5% reduction operational water consumption vs 2020 operational waste managed assets re-used, composted, recycled development operational waste diverted landfill new construction major renovation projects designed achieve 10% net gain biodiversity % managed assets biodiversity action plans % managed assets major developments undergone flood risk assessment 5% offices: 80% retail: 70% 100% 100% 100% 1.',
#  'from 2021, 2030 strategy upgraded breeam targets outstanding offices (from excellent) excellent retail (from very good) 2.',
#  'excludes residential fy22 performance 5-star 70% 44% 28% 36% 13% offices: 76% retail: 48% 96% on track 15% 100% 2021 5-star 73% 27% 25% 24% 20% 71% 47% 100% nr 18% 100% 2020 4-star 24% 21% 25% 72% 54% 99% nr nr 100% breeam certifications to date, pursued breeam certificates 44% standing portfolio.',
#  'while target best-in-class certifications new developments major refurbishments, majority portfolio built prior bre certification schemes route certifying assets operational certifications, primarily breeam in use.',
#  'we currently pursuing multi-stage rollout breeam in use certifications including first-time pilots retail assets.',
#  'likewise, committed near term developments complete, entry standing portfolio increase proportion highly-rated assets.',
#  'following socio-economic assessments, business plans created sites fy23 priorities report social value generated develop social value target 5 year target to reported fy23 place based initiatives identified priority assets.',
#  'we use priority assets tables pages 21-23 report progress this.',
#  'overview net zero carbon net zero carbon we committed achieving net zero carbon portfolio 2030 set clear targets reduce embodied carbon developments operational carbon portfolio.',
#  'we long track record delivering sustainable space clear competitive advantage business customers prioritise sustainability.',
#  'overview net zero carbon net zero delivering pathway last year set pathway net zero.',
#  'we delivered commitments year advanced coming year.',
#  'overview net zero carbon blossom yard & studios, norton folgate net zero carbon reducing embodied carbon developments to progress target 500 co2e sqm embodied carbon office developments 2030, committed undertaking life carbon assessments developments major refurbishments.',
#  'to this, adopted one click lca life cycle assessment software developments.',
#  'this enables consolidate data consultants, benchmark performance monitor progress.',
#  'this helping identify designs, materials techniques generate significant carbon savings.',
#  'norton folgate case study we focus reusing existing materials structures far possible.',
#  'at blossom studios, buildings norton folgate development retained existing faade 80% floors, timber joists individually assessed re-used.',
#  'we rebuilt internal walls re-using reclaimed bricks original building retained original features iron columns glazed bricks preserve original character building.',
#  'new materials focused responsibly sourced low carbon alternatives; 100% fsc (forest stewardship council) wood concrete 40% cement replacement.',
#  'as result currently expect embodied carbon 403 co2e sqm (434 co2e sqm redevelopment), ahead 2030 target.',
#  'to drive operational performance adding roof solar panels air source heat pumps deliver electric offices 100% green power, operational energy intensity expected line trajectory 2030.',
#  'overview net zero carbon reducing embodied carbon developments continued canada water case study unlike norton folgate, greater capacity reuse existing materials, canada water ground redevelopment.',
#  'this means minimise embodied carbon emissions, focus piloting sustainable materials processes.',
#  'at a1, mixed use building includes 186 residential units 120,000 sq ft workspace, sustainable materials superstructure.',
#  'this includes ggbs (ground granulated blast-furnace slag), waste product blast furnaces iron repurposed cement replacement.',
#  'we post tensioned concrete slabs stronger thinner, requiring concrete, cross laminated timber reducing number steel beams required electric arc furnace steel.',
#  'these innovations line commitment pilot low carbon materials net zero pathway.',
#  'our current projections embodied carbon 682 co2e sqm 2030 target 500kg co2e sqm, glidepath 2030.',
#  'well gold certifications targeted outdoor space offsetting strategy we prioritise re-use existing materials minimise embodied carbon far possible.',
#  'where residual embodied carbon avoided design material choice, offset certified emission reduction projects.',
#  'we use nature based offset credits possible, select projects support biodiversity economic benefits local communities.',
#  'project works closely local farmers, employed project able grow crops.',
#  'aim expand 1,000 hectares year.',
#  'supporting planting 23,000 trees woodland carbon code.',
#  'this additional commitment formal offset 1 triton square.',
#  'overview net zero carbon reducing operational carbon the chart sets key opportunities reduce carbon emissions portfolio coming years.',
#  'on standing portfolio focus renewable power energy saving initiatives buildings.',
#  'renewable power (grid, onsite offsite) residual emissons offset 2030 2030 energy saving initiatives new developments present greatest opportunity deliver best class buildings operationally, highly energy efficient.',
#  'the chart illustrates improvement 1 broadgate, energy intensity sixth previous building.',
#  'relatively recent developments, 4 kingdom street, efficient portfolio thoughtful asset management deliver significant improvement relatively low cost.',
#  'in case, key intervention heat pump accounting 70% retrofit cost, altogether represents 1% buildings value.',
#  'older buildings broadgate tower require comprehensive retrofitting.',
#  'this year completed 29 net zero audits buildings portfolio identifying initiatives deliver 25% improvement building energy efficiency.',
#  'a case study exchange house shown page.',
#  'indicative view assumes developments built development pipeline excludes capital activity we offset residual embodied carbon developments 2030, offset operational carbon standing portfolio seek minimise far possible following ways.',
#  'the decarbonisation national grid play key role switch renewable power uk.',
#  'we supplement investing onsite offsite renewable energy sources.',
#  'already 2 mega watts capacity portfolio (of half meadowhall) undertaking feasibility studies identify opportunities rooftop solar car port possibilities.',
#  'detailed studies underway retail sites car park meadowhall shopping centre.',
#  'we exploring opportunities offsite renewables increase relative contribution renewable power overall pathway.',
#  'overview net zero carbon reducing operational carbon continued increasing energy efficiency standing portfolio this year, party consultants completed net zero audits covering 29 major assets.',
#  'these identified initiatives standing portfolio, actioned deliver 25% improvement building energy efficiency line target.',
#  'some initiatives delivered, reducing energy use 23% saving occupiers 340,000 annually.',
#  'one effective interventions delivered introducing co2 controls; sensors installed office floors enabling monitor fresh air levels adjust ventilation needed.',
#  'this relatively low cost measure significantly cut demand heating cooling.',
#  'we installing dedicated chillers hours cooling, reducing requirement run main chillers intensive.',
#  'the significant interventions led lighting heat pumps.',
#  'the improvements deliver savings payback investment 5 years expect two-thirds cost funded service charge covered directly occupiers.',
#  'these interventions improve buildings epc rating b e, making building fully compliant expected mees legislation.',
#  'overview place based approach our place based approach a place based approach means understanding important issues opportunities communities places focusing efforts collaboratively biggest impact.',
#  'overview place based approach place based approach social impact we invest directly local community organisations, support range ways, including use space work occupiers deliver positive social impact areas focus.',
#  'our local charter focuses key areas create lasting positive legacy work, shop live places.',
#  'connect we connect local communities bringing customers, suppliers community partners common goal place.',
#  'connecting customers community partners strongest social contributions.',
#  'following success regents place community fund, year worked customers launch funds broadgate paddington central.',
#  'together, agree priority local themes, pledge funds award grants community organisations working locally.',
#  'in year, 15 customers local stakeholders pledged 150,000 broadgate paddington central community funds.',
#  'we support educational initiatives local people helping discover potential, developing skills raising awareness career opportunities sectors.',
#  'this year, delivered 58 education initiatives.',
#  'these ranged primary school projects secondary school workshops college events university challenges.',
#  'we continued partnership national literacy trust 29 places, working collaboratively customers local schools encourage additional 7,800 children read pleasure improve literacy skills.',
#  'together, reached 56,000 children partnership began.',
#  'employment we support local training jobs bright lights, skills employment programme, working customers, suppliers local partners.',
#  'recognising impact covid-19 emerging cost living crisis, refocused bright lights support affected, including individuals lost livelihoods.',
#  'these initiatives run portfolio.',
#  'we reached 135 people virtual employment training one-to-one support designed local residents skills achieve lasting employment.',
#  'the programme included ringfenced opportunities businesses places.',
#  'on average 60% candidates gained employment, range sectors glasgow fort rises 75%.',
#  'supporting local business = affordable space we support local businesses opening opportunities local independents, social enterprises start-ups support future success.',
#  'we provided affordable space priority assets identified opportunities remaining three.',
#  'this includes affordable work space, affordable retail space community arts space.',
#  'following success new diorama theatre (ndt) regents place, launched ndt broadgate support recovery arts post-pandemic.',
#  'the project kind world, ndt broadgate attracted footfall 80,000 creatives, engaged 600,000 people supported creation highly successful productions.',
#  'new diorama theatre regents place won the stages fringe theatre year 2022 award.',
#  'we create places support health wellbeing customers, colleagues communities.',
#  'we develop partnerships communities support wellbeing people work, visit live places.',
#  'in 2022 range wellbeing initiatives, community partners darnall united global generation, supported 2,700 beneficiaries.',
#  'we track achieve well platinum, 1 broadgate, highest level certification globally-recognised benchmark health wellbeing.',
#  'working closely occupier jll architect ahmm, targeting industry leading standards air quality, water light.',
#  'we continue align developments well standard.',
#  'our office developments canada water, a1 a2, well-ready.',
#  'this pre-certification supports delivering outstanding workspaces customers opens opportunity customers partner pursuing well certification employee health wellbeing.',
#  'our social reporting subsequent pages focuses priority assets details specific activities 2022 commitments 2023.',
#  'however, place based approach goes far assets programmes delivered portfolio.',
#  'the reach biggest community initiatives, partnership the national literacy trust bright lights employment initiative seen map.',
#  'supporting ukraine to support affected war ukraine donated 25,000 disaster emergency committee included matching personal donations people.',
#  'we donated 5,000 ukrainian cathedral marylebone, close head office.',
#  'at paddington central, pledged 30,000 funding scheme support ukrainian institute setting english language school refugees donated space host classrooms storey club.',
#  'at number assets, rolled specific qr codes enable people donations british red cross easily.',
#  'cost living crisis during fy23 collaborating long term partners support excellent work help struggling cost living crisis.',
#  'our bright lights initiatives focus activities affected.',
#  'overview place based approach delivering place based working local partners, focusing core theme asset, biggest social impact.',
#  'we appreciate respect british land do.',
#  'they long term vision that, like weve brought subsoil wonderful conversation place comes together.',
#  'jane riddiford, global generation canada water at canada water, partnership environmental education charity global generation continues grow.',
#  'this year, global generation engaged 600 local primary schoolchildren workshops worked generator youth leaders.',
#  'constructed circular economy principles, new facility provide fantastic community resource years come.',
#  'paddington central at paddington central, connecting customers local partners inclusive opportunities year launched new community fund collaboration occupiers partner address key local issues.',
#  'in april 2021, unveiled community garden, supported occupiers wipro kingfisher.',
#  'local schoolchildren visitors garden year, customers volunteered 300 people took workshops gardening food growing urban farming experts, square mile farms.',
#  'customers volunteered 60 hours help adults learning disabilities run fruit smoothie stall campus, partnership local non-profit pursuing independent paths.',
#  'representatives businesses campus continue connect diversity inclusion network, activities year including session activist, ted speaker author nova reid mark black history month.',
#  'overview place based approach our place based approach action education supporting local business = affordable space wellbeing broadgate at broadgate, partnering open access educational opportunities age spectrum primary school university.',
#  'this year alone, engaged 47 schoolchildren local broadgate collaboration national literacy trust customers.',
#  'a 9 local students completed virtual work experience programme.',
#  'our partnership university east london continued grow, students worked collaboratively designs campus broadgate prize.',
#  'canada water at canada water, continue partner tree shepherd deliver thrive, affordable workspace business support entrepreneurs, prioritising se16 residents.',
#  'through project, aim create self-sustaining local business network, growing pipeline successful enterprises future opportunities canada water.',
#  'this year, supported 72 entrepreneurs business advice gone set businesses self-employed.',
#  'we provided low-cost workspace, including offices, meeting rooms makerspace.',
#  'british land authentically supports people community.',
#  'together, working create place local people run businesses supported successful.',
#  'its people place meaningful.',
#  'sandra ferguson, tree shepherd regents place at regents place, providing 10,000 sq ft affordable workspace 1 triton square donated space triton caf community uses.',
#  'this included meeting space local non-profit camden giving occupier new diorama theatre.',
#  'we provided space blackout uk run monthly events months supported peer learning, debates, networking meaningful connections 75 black queer men.',
#  'there tens thousands plants, including native species flowering varieties good bees, butterflies insects.',
#  'mature birch trees offer homes birds.',
#  'this enhance biodiversity open access nature, studies boosts wellbeing productivity.',
#  'the park valuable community space, designed accessibility.',
#  'we host events customers local people, including talks gardening led head gardener.',
#  'to help create network green spaces wildlife central london, working roof gardens exchange house nearby 1 appold street.',
#  'what nature loves things mixture change, thats mirrored environments planting exchange square.',
#  'british land exceptionally supportive taking different approach urban planting.',
#  'the reason recruitment skills partnership works theres real family feel fort kinnaird.',
#  'at fort kinnaird, strong relationship capital city partnership enabled respond rapidly retailers communities faced shifts covid sudden recruitment needs.',
#  'together, supported nearly 90 people jobs year delivered employability sessions 130 young people.',
#  'as developing confidence skills candidates face barriers employment, capital city partnership site day, retailers know vulnerable candidates network resources draw on.',
#  'as focus providing affordable retail space ealing broadway worked opportunity curated collective, family business supports independent artists makers.',
#  'the team identified unit good location supportive terms.',
#  'curative collective able use pre-existing shop fit avoid extra costs.',
#  'i thank andrew, ealing broadway team british land getting placemaking initiative supportive.',
#  'weve able work 25 local creative partners.',
#  'people ealing love able interact people items buying.',
#  'weve gone market stall thinking year leases support british land.',
#  'overview responsible business responsible business we advocate responsible business practices british land supply chain.',
#  'our key areas focus responsible employment, diversity, equality & inclusion responsible procurement.',
#  'our people competitive advantage.',
#  'we invest seek create environment achieve potential.',
#  'we apply approach supply chain.',
#  'overview responsible business responsible business we advocate responsible business practices british land supply chain.',
#  'our key areas focus set here.',
#  'responsible employment invest people we recognise importance growing talent internally.',
#  'this year, invested 440,000 training qualifications people (380,000 fy21), developing leadership talent business.',
#  'employees completed 7,000 hours training supporting 14 colleagues gain professional qualifications.',
#  'to support career development run internal mentorship scheme, includes senior leaders partner circl coaching, pairing people local students, growing coaching culture supporting local talent.',
#  'connect people we ran in-depth employee engagement survey early 2022, completed 87% people.',
#  'topics included leadership, engagement, learning development, social connection wellbeing, diversity equality & inclusion (de&i), response covid.',
#  'our overall engagement score 69%.',
#  'some positive messages emerged 90% staff reporting proud work british land 85% confirming recommend british land great place work.',
#  'the survey highlighted areas improvement ambition increase overall engagement score.',
#  'to this, leadership teams having detailed sessions departments working collaboratively teams create action plan addressing key points raised.',
#  'provide safe working environment we maintained excellent standards health safety ensure people places safe.',
#  'our health safety management accredited international iso standard accident frequency rates remain substantially national average.',
#  'families need flexibility, opportunities equal.',
#  'thats british land offers months shared parental leave pay.',
#  'they support employees live lives careers ways work us, reflecting modern lifestyles benefits.',
#  'michael olivia head planning (michael), team assistant (olivia) diversity, equality & inclusion in early 2022 launched diversity, equality & inclusion strategy, approved csr committee.',
#  'aligned united nations sustainable development goals, sets commitments improve diversity, equality inclusivity business 2030, ensuring reflect understand people work, shop, live spend time places.',
#  'all employee feedback channels, including exit interviews engagement surveys, include diversity demographics help understand employees different backgrounds, ethnicities experiences encounter challenges, improve.',
#  'to attract diverse workforce, ensure hiring managers complete anti-bias training receive blind cvs selection interview stage removed ethnicity gender indicators.',
#  'we work agencies bame recruitment london works reach candidates varied backgrounds.',
#  'we taken lead role 10,000 black interns initiative, real estate sector chair, continue support change 100 programme, offering paid internships university students recent graduates disabilities long-term conditions.',
#  'our employee-led networks continue drive progress diversity, equality inclusion.',
#  'these include ability network enable, reach (race ethnicity celebrating heritage), parents & carers, pride womens network, recently rebranded equitable.',
#  'overview responsible business nextgen, represent support generation property professionals.',
#  'improve gender diversity levels in 2022, exceeded commitment maintain minimum 35% female representation board, 36% women board 37% senior management female.',
#  'improve ethnic diversity levels we fulfilled commitment maintain minimum directors ethnic minority background, ahead parker review recommendations ethnic diversity board level.',
#  'this reduction ahead target reduce pay gap 2% year year.',
#  'responsible procurement a strong relationship suppliers plays key role successful delivery strategy governed supplier code conduct.',
#  'this sets clear social, ethical environmental obligations supply chain promotes safe fair working conditions.',
#  'compliance mandatory suppliers.',
#  'we pay real living wage british land employees strongly encourage suppliers pay uk employees real living wage.',
#  'our london campuses accredited living wage places comply mayors good work standard.',
#  'our slavery human trafficking statement website governance/modern-slavery-act mandating prompt payment paying suppliers partners promptly agreed payment terms ethical responsibility economically beneficial parties wider economy.',
#  'we signatory uk governments prompt payment code 2010 aim pay 95% suppliers 30 days.',
#  'group invoices settled 18 days average.',
#  'responsible procurement standards this year, introduced contractor framework, identifying key sustainability performance indicators monitor new contractors employed asset management initiatives.',
#  'we launched supplier excellence awards celebrate showcase best suppliers contributions range categories including responsible business.',
#  'active modern slavery we uphold human rights employees supply chain.',
#  'this year, provided anti-modern slavery training employees.',
#  'through partnership anti-modern slavery charity unseen, undertook independent audits 10 suppliers operating higher risk areas (with 11 scheduled), reviewing compliance 12 key areas supplier code conduct.',
#  'these included human rights, health safety, equal opportunities, fair reward, working hours, staff development worker representation.',
#  'informed risk impact assessments, audits prioritised property management service providers assets construction contractors developments.',
#  'all suppliers scored 77% working suppliers improvement opportunities identified agreed.',
#  'we continue member unseens business helpline portal, allows people report potential modern slavery occurrence anonymously.',
#  'our supplier excellence awards we delighted recognised british land supplier awards felt rewarding recognised clients way.',
#  'i confirm having fm industry 12 years i havent seen client approach service partner recognition trailblazing springs mind.',
#  'overview british land sustainability accounts 2022 net zero carbon carbon emissions fig.',
#  'please pages 85-87 assurance reports korn ferry (paygap data)and dnv.',
#  'selected datahas independently assured 2007 (see earlier reports).',
#  'however, delivered initiatives enhance energy efficiency year, notably exchange house (see p6).',
#  'overview carbon emissions (continued) fig.',
#  'the embodied emissions offset project achieves practical completion.',
#  'until uk government specifies long-term strategy low-carbon heating (including role hydrogen all-electric buildings), y include use renewable bio-gas.',
#  'office a1 units electric.',
#  'exploring electric option targeting <80.',
#  'n/a project undertaken nabers accreditation.',
#  'tbc data available future years projects progress fig.',
#  'overview carbon emissions (continued) fig.',
#  'overview carbon emissions (continued) fig.',
#  'in 2021/22, estimated energy consumption retail units assumes regular operations.',
#  'this significant rise vs year, assumed 50% operation retail units.',
#  'this years totals include embodied carbon 1 triton square following practical completion.',
#  'overview carbon emissions (continued) fig.',
#  'overview carbon emissions (continued) fig.',
#  'while proportion renewable gas rose 85% year, renewable power dropped 93%.',
#  'this reduced year primarily impact onboarding new assets time transfer assets renewable tariff.',
#  'overview carbon emissions (continued) fig.',
#  'overview carbon emissions (continued) fig.',
#  'retail: direct use retail units (occupier procured) fri non-landlord obtained energy non-bl managed assets upstream emissions landlord obtained water use indirect value chain greenhouse gas emissions in 2021/22, estimated energy consumption retail units assumes regular operations.',
#  'this significant rise vs year, assumed 50% operation retail units.',
#  'this years totals include embodied carbon 1 triton square following practical completion.',
#  'overview carbon emissions (continued) fig.',
#  'fig.',
#  'however, delivered initiatives enhance energy efficiency year, notably exchange house (see p16).',
#  'other energy intensity measures group occupied floors kwh sqm * common parts baseline.',
#  'overview carbon emissions (continued) fig.',
#  'the committed development figures provisional amounts adjusted differ completed values.',
#  'these figures proportionally disclosed share.',
#  'this figure excludes funds allocated offsets funds invested projects improve energy efficiency.',
#  'investment year included chiller replacement broadwalk house total capex 552,000.',
#  'this expected deliver annual cost savings 65,000 repaid service charge.',
#  'our net zero energy auditsassessed major assets representing 90% landlord procured power.',
#  'overview energy use fig.',
#  'renewable non-renewable purchased purchased managed portfolio offices: common parts offices: shared services offices: direct use occupier space sub-total retail: common parts retail: direct use occupier space (landlord procured) residential: common parts scope (managed properties) corporate group offices overall total proportion purchased electricity renewable sources proportion total electricity renewable sources 110 110 1,150 18,635 20,283 59,974 98,891 14,351 2,584 2,958 999 3,793 7,749 547 300 570 21,703 21,282 63,766 106,751 16,047 2,883 570 109/111 49 49 1,210 20,148 16,375 66,178 102,701 14,722 2 947 821 891 279 332 1,502 196 93 1,084 21,087 16,654 66,510 104,252 16,129 1,040 1,087 108/112 821 46 46 1,274 24 22,618 17,838 83,496 123,952 18,151 1,827 143 240 3,216 3,599 661 16 984 22,808 18,078 86,712 127,598 20,086 1,843 1,008 102/106 971 971 1,260 116,535 9,166 126,960 1,261 119,192 2,875 123,328 1,344 144,901 5,259 151,504 93% 93% 98% 98% 96% 97% total electricity consumption this year, proportion renewable power dropped 93%.',
#  'this reduction year primarily impact onboarding new assets time transfer assets renewable tariff.',
#  'overview energy use (continued) fig.',
#  'managed portfolio offices: common parts offices: shared services offices: direct use occupier space sub-total retail: common parts retail: direct use occupier space (landlord procured) residential: common parts sub-total all property types: on-site vehicles fuel consumption service providers on-site vehicles equipment corporate group offices overall total proportion purchased fuel renewable sources proportion total fuel renewable sources fig.',
#  'overview energy use (continued) fig.',
#  'managed portfolio offices: common parts offices: shared services offices: direct use occupier space sub-total retail: common parts retail: direct use occupier space residential: common parts all property types: on-site vehicles fuel consumption service providers on-site vehicles equipment all property types: district heating cooling sub-total corporate group offices overall total proportion purchased energy renewable sources proportion total energy renewable sources solar pv (including energy exported grid) chp (electricity generated) chp (heat generated) total generated proportion energy use common parts andsharedservices proportion energy use total energy consumed generated site this year, 90% landlord procured energy renewable sources.',
#  'while proportion renewable gas rose 85% year, renewable power dropped 93%.',
#  'this reduced year primarily impact onboarding new assets time transfer assets renewable tariff.',
#  'overview environmental leadership building certifications fig.',
#  'the revolving credit facility kpis exclude residential properties.',
#  'despite disposal breeam-rated assets recent years, overall proportion breeam certified assets continues rise.',
#  'likewise, 10 exchange square completed assessment year, breeam in use rating very good.',
#  'this year, piloted breeam in use (part 2) assessments number retail sites.',
#  'as traditionally procured energy water behalf retail occupiers, understood upfront lack unit consumption data limit assessment rating pass.',
#  'however, process served useful benchmark alignment breeams management criteria incentivises prioritise collection retailer consumption data, enable significantly improve ratings future.',
#  'overview building certifications (continued) fig.',
#  'we expect total cost retrofitting portfolio region 100m two-thirds funded service charge customers directly.',
#  'these typically low cost interventions attractive payback period support occupiers achieving sustainability ambitions.',
#  'overview water use fig.',
#  'fig.',
#  'at retail, water consumption returned familiar levels 2021/22, following significant increase previous year leak nugent shopping park.',
#  'overview water use (continued) fig.',
#  'overview overview waste materials fig.',
#  'overview waste materials (continued) fig.',
#  'overview waste materials (continued) fig.',
#  'assurance excludes waste diverted landfill re-use site landfilled tax costs ().',
#  'fig.',
#  'proportion sustainable sources 2020 58% 2021 88% 12% 100% 34/36 42% 100% 49/52 2022 56% 39% 95% 35/36 waste management developments during excavation works canada water projects, discovered soil contained historic land contamination, whilst classified hazardous waste, unsuitable repurposing existing ground conditions.',
#  'the team reviewed options including cleaning soil, onsite attendance dedicated waste supplier groundworks programme test segregate soil, possible landfill site capping/topper.',
#  'despite efforts, sizable proportion sent landfill.',
#  'sustainable timber at refurbishment exchange house, existing raised access floors poor condition; instead replacing brand new floors, opted install reclaimed tiles supplier takes raised floor tiles, tests provides new warranties.',
#  'whilst originally fsc certified, flooring supplier purchased hold fsc certification, breaking chain custody certification.',
#  'chain custody important choosing report non-certified.',
#  'installing reclaimed tiles keeps good quality materials circulation, saves virgin materials carbon emissions.',
#  'overview waste materials (continued) fig.',
#  'the non-compliance incident reported happened broadgate campus excavator strike occurred gas pipe utility diversion works 1 broadgate.',
#  'as precautionary measure, surrounding area evacuated london fire brigade, assisted onsite team campus staff, established gas dispersed pose risk neighbouring buildings.',
#  'the pipe quickly repaired cadent changes method statements implemented contractor, following review lessons learnt.',
#  'overview biodiversity fig.',
#  'fig.',
#  'overview community fig.',
#  'fig.',
#  'we work partnership customers, suppliers local partners develop skills local people empower access opportunities places supply chain.',
#  'initiatives include pre-employment training, virtual programmes, mentoring, work placements, graduate schemes, internships, apprenticeships job fairs.',
#  'overview contributions investment fig.',
#  'key supplier workforce (and british land employees outside working hours) time total beneficiaries total individuals directly benefitting community investment programme 2022 1,813,909 58,833 56,720 1,929,462 635,904 159,732 795,636 direct community investment () 2020 1,619,646 313,612 238,804 2,172,062 2021 1,475,171 102,474 53,509 1,631,154 170,367 973,188 29,663 200,030 84,547 1,057,735 23,949 23,024 40,076 long term space value space provided community organisations 2,861,454 nr nr volunteering fig.',
#  'community investment for year reporting value space provide community organisations.',
#  'this value reflects cost organisations bear space provided british land.',
#  'fig.',
#  'this spend associated planning consents.',
#  'our development activity varies significantly year year figure fluctuate.',
#  'overview considerate constructors fig.',
#  'considerate constructors scheme scoring considerate constructors scheme updated fy22, details here: fig.',
#  'the british land company plc (company number: ) signatory prompt payment code sets standards payment practices best practice administered chartered institute credit management behalf department business, energy industrial strategy (beis).',
#  'regulations section 3 small business, enterprise employment act 2015 (and, limited liability partnerships (llps), limited liability partnerships act 2000), introduce duty uks largest companies llps report half-yearly basis payment practices, policies performance.',
#  'overview health safety fig.',
#  'overview health safety (continued) fig.',
#  'in system, risks classed classed substantial, requiring resolution shorter timeframe previous compliance partner.',
#  'the significant dip 2020 resolved percentages indication transition new service provider subsequent work required integrate new classifications processes.',
#  'fig.',
#  'it includes lost days work-related accidents.',
#  'the absentee rate calculated total days lost, relative total number days scheduled worked employees.',
#  'group employment fig.',
#  'all numbers include maternity paternity leave, long term sick leave sabbatical.',
#  'overview group employment (continued) fig.',
#  'turnover rates based number leavers divided total number employees 31 march 2022.',
#  'overview group employment (continued) fig.',
#  'this compare gender pay ratios employees employment level.',
#  'please page 83 elements remuneration.',
#  'overview group employment (continued) fig.',
#  'overview group employment (continued) fig.',
#  'overview group employment (continued) fig.',
#  'overview group employment (continued) fig.',
#  'not mandatory training.',
#  'fig.',
#  'employee training proportion category dse assessment training (previously referred health safety training), fell significantly year alternative focus working home returning office assessments.',
#  'dse assessment mandatory year employees undertake assessments appropriate.',
#  'participation levels dse assessment training expecting return higher rate 2023.',
#  'we launched new cyber security awareness training year; mandatory course it team target reaching 85% trained, exceeded.',
#  'as epra best practice recommendations, total energy water data covers energy water procured british land.',
#  'energy carbon intensity data covers building offices common parts retail.',
#  'water intensity data covers buildings offices common parts retail.',
#  'per m2 comprises net internal areas offices common parts retail.',
#  'overview epra index (continued) social performance1 area health & safety epra code h&s-emp indicator gri code 403-2 employee health safety h&s-asset 416-1 asset health safety h&s-comp comty-eng community engagement 416-2 413-1 proportion managed portfolio (floor area) community activity implemented governance governance gov-board 102-22 composition highest governance body gov-select 102-23 nominating selecting highest governance body gov-col 102-25 process managing conflicts 1.',
#  'employee data restated headcount fte.',
#  'this index highlights existing reporting aligns framework provides limited data certain indicators previously reported against.',
#  'we continue consider reporting develop meet needs stakeholders.',
#  'details pathway net zero1, sustainability brief developments operations2 sustainability brief acquisitions3 figure 18, p44 by floor area, 48%4 assets management located areas high water stress.',
#  'of office assets account 51% floor area areas high water stress retail assets account 22%.',
#  'figure 16, p43 water management if-re-140a 1 water withdrawal data coverage percentage total floor area percentage regions high extremely high baseline water stress, property sector % floor area (ft2) if-re-140a 2 if-re-140a 3 if-re-140a 4 total water withdrawn portfolio area data coverage percentage regions high extremely high baseline water stress, property subsector lfl change water withdrawn portfolio area data coverage, property subsector discussion water management risks description strategies practices mitigate risks.',
#  'in 2022 undertook number independent water audits order identify existing potential issues.',
#  'our pathway net zero, transition plan, available online 2.',
#  'our sustainability brief developments operations available online 3.',
#  'our leases include sustainability clauses cost recovery clauses.',
#  'where lifecycle replacement requires replacement plant engage tenants encourage selection efficient option.',
#  'our service charge agreement allows like-for-lie replacement plant equipment, use transition vehicle fund gaps efficient equipment installed.',
#  'electricity figure 10, p38 water-our sustainability brief requires tenant sub-meters water new developments.',
#  'following net zero audits programme pathway major asset.',
#  'these pathways arebeing presented occupiers.',
#  'collaboration andcontribution occupiers essential.',
#  'sustainability impacts standing agenda item property management forums.',
#  'all tenants access data.',
#  'the following section provides specific explanations data figures above.',
#  'it sets overall principles, boundaries, scope methodologies applied reporting sustainability data 2022 annual report accounts, sustainability accounts corporate website.',
#  'the following sets overall principles, boundaries, scope methodologies applied reporting sustainability data 2022 annual report accounts, sustainability accounts (the report) corporate website.',
#  'further explanations provided section reporting criteria.',
#  'we report data issues relevant sustainability strategy.',
#  'data reported meaningful consistent dnvs assurance report included report assurance statement section.',
#  'data included scope dnvs assurance outlined section.',
#  'this dnvs year assurance partner.',
#  'the explanatory notes.',
#  'data presented transparently aid reader making judgements decisions performance confidence report.',
#  'data accurate complete practical feasible.',
#  'consistent boundaries methodologies possible allow comparisons time.',
#  'assumptions, estimates exclusions stated explained.',
#  'certain key data independently assured (see below).',
#  'we aim ensure data accurate comparable years possible.',
#  'where updated new data available, restate data prior years restatement material.',
#  'details restatements provided relevant sections reporting criteria.',
#  'rounding mean columns sum precisely.',
#  'we engaged dnv perform independent limited assurance selection material 2022 data.',
#  'we designed, implemented maintained internal controls processes information relevant measurement preparation assured data, best knowledge free material misstatement, fraud error.',
#  'where data report assured, explicitly stated.',
#  'assets management assets owned managed british land including 100% joint ventures funds.',
#  'managed portfolio multi-let properties operational management influence control day-to-day operation facilities utilities.',
#  'group offices floors areas occupied british land, including property management offices.',
#  'in may 2018, brought wholly-owned property management subsidiary, broadgate estates, in-house, selling third-party property management portfolio savills.',
#  'broadgate estates data included british land group data, stated otherwise.',
#  'we report data day-to-day operational management influence (our managed portfolio).',
#  'this includes assets 100% owned british land stake joint venture investment fund.',
#  'as 31 march 2022, managed portfolio comprises 84% assets management.',
#  'performance overview sustainability reporting covid-19 the continually evolving circumstances caused covid-19 pandemic presented rapidly changing near term operating environment business navigate.',
#  'covid-19 significant impact number reporting areas 2021 2022 creating anomalous years.',
#  'those areas impacted greenhouse gas emissions, energy use, water use, waste management, health safety community investment.',
#  'for scope methodology indicator, refer relevant focus area section reporting criteria.',
#  'residential3 total 2022 48 59 9 116 number assets 2020 45 56 10 111 2021 54 50 10 114 1.',
#  'includes industrial leisure assets.',
# ...
#  'data total people working office building calculated average fte period.',
#  'occupiers provided data email differences reporting methodologies; accept 10% variance reported fte data.',
#  'retail total reportable accidents period divided total footfall period x 100,000.',
#  'group offices total reportable accidents period divided total number british land employees period x 100,000.',
#  'does include dangerous occurrences.',
#  'injury frequency rate calculated total reportable accidents period divided total time worked british land employees period 100,000 hours worked.',
#  'rates calculated number incidents involving british land employees only.',
#  'fig.',
#  'injury frequency rate refers number riddor reportable incidents (this calculated combined total fatalities, specified injuries seven-day absent incident totals) 100,000 hours worked (that is, riddor reportable injuries x 100,000/number hours worked).',
#  'number hours worked data estimated developments digital security record hours: (average number personnel day) x (hours worked) x (days worked month).',
#  'fig.',
#  'within system, objectives managed portfolio, group offices developments.',
#  'incidents non-compliance number hse prohibition notices improvement notices served.',
#  'managed portfolio group offices for managed portfolio sites group offices, key metrics monitor health safety management are: risks controlled annual audit: risks identified classified.',
#  'we target management agents ensure 90% risks deemed control annual assessment.',
#  'uncontrolled risks resolved: monitor time takes managing agents complete actions required convert risk requires action control.',
#  'statutory document compliance: require documents required statute british lands standards available site valid.',
#  'this includes lift inspection reports legionella risk assessments.',
#  'where new property acquired british land management responsibility, risk assessment audit undertaken weeks.',
#  'this risk assessment based hses five steps approach adopts scoring methodology pas 79 guidance issued bsi.',
#  'developments incidents non-compliance number hse prohibition notices improvement notices served.',
#  'it includes lost days work-related accidents.',
#  'the absentee rate calculated total days lost, relative total number days scheduled worked employees.',
#  'lost day rate specifically covers lost days work-related accidents diseases.',
#  'lost day rate calculated total lost days riddor reportable injuries occupational diseases 100,000 hours worked (that is, lost days x 100,000/number hours worked).',
#  'all lost days calculated moment employee leaves work (half day, example) arrive work.',
#  'overview group employment figs.',
#  'includes maternity paternity leave, long-term sick leave sabbatical.',
#  'unless stated, data excludes internships, temporary employees, contractors consultants.',
#  'employment type defined shown table 10 stated.',
#  'table 10: employment levels employment type executive directors senior management middle management non-management employees british land group permanent fixed term employees british land board directors.',
#  'where applicable includes non-executive directors.',
#  'executive committee level i, levels ii iii employees british land leadership team.',
#  'all employees, excluding executive directors senior management.',
#  'all permanent fixed term employees.',
#  'fig.',
#  'new hires includes permanent ftcs joined year left year.',
#  'non-executive directors included table reflect new joiners board year.',
#  'fig.',
#  'employees left tupe end agreed fixed term employment contract excluded.',
#  'turnover rates based number leavers divided total number number employees end year (as reported fig.',
#  'proportion leavers gender, employment level age based number leavers category divided total number leavers year.',
#  'non-executive directors included table reflect leavers board year.',
#  'figures include salary, discretionary performance bonuses, car allowance, board fees private medical insurance.',
#  'remuneration related share schemes included.',
#  'the bonus element based prior year bonus paid, current year bonuses paid 31 march 2022 determined data compiled.',
#  'salary bonus payment data time employees pro-rated fte data.',
#  'non-executive directors included table, executive directors employed permanently british land included.',
#  'fig.',
#  'full details previous years gender pay gap reporting we reporting 2022 pay gap ahead 2023 deadline set government.',
#  'all employees employed 5 april 2022 included data.',
#  'fig.',
#  'ethnicity pay gap british land broadgate estates ltd comply mandatory government criteria gender pay gap reporting, ethnicity pay gap followed methodology.',
#  'all employees employed 5 april 2022 voluntarily disclosed ethnicity included data.',
#  'any bonus received year preceding 5 april 2022 included bonus calculations.',
#  'due small population size ensure anonymity, employees split bame (black, asian minority ethnic) non-bame report ethnicity pay gap.',
#  'fig.',
#  'in line recommendations global reporting initiative (gri), fourth year reporting median employee ceo pay ratio.',
#  'ceo pay data includes salary, benefits, pension, annual incentives, long term incentives items nature compensation.',
#  'it consistent single figure reported 2022 annual report accounts.',
#  'the data follows method a governments reporting criteria, showing time equivalent total remuneration uk employees financial year april 2021 march 2022.',
#  'from 2016, ethnicity data captured human resources systems request human resources.',
#  'all data given voluntarily employees.',
#  'for reporting purposes, use office national statistics ethnicity categories, shown table 11.',
#  'other white not disclosed includes asian bangladeshi asian chinese asian indian asian pakistani asian other black african black caribbean black other mixed other mixed white asian mixed white black african mixed white black caribbean arab other ethnic groups white english/welsh/scottish/northern irish white gipsy irish traveller white irish white other includes employees actively chosen disclose employees respond fig 51: employee diversity sexual orientation proportion employees voluntarily recording hr identify lgbt+.',
#  'this data excludes non-executive directors.',
#  'fig 52: employee diversity disability proportion employees voluntarily recording hr disability long-term condition.',
#  'employees select categories disclosing disability: this data excludes non-executive directors.',
#  'none hidden disability hearing disability visual disability mobility physical impairment mental health condition prefer fig 53: employee diversity social mobility proportion employees voluntarily recording hr school received free school meal, generation family attend university attended non-selective state run state funded school.',
#  'this data excludes non-executive directors.',
#  'fig.',
#  'it excludes new starters, weeks complete training, reported financial year.',
#  'anti-corruption bribery, information security health safety training mandatory training modules.',
#  'all employees complete training modules employed british land group.',
#  'this data excludes non-executive directors.',
#  'fig.',
#  'this proportion calculated employees employed british land group beginning performance review year.',
#  'this data excludes non-executive directors.',
#  'the british land company plc (british land) engaged korn ferry (uk) limited (korn ferry) conduct limited assurance engagement british land broadgate estates 2022 gender ethnicity pay gaps.',
#  'conclusion based review korn ferry undertaken british land broadgate estates gender ethnicity pay gaps, come attention causes believe calculations resultant gender ethnicity pay gap figures fairly stated prepared, material respects, accordance applicable criteria.',
#  'the scope review based 2022 data presented following figures gender ethnicity pay gap reports, based snapshot date 5 april 2022.',
#  'proportion employees receiving bonus number male female employees quartile basis conclusion korn ferry asked review gender pay gap calculations government regulations gender pay gap calculations, relevant guidance.',
#  'the ethnicity pay gap calculations reviewed basis.',
#  'a review allocation male females employee band final calculation a review method calculate proportion employees receiving bonus pay during review process, observations questions relating methodology raised british land.',
#  'korn ferry confirms resolved confirmed appropriate british land.',
#  'our competence, independence quality control korn ferry independent adviser remuneration committee british land conflict scope work.',
#  'korn ferry policies procedures designed ensure provision objective independent advice.',
#  'this independent review carried team pay governance specialists experienced review relevant regulations.',
#  'inherent limitations assurance all assurance engagements subject inherent limitations data sampling detect errors, fraud irregularities.',
#  'furthermore, assurance relies premise data information provided british land provided good faith.',
#  'korn ferry expressly disclaims liability co-responsibility decision person entity based report.',
#  'overview independent limited assurance report board directors the british land company plc the british land company plc (british land) commissioned dnv business assurance services uk limited (dnv, we) conduct limited assurance engagement selected information presented sustainability accounts 2022 (the report) reporting year ended 31 march 2022.',
#  'our conclusion: based procedures performed evidence obtained, come attention causes believe selected information fairly stated prepared, material respects, accordance criteria.',
#  'this conclusion relates selected information, read context independent limited assurance report, particular inherent limitations explained overleaf.',
#  'our observations areas improvement raised separate report british lands management.',
#  'the scope boundary work restricted 2022 data presented figures marked a (the selected information) report.',
#  'a summary figures listed below: 1.',
#  'net zero carbon developments 4.',
#  'like-for-like total direct indirect (scopes 1, 2 3) landlord-influenced greenhouse gas emissions 6.',
#  'indirect (scope 3) value chain greenhouse gas emissions 7.',
#  'total greenhouse gas emissions gas 8.',
#  'building energy target intensity 9.',
#  'internal carbon levy transition vehicle 10.',
#  'total electricity consumption 11.',
#  'total fuel consumption 12.',
#  'like-for-like total electricity fuel consumption 13.',
#  'total energy consumed generated on-site 14.',
#  'sustainability ratings 15.',
#  'energy performance certificates (epc) 16.',
#  'total water consumption 17.',
#  'like-for-like total water consumption 18.',
#  'building water target intensity 19.',
#  'waste management-managed portfolio corporate 20.',
#  'like like waste management-managed portfolio 21.',
#  'waste management-developments 23.',
#  'environmental compliance 32 community contributions planning development 37 accidents-managed portfolio corporate 38 accidents-developments 39 health safety-compliance 40 lost working days 41 employment 42 new employees 43 employee turnover 44 salary remuneration 48 employee diversity-gender our competence, independence quality control dnv established policies procedures designed ensure dnv, personnel and, applicable, subject independence requirements (including personnel entities dnv) maintain independence required relevant ethical requirements.',
#  'this engagement work carried independent team sustainability assurance professionals.',
#  'dnv held audit assurance contracts british land, conflict scope work.',
#  'our multi-disciplinary team consisted professionals combination environmental sustainability assurance experience.',
#  'to assess selected information, includes assessment risk material misstatement report, british lands reporting criteria (the criteria), page 66 report.',
#  'we performed work, express conclusion, information published report british lands website current reporting period previous periods.',
#  'overview standard level assurance we performed limited assurance engagement accordance international standard assurance engagements (isae) 3000 revised assurance engagements audits reviews historical financial information (revised), issued international auditing assurance standards board.',
#  'this standard requires comply ethical requirements plan perform assurance engagement obtain limited assurance.',
#  'dnv applies management standards compliance policies quality control, accordance iso/iec -1:2015-conformity assessment requirements bodies providing audit certification management systems, accordingly maintains comprehensive quality control including documented policies procedures compliance ethical requirements, professional standards applicable legal regulatory requirements.',
#  'the procedures performed limited assurance engagement vary nature timing from, extent for, reasonable assurance engagement; level assurance obtained substantially lower assurance obtained reasonable assurance engagement performed.',
#  'we planned performed work obtain evidence considered sufficient provide basis opinion, risk conclusion error reduced reduced low.',
#  'basis conclusion we required plan perform work order consider risk material misstatement selected information; work included, restricted to: conducting interviews british land management data owners obtain understanding key processes, systems controls place generate, aggregate report selected information; performing limited substantive testing selective basis selected information check data appropriately measured, recorded, collated reported; reviewing evidence, measurements scope provided british land selected information prepared line criteria; a remote visit head office test consolidation data group level; a remote site visit canada water (waste) norton folgate (h&s) development portfolio review processes systems preparing site level data consolidated group level.',
#  'dnv free choose site basis materiality group level figures; assessing appropriateness criteria selected information; reading report narrative accompanying selected information regard criteria.',
#  'dnv business assurance services uk limited london, uk 09 june 2022 inherent limitations all assurance engagements subject inherent limitations selective testing (sampling) detect errors, fraud irregularities.',
#  'non-financial data subject greater inherent uncertainty financial data, given nature methods calculating, estimating determining data.',
#  'the selection different, acceptable, measurement techniques result different quantifications different entities.',
#  'our assurance relies premise data information provided british land provided good faith.',
#  'dnv expressly disclaims liability co-responsibility decision person entity based independent limited assurance report.',
#  'responsibilities board directors british land dnv the directors british land sole responsibility for: preparing presenting selected information accordance criteria; designing, implementing maintaining effective internal controls information data, resulting preparation selected information free material misstatements; measuring reporting selected information based established criteria; contents statements contained report criteria.',
#  'our responsibility plan perform work obtain limited assurance selected information prepared accordance criteria report british land form independent limited assurance conclusion, based work performed evidence obtained.',
#  'we responsible preparation report.',
#  'dnv business assurance dnv business assurance services uk limited dnv business assurance, global provider certification, verification, assessment training services, helping customers build sustainable business performance.']

# %%
# Test on 20% of the valid result
test_valid = [check_relevancy(line) for line in related_sentences]

# %%
print(len(test_valid))
print(sum(test_valid))
# Out:
# 26
# 0

# %%
test_invalid = [check_relevancy(line) for line in unrelated_sentences]

# %%
X_test
# Out:
# ['emissions grouped scope 1, 2 3 accordance ghg protocol, follows: scope 1: combustion fuels, refrigerant loss.',
#  'b1-b5 emissions (embodied carbon operations managed assets): currently, ghg emissions estimated industry benchmarks developed industry expert simon sturgis (see table below).',
#  'scope 1 2 absolute target: science based target initiative (sbti) target reported calculating absolute percentage reduction reporting years absolute location-based scope 1 2 ghg emissions versus baseline year 2020.',
#  'for sbti numerator, a1-a5 emissions pro-rated duration construction project.',
#  'we use location-based method report total ghg emissions track performance 2019 baseline.',
#  'overview sasb table this british lands sustainability accounts references indicators set sustainability accounting standards board (sasb) framework.',
#  'sbti nzc targets greenhouse gas intensity 2.',
#  'scope 1 2 ghg emissions financial intensity measures: we publish financial scope 1 2 ghg emissions intensity annual report accounts 2022.',
#  'the location-based method ghg emissions reported previous years.',
#  'sbti, net zero targets greenhouse gas intensity for second consecutive year, covid-19 related government restrictions significantly affected portfolios carbon intensity, representing majority reduction.',
#  'overview sasb table (continued) area management tenant sustainability impacts sasb code if-re-410a 1 gri code activity metric percentage new leases contain cost recovery clause resource efficiency-related capital improvements associated leased floor area, property subsector units if-re-410a 2 percentage tenants separately metered submetered (1) grid electricity consumption (2) water withdrawals, property sector % floor area (ft2) if-re-410a 3 description approach measuring, incentivizing, improving sustainability impacts tenants.',
#  'ghg conversion emissions factors 2022 (see table 4) sourced uk department business, energy & industrial strategys (beis) 2021 guidelines.',
#  'for financial ratio, ghg emissions scope 1 2 financial intensity measures.']

# %%
related_sentences
# Out:
# ['our esg journey our 2030 commitments performance overview (kpis) net zero carbon place based approach responsible business performance data 2022 epra index sasb index reporting criteria assurance reports 2 3 4 5 9 17 24 27 61 64 66 85 read tcfd disclosures 2022 annual report against challenging backdrop, teams fantastic job year, working customers partners support local communities.',
#  'sbti, net zero targets greenhouse gas intensity for second consecutive year, covid-19 related government restrictions significantly affected portfolios carbon intensity, representing majority reduction.',
#  'location based: our use 2021 uk greenhouse gas conversion factors reflect +3% increase ghg intensity gas (vs 2020) +1% increase ghg intensity electricity (vs 2020).',
#  'overview sasb table this british lands sustainability accounts references indicators set sustainability accounting standards board (sasb) framework.',
#  'area energy management units kwhe sqm sasb code if-re-130a 1 location figure 8, p36 gri code 302-1 if-re-130a 2 302-1 if-re-130a 3 302-1 if-re-130a 4 if-re-130a 5 103-2 activity metric energy consumption data coverage percentage floor area, property subsector total energy consumed portfolio area data coverage, percentage grid electricity, percentage renewable, property subsector lfl change energy consumption portfolio area data coverage, property subsector percentage eligible portfolio (1) obtained energy rating (2) certified energy star, property subsector description building energy management consideration integrated property investment analysis operational strategy mwh figure 13, p40 mwh figure 12, p39 % floor area (sqm) figure 14, p41 discussion analysis energy carbon management integrated policies procedures.',
#  'overview sasb table (continued) area management tenant sustainability impacts sasb code if-re-410a 1 gri code activity metric percentage new leases contain cost recovery clause resource efficiency-related capital improvements associated leased floor area, property subsector units if-re-410a 2 percentage tenants separately metered submetered (1) grid electricity consumption (2) water withdrawals, property sector % floor area (ft2) if-re-410a 3 description approach measuring, incentivizing, improving sustainability impacts tenants.',
#  'scope 1 2 ghg emissions intensities epra reporting reported fig.',
#  'for financial ratio, ghg emissions scope 1 2 financial intensity measures.',
#  'carbon intensity includes scope 1, 2 3 ghg emissions related energy sources plus emissions building sources waste disposal management water consumption.',
#  'scope 1 2 ghg emissions financial intensity measures: we publish financial scope 1 2 ghg emissions intensity annual report accounts 2022.',
#  'financial intensity ratio expresses absolute scope 1 2 ghg emissions relation gross rental income properties managed portfolio.',
#  'absolute scope 1 2 ghg emissions relate managed portfolio electricity, gas use refrigerant loss air conditioning, fuel use british land owned vehicles.',
#  'includes 100% ghg emissions developments, joint venture developments developments undertaken funding.',
#  'ghg conversion emissions factors 2022 (see table 4) sourced uk department business, energy & industrial strategys (beis) 2021 guidelines.',
#  'this includes seven main ghg emissions covered kyoto greenhouse gas protocols, line common practice: carbon dioxide (co2), methane (ch4), hydrofluorocarbons (hfcs), nitrous oxide (n2o), perfluorocarbons (pfcs), sulphur hexafluoride (sf6) nitrogen trifluoride (nf3).',
#  'emissions grouped scope 1, 2 3 accordance ghg protocol, follows: scope 1: combustion fuels, refrigerant loss.',
#  'scope 1 2 absolute target: science based target initiative (sbti) target reported calculating absolute percentage reduction reporting years absolute location-based scope 1 2 ghg emissions versus baseline year 2020.',
#  'the reporting years total scope 1 2 ghg emissions prepared sourced figure 4.',
#  'a1-a5 emissions (embodied carbon construction stages new developments refurbishments carbon levy applies): includes ghg emissions new developments refurbishments, carbon levy applies, completed 2020 construction (stage 5).',
#  'for sbti numerator, a1-a5 emissions pro-rated duration construction project.',
#  'b1-b5 emissions (embodied carbon operations managed assets): currently, ghg emissions estimated industry benchmarks developed industry expert simon sturgis (see table below).',
#  'we use location-based method report total ghg emissions track performance 2019 baseline.',
#  'the location-based method ghg emissions reported previous years.',
#  'table 4 shows combined carbon-equivalent emission factors different ghgs considered.',
#  'sbti nzc targets greenhouse gas intensity 2.',
#  'total direct indirect (scopes 1 2 & 3) ghg emissions location market based 5.']

# %% [markdown]
# ## CNN

# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Embedding
from keras.preprocessing import sequence

# %%
df_c = pd.read_csv('bl_ratios.csv')

# %%
df_c = df_c.drop(columns='Unnamed: 0')

# %%
X = df_c['corpus']
y = df_c['have_transition_plan']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, random_state=42)
X_train[:5]
# Out:
# 906    due small population size ensure anonymity, em...
# 934    a review allocation male females employee band...
# 684    in general, offices shopping centres floor are...
# 922    it excludes new starters, weeks complete train...
# 404    water intensity data covers buildings offices ...
# Name: corpus, dtype: object

# %%
vectorizer = TfidfVectorizer()
tf_idf_matrix = vectorizer.fit_transform(X_train)

# %%
tf_idf_matrix
# Out:
# <691x2470 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8239 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Relation Extraction

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.6.0-py2.py3-none-any.whl (22 kB)
# Collecting rich>=10.4.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\anaconda3\lib\site-packages (from keybert) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\anaconda3\lib\site-packages (from keybert) (1.0.2)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.11.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.7.3)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.23.0-py3-none-any.whl (5.3 MB)
# Requirement already satisfied: tqdm in c:\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in c:\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (1.12.1)
# Requirement already satisfied: torchvision in c:\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.13.1)
# Requirement already satisfied: nltk in c:\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.10.0-py3-none-any.whl (163 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (21.3)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.6.0)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.0.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.3.15)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm->sentence-transformers>=0.3.8->keybert) (0.4.4)
# Requirement already satisfied: click in c:\anaconda3\lib\site-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda3\lib\site-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (9.0.1)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125940 sha256=b04a065ff948e08b5844e68bed34c23fb2c25d51e410bebc01b901255be80094
#   Stored in directory: c:\users\chen wei\appdata\local\pip\cache\wheels\71\67\06\162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers, sentencepiece, commonmark, sentence-transformers, rich, keybert
# Successfully installed commonmark-0.9.1 huggingface-hub-0.10.0 keybert-0.6.0 rich-12.6.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.1 transformers-4.23.0

# %%
import spacy
from spacy.matcher import Matcher 
from spacy.tokens import Span 
nlp = spacy.load('en_core_web_sm')

from keybert import KeyBERT

# %%
# Corpus has already been extract to corpus.txt, take around 15 mins to extract 24 reports
spacy_model = spacy.load("en_core_web_sm")
list_dataset = os.listdir(DATA_FOLDER)
corpus = []
#for file in list_dataset: ##clean loop
pages_content, pages_sentences, all_sentences = extract_pages_sentences(spacy_model,extract_pdf("british-land-sustainability-accounts-2022.pdf"))
corpus.extend(all_sentences)
np.shape(corpus)
# Out:
# (988,)

# %%
#Store corpus in text file
with open("bl_corpus.txt", "w") as fp:
    json.dump(corpus, fp)

# %%
corpus_data = open('bl_corpus.txt')
corpus = json.load(corpus_data)
corpus
# Out:
# ['Our ESG journey Our 2030 commitments Performance overview (KPIs) Net Zero carbon Place based approach Responsible business Performance data 2022 EPRA index SASB index Reporting criteria Assurance Reports 2 3 4 5 9 17 24 27 61 64 66 85 Read more about our TCFD disclosures in our 2022 Annual Report Against a challenging backdrop, our teams have done a fantastic job this year, working with our customers and partners to support local communities.',
#  'As we go into a new year, with new uncertainties on the horizon, their dedication will be more vital than ever.',
#  'Introduction This year we celebrate 20 years of sustainability reporting, and never has our environmental and social focus been more integral to the way we do business.',
#  'The climate emergency is high on everyones agenda; we face a cost of living crisis and the impact of Covid 19 continues to reverberate throughout our communities.',
#  'This means progressing our pathway to net zero and making a positive impact at our places is more important than ever.',
#  'We have continued to deliver strong progress this year.',
#  'At 1 Triton Square, we completed our second net zero carbon development and we are now on site at Canada Water, where we are piloting some of the most innovative building materials and technologies to deliver market leading, highly sustainable buildings.',
#  'Our approach is not only right in terms of the environment, but it also reflects what our customers increasingly expect.',
#  'The strong business case for sustainable buildings was underlined this year by our leasing success at 1 Broadgate, which will be one of the most sustainable buildings in London and is fully let (or under option) four years ahead of completion.',
#  'On the standing portfolio, we completed our net zero audits and are working with our customers to invest into the energy efficient interventions that programme has identified.',
#  'One outcome will be to raise EPC ratings across our portfolio to A or B by 2030 in line with expected MEES legislation.',
#  'We were delighted that our efforts have again been recognised by GRESB, the Global Real Estate Sustainability Benchmark where we achieved a 5* rating for both developments and standing investments.',
#  'On the social side, our Place Based approach and our strong local relationships allow us to adapt to emerging needs and opportunities at each place to make the biggest impact.',
#  'This year our community activities benefitted nearly 24,000 people.',
#  'Our lasting collaboration with Capital City Partnership at Fort Kinnaird, where together we help people who face barriers move into employment, is a powerful example of that (see p23).',
#  'This year marked ten years of our partnership with the National Literacy Trust.',
#  'Against a challenging backdrop, our teams have done a fantastic job, working with our customers and partners to support local communities.',
#  'I would like to thank them for all their hard work and for their huge contribution to making our places vibrant and successful.',
#  'As we go into a new year, with new uncertainties, their dedication will be more vital than ever.',
#  'Overview Overview Broadgate Places People Prefer Our purpose is to create and manage outstanding places which deliver positive outcomes for all our stakeholders on a long term, sustainable basis.',
#  'We do this by understanding the evolving needs ofthe people and the organisations who use our places and the communities who live around them.',
#  'The deep connections we have created between our customers, communities, partners and people have never been more important as we emerge from the pandemic.',
#  'Second net zero carbon development completed Embodied carbon at 1 Triton Square was below our 2030 target at 436 kg CO2e per sqm and was offset through certified schemes including a teak afforestation project in Mexico and a community reforestation project in Ghana.',
#  'Net zero asset audits completed Working with third party experts, we completed 29 audits across the portfolio identifying opportunities to improve the energy efficiency of our standing portfolio.',
#  'Awarded two BRE4 innovation credits For a heat exchange system, recycling waste heat from offices to residential at Canada Water and for introducing a Materials Passport, facilitating materials re-use at 1 Broadgate.',
#  'Offices development pipeline, including completed developments 2.',
#  'Whole building operational energy intensity improvement vs 2019 baseline for offices 3.',
#  'Impacted by Covid-19 restrictions requiring assets to close or operate at lower capacity 4.',
#  'Building Research Establishment, parent organisation of BREEAM certification framework Launched NDT Broadgate Together with New Diorama Theatre we launched NDT Broadgate to support the recovery of the arts post-pandemic.',
#  'One of Londons biggest rehearsal and artist development complexes.',
#  'This year we celebrate 20 years of sustainability reporting and our environmental and social focus has never been more integral to our business.',
#  'Launched Sustainability Brief for Developments.',
#  'Founding member of the UK Green Building Council.',
#  'Launched Community Investment Fund.',
#  'Signatory to the UN Global Compact.',
#  'Delivered first BREEAM Excellent projects.',
#  'Introduced smart energy management system.',
#  'Completed first whole life carbon assessments.',
#  'Our Sustainability Brief established the social and environmental requirements for our developments.',
#  'The UKGBC works to promote sustainability within the built environment.',
#  'Supported 56,000 children to read since our partnership with the National Literacy Trust began.',
#  'Launched Community Charter, laying the foundation for todays Local Charter.',
#  'Started Young Readers Programme partnership.',
#  'Queens Award for lasting economic, social and environmental achievements Launched Regents Place Customer Community Fund an industry first.',
#  'Launched Bright Lights, our skills and employment programme.',
#  'Worked with Happy City to establish seven core principles which guide our placemaking activities.',
#  'Launched 2030 sustainability strategy commitment to be net zero by 2030.',
#  'Introduced internal carbon levy of 60 per tonne on embodied carbon in developments.',
#  'Launched Transition Vehicle to fund energy efficient improvements.',
#  'Our Bright Lights skills and employment programme Science Based Targets initiative validated our carbon reduction targets.',
#  'Our Net Zero Pathway* sets out the ways in which we will reduce our carbon emissions.',
#  'We already offset embodied carbon in developments and from 2030 will offset operational carbon.',
#  'Overview Overview Our 2030 commitments Net zero carbon Environmental leadership Place Based approach We have committed to achieving a net zero carbon portfolio by 2030 and have set out clear targets to reduce both the embodied carbon in our developments and the operational carbon across our portfolio.',
#  'We demonstrate the strong progress we are delivering by participating in leading international benchmarks.',
#  'Our target is to achieve a 5* GRESB rating by 2022 and we are pleased to have achieved this two years ahead of target.',
#  'Top 81st percentile Science Based Targets: approval in 2021 Our Place Based approach means understanding the most important issues and opportunities in the communities around each of our places and focusing our efforts collaboratively to make the biggest impact at each place.',
#  'To deliver on this, we work directly with our community partners and we collaborate with our customers to identify key local issues where they can make an impact.',
#  'Connect: connecting customers, suppliers and community partners around priority local issues and opportunities.',
#  'Our Community Funds at Broadgate, Paddington and Regents Place are an example of this approach Education: needs-based initiatives at our places and working with long term partner the National Literacy Trust Employment: needs-based initiatives at our places.',
#  'Recent focus has been on supporting those impacted by Covid 19, for example through virtual employment training Supporting local business: supporting local business through the provision of affordable workspace, such as Thrive at Canada Water Wellbeing: putting our Wellbeing Principles into practice, which this year included a new park at Exchange Square, Broadgate.',
#  'Responsible business We advocate responsible business practices across British Land and throughout our supply chain.',
#  'Our key areas of focus are set out below.',
#  'Proportion of units with EPCs rated A or B across Assets Under Management 2030 Target 5-star by 2022 100% 50% by 2025 5% reduction in operational water consumption vs 2020 Operational waste from managed assets that is re-used, composted, or recycled Development and operational waste diverted from landfill New construction and major renovation projects designed to achieve a 10% net gain in biodiversity % of managed assets with Biodiversity Action Plans % of managed assets and major developments which have undergone a flood risk assessment 5% Offices: 80% Retail: 70% 100% 100% 100% 1.',
#  'From 2021, the 2030 strategy upgraded our BREEAM targets to Outstanding for Offices (from Excellent) and Excellent for Retail (from Very Good) 2.',
#  'Excludes residential FY22 Performance 5-star 70% 44% 28% 36% 13% Offices: 76% Retail: 48% 96% On track 15% 100% 2021 5-star 73% 27% 25% 24% 20% 71% 47% 100% nr 18% 100% 2020 4-star 24% 21% 25% 72% 54% 99% nr nr 100% BREEAM certifications To date, we have pursued BREEAM certificates at 44% of our standing portfolio.',
#  'While we target best-in-class certifications for new developments and major refurbishments, the majority of our portfolio was built prior to the BRE certification schemes and therefore the route for certifying these assets is through operational certifications, primarily BREEAM In Use.',
#  'We are currently pursuing a multi-stage rollout of BREEAM In Use certifications including first-time pilots at retail assets.',
#  'Likewise, as Committed and Near Term developments complete, their entry into the standing portfolio will increase the proportion of highly-rated assets.',
#  'Following socio-economic assessments, business plans have been created for all sites FY23 Priorities Report on social value generated Develop social value target 5 year target To be reported from FY23 Place Based initiatives identified at all priority assets.',
#  'We will use the priority assets tables on pages 21-23 to report progress against this.',
#  'Overview Net Zero Carbon Net Zero Carbon We have committed to achieving a net zero carbon portfolio by 2030 and have set out clear targets to reduce both the embodied carbon in our developments and the operational carbon across our portfolio.',
#  'We have a long track record of delivering sustainable space and this a clear competitive advantage for our business as more and more of our customers prioritise sustainability.',
#  'Overview Net Zero Carbon Net Zero delivering on our Pathway Last year we set out our Pathway to Net Zero.',
#  'We have delivered on our commitments for this year and are well advanced on those for the coming year.',
#  'Overview Net Zero Carbon Blossom Yard & Studios, Norton Folgate Net Zero carbon Reducing embodied carbon in developments To progress our target of 500 kg CO2e per sqm of embodied carbon on office developments from 2030, we committed to undertaking whole life carbon assessments on all our developments and major refurbishments.',
#  'To do this, we have adopted One Click LCA life cycle assessment software for all our developments.',
#  'This enables us to consolidate data so together with our consultants, we can benchmark performance and monitor progress.',
#  'This is helping to identify which designs, materials and techniques generate the most significant carbon savings.',
#  'Norton Folgate case study We focus on reusing existing materials and structures as far as possible.',
#  'At Blossom Studios, one of the buildings within the Norton Folgate development we retained almost all of the existing faade and 80% of the floors, and all the timber joists were individually assessed with most being re-used.',
#  'We rebuilt some internal walls re-using reclaimed bricks from the original building and retained original features such as iron columns and glazed bricks to preserve the original character of the building.',
#  'New materials focused on responsibly sourced and low carbon alternatives; we are using 100% FSC (Forest Stewardship Council) wood and all the concrete used has 40% cement replacement.',
#  'As a result we currently expect embodied carbon to be 403 kg CO2e per sqm (434 kg CO2e per sqm for the whole redevelopment), ahead of our 2030 target.',
#  'To drive operational performance we are adding roof top solar panels and using air source heat pumps to deliver all electric offices with 100% green power, so operational energy intensity is expected to be in line with our trajectory to 2030.',
#  'Overview Net Zero Carbon Reducing embodied carbon in developments continued Canada Water case study Unlike Norton Folgate, where we have greater capacity to reuse existing materials, Canada Water is a ground up redevelopment.',
#  'This means that to minimise embodied carbon emissions, our focus is on piloting more sustainable materials and processes.',
#  'At A1, a mixed use building which includes 186 residential units and 120,000 sq ft of workspace, we are using more sustainable materials in the superstructure.',
#  'This includes GGBS (ground granulated blast-furnace slag), a waste product from the blast furnaces used to make iron which can be repurposed as a cement replacement.',
#  'We are using post tensioned concrete slabs which are stronger and thinner, requiring less concrete, more cross laminated timber reducing the number of steel beams required and electric arc furnace steel.',
#  'These innovations are in line with the commitment to pilot low carbon materials in our Net Zero Pathway.',
#  'Our current projections are for embodied carbon to be 682 kg CO2e per sqm which is above our 2030 target of 500kg CO2e per sqm, but below the glidepath to 2030.',
#  'WELL Gold Certifications targeted Outdoor space Offsetting strategy We prioritise the re-use of existing materials to minimise embodied carbon as far as possible.',
#  'Where residual embodied carbon cannot be avoided by design and material choice, we offset this through certified emission reduction projects.',
#  'We use nature based offset credits and where possible, we select projects which also support biodiversity or have economic benefits for local communities.',
#  'Project works closely with local farmers, some of whom are employed on the project and others are able to grow crops.',
#  'Aim is to expand by 1,000 hectares each year.',
#  'Supporting the planting of 23,000 trees through the Woodland Carbon Code.',
#  'This was an additional commitment and not part of our formal offset at 1 Triton Square.',
#  'Overview Net Zero Carbon Reducing operational carbon The chart below sets out the key opportunities we have to reduce carbon emissions across our portfolio over the coming eight years.',
#  'On our standing portfolio these focus on renewable power and energy saving initiatives in our buildings.',
#  'Renewable power (grid, onsite and offsite) Residual emissons to be offset from 2030 2030 Energy saving initiatives New developments present the greatest opportunity to deliver best in class buildings which are operationally, highly energy efficient.',
#  'The chart below illustrates the improvement at 1 Broadgate, where energy intensity is just one sixth of the previous building.',
#  'Relatively recent developments, such as 4 Kingdom Street, are already among the most efficient in our portfolio and thoughtful asset management can deliver a significant improvement at relatively low cost.',
#  'In this case, the key intervention is a heat pump accounting for over 70% of the retrofit cost, which altogether represents less than 1% of the buildings value.',
#  'Older buildings such as Broadgate Tower require more comprehensive retrofitting.',
#  'This year we completed 29 net zero audits of buildings across our portfolio identifying initiatives which would deliver at least a 25% improvement in whole building energy efficiency.',
#  'A case study of Exchange House is shown over the page.',
#  'Indicative view which assumes developments are built out per development pipeline and excludes any capital activity We already offset residual embodied carbon on our developments and from 2030, will offset operational carbon across our standing portfolio but will seek to minimise this as far as possible in the following ways.',
#  'The decarbonisation of the National Grid will play a key role in the switch to renewable power across the UK.',
#  'We will supplement this by investing in onsite and offsite renewable energy sources.',
#  'Already we have 2 mega watts of capacity across our portfolio (of which half is at Meadowhall) and are now undertaking feasibility studies to identify further opportunities for rooftop and solar car port possibilities.',
#  'Detailed studies are now underway at two retail sites and the car park at Meadowhall shopping centre.',
#  'We are also exploring opportunities for offsite renewables which would increase the relative contribution of Renewable Power to our overall Pathway.',
#  'Overview Net Zero Carbon Reducing operational carbon continued Increasing energy efficiency on the standing portfolio This year, third party consultants completed net zero audits covering 29 of our major assets.',
#  'These have identified initiatives on the standing portfolio, which if actioned would deliver a 25% improvement in whole building energy efficiency in line with our target.',
#  'Some of these initiatives have already been delivered, reducing energy use by 23% and saving occupiers 340,000 annually.',
#  'One of the most effective interventions we have already delivered is introducing CO2 controls; sensors were installed on all office floors enabling us to monitor fresh air levels and adjust ventilation as needed.',
#  'This relatively low cost measure has significantly cut demand for heating and cooling.',
#  'We are also installing dedicated chillers for out of hours cooling, reducing the requirement to run the main chillers which are more intensive.',
#  'The most significant interventions are LED lighting and heat pumps.',
#  'The improvements will deliver savings which payback the investment over 5 years and we expect that around two-thirds of the cost will be funded through the service charge or covered directly by occupiers.',
#  'These interventions will also improve the buildings EPC rating to a B from an E, making the building fully compliant with expected MEES legislation.',
#  'Overview Place Based approach Our Place Based approach A Place Based approach means understanding the most important issues and opportunities in the communities around each of our places and focusing our efforts collaboratively to make the biggest impact.',
#  'Overview Place Based approach Place Based approach to Social Impact We invest directly into local community organisations, support them in a range of ways, including through the use of our space and work with our occupiers to deliver a positive social impact across our areas of focus.',
#  'Our Local Charter focuses on five key areas where we can create a lasting positive legacy for those who work, shop and live in and around our places.',
#  'Connect We connect with local communities bringing our customers, suppliers and community partners together around a common goal at each place.',
#  'Connecting customers and community partners is one of our strongest social contributions.',
#  'Following the success of the Regents Place Community Fund, this year we worked with our customers to launch funds at Broadgate and Paddington Central.',
#  'Together, we agree priority local themes, pledge funds and award grants to community organisations working locally.',
#  'In the first year, 15 customers and local stakeholders pledged over 150,000 to our Broadgate and Paddington Central Community Funds.',
#  'We support educational initiatives for local people helping them discover their potential, developing skills and raising awareness of career opportunities in our sectors.',
#  'This year, we delivered 58 education initiatives.',
#  'These ranged from primary school projects and secondary school workshops to college events and university challenges.',
#  'We continued our partnership with the National Literacy Trust across 29 of our places, working collaboratively with our customers and local schools to encourage an additional 7,800 children to read for pleasure and improve their literacy skills.',
#  'Together, we have reached 56,000 children since our partnership began.',
#  'Employment We support local training and jobs through Bright Lights, our skills and employment programme, working with customers, suppliers and local partners.',
#  'Recognising the impact of Covid-19 and the emerging cost of living crisis, we have refocused Bright Lights to support some of those most affected, including individuals who have lost their livelihoods.',
#  'These initiatives run across our portfolio.',
#  'We reached over 135 people through virtual employment training and one-to-one support designed to give local residents the skills to achieve lasting employment.',
#  'The programme included ringfenced opportunities with businesses at our places.',
#  'On average over 60% of candidates have already gained employment, in a range of sectors and at Glasgow Fort this rises to 75%.',
#  'Supporting local business = affordable space We support local businesses opening opportunities to local independents, social enterprises and start-ups to support their future success.',
#  'We provided affordable space at five of the eight priority assets and identified opportunities at the remaining three.',
#  'This includes affordable work space, affordable retail space and community and arts space.',
#  'Following the success of New Diorama Theatre (NDT) at Regents Place, together we launched NDT Broadgate to support the recovery of the arts post-pandemic.',
#  'The first project of its kind in the world, NDT Broadgate has attracted a footfall of 80,000 creatives, engaged over 600,000 people and supported the creation of highly successful productions.',
#  'New Diorama Theatre at Regents Place also won The Stages Fringe Theatre of the Year 2022 Award.',
#  'We create places that support health and wellbeing for our customers, colleagues and communities.',
#  'We develop partnerships in our communities which support the wellbeing of the people who work, visit and live in and around our places.',
#  'In 2022 our range of wellbeing initiatives, with community partners such as Darnall United and Global Generation, supported over 2,700 beneficiaries.',
#  'We are on track to achieve WELL Platinum, at 1 Broadgate, the highest level of certification on this globally-recognised benchmark for health and wellbeing.',
#  'Working closely with occupier JLL and architect AHMM, we are targeting industry leading standards for air quality, water and light.',
#  'We continue to align developments to the WELL standard.',
#  'Our first two office developments at Canada Water, A1 and A2, will both be WELL-ready.',
#  'This pre-certification supports us in delivering outstanding workspaces for our customers and opens up the opportunity for customers to partner with us in pursuing full WELL certification for employee health and wellbeing.',
#  'Our social reporting on the subsequent pages focuses on our priority assets and details our specific activities from 2022 and commitments for 2023.',
#  'However, our Place Based approach goes far beyond those assets with programmes delivered across our portfolio.',
#  'The reach of our biggest community initiatives, our partnership with The National Literacy Trust and our Bright Lights Employment initiative can be seen on the map.',
#  'Supporting Ukraine To support those affected by the war in Ukraine we donated 25,000 to the Disaster Emergency Committee which included matching personal donations from our people.',
#  'We also donated 5,000 to the Ukrainian Cathedral in Marylebone, close to our head office.',
#  'At Paddington Central, we pledged 30,000 funding for a scheme to support the Ukrainian Institute setting up an English Language School for refugees and have donated space to host classrooms at Storey Club.',
#  'At a number of assets, we have rolled out specific QR codes to enable people to make donations to the British Red Cross easily.',
#  'Cost of living crisis During FY23 we will be collaborating with our long term partners to support the excellent work they are already doing to help those struggling with the cost of living crisis.',
#  'Our Bright Lights initiatives will focus many of their activities on those most affected.',
#  'Overview Place Based approach Delivering Place Based Working with local partners, we are focusing on a core theme at each asset, to make the biggest social impact.',
#  'We appreciate the interest and respect British Land have for what we do.',
#  'They have a long term vision and were part of that, its like weve been brought into the subsoil and its wonderful to be part of the conversation around how this place comes together.',
#  'Jane Riddiford, Global Generation Canada Water At Canada Water, our partnership with environmental education charity Global Generation continues to grow.',
#  'This year, Global Generation engaged over 600 local primary schoolchildren through workshops and worked with Generator youth leaders.',
#  'Constructed using circular economy principles, the new facility will provide a fantastic community resource for years to come.',
#  'Paddington Central At Paddington Central, we are connecting customers and local partners around inclusive opportunities and this year launched our new Community Fund in collaboration with our occupiers where we will partner with them to address key local issues.',
#  'In April 2021, we unveiled a community garden, supported by occupiers Wipro and Kingfisher.',
#  'Local schoolchildren were among the first visitors to the garden and in the first year, customers volunteered and over 300 people took part in workshops on gardening and food growing with urban farming experts, Square Mile Farms.',
#  'Customers also volunteered 60 hours to help adults with learning disabilities run a fruit and smoothie stall on the campus, through our partnership with local non-profit Pursuing Independent Paths.',
#  'Representatives from businesses on the campus continue to connect through our diversity and inclusion network, with activities this year including a session with activist, TED speaker and author Nova Reid to mark Black History Month.',
#  'Overview Place Based approach Our Place Based approach in action Education Supporting local business = affordable space Wellbeing Broadgate At Broadgate, we are partnering to open access to educational opportunities across the age spectrum from primary school to university.',
#  'This year alone, we engaged 47 schoolchildren local to Broadgate through our collaboration with the National Literacy Trust and customers.',
#  'A further 9 local students completed our virtual work experience programme.',
#  'Our partnership with the University of East London continued to grow, students worked collaboratively on designs for the campus through the Broadgate Prize.',
#  'Canada Water At Canada Water, we continue to partner with Tree Shepherd to deliver Thrive, affordable workspace and business support for entrepreneurs, prioritising SE16 residents.',
#  'Through this project, we aim to create a self-sustaining local business network, growing a pipeline of successful enterprises for future opportunities at Canada Water.',
#  'This year, we supported 72 entrepreneurs with business advice of which five have gone on to set up businesses or become self-employed.',
#  'We provided low-cost workspace, including offices, meeting rooms and makerspace.',
#  'British Land authentically supports people in the community.',
#  'Together, were working to create a place where local people run businesses and are supported to be successful.',
#  'Its people who make a place meaningful.',
#  'Sandra Ferguson, Tree Shepherd Regents Place At Regents Place, we are providing 10,000 sq ft of affordable workspace at 1 Triton Square and donated space at the Triton Caf for community uses.',
#  'This included meeting space for local non-profit Camden Giving and occupier New Diorama Theatre.',
#  'We also provided space to BlackOut UK to run five monthly events across six months that supported peer learning, debates, networking and meaningful connections for 75 black queer men.',
#  'There are tens of thousands of plants, including many native species and flowering varieties good for bees, butterflies and other insects.',
#  'Mature birch trees will offer homes for birds.',
#  'This will all enhance biodiversity and open up access to nature, which studies show boosts wellbeing and productivity.',
#  'The park is also a valuable community space, designed for accessibility.',
#  'We will host events for customers and local people, including talks on gardening led by our Head Gardener.',
#  'To help create a network of green spaces for wildlife in central London, we are now working on roof gardens at Exchange House and nearby 1 Appold Street.',
#  'What nature loves above all things is mixture and change, and thats mirrored in the environments and planting at Exchange Square.',
#  'British Land was exceptionally supportive about us taking a different approach to urban planting.',
#  'The reason our recruitment and skills partnership works so well is because theres a real family feel at Fort Kinnaird.',
#  'At Fort Kinnaird, our strong relationship with Capital City Partnership has enabled us to respond rapidly as retailers and communities have faced shifts in Covid and sudden recruitment needs.',
#  'Together, we have supported nearly 90 people into jobs this year and delivered employability sessions to almost 130 young people.',
#  'As well as developing the confidence and skills of candidates who face barriers to employment, Capital City Partnership is on site every day, so retailers know vulnerable candidates have a network of resources to draw on.',
#  'As part of our focus on providing affordable retail space at Ealing Broadway we worked to find an opportunity for Curated Collective, a family business which supports independent artists and makers.',
#  'The team identified a unit in a good location with supportive terms.',
#  'Curative Collective was also able to use a pre-existing shop fit to avoid extra costs.',
#  'I cant thank Andrew, the Ealing Broadway team and British Land enough for getting behind this placemaking initiative and being so supportive.',
#  'Weve been able to work with 25 local creative partners.',
#  'People in Ealing love being able to interact with the people who made the items they are buying.',
#  'Weve gone from a market stall to thinking about five year leases and we couldnt have done that without the support of British Land.',
#  'Overview Responsible business Responsible business We advocate responsible business practices across British Land and throughout our supply chain.',
#  'Our key areas of focus are Responsible Employment, Diversity, Equality & Inclusion and Responsible Procurement.',
#  'Our people are our competitive advantage.',
#  'We invest in them and seek to create an environment where they can achieve their potential.',
#  'We apply this approach across our supply chain.',
#  'Overview Responsible business Responsible Business We advocate responsible business practices across British Land and throughout our supply chain.',
#  'Our key areas of focus are set out here.',
#  'Responsible Employment Invest in our people We recognise the importance of growing talent internally.',
#  'This year, we invested 440,000 in training and qualifications for our people (380,000 in FY21), developing leadership talent within the business.',
#  'Employees completed over 7,000 hours of training and we are supporting 14 colleagues to gain professional qualifications.',
#  'To support career development we run an internal mentorship scheme, which includes senior leaders and we also partner with Circl Coaching, pairing our people with local students, growing our coaching culture and supporting local talent.',
#  'Connect with our people We ran an in-depth employee engagement survey in early 2022, completed by 87% of our people.',
#  'Topics included leadership, engagement, learning and development, social connection and wellbeing, Diversity Equality & Inclusion (DE&I), and our response to Covid.',
#  'Our overall engagement score was 69%.',
#  'Some very positive messages emerged with 90% of staff reporting that they were proud to work for British Land and 85% confirming that they would recommend British Land as a great place to work.',
#  'The survey also highlighted areas for improvement and our ambition is to increase our overall engagement score.',
#  'To do this, our leadership teams are having detailed sessions across their departments and working collaboratively with their teams to create an action plan addressing the key points raised.',
#  'Provide a safe working environment We maintained our excellent standards for health and safety to ensure our people and places are safe.',
#  'Our health and safety management system is accredited to the international ISO standard and our accident frequency rates remain substantially below the national average.',
#  'Families need flexibility, and opportunities should be equal.',
#  'Thats why British Land offers up to six months of shared parental leave on full pay.',
#  'They support employees to live our lives and careers in ways that work for us, reflecting modern lifestyles through their benefits.',
#  'Michael and Olivia Head of Planning (Michael), Team Assistant (Olivia) Diversity, Equality & Inclusion In early 2022 we launched our Diversity, Equality & Inclusion Strategy, approved by our CSR Committee.',
#  'Aligned with the United Nations Sustainable Development Goals, this sets out our commitments to improve the diversity, equality and inclusivity of our business by 2030, ensuring that we reflect and understand the people who work, shop, live and spend time at our places.',
#  'All our employee feedback channels, including exit interviews and engagement surveys, include diversity demographics to help us understand where employees of different backgrounds, ethnicities and experiences encounter challenges, so we can improve.',
#  'To attract a more diverse workforce, we ensure hiring managers complete anti-bias training and receive blind CVs at the selection for interview stage which have removed the ethnicity and gender indicators.',
#  'We also work with agencies such as BAME Recruitment and London Works to reach candidates from varied backgrounds.',
#  'We have taken a lead role in the 10,000 Black Interns initiative, as real estate sector chair, and continue to support the Change 100 programme, offering paid internships to university students or recent graduates with disabilities or long-term conditions.',
#  'Our ten employee-led networks continue to drive progress on diversity, equality and inclusion.',
#  'These include our ability network enaBLe, REACH (Race Ethnicity and Celebrating Heritage), Parents & Carers, Pride and Womens Network, recently rebranded as equitaBLe.',
#  'Overview Responsible business NextGen, to represent and support the next generation of property professionals.',
#  'Improve gender diversity at all levels In 2022, we exceeded our commitment to maintain a minimum of 35% female representation on the Board, with 36% women on the Board and 37% of senior management female.',
#  'Improve ethnic diversity at all levels We fulfilled our commitment to maintain a minimum of two Directors from an ethnic minority background, ahead of the Parker Review recommendations for ethnic diversity at Board level.',
#  'This reduction was ahead of our target to reduce the pay gap by 2% year on year.',
#  'Responsible Procurement A strong relationship with our suppliers plays a key role in the successful delivery of our strategy which is governed by our Supplier Code of Conduct.',
#  'This sets out clear social, ethical and environmental obligations for our supply chain and promotes safe and fair working conditions.',
#  'Compliance is mandatory for all suppliers.',
#  'We pay at least the Real Living Wage to all British Land employees and we strongly encourage all suppliers to pay their UK employees at or above the Real Living Wage.',
#  'Our London Campuses are accredited Living Wage Places and also comply with the Mayors Good Work Standard.',
#  'Our Slavery and Human Trafficking Statement can be found on our website governance/modern-slavery-act Mandating prompt payment Paying suppliers and partners promptly and within the agreed payment terms is not only an ethical responsibility but also economically beneficial for all parties and the wider economy.',
#  'We have been a signatory to the UK Governments Prompt Payment Code since 2010 and aim to pay 95% of suppliers within 30 days.',
#  'Group invoices are settled within 18 days on average.',
#  'Responsible procurement standards This year, we introduced our Contractor Framework, identifying key sustainability performance indicators that we will monitor for new contractors employed on asset management initiatives.',
#  'We also launched our Supplier Excellence Awards to celebrate and showcase the best suppliers contributions in a range of categories including responsible business.',
#  'Active against modern slavery We uphold the human rights of our employees and throughout the supply chain.',
#  'This year, we provided anti-modern slavery training to all employees.',
#  'Through our partnership with anti-modern slavery charity Unseen, we also undertook independent audits of 10 of our suppliers operating in higher risk areas (with 11 more scheduled), reviewing compliance on 12 key areas of our Supplier Code of Conduct.',
#  'These included human rights, health and safety, equal opportunities, fair reward, working hours, staff development and worker representation.',
#  'Informed by risk and impact assessments, audits prioritised property management service providers at our assets and construction contractors on our developments.',
#  'All suppliers scored above 77% and by working with these suppliers improvement opportunities will be identified and agreed.',
#  'We continue to be a member of Unseens business helpline portal, which allows people to report a potential modern slavery occurrence anonymously.',
#  'Our Supplier Excellence Awards We are delighted to be recognised by British Land in their first supplier awards it felt so rewarding to be recognised by one of our clients in this way.',
#  'I can also confirm that having been in the FM industry for the last 12 years I havent seen any other client take this approach to service partner recognition trailblazing springs to mind.',
#  'Overview British Land Sustainability Accounts 2022 Net zero carbon Carbon emissions Fig.',
#  'Please see pages 85-87 for the full Assurance Reports from Korn Ferry (paygap data)and DNV.',
#  'Selected datahas been independently assured since 2007 (see earlier reports).',
#  'SBTi, Net Zero targets and greenhouse gas intensity For the second consecutive year, COVID-19 and related government restrictions has significantly affected our portfolios carbon intensity, representing the majority of the reduction.',
#  'However, we have also delivered initiatives which enhance energy efficiency over the last year, notably at Exchange House (see p6).',
#  'Overview Carbon emissions (continued) Fig.',
#  'The embodied emissions are offset after the project achieves the practical completion.',
#  'Until the UK Government specifies the long-term strategy for low-carbon heating (including the role of hydrogen and all-electric buildings), Y will include the use of renewable bio-gas.',
#  'Office and A1 units are all electric.',
#  'Exploring all electric option targeting <80.',
#  'N/A project has not undertaken the full NABERS accreditation.',
#  'TBC data will be available in future years as projects progress Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'In 2021/22, our estimated energy consumption in retail units assumes regular operations.',
#  'This will show a significant rise vs last year, where we assumed only 50% operation in retail units.',
#  'This years totals also include the embodied carbon of 1 Triton Square following its practical completion.',
#  'Location based: Our use of the 2021 UK greenhouse gas conversion factors reflect a +3% increase in the GHG intensity of gas (vs 2020) and a +1% increase in the GHG intensity of electricity (vs 2020).',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'While our proportion of renewable gas rose to 85% this year, renewable power dropped to 93%.',
#  'This reduced from last year primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Retail: direct use in retail units (occupier procured) FRI or non-landlord obtained energy at non-BL managed assets Upstream emissions from landlord obtained water use Indirect value chain greenhouse gas emissions In 2021/22, our estimated energy consumption in retail units assumes regular operations.',
#  'This will show a significant rise vs last year, where we assumed only 50% operation in retail units.',
#  'This years totals also include the embodied carbon of 1 Triton Square following its practical completion.',
#  'Overview Carbon emissions (continued) Fig.',
#  'Fig.',
#  'However, we have also delivered initiatives which enhance energy efficiency over the last year, notably at Exchange House (see p16).',
#  'Other energy intensity measures Group occupied floors kWh per sqm * Common parts baseline.',
#  'Overview Carbon emissions (continued) Fig.',
#  'The committed development figures are provisional and amounts will be adjusted if they differ from the completed values.',
#  'These figures are proportionally disclosed at share.',
#  'This figure excludes funds allocated to offsets and funds already invested in projects to improve energy efficiency.',
#  'Investment this year included a chiller replacement at Broadwalk House with a total capex of 552,000.',
#  'This is expected to deliver annual cost savings of 65,000 which will be repaid through the service charge.',
#  'Our Net Zero and energy auditsassessed major assets representing 90% of landlord procured power.',
#  'Overview Energy use Fig.',
#  'Renewable Non-renewable Purchased Purchased Managed portfolio Offices: common parts Offices: shared services Offices: direct use in occupier space Sub-total Retail: common parts Retail: direct use in occupier space (landlord procured) Residential: common parts Scope (managed properties) Corporate Group offices Overall Total Proportion of purchased electricity from renewable sources Proportion of total electricity from renewable sources 110 110 1,150 18,635 20,283 59,974 98,891 14,351 2,584 2,958 999 3,793 7,749 547 300 570 21,703 21,282 63,766 106,751 16,047 2,883 570 109/111 49 49 1,210 20,148 16,375 66,178 102,701 14,722 2 947 821 891 279 332 1,502 196 93 1,084 21,087 16,654 66,510 104,252 16,129 1,040 1,087 108/112 821 46 46 1,274 24 22,618 17,838 83,496 123,952 18,151 1,827 143 240 3,216 3,599 661 16 984 22,808 18,078 86,712 127,598 20,086 1,843 1,008 102/106 971 971 1,260 116,535 9,166 126,960 1,261 119,192 2,875 123,328 1,344 144,901 5,259 151,504 93% 93% 98% 98% 96% 97% Total electricity consumption This year, our proportion of renewable power dropped to 93%.',
#  'This reduction from last year is primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff.',
#  'Overview Energy use (continued) Fig.',
#  'Managed portfolio Offices: common parts Offices: shared services Offices: direct use in occupier space Sub-total Retail: common parts Retail: direct use in occupier space (landlord procured) Residential: common parts Sub-total All property types: on-site vehicles Fuel consumption from service providers on-site vehicles and equipment Corporate Group offices Overall Total Proportion of purchased fuel from renewable sources Proportion of total fuel from renewable sources Fig.',
#  'Overview Energy use (continued) Fig.',
#  'Managed portfolio Offices: common parts Offices: shared services Offices: direct use in occupier space Sub-total Retail: common parts Retail: direct use in occupier space Residential: common parts All property types: on-site vehicles Fuel consumption from service providers on-site vehicles and equipment All property types: district heating and cooling Sub-total Corporate Group offices Overall Total Proportion of purchased energy from renewable sources Proportion of total energy from renewable sources Solar PV (including energy exported to the grid) CHP (electricity generated) CHP (heat generated) Total generated Proportion of energy use in common parts andsharedservices Proportion of all energy use Total energy consumed and generated on site This year, 90% of landlord procured energy was from renewable sources.',
#  'While our proportion of renewable gas rose to 85% this year, renewable power dropped to 93%.',
#  'This reduced from last year primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff.',
#  'Overview Environmental leadership Building certifications Fig.',
#  'The Revolving Credit Facility KPIs exclude residential properties.',
#  'Despite the disposal of some BREEAM-rated assets in recent years, our overall proportion of BREEAM certified assets continues to rise.',
#  'Likewise, 10 Exchange Square completed its first assessment this year, with a BREEAM In Use rating of Very Good.',
#  'This year, we also piloted BREEAM In Use (Part 2) assessments at a number of our retail sites.',
#  'As we have not traditionally procured energy and water on behalf of retail occupiers, we understood upfront that this lack of unit consumption data would limit the assessment rating to Pass.',
#  'However, the process has served as a useful benchmark of our alignment with BREEAMs management criteria and incentivises us to prioritise the collection of retailer consumption data, which will enable us to significantly improve these ratings in future.',
#  'Overview Building certifications (continued) Fig.',
#  'We expect the total cost for retrofitting the portfolio to be in the region of 100m and that two-thirds of this will be funded through the service charge or by customers directly.',
#  'These are typically low cost interventions with an attractive payback period and support occupiers in achieving their own sustainability ambitions.',
#  'Overview Water use Fig.',
#  'Fig.',
#  'At retail, water consumption returned to familiar levels in 2021/22, following a significant increase in the previous year due to a leak at Nugent Shopping Park.',
#  'Overview Water use (continued) Fig.',
#  'Overview Overview Waste and materials Fig.',
#  'Overview Waste and materials (continued) Fig.',
#  'Overview Waste and materials (continued) Fig.',
#  'Assurance excludes waste diverted from landfill through re-use on site and landfilled tax costs ().',
#  'Fig.',
#  'Proportion from sustainable sources 2020 58% 2021 88% 12% 100% 34/36 42% 100% 49/52 2022 56% 39% 95% 35/36 Waste management developments During excavation works at one of our Canada Water projects, it was discovered that some of the soil contained historic land contamination, and whilst not classified as hazardous waste, it would be unsuitable for repurposing due to the existing ground conditions.',
# ...
#  'Non-executive directors are included in this table to reflect any new joiners to the Board within the year.',
#  'Fig.',
#  'Employees who left under TUPE or at the end of their agreed fixed term employment contract are excluded.',
#  'Turnover rates are based on the number of leavers divided by the total number of number of employees at the end of the year (as reported in Fig.',
#  'Proportion of leavers by gender, employment level and age is based on the number of leavers in each category divided by total number of leavers within the year.',
#  'Non-executive directors are included in this table to reflect any leavers to the Board within the year.',
#  'Figures include salary, discretionary performance bonuses, car allowance, board fees and private medical insurance.',
#  'Remuneration related to share schemes is not included.',
#  'The bonus element is based on the prior year bonus paid, as current year bonuses will be paid after 31 March 2022 and had not been determined when data was compiled.',
#  'Salary and bonus payment data for part time employees has been pro-rated to their FTE data.',
#  'Non-executive directors are not included in this table, only executive directors employed permanently by British Land are included.',
#  'Fig.',
#  'Full details and previous years of gender pay gap reporting can be found on We are reporting on the 2022 pay gap ahead of the 2023 deadline set by the government.',
#  'All employees employed on 5 April 2022 are included in the data.',
#  'Fig.',
#  'Ethnicity pay gap British Land and Broadgate Estates Ltd comply with the mandatory government criteria for gender pay gap reporting, our ethnicity pay gap has followed the same methodology.',
#  'All employees employed on 5 April 2022 and who have voluntarily disclosed their ethnicity are included in the data.',
#  'Any bonus received in the year preceding 5 April 2022 is included in the bonus calculations.',
#  'Due to the small population size and to ensure anonymity, employees have been split into BAME (Black, Asian and minority ethnic) and non-BAME to report the ethnicity pay gap.',
#  'Fig.',
#  'In line with recommendations from the Global Reporting Initiative (GRI), this is the fourth year we are reporting on the median employee to CEO pay ratio.',
#  'CEO pay data includes salary, benefits, pension, annual incentives, long term incentives and other items in nature of compensation.',
#  'It is consistent with the single figure reported in our 2022 Annual Report and Accounts.',
#  'The data follows method A of the governments reporting criteria, therefore showing full time equivalent total remuneration of all UK employees for the financial year April 2021 to March 2022.',
#  'From 2016, ethnicity data has been captured through the human resources systems upon request from human resources.',
#  'All data has been given voluntarily by employees.',
#  'For reporting purposes, we use the Office of National Statistics ethnicity categories, shown in Table 11.',
#  'Other White Not disclosed Includes Asian Bangladeshi Asian Chinese Asian Indian Asian Pakistani Asian Other Black African Black Caribbean Black Other Mixed Other Mixed White and Asian Mixed White and Black African Mixed White and Black Caribbean Arab Other Ethnic Groups White English/Welsh/Scottish/Northern Irish White Gipsy or Irish Traveller White Irish White Other Includes employees who have actively chosen not to disclose and employees who did not respond at all Fig 51: Employee Diversity Sexual Orientation Proportion of employees voluntarily recording on our HR system whether they identify as LGBT+.',
#  'This data excludes non-executive directors.',
#  'Fig 52: Employee Diversity Disability Proportion of employees voluntarily recording on our HR system whether they have a disability or long-term condition.',
#  'Employees can select from one of the categories when disclosing their disability: This data excludes non-executive directors.',
#  'None Hidden Disability Hearing Disability Visual Disability Mobility and Physical Impairment Mental Health Condition Prefer not to say Fig 53: Employee Diversity Social Mobility Proportion of employees voluntarily recording on our HR system whether while at school received free school meal, were the first generation in their family to attend university or attended a non-selective state run or state funded school.',
#  'This data excludes non-executive directors.',
#  'Fig.',
#  'It excludes new starters, who have six weeks to complete the training, and are therefore reported in the next financial year.',
#  'Anti-corruption and bribery, information security and health and safety training are mandatory training modules.',
#  'All employees complete these training modules while employed at British Land Group.',
#  'This data excludes non-executive directors.',
#  'Fig.',
#  'This proportion is calculated for employees employed by British Land Group since the beginning of the performance review year.',
#  'This data excludes non-executive directors.',
#  'The British Land Company PLC (British Land) engaged Korn Ferry (UK) Limited (Korn Ferry) to conduct a limited assurance engagement of the British Land and Broadgate Estates 2022 Gender and Ethnicity pay gaps.',
#  'Conclusion Based on the review Korn Ferry has undertaken of the British Land and Broadgate Estates Gender and Ethnicity pay gaps, nothing has come to our attention that causes us to believe that the calculations and resultant gender and ethnicity pay gap figures are not fairly stated and have not been prepared, in all material respects, in accordance with the applicable criteria.',
#  'The scope of the review is based on the 2022 data presented in the following figures in the Gender and Ethnicity pay gap reports, based on the snapshot date of 5 April 2022.',
#  'Proportion of employees receiving a bonus Number of male and female employees by quartile Basis for our conclusion Korn Ferry were asked to review the Gender pay gap calculations against the Government regulations for Gender pay gap calculations, and relevant guidance.',
#  'The Ethnicity pay gap calculations were also reviewed on the same basis.',
#  'A review of the allocation of male and females by employee band and final calculation A review of the method to calculate the proportion of employees receiving bonus pay During the review process, our observations and questions relating to methodology were raised with British Land.',
#  'Korn Ferry confirms these were resolved or confirmed as appropriate by British Land.',
#  'Our competence, independence and quality control Korn Ferry is the independent adviser to the Remuneration Committee of British Land which does not conflict with the scope of this work.',
#  'Korn Ferry policies and procedures are designed to ensure the provision of objective and independent advice.',
#  'This independent review was carried out by a team of Pay and Governance specialists who are experienced in the review of the relevant regulations.',
#  'Inherent limitations of assurance All assurance engagements are subject to inherent limitations such as data sampling and may not detect errors, fraud or other irregularities.',
#  'Furthermore, our assurance relies on the premise that the data and information provided to us by British Land have been provided in good faith.',
#  'Korn Ferry expressly disclaims any liability or co-responsibility for any decision a person or an entity may make based on this report.',
#  'Overview Independent Limited Assurance Report to the Board of Directors of The British Land Company Plc The British Land Company Plc (British Land) commissioned DNV Business Assurance Services UK Limited (DNV, us or we) to conduct a limited assurance engagement over Selected Information presented in the Sustainability Accounts 2022 (the Report) for the reporting year ended 31 March 2022.',
#  'Our Conclusion: Based on the procedures we have performed and the evidence we have obtained, nothing has come to our attention that causes us to believe that the Selected Information is not fairly stated and has not been prepared, in all material respects, in accordance with the Criteria.',
#  'This conclusion relates only to the Selected Information, and is to be read in the context of this Independent Limited Assurance Report, in particular the inherent limitations explained overleaf.',
#  'Our observations and areas for improvement will be raised in a separate report to British Lands Management.',
#  'The scope and boundary of our work is restricted to the 2022 data presented in Figures marked with A (the Selected Information) in the Report.',
#  'A summary of these Figures is listed below: 1.',
#  'SBTi NZC targets greenhouse gas intensity 2.',
#  'Net Zero Carbon Developments 4.',
#  'Total direct and indirect (Scopes 1 2 & 3) GHG emissions Location and market based 5.',
#  'Like-for-like total direct and indirect (Scopes 1, 2 and 3) landlord-influenced greenhouse gas emissions 6.',
#  'Indirect (Scope 3) value chain greenhouse gas emissions 7.',
#  'Total greenhouse gas emissions by gas 8.',
#  'Building energy target and intensity 9.',
#  'Internal carbon levy and Transition Vehicle 10.',
#  'Total electricity consumption 11.',
#  'Total fuel consumption 12.',
#  'Like-for-like total electricity and fuel consumption 13.',
#  'Total energy consumed and generated on-site 14.',
#  'Sustainability ratings 15.',
#  'Energy Performance Certificates (EPC) 16.',
#  'Total water consumption 17.',
#  'Like-for-like total water consumption 18.',
#  'Building water target and intensity 19.',
#  'Waste management-managed portfolio and corporate 20.',
#  'Like for like waste management-managed portfolio 21.',
#  'Waste management-developments 23.',
#  'Environmental compliance 32 Community contributions through planning and development 37 Accidents-managed portfolio and corporate 38 Accidents-developments 39 Health and safety-compliance 40 Lost working days 41 Employment 42 New employees 43 Employee turnover 44 Salary and remuneration 48 Employee diversity-gender Our competence, independence and quality control DNV established policies and procedures are designed to ensure that DNV, its personnel and, where applicable, others are subject to independence requirements (including personnel of other entities of DNV) and maintain independence where required by relevant ethical requirements.',
#  'This engagement work was carried out by an independent team of sustainability assurance professionals.',
#  'DNV has held other audit and assurance contracts with British Land, none of which conflict with the scope of this work.',
#  'Our multi-disciplinary team consisted of professionals with a combination of environmental and sustainability assurance experience.',
#  'To assess the Selected Information, which includes an assessment of the risk of material misstatement in the Report, we have used British Lands Reporting Criteria (the Criteria), which can be found from page 66 of the Report.',
#  'We have not performed any work, and do not express any conclusion, on any other information that may be published in the Report or on British Lands website for the current reporting period or for previous periods.',
#  'Overview Standard and level of assurance We performed a limited assurance engagement in accordance with the International Standard on Assurance Engagements (ISAE) 3000 revised Assurance Engagements other than Audits and Reviews of Historical Financial Information (revised), issued by the International Auditing and Assurance Standards Board.',
#  'This standard requires that we comply with ethical requirements and plan and perform the assurance engagement to obtain limited assurance.',
#  'DNV applies its own management standards and compliance policies for quality control, in accordance with ISO/IEC -1:2015-Conformity Assessment Requirements for bodies providing audit and certification of management systems, and accordingly maintains a comprehensive system of quality control including documented policies and procedures regarding compliance with ethical requirements, professional standards and applicable legal and regulatory requirements.',
#  'The procedures performed in a limited assurance engagement vary in nature and timing from, and are less in extent than for, a reasonable assurance engagement; and the level of assurance obtained is substantially lower than the assurance that would have been obtained had a reasonable assurance engagement been performed.',
#  'We planned and performed our work to obtain the evidence we considered sufficient to provide a basis for our opinion, so that the risk of this conclusion being in error is reduced but not reduced to very low.',
#  'Basis of our conclusion We are required to plan and perform our work in order to consider the risk of material misstatement of the Selected Information; our work included, but was not restricted to: Conducting interviews with British Land management and data owners to obtain an understanding of the key processes, systems and controls in place to generate, aggregate and report the Selected Information; Performing limited substantive testing on a selective basis of the Selected Information to check that data had been appropriately measured, recorded, collated and reported; Reviewing that the evidence, measurements and their scope provided to us by British Land for the Selected Information is prepared in line with the Criteria; A remote visit to Head Office to test the consolidation of data at Group level; A remote site visit to Canada Water (Waste) and Norton Folgate (H&S) in the Development portfolio to review the processes and systems for preparing site level data consolidated at Group level.',
#  'DNV were free to choose the site on the basis of materiality to the Group level figures; Assessing the appropriateness of the Criteria for the Selected Information; and Reading the Report and narrative accompanying the Selected Information within it with regard to the Criteria.',
#  'DNV Business Assurance Services UK Limited London, UK 09 June 2022 Inherent limitations All assurance engagements are subject to inherent limitations as selective testing (sampling) may not detect errors, fraud or other irregularities.',
#  'Non-financial data may be subject to greater inherent uncertainty than financial data, given the nature and methods used for calculating, estimating and determining such data.',
#  'The selection of different, but acceptable, measurement techniques may result in different quantifications between different entities.',
#  'Our assurance relies on the premise that the data and information provided to us by British Land have been provided in good faith.',
#  'DNV expressly disclaims any liability or co-responsibility for any decision a person or an entity may make based on this Independent Limited Assurance Report.',
#  'Responsibilities of the Board of Directors of British Land and DNV The Directors of British Land have sole responsibility for: Preparing and presenting the Selected information in accordance with the Criteria; Designing, implementing and maintaining effective internal controls over the information and data, resulting in the preparation of the Selected Information that is free from material misstatements; Measuring and reporting the Selected Information based on their established Criteria; and Contents and statements contained within the Report and the Criteria.',
#  'Our responsibility is to plan and perform our work to obtain limited assurance about whether the Selected Information has been prepared in accordance with the Criteria and to report to British Land in the form of an independent limited assurance conclusion, based on the work performed and the evidence obtained.',
#  'We have not been responsible for the preparation of the Report.',
#  'DNV Business Assurance DNV Business Assurance Services UK Limited is part of DNV Business Assurance, a global provider of certification, verification, assessment and training services, helping customers to build sustainable business performance.']

# %%
res = pd.DataFrame(corpus, columns=['words'])

# %%
res
# Out:
#                                                  words
# 0    Our ESG journey Our 2030 commitments Performan...
# 1    As we go into a new year, with new uncertainti...
# 2    Introduction This year we celebrate 20 years o...
# 3    The climate emergency is high on everyones age...
# 4    This means progressing our pathway to net zero...
# ..                                                 ...
# 983  DNV expressly disclaims any liability or co-re...
# 984  Responsibilities of the Board of Directors of ...
# 985  Our responsibility is to plan and perform our ...
# 986  We have not been responsible for the preparati...
# 987  DNV Business Assurance DNV Business Assurance ...
#
# [988 rows x 1 columns]

# %%
res.to_csv('test.csv', index=False)

# %%
df_w = pd.read_csv('test.csv')

# %%
df_w.head()
# Out:
#                                                words
# 0  Our ESG journey Our 2030 commitments Performan...
# 1  As we go into a new year, with new uncertainti...
# 2  Introduction This year we celebrate 20 years o...
# 3  The climate emergency is high on everyones age...
# 4  This means progressing our pathway to net zero...

# %%
def get_entities(sent):
    ## chunk 1
    ent1 = ""
    ent2 = ""
    
    prv_tok_dep = ""    # dependency tag of previous token in the sentence
    prv_tok_text = ""   # previous token in the sentence
    
    prefix = ""
    modifier = ""

  #############################################################
    for tok in nlp(sent):
        ## chunk 2
        # if token is a punctuation mark then move on to the next token
        if tok.dep_ != "punct":
            # check: token is a compound word or not
            if tok.dep_ == "compound":
                prefix = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    prefix = prv_tok_text + " "+ tok.text
      
            # check: token is a modifier or not
            if tok.dep_.endswith("mod") == True:
                modifier = tok.text
                # if the previous word was also a 'compound' then add the current word to it
                if prv_tok_dep == "compound":
                    modifier = prv_tok_text + " "+ tok.text
            
            ## chunk 3
            if tok.dep_.find("subj") == True:
                ent1 = modifier +" "+ prefix + " "+ tok.text
                prefix = ""
                modifier = ""
                prv_tok_dep = ""
                prv_tok_text = ""      
                
            ## chunk 4
            if tok.dep_.find("obj") == True:
                ent2 = modifier +" "+ prefix +" "+ tok.text
                
            ## chunk 5  
            # update variables
            prv_tok_dep = tok.dep_
            prv_tok_text = tok.text
  #############################################################
    return [ent1.strip(), ent2.strip()]

# %%
get_entities('We have a transition plan')
# Out:
# ['We', 'transition plan']

# %%
entities = []
for i in tqdm(df_w['words']):
    entities.append(get_entities(i))
# Out:
#   0%|          | 0/988 [00:00<?, ?it/s]

# %%
entities
# Out:
# [['challenging Annual teams', 'local  communities'],
#  ['new  dedication', 'new  horizon'],
#  ['more  we', 'business'],
#  ['living impact', '19  communities'],
#  ['progressing', 'positive  places'],
#  ['We', 'strong  progress'],
#  ['where Canada we', 'sustainable market buildings'],
#  ['also  customers', 'also  what'],
#  ['1 leasing which', 'ahead  completion'],
#  ['efficient  programme', 'efficient  that'],
#  ['One  outcome', 'expected MEES legislation'],
#  ['where Estate Sustainability we', '* developments'],
#  ['local  us', 'biggest  impact'],
#  ['year community activities', '24,000  people'],
#  ['who', 'powerful  p23'],
#  ['', 'ten National Literacy Trust'],
#  ['challenging  teams', 'local  communities'],
#  ['huge  places', 'huge  contribution'],
#  ['new  dedication', 'new  uncertainties'],
#  ['outstanding  which', 'long  term'],
#  ['who', 'them'],
#  ['more  we', 'pandemic'],
#  ['zero carbon development', 'teak community reforestation Ghana'],
#  ['third party we', 'standing energy portfolio'],
#  ['', '1 Materials Broadgate'],
#  ['', 'completed Offices development developments'],
#  ['', '2019 energy intensity offices'],
#  ['', 'lower Covid-19 capacity'],
#  ['Together New Diorama we', 'NDT post'],
#  ['One', 'Londons'],
#  ['environmental sustainability focus', 'more  business'],
#  ['', 'Sustainability Developments'],
#  ['', 'Founding Green Building Council'],
#  ['', 'Community Investment Fund'],
#  ['', 'UN Global Compact'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['Sustainability Brief', 'social  developments'],
#  ['UKGBC', 'built  environment'],
#  ['56,000  partnership', 'National Literacy Trust'],
#  ['', 'todays Local Charter'],
#  ['', 'Readers Programme partnership'],
#  ['Queens Award', 'economic Customer Community Fund'],
#  ['', 'Bright Lights'],
#  ['seven core which', 'placemaking activities'],
#  ['2030 sustainability strategy commitment', 'net  2030'],
#  ['', 'embodied carbon developments'],
#  ['', 'efficient Transition improvements'],
#  ['Bright Lights skills', 'carbon reduction targets'],
#  ['we', 'carbon emissions'],
#  ['We', 'operational  carbon'],
#  ['carbon Environmental Place Based We', 'operational carbon portfolio'],
#  ['strong  we', 'international  benchmarks'],
#  ['GRESB  we', 'ahead  target'],
#  ['Place Based approach', 'biggest  place'],
#  ['where  they', 'impact'],
#  ['', 'local community issues'],
#  ['Community Funds', 'based Literacy Trust places'],
#  ['such Wellbeing which', 'new Exchange Square'],
#  ['business  We', 'responsible supply chain'],
#  ['key  areas', 'focus'],
#  ['major Action Plans which', '5 % Offices'],
#  ['2030  strategy', 'Very BREEAM Good'],
#  ['100 % BREEAM we', 'standing BREEAM portfolio'],
#  ['therefore BRE certification route', 'primarily  Use'],
#  ['We', 'retail time assets'],
#  ['entry', 'rated  assets'],
#  ['FY23 Priorities Report', 'Place Based priority assets'],
#  ['We', '21 priority assets this'],
#  ['Net Zero We', 'operational carbon portfolio'],
#  ['We', 'more track sustainability'],
#  ['year  we', 'Net Zero'],
#  ['We', 'coming  year'],
#  ['embodied office we', 'whole life carbon developments'],
#  ['we', 'One cycle assessment developments'],
#  ['together  we', 'progress'],
#  ['materials', 'significant carbon savings'],
#  ['Folgate case We', 'existing  materials'],
#  ['80 timber joists', 'most  -'],
#  ['We', 'original iron building'],
#  ['sourced carbon we', '40 % cement replacement'],
#  ['embodied  carbon', '2030  target'],
#  ['operational energy intensity', '2030'],
#  ['existing Canada Water', 'existing  materials'],
#  ['carbon focus', 'sustainable  materials'],
#  ['sq  we', 'sustainable  superstructure'],
#  ['granulated blast which', 'cement replacement'],
#  ['concrete  which', 'laminated steel beams'],
#  ['innovations', 'low Net Zero Pathway'],
#  ['682  which', '500  2030'],
#  ['Offsetting We', 'existing  carbon'],
#  ['design  we', 'certified emission reduction projects'],
#  ['which', 'local  communities'],
#  ['others', 'crops'],
#  ['Aim', '1,000  hectares'],
#  ['', '23,000 Woodland Carbon Code'],
#  ['This', '1 Triton Square'],
#  ['key  we', 'eight carbon years'],
#  ['', 'renewable  buildings'],
#  ['best class which', 'best class buildings'],
#  ['where energy intensity', 'previous  building'],
#  ['recent  developments', 'low asset cost'],
#  ['70 retrofit which', '1 buildings value'],
#  ['Older  buildings', 'comprehensive Broadgate retrofitting'],
#  ['zero  which', 'whole building energy efficiency'],
#  ['case study', 'Exchange page'],
#  ['capital We', 'following  ways'],
#  ['decarbonisation', 'key National UK'],
#  ['We', 'renewable energy sources'],
#  ['mega  half', 'further feasibility rooftop'],
#  ['Detailed  studies', 'retail Meadowhall shopping centre'],
#  ['offsite  which', 'overall  Pathway'],
#  ['third party consultants', 'major  assets'],
#  ['standing  which', 'whole building energy target'],
#  ['Some', '23 energy 340,000'],
#  ['already CO2 sensors', 'fresh air ventilation'],
#  ['low cost measure', 'significantly  heating'],
#  ['main  which', 'main  chillers'],
#  ['significant  interventions', ''],
#  ['two  thirds', 'directly service occupiers'],
#  ['building', 'expected MEES legislation'],
#  ['Place Based Place Based approach', 'biggest  impact'],
#  ['Social We', 'social community focus'],
#  ['positive  who', 'places'],
#  ['We', 'common community place'],
#  ['Connecting  customers', 'social community contributions'],
#  ['year Place Community we', 'Broadgate'],
#  ['Together  we', 'local community organisations'],
#  ['15  customers', 'over  Broadgate'],
#  ['local  them', 'developing career sectors'],
#  ['year  we', '58 education initiatives'],
#  ['These', 'secondary college events'],
#  ['We', '7,800 literacy skills'],
#  ['56,000  partnership', '56,000  children'],
#  ['Employment  We', 'local employment customers'],
#  ['most Bright who', 'livelihoods'],
#  ['initiatives', 'portfolio'],
#  ['We', 'lasting employment employment'],
#  ['programme', 'ringfenced  places'],
#  ['already Glasgow this', '75  %'],
#  ['affordable  We', 'future start success'],
#  ['We', 'remaining priority three'],
#  ['This', 'affordable work space'],
#  ['together Regents we', 'NDT post'],
#  ['NDT Broadgate', 'successful  productions'],
#  ['New Diorama Theatre', '2022 Stages Fringe Award'],
#  ['that', 'customers'],
#  ['who', 'places'],
#  ['range', '2,700 Global beneficiaries'],
#  ['We', 'recognised WELL health'],
#  ['occupier  we', 'leading air quality'],
#  ['We', 'WELL  standard'],
#  ['two office developments', 'Canada Water'],
#  ['outstanding  customers', 'full employee health'],
#  ['social  reporting', 'specific priority 2023'],
#  ['However Place Based approach', 'far  portfolio'],
#  ['biggest community partnership', 'Lights Employment map'],
#  ['Disaster Emergency which', 'personal  people'],
#  ['We', 'close head office'],
#  ['Paddington we', '30,000 Storey Club'],
#  ['we', 'specific British Red Cross'],
#  ['excellent term they', 'already living crisis'],
#  ['Bright Lights initiatives', 'most  affected'],
#  ['local Delivering we', 'social core impact'],
#  ['British we', 'British what'],
#  ['how  place', 'conversation'],
#  ['Jane Riddiford', 'environmental charity Global Generation'],
#  ['year Global Generation', 'primary Generator youth leaders'],
#  ['new economy facility', 'fantastic community years'],
#  ['where Community we', 'local  issues'],
#  ['2021  we', 'occupiers Wipro'],
#  ['300  people', 'urban farming experts'],
#  ['Customers', 'profit Independent Paths'],
#  ['Representatives', 'year Black History Month'],
#  ['affordable Wellbeing we', 'primary age university'],
#  ['alone  we', 'local National Literacy Trust'],
#  ['local  students', 'virtual work experience programme'],
#  ['University  students', 'collaboratively Broadgate Prize'],
#  ['Canada Water Canada we', 'affordable SE16 residents'],
#  ['we', 'future Canada Water'],
#  ['72 business five', 'businesses'],
#  ['We', 'low cost rooms'],
#  ['British  Land', 'authentically  community'],
#  ['local  people', 'businesses'],
#  ['place', ''],
#  ['Regents we', '1 community uses'],
#  ['This', 'profit New Diorama Theatre'],
#  ['six BlackOut that', 'black queer men'],
#  ['', 'good  bees'],
#  ['Mature birch trees', 'birds'],
#  ['boosts', 'all  which'],
#  ['park', 'valuable community accessibility'],
#  ['We', 'local Head Gardener'],
#  ['central  we', 'now Exchange House'],
#  ['that', 'Exchange Square'],
#  ['exceptionally  us', 'urban  planting'],
#  ['recruitment  partnership', 'real Fort Kinnaird'],
#  ['rapidly Capital City retailers', 'Covid'],
#  ['Together  we', 'young employability people'],
#  ['vulnerable  candidates', 'resources'],
#  ['family which', 'independent  artists'],
#  ['team', 'supportive  terms'],
#  ['Curative Collective', 'extra  costs'],
#  ['I', 'placemaking British initiative'],
#  ['We', 'creative  partners'],
#  ['they', 'items'],
#  ['five year we', 'British Land'],
#  ['business Overview We', 'responsible supply chain'],
#  ['key  areas', 'focus'],
#  ['people', ''],
#  ['where  they', 'potential'],
#  ['We', 'supply chain'],
#  ['Business business We', 'responsible supply chain'],
#  ['key  areas', 'focus'],
#  ['Responsible Employment We', 'growing  talent'],
#  ['year  we', 'leadership business'],
#  ['7,000  we', 'professional  qualifications'],
#  ['senior  we', 'local coaching talent'],
#  ['We', '87 employee engagement people'],
#  ['Topics', 'Diversity Equality Diversity Covid'],
#  ['overall engagement score', ''],
#  ['85 British they', 'great  place'],
#  ['also  ambition', 'overall engagement score'],
#  ['collaboratively  teams', 'key action points'],
#  ['excellent  people', 'excellent  health'],
#  ['health management system', 'national accident frequency average'],
#  ['opportunities', 'flexibility'],
#  ['why British Land', 'full  pay'],
#  ['that', 'modern  benefits'],
#  ['early Team we', 'CSR Committee'],
#  ['who', 'places'],
#  ['different encounter we', 'different encounter challenges'],
#  ['blind interview which', 'ethnicity'],
#  ['We', 'varied BAME backgrounds'],
#  ['100 estate sector offering', 'recent university disabilities'],
#  ['led  networks', 'diversity'],
#  ['These', 'recently Race equitaBLe'],
#  ['', 'next property professionals'],
#  ['gender we', 'senior management female'],
#  ['ethnic  We', 'ethnic Board level'],
#  ['reduction', '2 % year'],
#  ['successful  which', 'Supplier Conduct'],
#  ['This', 'working supply conditions'],
#  ['Compliance', 'suppliers'],
#  ['British Land we', 'strongly Real Living Wage'],
#  ['London Campuses', 'also Good Work Standard'],
#  ['Slavery Human Statement', 'beneficial payment parties'],
#  ['We', '30 Prompt Payment days'],
#  ['Group invoices', '18  days'],
#  ['key sustainability performance we', 'new asset management initiatives'],
#  ['We', 'responsible suppliers business'],
#  ['modern  We', 'human supply chain'],
#  ['year  we', 'modern slavery employees'],
#  ['modern slavery we', 'key Supplier Conduct'],
#  ['These', 'human  rights'],
#  ['risk  audits', 'assets management service developments'],
#  ['suppliers', '77 suppliers improvement opportunities'],
#  ['people', 'modern slavery occurrence'],
#  ['first supplier it', 'so  way'],
#  ['other  client', 'partner recognition springs'],
#  ['', 'British Land Sustainability Accounts'],
#  ['', 'full Korn data)and'],
#  ['Selected  datahas', 'earlier  reports'],
#  ['SBTi', 'significantly portfolios carbon reduction'],
#  ['also  which', 'notably Exchange House'],
#  ['', ''],
#  ['project', 'practical  completion'],
#  ['electric carbon Y', 'renewable  gas'],
#  ['Office  units', ''],
#  ['', '<  80'],
#  ['N  project', 'full NABERS accreditation'],
#  ['future  projects', 'Fig'],
#  ['', ''],
#  ['', ''],
#  ['estimated energy consumption', 'regular  operations'],
#  ['where  we', 'retail % units'],
#  ['years  totals', 'practical Triton completion'],
#  ['use', '+1 GHG 2020'],
#  ['', ''],
#  ['', ''],
#  ['renewable  power', '93  %'],
#  ['where  it', 'renewable  tariff'],
#  ['', ''],
#  ['', ''],
#  ['estimated energy consumption', 'regular  operations'],
#  ['where  we', 'retail % units'],
#  ['years  totals', 'practical Triton completion'],
#  ['', ''],
#  ['', ''],
#  ['also  which', 'notably Exchange p16'],
#  ['Common parts', 'floors sqm'],
#  ['', ''],
#  ['they', 'completed  values'],
#  ['figures', 'proportionally  share'],
#  ['figure', 'already energy efficiency'],
#  ['Investment', 'total Broadwalk 552,000'],
#  ['annual cost which', 'service charge'],
#  ['Net  Zero', 'procured  power'],
#  ['Overview Energy', 'Fig'],
#  ['year electricity proportion', '93  %'],
#  ['where  it', 'renewable  tariff'],
#  ['', ''],
#  ['occupier parts landlord', 'renewable Overall Total sources'],
#  ['', ''],
#  ['procured  energy', 'renewable  sources'],
#  ['renewable  power', '93  %'],
#  ['where  it', 'renewable  tariff'],
#  ['', 'Environmental  certifications'],
#  ['Credit Facility KPIs', 'residential  properties'],
#  ['overall  proportion', 'certified  assets'],
#  ['10 Exchange Square', 'Very Use Good'],
#  ['year  we', 'retail  sites'],
#  ['lack', 'assessment Pass'],
#  ['useful retailer consumption which', 'significantly  future'],
#  ['', ''],
#  ['two  thirds', 'service customers'],
#  ['These', 'own sustainability ambitions'],
#  ['Overview Water', 'Fig'],
#  ['', ''],
#  ['water consumption', 'previous Nugent Shopping Park'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['Assurance', 'tax costs'],
#  ['', ''],
#  ['hazardous land it', 'existing ground conditions'],
#  ['team', 'capping landfill topper'],
#  ['sizable  proportion', 'still  landfill'],
#  ['reclaimed  that', 'new floor warranties'],
#  ['they', 'FSC certification'],
#  ['we', 'non  -'],
#  ['Installing', 'virgin quality materials'],
#  ['', ''],
#  ['where excavator strike', '1 utility Broadgate'],
#  ['gas', 'neighbouring buildings'],
#  ['pipe', 'method  lessons'],
#  ['', 'Biodiversity Fig'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['We', 'local supply chain'],
#  ['Initiatives', 'employment  training'],
#  ['', ''],
#  ['', '2,861,454 community Fig'],
#  ['we', 'community organisations'],
#  ['space', 'British Land'],
#  ['', ''],
#  ['spend', 'planning consents'],
#  ['significantly  figure', 'significantly  year'],
#  ['', 'Considerate Constructors Fig'],
#  ['Considerate Constructors details', 'Considerate Constructors FY22'],
#  ['Prompt Payment which', 'best Credit Business'],
#  ['Regulations', 'yearly payment practices'],
#  ['', ''],
#  ['', ''],
#  ['risks', 'previous compliance partner'],
#  ['significant  dip', 'new service processes'],
#  ['', ''],
#  ['It', 'related  accidents'],
#  ['absentee rate', 'total  employees'],
#  ['', ''],
#  ['numbers', 'maternity  leave'],
#  ['', ''],
#  ['Turnover rates', '31  March'],
#  ['', ''],
#  ['This', 'same employment level'],
#  ['83  that', 'remuneration'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['Employee training proportion', 'alternative office assessments'],
#  ['other  which', 'other  assessments'],
#  ['Participation levels', 'higher DSE 2023'],
#  ['85  which', '85  %'],
#  ['energy practice data', 'British Land'],
#  ['Energy carbon data', 'common  Retail'],
#  ['Water intensity data', 'common  Retail'],
#  ['', 'common  Retail'],
#  ['where community activity', '102 governance interest'],
#  ['Employee data', 'rather  FTE'],
#  ['first Sustainability which', 'SASB Accounting Standards framework'],
#  ['certain reporting which', 'certain reporting indicators'],
#  ['how  reporting', 'stakeholders'],
#  ['Energy p41 management', 'policies'],
#  ['net Sustainability brief', 'high water stress'],
#  ['office assets', '22 water %'],
#  ['', 'property subsector water management risks'],
#  ['we', 'existing water issues'],
#  ['Pathway transition plan', 'online  2'],
#  ['Sustainability Brief', 'online  3'],
#  ['2 property subsector that', '3 sustainability tenants'],
#  ['leases', 'cost recovery clauses'],
#  ['we', 'efficient  option'],
#  ['efficient Transition equipment', 'Transition gaps'],
#  ['p38 Water Sustainability Brief', 'new  developments'],
#  ['Zero Audits we', 'major  asset'],
#  ['pathways', 'occupiers'],
#  ['Collaboration andcontribution', 'occupiers'],
#  ['Sustainability impacts', 'standing property management forums'],
#  ['tenants', 'own  data'],
#  ['following  section', 'specific data figures'],
#  ['It', '2022 Annual Report'],
#  ['following', '2022 Annual Report'],
#  ['Further  explanations', 'Reporting Criteria'],
#  ['We', 'relevant sustainability strategy'],
#  ['Data', 'Assurance Statement section'],
#  ['Data', 'DNVs section'],
#  ['This', 'year assurance partner'],
#  ['', ''],
#  ['Data', 'transparently  Report'],
#  ['Data', ''],
#  ['Consistent boundaries', 'wherever  time'],
#  ['Assumptions', ''],
#  ['key  data', ''],
#  ['data', 'as  years'],
#  ['where  restatement', 'prior  years'],
#  ['Details', 'relevant Reporting Criteria'],
#  ['columns', ''],
#  ['We', '2022  data'],
#  ['We', 'material  fraud'],
#  ['this', 'Report'],
#  ['', 'joint British ventures'],
#  ['where portfolio we', 'day  facilities'],
#  ['', 'property management offices'],
#  ['2018  we', 'third property management Savills'],
#  ['Broadgate Estates data', 'British Land British data'],
#  ['where  we', 'operational  influence'],
#  ['where British we', 'venture investment fund'],
#  ['managed  portfolio', '84  management'],
#  ['near operating business', 'near operating environment'],
#  ['COVID-19', 'anomalous reporting years'],
#  ['areas', ''],
#  ['', 'relevant Reporting Criteria'],
#  ['', '116  assets'],
#  ['', 'one  industrial'],
#  ['Residential  units', 'one  estate'],
#  ['', '0 36 0 projects'],
#  ['that', 'planning'],
#  ['where Greenhouse we', '100  management'],
#  ['We', 'managed portfolio type'],
#  ['index intensity we', 'retail shopping centres'],
#  ['We', 'financial  year'],
#  ['We', 'joint venture developments'],
#  ['We', 'construction value'],
#  ['small  developments', 'same  contractor'],
#  ['than construction 300,000', 'construction value'],
#  ['2022  data', '31  March'],
#  ['where  data', 'total  assets'],
#  ['Data', 'sale management handover'],
#  ['we', 'data'],
#  ['this', 'Reporting Criteria'],
#  ['developments', 'managed  UK'],
#  ['European Real Estate assets', 'two  years'],
#  ['data', 'like  comparison'],
#  ['Net we', 'zero carbon intensity targets'],
#  ['targets', 'whole building intensity'],
#  ['building energy building data', 'only  offices'],
#  ['landlord', 'retail occupier consumption'],
#  ['Residential  assets', 'scope'],
#  ['property', 'asset type'],
#  ['2 GHG emissions intensities', 'also EPRA Fig'],
#  ['', 'financial GHG Emissions Scope'],
#  ['where intensity they', 'robust denominator data'],
#  ['Floor area', 'refurbishment car park work'],
#  ['scope', 'energy Green Building Council'],
#  ['It', 'natural generator fuel'],
#  ['Carbon intensity', 'management waste consumption'],
#  ['Energy intensity', 'kWh'],
#  ['new  which', '80 % occupancy'],
#  ['new  acquisitions', '80 % occupancy'],
#  ['Energy', 'whole  landlord'],
#  ['Floor areas', 'Net Lettable Areas'],
#  ['2021 floor area figures', 'mid - year valuations'],
#  ['occupier water FTE', 'equivalent  denominator'],
#  ['public  landlord', 'intensity calculations'],
#  ['new  which', '80 % occupancy'],
#  ['new  acquisitions', '80 % occupancy'],
#  ['occupier parts data', 'common parts intensity'],
#  ['Common parts floor area', 'water'],
#  ['Data', 'vacant  space'],
#  ['Footfall', 'Royal Victoria 2020'],
#  ['occupier parts data', 'common parts intensity'],
#  ['Car park spaces', 'water'],
#  ['Data', 'vacant  space'],
#  ['One  asset', 'de minimis rule'],
#  ['negligible  landlord', 'common parts consumption'],
#  ['Footfall', 'Peters Retail 2022'],
#  ['footfall data', 'estimation calculation'],
#  ['Riverside', 'incomplete A1 Retail data'],
#  ['further carbon data', ''],
#  ['common car which', 'common car parks'],
#  ['common parts floor area', 'occupier car park data'],
#  ['Water intensity', 'shopping denominator'],
#  ['landlord', 'energy'],
#  ['2023 water We', 'like water assets'],
#  ['This', 'retail  properties'],
#  ['Properties', 'managed  2020'],
#  ['occupied  floors', 'British Land'],
#  ['financial intensity We', '2 Annual Report'],
#  ['Financial intensity ratio', 'managed Gross Rental portfolio'],
#  ['2 GHG emissions', 'owned fuel vehicles'],
#  ['Gross Rental Income', 'managed 50 million'],
#  ['', ''],
#  ['', 'Refrigerant air conditioning units'],
#  ['', 'British Land'],
#  ['', 'major  year'],
#  ['', 'joint venture funding'],
#  ['', 'Corporate British Land'],
#  ['', 'employee business travel'],
#  ['', 'average Building Services Engineers'],
#  ['full Value details', 'Reporting Fig'],
#  ['', 'Accounting Company Reporting'],
#  ['conversion emissions factors', '2021 Industrial guidelines'],
#  ['Similarly conversion factors', '2019  guidelines'],
#  ['Global Warming Potential', 'Fourth Assessment Report'],
#  ['greenhouse gas emissions', 'carbon dioxide equivalent'],
#  ['This', 'common Greenhouse Gas practice'],
#  ['Emissions', '1 GHG fuels'],
#  ['', ''],
#  ['retail waste visitors', 'managed Land employee assets'],
#  ['', ''],
#  ['SBTi Based Target target', 'baseline GHG 2020'],
#  ['2 GHG emissions', 'Figure'],
#  ['3 intensity numerator', 'managed energy portfolio'],
#  ['where carbon levy', 'Stage'],
#  ['', 'built environment 1st edition'],
#  ['practical construction recalculation', 'practical carbon completion'],
#  ['SBTi A1 A5 emissions', 'construction project'],
#  ['-  rating', 'this'],
#  ['four year project', 'year projects life'],
#  ['-  rating', '1,500  tonnes'],
#  ['Currently GHG emissions', 'expert Simon table'],
#  ['British Land', 'managed  assets'],
#  ['', 'common parts ratios'],
#  ['denominator', 'lettable reporting year'],
#  ['', ''],
#  ['NZC2020Standard', 'embodied carbon carbon'],
#  ['2030 British Land', 'newly fossil fuel installed(additional)sources'],
#  ['which', 'practical carbon completion'],
#  ['Embodied  carbon', 'such life carbon Oneclick'],
#  ['emissions', 'practical  completion'],
#  ['Embodied carbon intensity', 'internal biogenic carbon'],
#  ['', 'square NABERS Performance'],
#  ['modelling', 'currently  offices'],
#  ['that', 'practical  completion'],
#  ['conditions', 'formal  development'],
#  ['', 'significant  development'],
#  ['', 'certain Medium expiries'],
#  ['development', 'renewable  gas'],
#  ['operational PPA that', 'renewable energy generation'],
#  ['subject development project', 'local government carbon taxes'],
#  ['carbon reduction developer', 'offsetting  fund'],
#  ['offsetting  fund', 'raising emissions reductions activities'],
#  ['Committed  projects', 'construction stage'],
#  ['that', 'practical  completion'],
#  ['', ''],
#  ['where carbon levy', 'practical  completion'],
#  ['Embodied Carbon', 'such biogenic carbon'],
#  ['RICS Assessments', 'low carbon materials'],
#  ['', 'Greenhouse gas emissions'],
#  ['2  emissions', 'also electricity Fig'],
#  ['we', 'based  method'],
#  ['We', '2019 track baseline'],
#  ['based  method', 'previous GHG years'],
#  ['based  method', 'average emissions Grid'],
#  ['based emissions Electricity', 'Scope'],
#  ['we', 'that'],
#  ['We', 'remaining mix emissions Table'],
#  ['93  %', 'purchased Renewable Energy Origin'],
#  ['This', 'suppliers assurance provider'],
#  ['REGOs', 'annually  June'],
#  ['85  %', 'Renewable Gas Origin'],
#  ['This', 'suppliers assurance provider'],
#  ['based  emissions', 'office Scope'],
#  ['', 'retail energy assets'],
#  ['we', 'average Building Services Engineers'],
#  ['We', 'future  years'],
#  ['', 'average Building Services Engineers'],
#  ['', 'Product Built Environment'],
#  ['that', 'practical reporting year'],
#  ['new  builds', 'emissions reporting year'],
#  ['new  builds', '2020/21'],
#  ['', 'Land staff commuting'],
#  ['', 'previous employee FTE'],
#  ['Employee commuting', 'small  year'],
#  ['Employee commuting', 'when  home'],
#  ['all British Land that', 'short  period'],
#  ['Employee homeworking Employee data', 'when  home'],
#  ['', 'staff business air'],
#  ['', 'great Great Circle Mapper'],
#  ['Air travel emissions', 'average emission passenger'],
#  ['', 'staff business rail'],
#  ['Where  this', 'two travel management companies'],
#  ['average  kilometres', 'GBP'],
#  ['Emissions', 'Tube travel'],
#  ['', 'staff taxis'],
#  ['This', 'claimed  expenses'],
#  ['', 'retail visitor assets'],
#  ['', 'third visitors travel'],
#  ['office occupier employee', 'office assets'],
#  ['Estimated', 'campus workers transport'],
#  ['', 'retail water consumption assets'],
#  ['where water data', 'therefore  Fig'],
#  ['3  emissions', 'hazardous waste disposal'],
#  ['scope', 'year  fitouts'],
#  ['', 'practical project completion'],
#  ['', ''],
#  ['2  emissions', 'based  method'],
#  ['', ''],
#  ['', ''],
#  ['equivalent emission factors', 'different  GHGs'],
#  ['', ''],
#  ['', ''],
#  ['carbon levy transition Data', 'cumulative  basis'],
#  ['2020 British Land', 'embodied carbon developments'],
#  ['new British Land', '20 carbon offset credits'],
#  ['British  Lands', 'property assets'],
#  ['100 Liverpool Street', 'FY21'],
#  ['St Annes', '1 Square development project'],
#  ['conditions', 'formal  development'],
#  ['Norton Folgate', 'FY21'],
#  ['100  figures', 'equity share'],
#  ['British  Lands', 'embodied % carbon'],
#  ['40  tonne', 'British Land equity share'],
#  ['internal retrofitting that', 'standing energy portfolio'],
#  ['additionally  year', '5 Transition Vehicle'],
#  ['Investment', 'standing  assets'],
#  ['emissions saving Transition costs', 'emissions saving Transition Vehicle'],
#  ['funds', 'further retrofitting projects'],
#  ['savings', 'direct energy initiative'],
#  ['', 'burning occupancy change'],
#  ['kWh energy unit', 'reduced maintenance needs'],
#  ['where landlord consumption', 'High End Residential'],
#  ['partially  we', 'missing  periods'],
#  ['meter  readings', 'common parts consumption'],
#  ['split', 'common  parts'],
#  ['mixed  meters', 'common  parts'],
#  ['', 'managed  offices'],
#  ['split', 'common  parts'],
#  ['Energy use', 'common  parts'],
#  ['Energy use', 'total development consumption'],
#  ['Oil use', ''],
#  ['equipment', 'methods'],
#  ['', '4 oil conversion factors'],
#  ['On  renewables', 'photovoltaic  offices'],
#  ['energy', 'common parts data'],
#  ['Low carbon technologies', '10 Portman Square'],
#  ['heat  output', 'Fig'],
#  ['On  renewables', 'photovoltaic  Whiteley'],
#  ['Energy', 'common parts energy grid'],
#  ['Energy', 'Old grid'],
#  ['electricity', 'retail  grid'],
#  ['Proportion', 'purchased  electricity'],
#  ['Proportion', 'Total electricity consumption'],
#  ['calorific  value', 'fuel kWh'],
#  ['we', 'flexible workspace reporting'],
#  ['Generation', 'renewable carbon sources'],
#  ['', 'Environmental  certifications'],
#  ['it', 'higher acceptableto rating'],
#  ['certification', 'same  building'],
#  ['default selection', 'reporting'],
#  ['existing development it', 'previous development certificates rating'],
#  ['many development certifications', 'rather  other'],
#  ['Code', 'new Sustainable developments'],
#  ['current  certificates', ''],
#  ['where  requirement', 'existing planning consents'],
#  ['we', 'residential Home Quality Mark'],
#  ['assessed design these', 'certified  assessors'],
#  ['final  which', 'post completion'],
#  ['Final building certifications', 'final  Assetssection'],
#  ['We', 'appropriate  development'],
#  ['We', '3 BREEAM Residential'],
#  ['Canada we', 'local authoritys target rating'],
#  ['major BREEAM design developments', 'In BREEAM Use'],
#  ['table', 'financial floor reporting'],
#  ['annual  updates', 'financial  reporting'],
#  ['floor areas', 'property valuations'],
#  ['Parks floor areas', 'Gross Internal Area'],
#  ['floor areas', '- year valuation reports'],
#  ['financial floor which', 'sustainability reporting'],
#  ['Linked British Land', 'revolving sustainability portfolio'],
#  ['facility', 'agreed sustainability KPIs'],
#  ['two sustainability KPIs', 'Very BREEAM Good'],
#  ['residential data properties', 'scope'],
#  ['', ''],
#  ['A which', 'units'],
#  ['Assets', 'currently  EPC'],
#  ['Assets', 'currently  scope'],
#  ['which', 'managed  scope'],
#  ['which', 'scope'],
#  ['that', 'retail  assets'],
#  ['retail  units', 'office campuses'],
#  ['office sector', 'also life sciences'],
#  ['Retail  sector', 'retail  assets'],
#  ['It', 'retail  property'],
#  ['where  EPC', 'office  sectors'],
#  ['which', 'future  developments'],
#  ['Overview Water', 'Fig'],
#  ['insufficient building metering', 'whole building use'],
#  ['we', 'common parts use'],
#  ['water', 'on borehole harvesting'],
#  ['partially  we', 'missing  periods'],
#  ['Borehole water', 'common  Meadowhall'],
#  ['borehole water', 'borehole plant'],
#  ['water', ''],
#  ['', ''],
#  ['Occupier  waste', 'us'],
#  ['Waste', 'recycling Material Recovery figures'],
#  ['MRF output', 'average site performance'],
#  ['Waste data', 'operational  knowledge'],
#  ['', 'Excavation Non categories'],
#  ['that', 'location'],
#  ['longer waste we', 'rather  waste'],
#  ['Landfill tax costs', ''],
#  ['Waste data', 'operational  knowledge'],
#  ['', ''],
#  ['Overview Physical', 'Fig'],
#  ['Significant  incidents', 'local  authority'],
#  ['proportion', 'managed ISO portfolio'],
#  ['where construction we', '0 RIBA 6'],
#  ['assets', '100 year return period'],
#  ['expert Willis Towers which', 'Munich RE NATHAN'],
#  ['Exposure', 'consideration oflocal flood defences'],
#  ['proportion', 'high asset value'],
#  ['Resource efficiency metrics', 'Figs'],
#  ['Energy sources metrics', 'Figs'],
#  ['Portfolio', 'green building Fig'],
#  ['Proportion', 'total BREEAM GRI'],
#  ['', ''],
#  ['Information', 'formal ecologists reports'],
#  ['Reporting', 'net renovation Fig'],
#  ['net  improvements', 'double  counting'],
#  ['reporting  metrics', 'Sustainability result'],
#  ['British  Land', 'sites'],
#  ['floorarea)where community implementedis', 'alldirectly floor developments'],
#  ['that', 'strategic community investment programme'],
#  ['They', 'pilot initiatives'],
#  ['multiple  it', 'site'],
#  ['where  outcomes', 'same reporting Fig'],
#  ['', 'initiatives figures'],
#  ['related Group initiative', 'once  site'],
#  ['initiatives', 'such Fort Kinnaird'],
#  ['Ourapprenticeship which', 'local British communities'],
#  ['', 'off property developments'],
#  ['', 'Group offices'],
#  ['', 'graduate Group offices'],
#  ['employment  outcomes', 'employment'],
#  ['related  who', 'meaningful  programmes'],
#  ['who', 'benefitedfrom programme'],
#  ['employment who', 'direct throughBright Lights'],
#  ['', 'employmentrelated subset support'],
#  ['related  who', 'Bright Lights programme'],
#  ['also  who', 'jobs throughjobs places'],
#  ['FY20  figures', 'new table format'],
#  ['that', 'initiative'],
#  ['education programme', 'further  education'],
#  ['It', 'related  projects'],
#  ['', ''],
#  ['', 'working covers hours'],
#  ['', 'In British cost'],
#  ['This', 'other benefits payroll'],
#  ['hourly  costs', 'accordingly share incentive costs'],
#  ['retail Broadgate Estates those', 'average Group salary'],
#  ['Separate  values', 'retail our2017 Sustainability Accounts'],
#  ['Supplier time', '5 pension contributions'],
#  ['Direct beneficiary numbers', 'community activity'],
#  ['We', 'reasonable  which'],
#  ['', 'direct ourcampusCommunity contributions'],
#  ['where working it', 'communityinvestment  programme'],
#  ['directly community investment we',
#   'ofuniqueindividualsthatdirectly British Land'],
#  ['direct beneficiary beneficiaries', 'beneficiary which'],
#  ['Examples', 'local British Land'],
#  ['thatare', 'contribution'],
#  ['direct  activity', 'joint venture partner'],
#  ['fully site teams', 'other  sources'],
#  ['where  it', 'total  beneficiaries'],
#  ['Total community initiatives', 'FY21'],
#  ['which', ''],
#  ['We', '25  places'],
#  ['local impact positivesand', 'places'],
#  ['reports', 'coming reviewedat years'],
#  ['space donation term space value', 'long B4SI methodology'],
#  ['reduced  difference', 'community benefit'],
#  ['equivalent  figures', 'previous  years'],
#  ['', 'volunteeringdata'],
#  ['employees', 'byBroadgate Estates May'],
#  ['', 'broader community organisations'],
#  ['detailed  percentage', 'four reporting period'],
#  ['Expertvolunteering(%', 'based  volunteering'],
#  ['This', 'strategic school issues'],
#  ['working  itis', 'withour community investment programme'],
#  ['Expert volunteering', 'industry Commerce'],
#  ['This', 'affordable design fees'],
#  ['', 'regardless land ownership'],
#  ['', 'local ownership authorities'],
#  ['', 'general community investment programme'],
#  ['', 'PR fees'],
#  ['', 'legal  fees'],
#  ['Figures', 'financial  year'],
#  ['wider construction data', 'monthly construction period'],
#  ['', 'affordable Regents Place'],
#  ['Scope', 'year'],
#  ['', 'Overview Responsible business Considerate Fig'],
#  ['5  points', 'available  innovation'],
#  ['target score', 'projects'],
#  ['', ''],
#  ['furloughed  hours', 'reporting'],
#  ['Spend data', 'entire project spend'],
#  ['', 'permanent British Land development'],
#  ['where British S106', 'place'],
#  ['Local  branches', 'defined  area'],
#  ['that', 'suppliers'],
#  ['This', '250  people'],
#  ['', ''],
#  ['We', 'time  invoices'],
#  ['data', 'third property management portfolio'],
#  ['Corporate  data', 'disputes'],
#  ['', ''],
#  ['development project that', 'Health  Executive'],
#  ['2013 Dangerous Occurrences which', '1995  Regulations'],
#  ['unintended  which', 'physical  injury'],
#  ['This', 'consensual  work'],
#  ['workersmust  they', 'arenot  reportable'],
#  ['specified  injury', 'other  fingers'],
#  ['', ''],
#  ['', 'permanent  sight'],
#  ['', 'crush brain'],
#  ['which', 'significant  eyes'],
#  ['', 'hospital treatment'],
#  ['', 'head injury'],
#  ['enclosed  which', '24  hours'],
#  ['Overview that', 'seven  days'],
#  ['person', 'directly  treatment'],
#  ['ill  it', 'persons work activity'],
#  ['', 'electrical pressure scaffolding'],
#  ['', ''],
#  ['where British Land', 'responsibility'],
#  ['where British Land', 'management responsibility'],
#  ['they', 'date'],
#  ['', ''],
#  ['Thie', 'British Land public'],
#  ['health Group incidents', 'British employees'],
#  ['This', 'permanent  employees'],
#  ['Injury Incidence Rates', 'x office 100,000'],
#  ['Data', 'average office period'],
#  ['reporting we', 'reported FTE data'],
#  ['', 'total reportable period'],
#  ['Group offices', 'total British Land 100,000'],
#  ['', 'dangerous  occurrences'],
#  ['reportable  accidents', '100,000 Land hours'],
#  ['Rates', 'British Land employees'],
#  ['', ''],
#  ['100,000 absent incident that', 'Number RIDDOR hours'],
#  ['average security hours', 'days  month'],
#  ['', ''],
#  ['', 'managed  portfolio'],
#  ['Incidents', 'HSE Prohibition Notices'],
#  ['key group metrics', 'annual  audit'],
#  ['90 management %', 'annual  assessment'],
#  ['which', 'control'],
#  ['Statutory document we', 'own  site'],
#  ['This', 'lift inspection reports'],
#  ['risk assessment audit', 'two  weeks'],
#  ['risk assessment', 'other scoring BSI'],
#  ['Developments Incidents', 'HSE Prohibition notices'],
#  ['It', 'related  accidents'],
#  ['absentee rate', 'total  employees'],
#  ['Lost day rate', 'related  accidents'],
#  ['100,000 Lost Number', 'hours'],
#  ['employee', 'day  work'],
#  ['', ''],
#  ['', 'maternity  leave'],
#  ['otherwise  data', 'internships'],
#  ['Employment type', 'Table'],
#  ['Permanent term who', ''],
#  ['Where  this', '- Executive Non - Directors'],
#  ['Committee level I', 'Land Leadership Team'],
#  ['', 'Executive Directors'],
#  ['', ''],
#  ['', ''],
#  ['permanent  who', 'even  year'],
#  ['executive  directors', 'new  year'],
#  ['', ''],
#  ['who', 'fixed term employment contract'],
#  ['Turnover rates', 'total  Fig'],
#  ['Proportion', 'total employment year'],
#  ['executive  directors', 'year'],
#  ['Figures', 'salary'],
#  ['Remuneration', 'schemes'],
#  ['when  data', '31  March'],
#  ['Salary', 'FTE data'],
#  ['executive  directors', 'permanently British Land'],
#  ['', ''],
#  ['previous pay gap We', '2023 pay government'],
#  ['employees', '2022  data'],
#  ['', ''],
#  ['mandatory ethnicity pay gap', 'same  methodology'],
#  ['2022  who', 'voluntarily  data'],
#  ['bonus', '2022 bonus calculations'],
#  ['small population employees', 'Black ethnicity pay gap'],
#  ['', ''],
#  ['fourth  we', 'median CEO pay ratio'],
#  ['CEO pay data', 'other term compensation'],
#  ['It', '2022 Annual Report'],
#  ['A', '2021 UK March'],
#  ['ethnicity data', 'human resources resources'],
#  ['data', 'voluntarily  employees'],
#  ['reporting we', 'Statistics ethnicity Table'],
#  ['voluntarily HR they', 'LGBT+'],
#  ['data', 'executive  directors'],
#  ['voluntarily HR they', 'long term condition'],
#  ['when  data', 'executive  directors'],
#  ['53 Social Mobility Proportion', 'selective state run'],
#  ['data', 'executive  directors'],
#  ['', ''],
#  ['new  who', 'financial  year'],
#  ['Anti - corruption', ''],
#  ['employees', 'British Land Group'],
#  ['data', 'executive  directors'],
#  ['', ''],
#  ['proportion', 'performance review year'],
#  ['data', 'executive  directors'],
#  ['Land Company PLC', 'Land assurance Estates'],
#  ['calculations', 'applicable pay gap criteria'],
#  ['scope', '5 snapshot April'],
#  ['male Korn Ferry', 'pay gap calculations'],
#  ['pay gap calculations', 'same  basis'],
#  ['final review observations', 'British Land'],
#  ['these', 'appropriate British Land'],
#  ['independent British which', 'work'],
#  ['Korn Ferry policies', 'objective  advice'],
#  ['Pay  who', 'relevant  regulations'],
#  ['assurance engagements', 'such data errors'],
#  ['data', 'good British faith'],
#  ['expressly  person', 'report'],
#  ['Land Company Plc', '2022 reporting year'],
#  ['Selected Information', 'material  Criteria'],
#  ['inherent Limited Assurance limitations', 'overleaf'],
#  ['observations', 'separate British Lands Management'],
#  ['scope', '2022 Selected Report'],
#  ['summary', '1'],
#  ['SBTi', 'greenhouse gas intensity'],
#  ['', ''],
#  ['', ''],
#  ['', 'Like  total'],
#  ['', ''],
#  ['', 'Total greenhouse gas gas'],
#  ['', 'energy target'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', 'Like  like'],
#  ['', 'Total  14'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', 'Like  like'],
#  ['', 'water target'],
#  ['', ''],
#  ['', 'managed waste portfolio'],
#  ['', ''],
#  ['where  others', 'ethical independence requirements'],
#  ['engagement work', 'independent sustainability assurance professionals'],
#  ['DNV', 'none British work'],
#  ['disciplinary  team', 'environmental assurance experience'],
#  ['British Lands Reporting which', '66  Report'],
#  ['other  that', 'previous reporting periods'],
#  ['Overview Standard Overview We', 'Auditing Historical Financial Board'],
#  ['we', 'limited assurance assurance'],
#  ['DNV', 'ethical quality requirements'],
#  ['reasonable assurance engagement', 'substantially  assurance'],
#  ['risk', 'very  low'],
#  ['appropriately  evidence', 'remote Group level'],
#  ['DNV', 'Selected Group level Criteria'],
#  ['Inherent assurance engagements', 'selective  errors'],
#  ['financial  data', 'such  data'],
#  ['measurement techniques', 'different  entities'],
#  ['data', 'good British faith'],
#  ['expressly  person', 'Limited Assurance Report'],
#  ['internal Selected that', 'established Selected Report'],
#  ['Selected  Information', 'limited assurance work'],
#  ['We', 'Report'],
#  ['global training customers', 'sustainable business performance']]

# %%
def get_relation(sent):
    doc = nlp(sent)
    
    # Matcher class object 
    matcher = Matcher(nlp.vocab)
    
    #define the pattern 
    pattern = [{'DEP':'ROOT'}, {'DEP':'prep','OP':"?"},
               {'DEP':'agent','OP':"?"},  {'POS':'ADJ','OP':"?"}] 

    matcher.add("matching_1",[pattern]) 

    matches = matcher(doc)
    k = len(matches) - 1

    span = doc[matches[k][1]:matches[k][2]] 

    return(span.text)

# %%
relations = []
for i in tqdm(df['words']):
    relations.append(get_relation(i))
# Out:
#   0%|          | 0/988 [00:00<?, ?it/s]

# %%
relations
# Out:
# ['done',
#  'be',
#  'celebrate',
#  'face',
#  'means',
#  'continued',
#  'completed',
#  'is',
#  'underlined',
#  'completed',
#  'be',
#  'were delighted',
#  'allow',
#  'benefitted',
#  'is',
#  'marked',
#  'done',
#  'like',
#  'be',
#  'Prefer',
#  'do',
#  'been',
#  'completed',
#  'completed',
#  'Awarded',
#  'pipeline',
#  'Whole',
#  'Impacted by',
#  'launched',
#  'complexes',
#  'celebrate',
#  'Launched',
#  'member of',
#  'Launched',
#  'Signatory to',
#  'projects',
#  'system',
#  'assessments',
#  'established',
#  'works',
#  'Supported',
#  'Launched',
#  'Started',
#  'Launched',
#  'Launched',
#  'Worked with',
#  'Launched',
#  'levy of',
#  'Launched',
#  'validated',
#  'sets',
#  'offset embodied',
#  'Overview',
#  'demonstrate',
#  'is',
#  'means',
#  'work',
#  'Connect',
#  'are',
#  'been on',
#  'advocate responsible',
#  'set',
#  'rated',
#  'upgraded',
#  'pursued',
#  'built',
#  'pursuing',
#  'increase',
#  'created',
#  'use',
#  'Carbon',
#  'have',
#  'set',
#  'delivered on',
#  'committed to',
#  'adopted',
#  'benchmark',
#  'helping',
#  'study',
#  'assessed with most',
#  'rebuilt',
#  'using',
#  'expect',
#  'adding',
#  'is',
#  'means',
#  'using',
#  'includes',
#  'using',
#  'are in',
#  'are for embodied',
#  'prioritise',
#  'offset',
#  'use',
#  'works',
#  'is',
#  'Supporting',
#  'was',
#  'sets',
#  'focus on renewable',
#  'initiatives New',
#  'illustrates',
#  'are',
#  'is',
#  'require',
#  'completed',
#  'shown over',
#  'built out',
#  'play',
#  'supplement',
#  'have',
#  'are',
#  'exploring',
#  'completed net',
#  'identified',
#  'delivered',
#  'installed on',
#  'cut',
#  'installing dedicated',
#  'LED',
#  'deliver',
#  'improve',
#  'means',
#  'approach to',
#  'focuses on',
#  'Connect',
#  'is',
#  'worked with',
#  'agree',
#  'pledged',
#  'support educational',
#  'delivered',
#  'ranged from primary',
#  'continued',
#  'reached',
#  'support local',
#  'refocused',
#  'run across',
#  'reached',
#  'included',
#  'rises to',
#  'support local',
#  'provided affordable',
#  'includes affordable',
#  'launched',
#  'attracted',
#  'won',
#  'create',
#  'develop',
#  'supported',
#  'are on',
#  'targeting',
#  'continue',
#  'be',
#  'supports',
#  'focuses on',
#  'goes',
#  'seen on',
#  'donated',
#  'donated',
#  'pledged',
#  'rolled',
#  'Cost of',
#  'focus many',
#  'focusing on',
#  'appreciate',
#  'brought into',
#  'continues',
#  'engaged',
#  'provide',
#  'connecting',
#  'unveiled',
#  'were among',
#  'volunteered',
#  'continue',
#  'partnering',
#  'engaged',
#  'completed',
#  'worked',
#  'continue',
#  'aim',
#  'supported',
#  'provided low',
#  'supports',
#  'working',
#  'people',
#  'providing',
#  'included',
#  'provided',
#  'are',
#  'offer',
#  'enhance',
#  'is',
#  'host',
#  'working on',
#  'is',
#  'was',
#  'is',
#  'enabled',
#  'supported',
#  'is on',
#  'worked',
#  'identified',
#  'was',
#  'thank',
#  'been able',
#  'People in',
#  'gone from',
#  'advocate responsible',
#  'are Responsible',
#  'are',
#  'invest in',
#  'apply',
#  'advocate responsible',
#  'set',
#  'Invest in',
#  'invested',
#  'completed',
#  'run',
#  'ran',
#  'included',
#  'was',
#  'emerged with',
#  'highlighted',
#  'having detailed',
#  'Provide',
#  'accredited to',
#  'need',
#  's',
#  'support',
#  'launched',
#  'sets',
#  'improve',
#  'ensure',
#  'work with',
#  'taken',
#  'continue',
#  'include',
#  'NextGen',
#  'exceeded',
#  'fulfilled',
#  'was',
#  'plays',
#  'sets',
#  'is mandatory',
#  'pay',
#  'accredited',
#  'found on',
#  'been',
#  'settled within',
#  'introduced',
#  'launched',
#  'uphold',
#  'provided anti',
#  'undertook independent',
#  'included human',
#  'prioritised',
#  'scored above',
#  'continue',
#  'are delighted',
#  'confirm',
#  'Overview',
#  'see',
#  'assured since',
#  'affected',
#  'delivered',
#  'emissions',
#  'offset',
#  'include',
#  'are',
#  'Exploring',
#  'undertaken',
#  'be available',
#  'emissions',
#  'emissions',
#  'assumes regular',
#  'show',
#  'include',
#  'based',
#  'emissions',
#  'emissions',
#  'dropped to',
#  'reduced from last',
#  'emissions',
#  'emissions',
#  'assumes regular',
#  'show',
#  'include',
#  'emissions',
#  'Fig',
#  'delivered',
#  'baseline',
#  'emissions',
#  'are provisional',
#  'disclosed at',
#  'excludes',
#  'included',
#  'expected',
#  'auditsassessed major',
#  'use',
#  'dropped to',
#  'is',
#  'Fig',
#  'Offices',
#  'Fig',
#  'was from renewable',
#  'dropped to',
#  'reduced from last',
#  'Overview Environmental',
#  'exclude residential',
#  'continues',
#  'completed',
#  'piloted',
#  'understood upfront',
#  'served as',
#  'certifications',
#  'expect',
#  'are',
#  'use',
#  'Fig',
#  'returned to familiar',
#  'Fig',
#  'Waste',
#  'Fig',
#  'Fig',
#  'excludes',
#  'Fig',
#  'discovered',
#  'reviewed various',
#  'had',
#  'opted',
#  'hold',
#  'is important',
#  'keeps good',
#  'Fig',
#  'happened at',
#  'evacuated by',
#  'repaired by',
#  'Overview',
#  'Fig',
#  'Fig',
#  'Fig',
#  'work in',
#  'include pre',
#  'Contributions',
#  'time',
#  'reporting on',
#  'reflects',
#  'Fig',
#  'associated with',
#  'varies',
#  'Overview',
#  'found',
#  'is',
#  'introduce',
#  'Health',
#  'Fig',
#  'classed as substantial',
#  'are',
#  'Fig',
#  'includes',
#  'calculated as total',
#  'Fig',
#  'include',
#  'Fig',
#  'based on',
#  'Fig',
#  'is',
#  'see',
#  'Fig',
#  'Fig',
#  'Fig',
#  'Fig',
#  'training',
#  'Fig',
#  'fell',
#  'were',
#  'expecting',
#  'is',
#  'covers',
#  'covers whole',
#  'covers whole',
#  'comprises net',
#  'engagement',
#  'restated',
#  'is British',
#  'highlights',
#  'continue',
#  'obtained',
#  'found in',
#  'account for',
#  'Figure',
#  'undertook',
#  'is available',
#  'is available',
#  'table',
#  'include',
#  'engage with',
#  'use',
#  'requires',
#  'have',
#  'arebeing',
#  'is essential',
#  'are',
#  'have',
#  'provides specific',
#  'sets',
#  'sets',
#  'provided in',
#  'report',
#  'reported',
#  'included in',
#  'is',
#  'notes',
#  'presented',
#  'is',
#  'used',
#  'stated',
#  'assured',
#  'aim',
#  'restate',
#  'provided in',
#  'mean',
#  'engaged',
#  'designed',
#  'stated',
#  'Assets under',
#  'properties',
#  'floors',
#  'brought',
#  'included within',
#  'report',
#  'includes',
#  'comprises',
#  'presented',
#  'had',
#  'impacted',
#  'refer to',
#  'Residential3',
#  'Includes',
#  'reported',
#  'Table',
#  'changed in',
#  'are',
#  'report much',
#  'categorise retail',
#  'report on committed',
#  'information for joint',
#  'report',
#  'reported as small',
#  'reported',
#  'covers',
#  'show',
#  'reported from',
#  'aim',
#  'make',
#  'are in',
#  'report',
#  'excluded from',
#  'monitor',
#  'based on',
#  'is',
#  'covers',
#  'excluded from',
#  'classified',
#  'reported in',
#  'see',
#  'included in',
#  'vary slightly',
#  'is in',
#  'includes',
#  'includes',
#  'calculated',
#  'managed by',
#  'reached',
#  'relate to',
#  'relate to Net',
#  'sourced from mid',
#  'used as',
#  'excluded from',
#  'managed by',
#  'reached',
#  'reported',
#  'used as',
#  'excluded',
#  'estimated for',
#  'reported',
#  'used as',
#  'excluded',
#  'excluded from',
#  'has',
#  'estimated for',
#  'included in',
#  'excluded for',
#  'reported',
#  'have external',
#  'is',
#  'reported for',
#  'contain',
#  'report',
#  'encompasses',
#  'been in',
#  'relates to',
#  'publish',
#  'expresses absolute',
#  'Scope',
#  'comprises',
#  'Figs',
#  'loss from',
#  'Waste',
#  'Developments',
#  'Includes',
#  'electricity in',
#  'use by British',
#  'Estimated based',
#  'found in',
#  'Edition',
#  'sourced from',
#  'sourced from',
#  'sourced from',
#  'reported as',
#  'includes',
#  'grouped by',
#  'Scope',
#  'Scope',
#  'Fig',
#  'reported by',
#  'total',
#  'is',
#  'Includes',
#  'assessment for',
#  'Actual',
#  'are pro',
#  'adjusted',
#  'estimated',
#  'reduced from',
#  'emissions',
#  'intends',
#  'Offices',
#  'is',
#  'Fig',
#  'ourapproach includesthe',
#  'incorporate theadditional',
#  'required',
#  'calculated by',
#  'have',
#  'embodied',
#  'efficiency',
#  'is',
#  'indicates',
#  'refers to',
#  'refers to',
#  'is',
#  'indicates',
#  'forecasted operational',
#  'indicates',
#  'is',
#  'is',
#  'refer to',
#  'refer to',
#  'Fig',
#  'required',
#  'calculated by',
#  'produced at',
#  'Overview',
#  'managed',
#  'reported',
#  'use',
#  'used for',
#  'reflects',
#  'use',
#  'reflects',
#  'use',
#  'backed by Renewable',
#  'based on',
#  'retired',
#  'backed by Renewable',
#  'based on',
#  'reported in',
#  'Procured',
#  'estimated retail',
#  'intend',
#  'Estimated based',
#  'emissions new',
#  'represent',
#  'acquired',
#  'acquired',
#  'commuting',
#  'Estimated',
#  'reported for',
#  'required',
#  'reported for',
#  'required',
#  'travel',
#  'distances from',
#  'based',
#  'travel',
#  'calculated',
#  'estimated',
#  'excluded',
#  'mileage',
#  'calculated',
#  'travel',
#  'Estimated based',
#  'commuting',
#  'travelled',
#  'instituted',
#  'reported for',
#  'include',
#  'limited to major',
#  'Assessed in',
#  'Fig',
#  'reported according',
#  'Fig',
#  'Fig',
#  'shows',
#  'Scope',
#  'Fig',
#  'reported on',
#  'applied',
#  'earmark',
#  'refers to',
#  'are',
#  'offset until',
#  'refer to',
#  'are',
#  'adjusted',
#  'matched by',
#  'directed into',
#  'is',
#  'invest',
#  'saving',
#  'repaid to',
#  'invested in further',
#  'based on',
#  'savings',
#  'savings',
#  'consists of',
#  'used',
#  'deducted from',
#  'estimated',
#  'reported in common',
#  'is sub',
#  'estimated',
#  'included in common',
#  'deducted from total',
#  'measured',
#  'estimated based',
#  'See',
#  'Square',
#  'used on',
#  'include',
#  'reported in',
#  'includes photovoltaic',
#  'consumed on',
#  'exported to',
#  'assumed',
#  'calculated as Total',
#  'calculated as',
#  'used for',
#  'included',
#  'relates to',
#  'Overview Environmental',
#  'is',
#  'applied for',
#  'is',
#  'permitted',
#  'seen as',
#  'withdrawn in',
#  'are',
#  'used',
#  'reporting on residential',
#  'provided by',
#  'is possible',
#  'reported',
#  'aim',
#  'target',
#  'have',
#  'hold',
#  'uses',
#  'undertaken with',
#  'sourced from',
#  'represent',
#  'sourced from mid',
#  'Existence of',
#  'completed',
#  'includes',
#  'are',
#  'use',
#  'Fig',
#  'Includes',
#  'have',
#  'included in',
#  'included in',
#  'excluded from',
#  'includes',
#  'included',
#  'includes',
#  'includes',
#  'includes',
#  'includes',
#  'are',
#  'use',
#  'report whole',
#  'report common',
#  'Note',
#  'used',
#  'relates',
#  'used',
#  'reported',
#  'Fig',
#  'reported',
#  'sent to',
#  'calculated at',
#  'estimated for',
#  'split into',
#  'refer to',
#  'reporting',
#  'are indicative',
#  'See',
#  'Fig',
#  'risks',
#  'involve',
#  'is at',
#  'developments',
#  'cover',
#  'assessed through expert',
#  'incorporates',
#  'calculated as',
#  'sourced from',
#  'sourced from',
#  'sourced from',
#  'is',
#  'Fig',
#  'based on formal',
#  'removed from',
#  'is',
#  'included in',
#  'is',
#  'reported in',
#  'defined as',
#  'tend',
#  'counted per',
#  'reported',
#  'Excluded from',
#  'counted',
#  'include',
#  'programme',
#  'Overview',
#  'Apprenticeships at',
#  'People on graduate',
#  'included',
#  'definepeople',
#  'completed',
#  'supported into',
#  'Dataforpeoplesupported into',
#  'People',
#  'excludesbeneficiaries',
#  'beenredistributed',
#  'includes',
#  'covers',
#  'includes',
#  'CashcontributionsexcludeVAT',
#  'time',
#  'contributions',
#  'covers',
#  'calculated for',
#  'basedat',
#  'attributed to retail',
#  'arevalued according',
#  'provided by',
#  'estimate',
#  'investment',
#  'time',
#  'look',
#  'Overview',
#  'include general',
#  'proportionateto',
#  'log',
#  'led by',
#  'record',
#  'were',
#  'includes',
#  'commissionedplace',
#  'assessmentswith local',
#  'provide baseline',
#  'is outside',
#  'reported as',
#  'used',
#  'From',
#  'employed byBroadgate',
#  'headcount',
#  'undertaken during',
#  'is',
#  'includes',
#  'includes',
#  'include',
#  'includes',
#  'space',
#  'Accessibility',
#  'facilities',
#  'consultation',
#  'Expenses',
#  'based on',
#  'estimated by',
#  'contributions',
#  'covers',
#  'constructors',
#  'changed from',
#  'remains',
#  'Fig',
#  'excluded',
#  'is cumulative',
#  'Spend within',
#  'defined as',
#  'included',
#  'Spend with',
#  'defined as',
#  'Fig',
#  'report',
#  'excludes',
#  'normalised',
#  'Health',
#  'Land',
#  'set',
#  'is',
#  'includes',
#  'reported',
#  'asRIDDORincidents in',
#  'Amputations',
#  'injury likely',
#  'injury to',
#  'causes significant',
#  'scalping',
#  'loss of',
#  'requires',
#  'Accidents',
#  'Accidents to',
#  'required',
#  'reportable',
#  'Figs',
#  'includes',
#  'includes',
#  'grouped by',
#  'Fig',
#  'includes',
#  'reported to',
#  'covers',
#  'referred to',
#  'calculated as',
#  'accept',
#  'accidents over',
#  'total reportable',
#  'include dangerous',
#  'calculated',
#  'calculated',
#  'Fig',
#  'refers to',
#  'estimated for',
#  'Fig',
#  'are',
#  'served',
#  'are',
#  'target',
#  'monitor',
#  'require',
#  'includes',
#  'acquired',
#  'based on',
#  'served',
#  'includes',
#  'calculated as total',
#  'covers',
#  'calculated as',
#  'calculated from',
#  'Figs',
#  'Includes',
#  'excludes',
#  'defined',
#  'Table',
#  'includes',
#  'levels',
#  'employees',
#  'employees',
#  'Fig',
#  'includes permanent',
#  'included in',
#  'Fig',
#  'excluded',
#  'based on',
#  'based on',
#  'included in',
#  'include',
#  'included',
#  'based on',
#  'been pro',
#  'included',
#  'Fig',
#  'found on',
#  'employed on',
#  'Fig',
#  'followed',
#  'employed on',
#  'included in',
#  'split into',
#  'Fig',
#  'is',
#  'includes',
#  'is consistent',
#  'showing full',
#  'captured through',
#  'given',
#  'use',
#  'disclosed',
#  'excludes non',
#  'Fig',
#  'excludes non',
#  'were',
#  'excludes non',
#  'Fig',
#  'excludes new',
#  'are mandatory',
#  'complete',
#  'excludes non',
#  'Fig',
#  'calculated for',
#  'excludes non',
#  'engaged',
#  'come to',
#  'based on',
#  'asked',
#  'reviewed on',
#  'raised with',
#  'confirms',
#  'is',
#  'designed',
#  'carried',
#  'are subject',
#  'relies on',
#  'disclaims',
#  'commissioned',
#  'come to',
#  'relates',
#  'raised in',
#  'restricted to',
#  'listed below',
#  'targets',
#  'Developments',
#  'Location',
#  'emissions',
#  'Indirect',
#  'emissions by',
#  'Building',
#  'levy',
#  'consumption',
#  'consumption',
#  'electricity',
#  'energy',
#  'ratings',
#  'Certificates',
#  'consumption',
#  'consumption',
#  'Building',
#  'portfolio',
#  'Like for',
#  'developments',
#  'established',
#  'carried',
#  'held other',
#  'consisted of',
#  'used British',
#  'performed',
#  'performed',
#  'requires',
#  'applies',
#  'vary in',
#  'planned',
#  'included',
#  'were free',
#  'are subject',
#  'be subject',
#  'result in different',
#  'relies on',
#  'disclaims',
#  'have sole',
#  'is',
#  'been responsible',
#  'is']

# %%
dict_df = {'entities': entities, 'relations': relations}

# %%
df = pd.DataFrame(dict_df)

# %%
df
# Out:
#                                               entities         relations
# 0       [challenging Annual teams, local  communities]              done
# 1                      [new  dedication, new  horizon]                be
# 2                                 [more  we, business]         celebrate
# 3                     [living impact, 19  communities]              face
# 4                      [progressing, positive  places]             means
# ..                                                 ...               ...
# 983      [expressly  person, Limited Assurance Report]         disclaims
# 984  [internal Selected that, established Selected ...         have sole
# 985    [Selected  Information, limited assurance work]                is
# 986                                       [We, Report]  been responsible
# 987  [global training customers, sustainable busine...                is
#
# [988 rows x 2 columns]

# %%
df['entities'].str.contains('local')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 983   NaN
# 984   NaN
# 985   NaN
# 986   NaN
# 987   NaN
# Name: entities, Length: 988, dtype: float64

# %% [markdown]
# ### KeyBERT

# %%
bert=KeyBERT()
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
df
# Out:
#                                               entities         relations
# 0       [challenging Annual teams, local  communities]              done
# 1                      [new  dedication, new  horizon]                be
# 2                                 [more  we, business]         celebrate
# 3                     [living impact, 19  communities]              face
# 4                      [progressing, positive  places]             means
# ..                                                 ...               ...
# 983      [expressly  person, Limited Assurance Report]         disclaims
# 984  [internal Selected that, established Selected ...         have sole
# 985    [Selected  Information, limited assurance work]                is
# 986                                       [We, Report]  been responsible
# 987  [global training customers, sustainable busine...                is
#
# [988 rows x 2 columns]

# %%
kw = []
for i in tqdm(df_w['words']):
    kw.append(bert.extract_keywords(i, keyphrase_ngram_range=(3,3), stop_words='english'))
# Out:
#   0%|          | 0/988 [00:00<?, ?it/s]

# %%
df_w
# Out:
#                                                  words  \
# 0    Our ESG journey Our 2030 commitments Performan...
# 1    As we go into a new year, with new uncertainti...
# 2    Introduction This year we celebrate 20 years o...
# 3    The climate emergency is high on everyones age...
# 4    This means progressing our pathway to net zero...
# ..                                                 ...
# 983  DNV expressly disclaims any liability or co-re...
# 984  Responsibilities of the Board of Directors of ...
# 985  Our responsibility is to plan and perform our ...
# 986  We have not been responsible for the preparati...
# 987  DNV Business Assurance DNV Business Assurance ...
#
#                                                     kw
# 0    [(kpis, 0.4649), (esg, 0.3891), (tcfd, 0.3596)...
# 1    [(dedication, 0.467), (uncertainties, 0.3364),...
# 2    [(sustainability, 0.6341), (environmental, 0.3...
# 3    [(covid, 0.4679), (climate, 0.4357), (crisis, ...
# 4    [(pathway, 0.2842), (important, 0.2683), (posi...
# ..                                                 ...
# 983  [(disclaims, 0.5645), (liability, 0.518), (dnv...
# 984  [(responsibilities, 0.436), (directors, 0.4093...
# 985  [(responsibility, 0.4778), (assurance, 0.4198)...
# 986  [(report, 0.338), (responsible, 0.2899), (prep...
# 987  [(dnv, 0.584), (certification, 0.3591), (assur...
#
# [988 rows x 2 columns]

# %%
kw
# Out:
# [[('esg journey 2030', 0.5345),
#   ('2022 epra index', 0.5165),
#   ('tcfd disclosures 2022', 0.5072),
#   ('overview kpis net', 0.494),
#   ('2030 commitments performance', 0.4932)],
#  [('uncertainties horizon dedication', 0.5294),
#   ('horizon dedication vital', 0.5184),
#   ('year new uncertainties', 0.5093),
#   ('new uncertainties horizon', 0.3787),
#   ('new year new', 0.3575)],
#  [('years sustainability reporting', 0.7734),
#   ('20 years sustainability', 0.7292),
#   ('sustainability reporting environmental', 0.6904),
#   ('reporting environmental social', 0.5771),
#   ('celebrate 20 years', 0.5148)],
#  [('climate emergency high', 0.6828),
#   ('crisis impact covid', 0.6692),
#   ('living crisis impact', 0.5545),
#   ('impact covid 19', 0.5098),
#   ('covid 19 continues', 0.507)],
#  [('making positive impact', 0.5332),
#   ('positive impact places', 0.4954),
#   ('impact places important', 0.4419),
#   ('net zero making', 0.4281),
#   ('pathway net zero', 0.4243)],
#  [('deliver strong progress', 0.7612),
#   ('strong progress year', 0.7212),
#   ('continued deliver strong', 0.6831)],
#  [('net zero carbon', 0.5944),
#   ('carbon development site', 0.5731),
#   ('zero carbon development', 0.555),
#   ('triton square completed', 0.5513),
#   ('site canada water', 0.5183)],
#  [('environment reflects customers', 0.7059),
#   ('customers increasingly expect', 0.618),
#   ('reflects customers increasingly', 0.5868),
#   ('right terms environment', 0.3888),
#   ('approach right terms', 0.3877)],
#  [('broadgate sustainable buildings', 0.7461),
#   ('success broadgate sustainable', 0.6696),
#   ('leasing success broadgate', 0.659),
#   ('sustainable buildings london', 0.6288),
#   ('case sustainable buildings', 0.6235)],
#  [('net zero audits', 0.6271),
#   ('standing portfolio completed', 0.5334),
#   ('portfolio completed net', 0.5322),
#   ('customers invest energy', 0.5135),
#   ('zero audits working', 0.505)],
#  [('raise epc ratings', 0.6604),
#   ('epc ratings portfolio', 0.6463),
#   ('outcome raise epc', 0.631),
#   ('ratings portfolio 2030', 0.587),
#   ('expected mees legislation', 0.4786)],
#  [('efforts recognised gresb', 0.6037),
#   ('recognised gresb global', 0.5764),
#   ('estate sustainability benchmark', 0.5733),
#   ('gresb global real', 0.5297),
#   ('real estate sustainability', 0.5251)],
#  [('social place based', 0.6171),
#   ('place based approach', 0.6075),
#   ('emerging needs opportunities', 0.5458),
#   ('adapt emerging needs', 0.4892),
#   ('strong local relationships', 0.489)],
#  [('community activities benefitted', 0.7355),
#   ('year community activities', 0.6363),
#   ('activities benefitted nearly', 0.6036),
#   ('24 000 people', 0.5937),
#   ('benefitted nearly 24', 0.541)],
#  [('partnership fort kinnaird', 0.6453),
#   ('collaboration capital city', 0.5781),
#   ('capital city partnership', 0.5744),
#   ('city partnership fort', 0.5724),
#   ('fort kinnaird help', 0.5065)],
#  [('national literacy trust', 0.746),
#   ('partnership national literacy', 0.6972),
#   ('years partnership national', 0.6233),
#   ('marked years partnership', 0.5838),
#   ('year marked years', 0.3823)],
#  [('teams fantastic job', 0.6345),
#   ('support local communities', 0.5875),
#   ('customers partners support', 0.5458),
#   ('working customers partners', 0.5176),
#   ('partners support local', 0.5135)],
#  [('places vibrant successful', 0.3678),
#   ('contribution making places', 0.359),
#   ('thank hard work', 0.3027),
#   ('huge contribution making', 0.3021),
#   ('making places vibrant', 0.2968)],
#  [('new uncertainties dedication', 0.6705),
#   ('uncertainties dedication vital', 0.6557),
#   ('year new uncertainties', 0.5306),
#   ('new year new', 0.3765)],
#  [('overview broadgate places', 0.6248),
#   ('manage outstanding places', 0.5964),
#   ('broadgate places people', 0.5955),
#   ('places people prefer', 0.5019),
#   ('positive outcomes stakeholders', 0.5019)],
#  [('use places communities', 0.5753),
#   ('understanding evolving needs', 0.554),
#   ('organisations use places', 0.5453),
#   ('evolving needs ofthe', 0.5306),
#   ('people organisations use', 0.5273)],
#  [('important emerge pandemic', 0.5452),
#   ('customers communities partners', 0.5363),
#   ('communities partners people', 0.4871),
#   ('created customers communities', 0.4869),
#   ('partners people important', 0.4748)],
#  [('zero carbon development', 0.7065),
#   ('net zero carbon', 0.6439),
#   ('carbon development completed', 0.6355),
#   ('completed embodied carbon', 0.5342),
#   ('carbon triton square', 0.525)],
#  [('29 audits portfolio', 0.72),
#   ('asset audits completed', 0.6685),
#   ('completed 29 audits', 0.6585),
#   ('zero asset audits', 0.6569),
#   ('audits portfolio identifying', 0.623)],
#  [('awarded bre4 innovation', 0.7323),
#   ('bre4 innovation credits', 0.7176),
#   ('heat exchange recycling', 0.5479),
#   ('innovation credits heat', 0.5323),
#   ('credits heat exchange', 0.5063)],
#  [('offices development pipeline', 0.8607),
#   ('development pipeline including', 0.7037),
#   ('pipeline including completed', 0.6253),
#   ('including completed developments', 0.5972)],
#  [('operational energy intensity', 0.6387),
#   ('building operational energy', 0.6354),
#   ('energy intensity improvement', 0.6213),
#   ('intensity improvement vs', 0.5447),
#   ('2019 baseline offices', 0.5334)],
#  [('covid 19 restrictions', 0.6847),
#   ('restrictions requiring assets', 0.5502),
#   ('impacted covid 19', 0.5326),
#   ('19 restrictions requiring', 0.5215),
#   ('operate lower capacity', 0.5177)],
#  [('launched ndt broadgate', 0.7511),
#   ('ndt broadgate new', 0.7184),
#   ('ndt broadgate support', 0.681),
#   ('theatre launched ndt', 0.6488),
#   ('framework launched ndt', 0.5628)],
#  [('londons biggest rehearsal', 0.7346),
#   ('rehearsal artist development', 0.7255),
#   ('artist development complexes', 0.7147),
#   ('biggest rehearsal artist', 0.6543)],
#  [('20 years sustainability', 0.6165),
#   ('years sustainability reporting', 0.6029),
#   ('sustainability reporting environmental', 0.4992),
#   ('celebrate 20 years', 0.493),
#   ('reporting environmental social', 0.4222)],
#  [('launched sustainability brief', 0.9429),
#   ('sustainability brief developments', 0.895)],
#  [('green building council', 0.8064),
#   ('member uk green', 0.7627),
#   ('uk green building', 0.6849),
#   ('founding member uk', 0.6729)],
#  [('community investment fund', 0.8968),
#   ('launched community investment', 0.8773)],
#  [('signatory global compact', 0.8727)],
#  [('breeam excellent projects', 0.833),
#   ('delivered breeam excellent', 0.8001)],
#  [('smart energy management', 0.8413), ('introduced smart energy', 0.7723)],
#  [('life carbon assessments', 0.8175), ('completed life carbon', 0.7397)],
#  [('sustainability brief established', 0.7819),
#   ('social environmental requirements', 0.7585),
#   ('environmental requirements developments', 0.6837),
#   ('established social environmental', 0.6661),
#   ('brief established social', 0.464)],
#  [('ukgbc works promote', 0.7206),
#   ('promote sustainability built', 0.5982),
#   ('sustainability built environment', 0.5764),
#   ('works promote sustainability', 0.5255)],
#  [('000 children read', 0.7058),
#   ('national literacy trust', 0.6917),
#   ('children read partnership', 0.6829),
#   ('partnership national literacy', 0.6793),
#   ('literacy trust began', 0.6349)],
#  [('launched community charter', 0.8268),
#   ('community charter laying', 0.7806),
#   ('todays local charter', 0.7198),
#   ('charter laying foundation', 0.6998),
#   ('foundation todays local', 0.5717)],
#  [('readers programme partnership', 0.8205),
#   ('started young readers', 0.7897),
#   ('young readers programme', 0.7849)],
#  [('launched regents place', 0.602),
#   ('regents place customer', 0.5788),
#   ('achievements launched regents', 0.5606),
#   ('queens award lasting', 0.547),
#   ('customer community fund', 0.4793)],
#  [('lights skills employment', 0.7051),
#   ('launched bright lights', 0.6653),
#   ('bright lights skills', 0.657),
#   ('skills employment programme', 0.535)],
#  [('happy city establish', 0.6207),
#   ('seven core principles', 0.6),
#   ('principles guide placemaking', 0.5971),
#   ('city establish seven', 0.5615),
#   ('guide placemaking activities', 0.5507)],
#  [('2030 sustainability strategy', 0.807),
#   ('launched 2030 sustainability', 0.7937),
#   ('sustainability strategy commitment', 0.7135),
#   ('net zero 2030', 0.6862),
#   ('commitment net zero', 0.6182)],
#  [('embodied carbon developments', 0.7744),
#   ('tonne embodied carbon', 0.7334),
#   ('internal carbon levy', 0.6843),
#   ('introduced internal carbon', 0.6508),
#   ('carbon levy 60', 0.6205)],
#  [('launched transition vehicle', 0.7405),
#   ('transition vehicle fund', 0.7086),
#   ('vehicle fund energy', 0.6919),
#   ('energy efficient improvements', 0.5369),
#   ('fund energy efficient', 0.4978)],
#  [('carbon reduction targets', 0.6085),
#   ('lights skills employment', 0.5555),
#   ('initiative validated carbon', 0.5497),
#   ('science based targets', 0.5284),
#   ('bright lights skills', 0.4956)],
#  [('net zero pathway', 0.6677),
#   ('reduce carbon emissions', 0.6146),
#   ('zero pathway sets', 0.5799),
#   ('ways reduce carbon', 0.5347),
#   ('pathway sets ways', 0.4861)],
#  [('carbon developments 2030', 0.7846),
#   ('offset embodied carbon', 0.7551),
#   ('embodied carbon developments', 0.7189),
#   ('offset operational carbon', 0.7054),
#   ('developments 2030 offset', 0.6371)],
#  [('carbon portfolio 2030', 0.7231),
#   ('zero carbon portfolio', 0.7009),
#   ('zero carbon environmental', 0.6459),
#   ('operational carbon portfolio', 0.6302),
#   ('carbon environmental leadership', 0.6292)],
#  [('leading international benchmarks', 0.7941),
#   ('strong progress delivering', 0.6128),
#   ('progress delivering participating', 0.5332),
#   ('demonstrate strong progress', 0.5313),
#   ('participating leading international', 0.5298)],
#  [('gresb rating 2022', 0.7865),
#   ('achieve gresb rating', 0.7381),
#   ('target achieve gresb', 0.6637),
#   ('rating 2022 pleased', 0.5315),
#   ('2022 pleased achieved', 0.5246)],
#  [('81st percentile science', 0.6119),
#   ('percentile science based', 0.5884),
#   ('targets approval 2021', 0.5707),
#   ('based targets approval', 0.5679),
#   ('science based targets', 0.529)],
#  [('community partners collaborate', 0.6533),
#   ('directly community partners', 0.6414),
#   ('partners collaborate customers', 0.5984),
#   ('collaborate customers identify', 0.587),
#   ('issues make impact', 0.4856)],
#  [('suppliers community partners', 0.7061),
#   ('community partners priority', 0.7055),
#   ('partners priority local', 0.6984),
#   ('customers suppliers community', 0.6806),
#   ('connecting customers suppliers', 0.638)],
#  [('literacy trust employment', 0.6008),
#   ('national literacy trust', 0.5568),
#   ('education needs based', 0.5527),
#   ('based initiatives places', 0.5407),
#   ('needs based initiatives', 0.5315)],
#  [('workspace thrive canada', 0.5972),
#   ('affordable workspace thrive', 0.5336),
#   ('supporting impacted covid', 0.5195),
#   ('local business supporting', 0.5026),
#   ('employment training supporting', 0.4934)],
#  [('responsible business practices', 0.7635),
#   ('business practices british', 0.7333),
#   ('advocate responsible business', 0.704),
#   ('responsible business advocate', 0.6954),
#   ('business advocate responsible', 0.6742)],
#  [('key areas focus', 0.8004), ('areas focus set', 0.7893)],
#  [('waste managed assets', 0.5573),
#   ('epcs rated assets', 0.5573),
#   ('rated assets management', 0.5466),
#   ('recycled development operational', 0.5433),
#   ('operational waste managed', 0.5389)],
#  [('2030 strategy upgraded', 0.7276),
#   ('2021 2030 strategy', 0.6742),
#   ('strategy upgraded breeam', 0.6021),
#   ('upgraded breeam targets', 0.594),
#   ('breeam targets outstanding', 0.5068)],
#  [('100 breeam certifications', 0.7273),
#   ('pursued breeam certificates', 0.6917),
#   ('breeam certificates 44', 0.6541),
#   ('breeam certifications date', 0.6444),
#   ('certifications date pursued', 0.5318)],
#  [('certifications primarily breeam', 0.7316),
#   ('bre certification schemes', 0.6931),
#   ('assets operational certifications', 0.6376),
#   ('prior bre certification', 0.6332),
#   ('certifications new developments', 0.5936)],
#  [('breeam use certifications', 0.749),
#   ('rollout breeam use', 0.5795),
#   ('stage rollout breeam', 0.5568),
#   ('pilots retail assets', 0.5081),
#   ('use certifications including', 0.4717)],
#  [('standing portfolio increase', 0.6644),
#   ('entry standing portfolio', 0.6246),
#   ('portfolio increase proportion', 0.5824),
#   ('highly rated assets', 0.5537),
#   ('proportion highly rated', 0.4415)],
#  [('social value target', 0.6279),
#   ('priorities report social', 0.6038),
#   ('report social value', 0.5958),
#   ('develop social value', 0.5442),
#   ('fy23 priorities report', 0.5384)],
#  [('priority assets tables', 0.5881),
#   ('assets tables pages', 0.5349),
#   ('23 report progress', 0.5079),
#   ('use priority assets', 0.4841),
#   ('tables pages 21', 0.4492)],
#  [('net zero carbon', 0.7744),
#   ('carbon net zero', 0.7687),
#   ('zero carbon portfolio', 0.7543),
#   ('zero carbon net', 0.7238),
#   ('carbon portfolio 2030', 0.7215)],
#  [('delivering sustainable space', 0.7312),
#   ('customers prioritise sustainability', 0.6864),
#   ('sustainable space clear', 0.5669),
#   ('record delivering sustainable', 0.5657),
#   ('competitive advantage business', 0.4552)],
#  [('pathway net zero', 0.8369),
#   ('carbon net zero', 0.7472),
#   ('zero carbon net', 0.7218),
#   ('net zero carbon', 0.7152),
#   ('zero delivering pathway', 0.6878)],
#  [('commitments year advanced', 0.7222),
#   ('delivered commitments year', 0.6381),
#   ('advanced coming year', 0.6305),
#   ('year advanced coming', 0.5817)],
#  [('net zero carbon', 0.7172),
#   ('zero carbon reducing', 0.6333),
#   ('life carbon assessments', 0.59),
#   ('undertaking life carbon', 0.575),
#   ('carbon office developments', 0.5743)],
#  [('click lca life', 0.6498),
#   ('life cycle assessment', 0.6453),
#   ('cycle assessment software', 0.6394),
#   ('lca life cycle', 0.6294),
#   ('adopted click lca', 0.5488)],
#  [('data consultants benchmark', 0.6517),
#   ('enables consolidate data', 0.6258),
#   ('consultants benchmark performance', 0.6077),
#   ('benchmark performance monitor', 0.6001),
#   ('performance monitor progress', 0.5951)],
#  [('significant carbon savings', 0.7535),
#   ('generate significant carbon', 0.6309),
#   ('materials techniques generate', 0.4577),
#   ('identify designs materials', 0.4161),
#   ('designs materials techniques', 0.4157)],
#  [('reusing existing materials', 0.6208),
#   ('norton folgate case', 0.6149),
#   ('existing materials structures', 0.5412),
#   ('folgate case study', 0.5117),
#   ('materials structures far', 0.3995)],
#  [('buildings norton folgate', 0.5509),
#   ('blossom studios buildings', 0.5468),
#   ('floors timber joists', 0.5318),
#   ('timber joists individually', 0.5253),
#   ('joists individually assessed', 0.4843)],
#  [('reclaimed bricks original', 0.7079),
#   ('rebuilt internal walls', 0.6998),
#   ('bricks preserve original', 0.6778),
#   ('using reclaimed bricks', 0.6625),
#   ('walls using reclaimed', 0.6358)],
#  [('wood concrete used', 0.662),
#   ('council wood concrete', 0.6326),
#   ('40 cement replacement', 0.5815),
#   ('concrete used 40', 0.5417),
#   ('used 40 cement', 0.5414)],
#  [('expect embodied carbon', 0.6623),
#   ('embodied carbon 403', 0.6147),
#   ('carbon 403 kg', 0.6082),
#   ('co2e sqm redevelopment', 0.5982),
#   ('kg co2e sqm', 0.5774)],
#  [('operational energy intensity', 0.62),
#   ('power operational energy', 0.5898),
#   ('green power operational', 0.5323),
#   ('operational performance adding', 0.4872),
#   ('performance adding roof', 0.4707)],
#  [('zero carbon reducing', 0.6349),
#   ('net zero carbon', 0.632),
#   ('reducing embodied carbon', 0.5814),
#   ('carbon reducing embodied', 0.5799),
#   ('embodied carbon developments', 0.5778)],
#  [('embodied carbon emissions', 0.7553),
#   ('minimise embodied carbon', 0.7056),
#   ('piloting sustainable materials', 0.6793),
#   ('focus piloting sustainable', 0.6727),
#   ('carbon emissions focus', 0.6718)],
#  [('mixed use building', 0.6689),
#   ('sustainable materials superstructure', 0.6141),
#   ('workspace using sustainable', 0.6106),
#   ('186 residential units', 0.5521),
#   ('using sustainable materials', 0.5472)],
#  [('ggbs ground granulated', 0.6162),
#   ('slag waste product', 0.5738),
#   ('includes ggbs ground', 0.5618),
#   ('iron repurposed cement', 0.5524),
#   ('furnace slag waste', 0.5426)],
#  [('concrete slabs stronger', 0.6557),
#   ('tensioned concrete slabs', 0.643),
#   ('slabs stronger thinner', 0.6428),
#   ('post tensioned concrete', 0.6203),
#   ('thinner requiring concrete', 0.6045)],
#  [('pilot low carbon', 0.6147),
#   ('carbon materials net', 0.5717),
#   ('net zero pathway', 0.5493),
#   ('low carbon materials', 0.5407),
#   ('materials net zero', 0.5277)],
#  [('projections embodied carbon', 0.7355),
#   ('co2e sqm 2030', 0.6088),
#   ('embodied carbon 682', 0.586),
#   ('co2e sqm glidepath', 0.5643),
#   ('682 kg co2e', 0.5582)],
#  [('certifications targeted outdoor', 0.5426),
#   ('minimise embodied carbon', 0.5335),
#   ('gold certifications targeted', 0.5141),
#   ('targeted outdoor space', 0.5035),
#   ('embodied carbon far', 0.4744)],
#  [('embodied carbon avoided', 0.7689),
#   ('residual embodied carbon', 0.7542),
#   ('carbon avoided design', 0.7392),
#   ('certified emission reduction', 0.6037),
#   ('emission reduction projects', 0.5526)],
#  [('projects support biodiversity', 0.7181),
#   ('support biodiversity economic', 0.6396),
#   ('biodiversity economic benefits', 0.6195),
#   ('benefits local communities', 0.535),
#   ('use nature based', 0.5325)],
#  [('farmers employed project', 0.8396),
#   ('local farmers employed', 0.7202),
#   ('closely local farmers', 0.7048),
#   ('able grow crops', 0.6445),
#   ('project able grow', 0.6168)],
#  [('expand 000 hectares', 0.8437),
#   ('000 hectares year', 0.7586),
#   ('aim expand 000', 0.4762)],
#  [('woodland carbon code', 0.7802),
#   ('trees woodland carbon', 0.7699),
#   ('000 trees woodland', 0.7384),
#   ('23 000 trees', 0.6768),
#   ('supporting planting 23', 0.5499)],
#  [('commitment formal offset', 0.5968),
#   ('offset triton square', 0.5534),
#   ('additional commitment formal', 0.5132),
#   ('formal offset triton', 0.5084)],
#  [('opportunities reduce carbon', 0.6774),
#   ('reducing operational carbon', 0.6663),
#   ('net zero carbon', 0.6622),
#   ('zero carbon reducing', 0.6618),
#   ('reduce carbon emissions', 0.6577)],
#  [('energy saving initiatives', 0.6964),
#   ('focus renewable power', 0.6413),
#   ('portfolio focus renewable', 0.6378),
#   ('saving initiatives buildings', 0.6341),
#   ('renewable power energy', 0.6067)],
#  [('renewable power grid', 0.5844),
#   ('2030 energy saving', 0.5507),
#   ('power grid onsite', 0.4948),
#   ('highly energy efficient', 0.4874),
#   ('offsite residual emissons', 0.4806)],
#  [('broadgate energy intensity', 0.6933),
#   ('improvement broadgate energy', 0.6727),
#   ('illustrates improvement broadgate', 0.55),
#   ('energy intensity just', 0.4868),
#   ('chart illustrates improvement', 0.477)],
#  [('developments kingdom street', 0.6439),
#   ('street efficient portfolio', 0.6303),
#   ('kingdom street efficient', 0.6258),
#   ('efficient portfolio thoughtful', 0.5464),
#   ('thoughtful asset management', 0.5047)],
#  [('intervention heat pump', 0.5703),
#   ('heat pump accounting', 0.5454),
#   ('70 retrofit cost', 0.5202),
#   ('key intervention heat', 0.4962),
#   ('retrofit cost altogether', 0.4936)],
#  [('older buildings broadgate', 0.737),
#   ('buildings broadgate tower', 0.6637),
#   ('broadgate tower require', 0.6154),
#   ('tower require comprehensive', 0.603),
#   ('require comprehensive retrofitting', 0.5467)],
#  [('zero audits buildings', 0.6902),
#   ('audits buildings portfolio', 0.6404),
#   ('net zero audits', 0.5935),
#   ('improvement building energy', 0.52),
#   ('25 improvement building', 0.5112)],
#  [('exchange house shown', 0.7739),
#   ('study exchange house', 0.7179),
#   ('case study exchange', 0.5992),
#   ('house shown page', 0.5356)],
#  [('carbon developments 2030', 0.604),
#   ('offset operational carbon', 0.5489),
#   ('carbon standing portfolio', 0.5322),
#   ('development pipeline excludes', 0.5306),
#   ('embodied carbon developments', 0.5217)],
#  [('decarbonisation national grid', 0.7024),
#   ('renewable power uk', 0.6266),
#   ('switch renewable power', 0.6209),
#   ('role switch renewable', 0.5259),
#   ('national grid play', 0.3591)],
#  [('onsite offsite renewable', 0.6419),
#   ('offsite renewable energy', 0.6196),
#   ('renewable energy sources', 0.619),
#   ('supplement investing onsite', 0.5528),
#   ('investing onsite offsite', 0.5105)],
#  [('solar car port', 0.5733),
#   ('rooftop solar car', 0.5698),
#   ('opportunities rooftop solar', 0.5609),
#   ('meadowhall undertaking feasibility', 0.5416),
#   ('watts capacity portfolio', 0.5151)],
#  [('meadowhall shopping centre', 0.6352),
#   ('park meadowhall shopping', 0.6166),
#   ('studies underway retail', 0.5705),
#   ('car park meadowhall', 0.5559),
#   ('detailed studies underway', 0.4848)],
#  [('opportunities offsite renewables', 0.7946),
#   ('offsite renewables increase', 0.7218),
#   ('contribution renewable power', 0.6854),
#   ('renewables increase relative', 0.6853),
#   ('renewable power overall', 0.6818)],
#  [('net zero audits', 0.6656),
#   ('net zero carbon', 0.6331),
#   ('overview net zero', 0.5357),
#   ('zero carbon reducing', 0.5303),
#   ('completed net zero', 0.5093)],
#  [('initiatives standing portfolio', 0.6766),
#   ('improvement building energy', 0.6018),
#   ('identified initiatives standing', 0.5939),
#   ('building energy efficiency', 0.5518),
#   ('standing portfolio actioned', 0.5355)],
#  [('initiatives delivered reducing', 0.6091),
#   ('reducing energy use', 0.5899),
#   ('delivered reducing energy', 0.5481),
#   ('energy use 23', 0.5182),
#   ('23 saving occupiers', 0.4713)],
#  [('co2 controls sensors', 0.7112),
#   ('introducing co2 controls', 0.6816),
#   ('monitor fresh air', 0.5305),
#   ('sensors installed office', 0.5101),
#   ('levels adjust ventilation', 0.506)],
#  [('cut demand heating', 0.7353),
#   ('demand heating cooling', 0.7274),
#   ('significantly cut demand', 0.6479),
#   ('cost measure significantly', 0.5136),
#   ('low cost measure', 0.4632)],
#  [('installing dedicated chillers', 0.7813),
#   ('chillers hours cooling', 0.773),
#   ('dedicated chillers hours', 0.7421),
#   ('main chillers intensive', 0.7251),
#   ('run main chillers', 0.7237)],
#  [('interventions led lighting', 0.7035),
#   ('significant interventions led', 0.6696),
#   ('lighting heat pumps', 0.6411),
#   ('led lighting heat', 0.4637)],
#  [('improvements deliver savings', 0.6039),
#   ('cost funded service', 0.564),
#   ('funded service charge', 0.5372),
#   ('payback investment years', 0.466),
#   ('thirds cost funded', 0.4569)],
#  [('improve buildings epc', 0.6658),
#   ('buildings epc rating', 0.665),
#   ('interventions improve buildings', 0.5745),
#   ('compliant expected mees', 0.5191),
#   ('expected mees legislation', 0.5074)],
#  [('approach place based', 0.7594),
#   ('place based approach', 0.7348),
#   ('based approach place', 0.7336),
#   ('overview place based', 0.5886),
#   ('based approach means', 0.577)],
#  [('approach place based', 0.7025),
#   ('approach social impact', 0.667),
#   ('social impact areas', 0.6568),
#   ('based approach place', 0.6563),
#   ('place based approach', 0.639)],
#  [('local charter focuses', 0.6089),
#   ('lasting positive legacy', 0.5061),
#   ('areas create lasting', 0.4883),
#   ('positive legacy work', 0.4636),
#   ('charter focuses key', 0.4099)],
#  [('suppliers community partners', 0.6673),
#   ('connect local communities', 0.6431),
#   ('communities bringing customers', 0.6387),
#   ('community partners common', 0.6143),
#   ('customers suppliers community', 0.5887)],
#  [('connecting customers community', 0.7454),
#   ('customers community partners', 0.7291),
#   ('community partners strongest', 0.6742),
#   ('partners strongest social', 0.6005),
#   ('strongest social contributions', 0.571)],
#  [('funds broadgate paddington', 0.7032),
#   ('broadgate paddington central', 0.6296),
#   ('launch funds broadgate', 0.6017),
#   ('regents place community', 0.5139),
#   ('success regents place', 0.4968)],
#  [('local themes pledge', 0.6248),
#   ('grants community organisations', 0.6244),
#   ('award grants community', 0.5829),
#   ('themes pledge funds', 0.5747),
#   ('pledge funds award', 0.5445)],
#  [('stakeholders pledged 150', 0.6448),
#   ('pledged 150 000', 0.5584),
#   ('local stakeholders pledged', 0.5415),
#   ('150 000 broadgate', 0.519),
#   ('000 broadgate paddington', 0.5031)],
#  [('educational initiatives local', 0.6944),
#   ('support educational initiatives', 0.6929),
#   ('raising awareness career', 0.575),
#   ('awareness career opportunities', 0.5724),
#   ('initiatives local people', 0.5635)],
#  [('58 education initiatives', 0.8536),
#   ('delivered 58 education', 0.7408),
#   ('year delivered 58', 0.4616)],
#  [('primary school projects', 0.7591),
#   ('school projects secondary', 0.7417),
#   ('projects secondary school', 0.681),
#   ('secondary school workshops', 0.6648),
#   ('events university challenges', 0.6329)],
#  [('national literacy trust', 0.7886),
#   ('partnership national literacy', 0.7418),
#   ('literacy trust 29', 0.7217),
#   ('pleasure improve literacy', 0.55),
#   ('improve literacy skills', 0.5471)],
#  [('000 children partnership', 0.8016),
#   ('children partnership began', 0.7198),
#   ('56 000 children', 0.6922),
#   ('reached 56 000', 0.4959)],
#  [('employment support local', 0.6593),
#   ('lights skills employment', 0.6204),
#   ('local training jobs', 0.5992),
#   ('jobs bright lights', 0.5945),
#   ('employment programme working', 0.5883)],
#  [('crisis refocused bright', 0.6589),
#   ('refocused bright lights', 0.5795),
#   ('bright lights support', 0.5778),
#   ('lights support affected', 0.5361),
#   ('living crisis refocused', 0.504)],
#  [('initiatives run portfolio', 0.8298)],
#  [('people virtual employment', 0.6066),
#   ('virtual employment training', 0.5909),
#   ('employment training support', 0.5439),
#   ('residents skills achieve', 0.5314),
#   ('135 people virtual', 0.5255)],
#  [('programme included ringfenced', 0.7684),
#   ('ringfenced opportunities businesses', 0.76),
#   ('included ringfenced opportunities', 0.73),
#   ('opportunities businesses places', 0.3998)],
#  [('candidates gained employment', 0.5266),
#   ('sectors glasgow fort', 0.5022),
#   ('average 60 candidates', 0.4991),
#   ('glasgow fort rises', 0.4921),
#   ('60 candidates gained', 0.48)],
#  [('support local businesses', 0.8388),
#   ('supporting local business', 0.8251),
#   ('local business affordable', 0.6602),
#   ('local businesses opening', 0.6167),
#   ('opportunities local independents', 0.6099)],
#  [('space priority assets', 0.6555),
#   ('affordable space priority', 0.6508),
#   ('provided affordable space', 0.5962),
#   ('priority assets identified', 0.5673),
#   ('assets identified opportunities', 0.5429)],
#  [('affordable work space', 0.7336),
#   ('affordable retail space', 0.7016),
#   ('work space affordable', 0.7001),
#   ('includes affordable work', 0.6312),
#   ('retail space community', 0.6058)],
#  [('theatre ndt regents', 0.7127),
#   ('launched ndt broadgate', 0.6947),
#   ('diorama theatre ndt', 0.6914),
#   ('ndt broadgate support', 0.6109),
#   ('new diorama theatre', 0.5973)],
#  [('world ndt broadgate', 0.6839),
#   ('ndt broadgate attracted', 0.6222),
#   ('broadgate attracted footfall', 0.4851),
#   ('highly successful productions', 0.4666),
#   ('000 creatives engaged', 0.4532)],
#  [('diorama theatre regents', 0.6676),
#   ('new diorama theatre', 0.6479),
#   ('theatre regents place', 0.6143),
#   ('stages fringe theatre', 0.589),
#   ('fringe theatre year', 0.5862)],
#  [('health wellbeing customers', 0.7022),
#   ('places support health', 0.6989),
#   ('support health wellbeing', 0.6193),
#   ('wellbeing customers colleagues', 0.602),
#   ('create places support', 0.5617)],
#  [('develop partnerships communities', 0.746),
#   ('partnerships communities support', 0.7401),
#   ('communities support wellbeing', 0.6701),
#   ('support wellbeing people', 0.519),
#   ('wellbeing people work', 0.4781)],
#  [('wellbeing initiatives community', 0.634),
#   ('supported 700 beneficiaries', 0.6331),
#   ('range wellbeing initiatives', 0.596),
#   ('2022 range wellbeing', 0.5714),
#   ('initiatives community partners', 0.4918)],
#  [('platinum broadgate highest', 0.6318),
#   ('achieve platinum broadgate', 0.6202),
#   ('highest level certification', 0.6162),
#   ('recognised benchmark health', 0.5733),
#   ('level certification globally', 0.5563)],
#  [('ahmm targeting industry', 0.6029),
#   ('occupier jll architect', 0.5854),
#   ('architect ahmm targeting', 0.5727),
#   ('jll architect ahmm', 0.5651),
#   ('standards air quality', 0.5413)],
#  [('align developments standard', 0.6541),
#   ('continue align developments', 0.6187)],
#  [('canada water a1', 0.658),
#   ('office developments canada', 0.6501),
#   ('developments canada water', 0.6215),
#   ('a1 a2 ready', 0.5828),
#   ('water a1 a2', 0.5472)],
#  [('pre certification supports', 0.7706),
#   ('certification supports delivering', 0.5991),
#   ('certification employee health', 0.566),
#   ('partner pursuing certification', 0.4998),
#   ('pursuing certification employee', 0.4824)],
#  [('specific activities 2022', 0.5973),
#   ('activities 2022 commitments', 0.5946),
#   ('social reporting subsequent', 0.5485),
#   ('2022 commitments 2023', 0.5429),
#   ('priority assets details', 0.4619)],
#  [('far assets programmes', 0.5881),
#   ('goes far assets', 0.5389),
#   ('assets programmes delivered', 0.5372),
#   ('programmes delivered portfolio', 0.5368),
#   ('place based approach', 0.4294)],
#  [('partnership national literacy', 0.6558),
#   ('national literacy trust', 0.6417),
#   ('literacy trust bright', 0.6399),
#   ('community initiatives partnership', 0.6175),
#   ('initiatives partnership national', 0.5908)],
#  [('ukraine donated 25', 0.7784),
#   ('war ukraine donated', 0.7284),
#   ('donated 25 000', 0.5869),
#   ('supporting ukraine support', 0.5761),
#   ('ukraine support affected', 0.529)],
#  [('ukrainian cathedral marylebone', 0.7213),
#   ('cathedral marylebone close', 0.65),
#   ('000 ukrainian cathedral', 0.6077),
#   ('donated 000 ukrainian', 0.4905),
#   ('marylebone close head', 0.4401)],
#  [('000 funding scheme', 0.6413),
#   ('funding scheme support', 0.6197),
#   ('30 000 funding', 0.5927),
#   ('school refugees donated', 0.5309),
#   ('refugees donated space', 0.5194)],
#  [('specific qr codes', 0.6219),
#   ('qr codes enable', 0.5935),
#   ('british red cross', 0.5521),
#   ('donations british red', 0.5385),
#   ('rolled specific qr', 0.4999)],
#  [('crisis fy23 collaborating', 0.7015),
#   ('living crisis fy23', 0.6709),
#   ('cost living crisis', 0.6188),
#   ('fy23 collaborating long', 0.5676),
#   ('struggling cost living', 0.5432)],
#  [('bright lights initiatives', 0.8455),
#   ('lights initiatives focus', 0.8177),
#   ('initiatives focus activities', 0.5922),
#   ('focus activities affected', 0.4711)],
#  [('approach delivering place', 0.6451),
#   ('delivering place based', 0.6196),
#   ('place based approach', 0.6099),
#   ('overview place based', 0.6078),
#   ('place based working', 0.5946)],
#  [('respect british land', 0.8238), ('appreciate respect british', 0.7052)],
#  [('subsoil wonderful conversation', 0.4719),
#   ('vision like weve', 0.4286),
#   ('wonderful conversation place', 0.4004),
#   ('long term vision', 0.3876),
#   ('weve brought subsoil', 0.3689)],
#  [('generation canada water', 0.631),
#   ('jane riddiford global', 0.6127),
#   ('canada water partnership', 0.6009),
#   ('water canada water', 0.5868),
#   ('canada water canada', 0.576)],
#  [('global generation engaged', 0.7296),
#   ('generator youth leaders', 0.6824),
#   ('year global generation', 0.664),
#   ('worked generator youth', 0.6424),
#   ('schoolchildren workshops worked', 0.6064)],
#  [('circular economy principles', 0.6081),
#   ('using circular economy', 0.5868),
#   ('principles new facility', 0.5493),
#   ('new facility provide', 0.5194),
#   ('fantastic community resource', 0.5185)],
#  [('community fund collaboration', 0.6476),
#   ('new community fund', 0.5999),
#   ('fund collaboration occupiers', 0.547),
#   ('paddington central connecting', 0.5418),
#   ('central paddington central', 0.5261)],
#  [('unveiled community garden', 0.7992),
#   ('community garden supported', 0.7587),
#   ('garden supported occupiers', 0.6238),
#   ('2021 unveiled community', 0.6047),
#   ('occupiers wipro kingfisher', 0.4222)],
#  [('took workshops gardening', 0.6815),
#   ('workshops gardening food', 0.6643),
#   ('schoolchildren visitors garden', 0.6273),
#   ('people took workshops', 0.5655),
#   ('garden year customers', 0.5654)],
#  [('customers volunteered 60', 0.5696),
#   ('smoothie stall campus', 0.5693),
#   ('disabilities run fruit', 0.5586),
#   ('volunteered 60 hours', 0.5501),
#   ('fruit smoothie stall', 0.529)],
#  [('continue connect diversity', 0.4963),
#   ('black history month', 0.485),
#   ('including session activist', 0.4745),
#   ('representatives businesses campus', 0.4713),
#   ('diversity inclusion network', 0.4662)],
#  [('approach place based', 0.6427),
#   ('based approach place', 0.6046),
#   ('place based approach', 0.5704),
#   ('access educational opportunities', 0.5612),
#   ('education supporting local', 0.552)],
#  [('schoolchildren local broadgate', 0.6505),
#   ('national literacy trust', 0.634),
#   ('collaboration national literacy', 0.6288),
#   ('literacy trust customers', 0.6066),
#   ('local broadgate collaboration', 0.574)],
#  [('students completed virtual', 0.7086),
#   ('virtual work experience', 0.676),
#   ('work experience programme', 0.6359),
#   ('completed virtual work', 0.5807),
#   ('local students completed', 0.5474)],
#  [('campus broadgate prize', 0.6808),
#   ('designs campus broadgate', 0.6203),
#   ('collaboratively designs campus', 0.5841),
#   ('partnership university east', 0.5621),
#   ('university east london', 0.5515)],
#  [('water canada water', 0.5884),
#   ('canada water canada', 0.5833),
#   ('partner tree shepherd', 0.5719),
#   ('canada water continue', 0.5444),
#   ('shepherd deliver thrive', 0.512)],
#  [('sustaining local business', 0.6736),
#   ('local business network', 0.6361),
#   ('business network growing', 0.5733),
#   ('pipeline successful enterprises', 0.5502),
#   ('opportunities canada water', 0.5346)],
#  [('supported 72 entrepreneurs', 0.7887),
#   ('72 entrepreneurs business', 0.7228),
#   ('entrepreneurs business advice', 0.6059),
#   ('businesses self employed', 0.5872),
#   ('set businesses self', 0.5432)],
#  [('low cost workspace', 0.7871),
#   ('cost workspace including', 0.738),
#   ('workspace including offices', 0.6838),
#   ('meeting rooms makerspace', 0.6537),
#   ('offices meeting rooms', 0.6186)],
#  [('british land authentically', 0.7532),
#   ('land authentically supports', 0.6399),
#   ('authentically supports people', 0.4993),
#   ('supports people community', 0.4944)],
#  [('run businesses supported', 0.7099),
#   ('businesses supported successful', 0.7029),
#   ('people run businesses', 0.6145),
#   ('place local people', 0.5323),
#   ('local people run', 0.4957)],
#  [('people make place', 0.572), ('make place meaningful', 0.5322)],
#  [('shepherd regents place', 0.7354),
#   ('place regents place', 0.6988),
#   ('regents place regents', 0.692),
#   ('regents place providing', 0.6847),
#   ('tree shepherd regents', 0.6734)],
#  [('non profit camden', 0.6189),
#   ('new diorama theatre', 0.5892),
#   ('included meeting space', 0.5757),
#   ('profit camden giving', 0.5663),
#   ('camden giving occupier', 0.4893)],
#  [('space blackout uk', 0.5727),
#   ('blackout uk run', 0.5538),
#   ('provided space blackout', 0.5337),
#   ('black queer men', 0.4459),
#   ('months supported peer', 0.4134)],
#  [('thousands plants including', 0.6679),
#   ('varieties good bees', 0.6399),
#   ('tens thousands plants', 0.599),
#   ('flowering varieties good', 0.5864),
#   ('bees butterflies insects', 0.5736)],
#  [('mature birch trees', 0.7399),
#   ('birch trees offer', 0.6996),
#   ('trees offer homes', 0.6517),
#   ('offer homes birds', 0.6347)],
#  [('enhance biodiversity open', 0.7341),
#   ('nature studies boosts', 0.6305),
#   ('biodiversity open access', 0.6237),
#   ('boosts wellbeing productivity', 0.5726),
#   ('studies boosts wellbeing', 0.4951)],
#  [('park valuable community', 0.745),
#   ('space designed accessibility', 0.623),
#   ('valuable community space', 0.5772),
#   ('community space designed', 0.5545)],
#  [('including talks gardening', 0.6166),
#   ('host events customers', 0.5734),
#   ('talks gardening led', 0.5673),
#   ('events customers local', 0.5086),
#   ('led head gardener', 0.4391)],
#  [('working roof gardens', 0.7352),
#   ('roof gardens exchange', 0.7238),
#   ('wildlife central london', 0.6296),
#   ('london working roof', 0.6078),
#   ('green spaces wildlife', 0.5801)],
#  [('environments planting exchange', 0.6791),
#   ('nature loves things', 0.6188),
#   ('planting exchange square', 0.5307),
#   ('mirrored environments planting', 0.5235),
#   ('loves things mixture', 0.4779)],
#  [('land exceptionally supportive', 0.5909),
#   ('british land exceptionally', 0.5698),
#   ('approach urban planting', 0.5564),
#   ('different approach urban', 0.4078),
#   ('supportive taking different', 0.2318)],
#  [('feel fort kinnaird', 0.6296),
#   ('recruitment skills partnership', 0.5659),
#   ('family feel fort', 0.5334),
#   ('skills partnership works', 0.4769),
#   ('real family feel', 0.4312)],
#  [('fort kinnaird strong', 0.554),
#   ('capital city partnership', 0.5467),
#   ('city partnership enabled', 0.5443),
#   ('kinnaird strong relationship', 0.5341),
#   ('relationship capital city', 0.5098)],
#  [('90 people jobs', 0.6503),
#   ('130 young people', 0.5992),
#   ('employability sessions 130', 0.5498),
#   ('delivered employability sessions', 0.4947),
#   ('nearly 90 people', 0.4919)],
#  [('capital city partnership', 0.6261),
#   ('city partnership site', 0.5952),
#   ('employment capital city', 0.4472),
#   ('retailers know vulnerable', 0.4437),
#   ('barriers employment capital', 0.4408)],
#  [('collective family business', 0.6378),
#   ('curated collective family', 0.6347),
#   ('opportunity curated collective', 0.5506),
#   ('independent artists makers', 0.5392),
#   ('ealing broadway worked', 0.5257)],
#  [('team identified unit', 0.7212),
#   ('unit good location', 0.628),
#   ('identified unit good', 0.6089),
#   ('good location supportive', 0.549),
#   ('location supportive terms', 0.5104)],
#  [('existing shop fit', 0.5566),
#   ('shop fit avoid', 0.5357),
#   ('pre existing shop', 0.5207),
#   ('avoid extra costs', 0.4156),
#   ('collective able use', 0.4124)],
#  [('andrew ealing broadway', 0.6103),
#   ('thank andrew ealing', 0.542),
#   ('broadway team british', 0.5274),
#   ('ealing broadway team', 0.5262),
#   ('placemaking initiative supportive', 0.4639)],
#  [('local creative partners', 0.7876),
#   ('25 local creative', 0.7133),
#   ('work 25 local', 0.6091),
#   ('able work 25', 0.4653),
#   ('weve able work', 0.4126)],
#  [('interact people items', 0.6536),
#   ('people items buying', 0.6297),
#   ('people ealing love', 0.5982),
#   ('able interact people', 0.5347),
#   ('love able interact', 0.5018)],
#  [('leases support british', 0.7474),
#   ('support british land', 0.5906),
#   ('thinking year leases', 0.5487),
#   ('year leases support', 0.5454),
#   ('market stall thinking', 0.4216)],
#  [('responsible business practices', 0.7738),
#   ('business responsible business', 0.7737),
#   ('responsible business responsible', 0.7641),
#   ('overview responsible business', 0.7323),
#   ('responsible business advocate', 0.6742)],
#  [('responsible employment diversity', 0.6972),
#   ('areas focus responsible', 0.6578),
#   ('focus responsible employment', 0.6441),
#   ('employment diversity equality', 0.5802),
#   ('inclusion responsible procurement', 0.5269)],
#  [('people competitive advantage', 0.7939)],
#  [('environment achieve potential', 0.5126),
#   ('create environment achieve', 0.3759),
#   ('invest seek create', 0.3437),
#   ('seek create environment', 0.3031)],
#  [('approach supply chain', 0.7098), ('apply approach supply', 0.6598)],
#  [('responsible business practices', 0.7738),
#   ('business responsible business', 0.7737),
#   ('responsible business responsible', 0.7641),
#   ('overview responsible business', 0.7323),
#   ('responsible business advocate', 0.6742)],
#  [('key areas focus', 0.7315), ('areas focus set', 0.6686)],
#  [('growing talent internally', 0.7056),
#   ('importance growing talent', 0.6992),
#   ('responsible employment invest', 0.5867),
#   ('employment invest people', 0.5393),
#   ('recognise importance growing', 0.4805)],
#  [('leadership talent business', 0.61),
#   ('440 000 training', 0.6096),
#   ('fy21 developing leadership', 0.5986),
#   ('000 fy21 developing', 0.588),
#   ('380 000 fy21', 0.5339)],
#  [('hours training supporting', 0.7055),
#   ('000 hours training', 0.6624),
#   ('training supporting 14', 0.5983),
#   ('supporting 14 colleagues', 0.5796),
#   ('14 colleagues gain', 0.5529)],
#  [('internal mentorship scheme', 0.6988),
#   ('run internal mentorship', 0.6789),
#   ('partner circl coaching', 0.6736),
#   ('mentorship scheme includes', 0.6679),
#   ('circl coaching pairing', 0.6063)],
#  [('employee engagement survey', 0.7878),
#   ('engagement survey early', 0.6775),
#   ('depth employee engagement', 0.6362),
#   ('survey early 2022', 0.5031),
#   ('completed 87 people', 0.3673)],
#  [('wellbeing diversity equality', 0.578),
#   ('topics included leadership', 0.5673),
#   ('connection wellbeing diversity', 0.5299),
#   ('included leadership engagement', 0.5101),
#   ('leadership engagement learning', 0.4355)],
#  [('overall engagement score', 0.7995), ('engagement score 69', 0.7874)],
#  [('work british land', 0.5905),
#   ('recommend british land', 0.5687),
#   ('british land great', 0.5325),
#   ('proud work british', 0.5304),
#   ('confirming recommend british', 0.484)],
#  [('overall engagement score', 0.662),
#   ('increase overall engagement', 0.6478),
#   ('survey highlighted areas', 0.5388),
#   ('areas improvement ambition', 0.5368),
#   ('improvement ambition increase', 0.5284)],
#  [('teams create action', 0.5998),
#   ('action plan addressing', 0.579),
#   ('create action plan', 0.5631),
#   ('working collaboratively teams', 0.52),
#   ('collaboratively teams create', 0.5179)],
#  [('provide safe working', 0.6639),
#   ('safe working environment', 0.6591),
#   ('health safety ensure', 0.6533),
#   ('safety ensure people', 0.6365),
#   ('standards health safety', 0.6322)],
#  [('iso standard accident', 0.5839),
#   ('accident frequency rates', 0.5663),
#   ('standard accident frequency', 0.5656),
#   ('international iso standard', 0.5648),
#   ('safety management accredited', 0.5503)],
#  [('families need flexibility', 0.8215),
#   ('flexibility opportunities equal', 0.7056),
#   ('need flexibility opportunities', 0.5911)],
#  [('parental leave pay', 0.5928),
#   ('british land offers', 0.5551),
#   ('shared parental leave', 0.535),
#   ('land offers months', 0.4995),
#   ('thats british land', 0.4851)],
#  [('support employees live', 0.6739),
#   ('modern lifestyles benefits', 0.5775),
#   ('employees live lives', 0.5519),
#   ('live lives careers', 0.5045),
#   ('reflecting modern lifestyles', 0.4881)],
#  [('assistant olivia diversity', 0.624),
#   ('olivia diversity equality', 0.6152),
#   ('launched diversity equality', 0.5818),
#   ('team assistant olivia', 0.5698),
#   ('olivia head planning', 0.564)],
#  [('sustainable development goals', 0.6883),
#   ('united nations sustainable', 0.606),
#   ('commitments improve diversity', 0.5986),
#   ('nations sustainable development', 0.5759),
#   ('business 2030 ensuring', 0.5492)],
#  [('employee feedback channels', 0.6755),
#   ('surveys include diversity', 0.6251),
#   ('diversity demographics help', 0.5448),
#   ('include diversity demographics', 0.5372),
#   ('interviews engagement surveys', 0.5155)],
#  [('blind cvs selection', 0.607),
#   ('receive blind cvs', 0.5768),
#   ('attract diverse workforce', 0.5718),
#   ('diverse workforce ensure', 0.5556),
#   ('ensure hiring managers', 0.4807)],
#  [('recruitment london works', 0.7116),
#   ('agencies bame recruitment', 0.7029),
#   ('bame recruitment london', 0.6911),
#   ('work agencies bame', 0.6252),
#   ('candidates varied backgrounds', 0.5229)],
#  [('black interns initiative', 0.7425),
#   ('000 black interns', 0.7048),
#   ('interns initiative real', 0.67),
#   ('offering paid internships', 0.5848),
#   ('initiative real estate', 0.5573)],
#  [('employee led networks', 0.6884),
#   ('progress diversity equality', 0.6165),
#   ('led networks continue', 0.5257),
#   ('diversity equality inclusion', 0.4941),
#   ('drive progress diversity', 0.4921)],
#  [('recently rebranded equitable', 0.7005),
#   ('pride womens network', 0.528),
#   ('womens network recently', 0.4292),
#   ('network recently rebranded', 0.4199),
#   ('carers pride womens', 0.4119)],
#  [('responsible business nextgen', 0.8082),
#   ('business nextgen represent', 0.7097),
#   ('overview responsible business', 0.5597),
#   ('nextgen represent support', 0.5544),
#   ('generation property professionals', 0.5176)],
#  [('improve gender diversity', 0.754),
#   ('gender diversity levels', 0.7162),
#   ('diversity levels 2022', 0.6302),
#   ('female representation board', 0.5754),
#   ('35 female representation', 0.5371)],
#  [('improve ethnic diversity', 0.6982),
#   ('ethnic diversity board', 0.697),
#   ('directors ethnic minority', 0.6733),
#   ('ethnic diversity levels', 0.6571),
#   ('recommendations ethnic diversity', 0.6523)],
#  [('pay gap year', 0.6651),
#   ('reduce pay gap', 0.6509),
#   ('target reduce pay', 0.545),
#   ('gap year year', 0.5085),
#   ('ahead target reduce', 0.4634)],
#  [('responsible procurement strong', 0.7323),
#   ('procurement strong relationship', 0.7212),
#   ('strong relationship suppliers', 0.6773),
#   ('supplier code conduct', 0.6708),
#   ('strategy governed supplier', 0.6576)],
#  [('obligations supply chain', 0.6744),
#   ('environmental obligations supply', 0.6713),
#   ('ethical environmental obligations', 0.625),
#   ('supply chain promotes', 0.5772),
#   ('social ethical environmental', 0.5423)],
#  [('compliance mandatory suppliers', 0.8641)],
#  [('living wage british', 0.7163),
#   ('pay uk employees', 0.7043),
#   ('suppliers pay uk', 0.6676),
#   ('wage british land', 0.6409),
#   ('uk employees real', 0.6234)],
#  [('london campuses accredited', 0.6856),
#   ('accredited living wage', 0.6001),
#   ('campuses accredited living', 0.5825),
#   ('wage places comply', 0.5563),
#   ('living wage places', 0.5053)],
#  [('human trafficking statement', 0.6608),
#   ('slavery human trafficking', 0.6549),
#   ('trafficking statement website', 0.6413),
#   ('governance modern slavery', 0.5864),
#   ('modern slavery act', 0.5379)],
#  [('payment code 2010', 0.574),
#   ('suppliers 30 days', 0.5443),
#   ('pay 95 suppliers', 0.5338),
#   ('governments prompt payment', 0.5324),
#   ('prompt payment code', 0.5161)],
#  [('group invoices settled', 0.7593),
#   ('invoices settled 18', 0.6784),
#   ('settled 18 days', 0.478),
#   ('18 days average', 0.3966)],
#  [('responsible procurement standards', 0.6178),
#   ('contractor framework identifying', 0.6039),
#   ('sustainability performance indicators', 0.5766),
#   ('introduced contractor framework', 0.568),
#   ('procurement standards year', 0.5491)],
#  [('supplier excellence awards', 0.8393),
#   ('launched supplier excellence', 0.7782),
#   ('best suppliers contributions', 0.6892),
#   ('excellence awards celebrate', 0.6782),
#   ('showcase best suppliers', 0.6716)],
#  [('slavery uphold human', 0.7404),
#   ('modern slavery uphold', 0.7155),
#   ('active modern slavery', 0.6708),
#   ('uphold human rights', 0.618),
#   ('human rights employees', 0.555)],
#  [('modern slavery training', 0.7433),
#   ('slavery training employees', 0.7367),
#   ('anti modern slavery', 0.6528),
#   ('year provided anti', 0.4218),
#   ('provided anti modern', 0.3645)],
#  [('audits 10 suppliers', 0.7304),
#   ('independent audits 10', 0.6608),
#   ('undertook independent audits', 0.6029),
#   ('10 suppliers operating', 0.5187),
#   ('supplier code conduct', 0.5059)],
#  [('hours staff development', 0.5467),
#   ('development worker representation', 0.5408),
#   ('included human rights', 0.5249),
#   ('working hours staff', 0.5151),
#   ('human rights health', 0.4642)],
#  [('audits prioritised property', 0.6648),
#   ('prioritised property management', 0.659),
#   ('assessments audits prioritised', 0.5633),
#   ('property management service', 0.5458),
#   ('providers assets construction', 0.5442)],
#  [('suppliers scored 77', 0.7136),
#   ('suppliers improvement opportunities', 0.674),
#   ('working suppliers improvement', 0.6605),
#   ('77 working suppliers', 0.6462),
#   ('improvement opportunities identified', 0.4463)],
#  [('unseens business helpline', 0.6733),
#   ('slavery occurrence anonymously', 0.5685),
#   ('member unseens business', 0.5492),
#   ('business helpline portal', 0.5306),
#   ('potential modern slavery', 0.4519)],
#  [('supplier excellence awards', 0.7479),
#   ('supplier awards felt', 0.7373),
# ...
#   ('executive directors included', 0.6124),
#   ('leavers board year', 0.589),
#   ('table reflect leavers', 0.4615)],
#  [('salary discretionary performance', 0.6107),
#   ('figures include salary', 0.6106),
#   ('include salary discretionary', 0.6066),
#   ('bonuses car allowance', 0.5702),
#   ('discretionary performance bonuses', 0.5559)],
#  [('remuneration related share', 0.6638),
#   ('share schemes included', 0.6504),
#   ('related share schemes', 0.5833)],
#  [('year bonus paid', 0.7046),
#   ('year bonuses paid', 0.6948),
#   ('current year bonuses', 0.6914),
#   ('prior year bonus', 0.6661),
#   ('bonus element based', 0.556)],
#  [('bonus payment data', 0.6409),
#   ('employees pro rated', 0.5851),
#   ('rated fte data', 0.5767),
#   ('pro rated fte', 0.5458),
#   ('salary bonus payment', 0.5424)],
#  [('non executive directors', 0.714),
#   ('directors included table', 0.615),
#   ('table executive directors', 0.5698),
#   ('executive directors included', 0.5695),
#   ('executive directors employed', 0.5682)],
#  [],
#  [('gender pay gap', 0.6844),
#   ('2022 pay gap', 0.6266),
#   ('pay gap reporting', 0.6154),
#   ('years gender pay', 0.5836),
#   ('reporting 2022 pay', 0.58)],
#  [('employees employed april', 0.6592),
#   ('employed april 2022', 0.6314),
#   ('2022 included data', 0.5032),
#   ('april 2022 included', 0.4975)],
#  [],
#  [('ethnicity pay gap', 0.6346),
#   ('gap reporting ethnicity', 0.6002),
#   ('pay gap british', 0.585),
#   ('gap british land', 0.5647),
#   ('gender pay gap', 0.5258)],
#  [('ethnicity included data', 0.5737),
#   ('disclosed ethnicity included', 0.5612),
#   ('employees employed april', 0.5556),
#   ('employed april 2022', 0.5425),
#   ('voluntarily disclosed ethnicity', 0.5219)],
#  [('included bonus calculations', 0.7388),
#   ('2022 included bonus', 0.7281),
#   ('bonus received year', 0.7133),
#   ('april 2022 included', 0.5865),
#   ('preceding april 2022', 0.4839)],
#  [('ethnicity pay gap', 0.7464),
#   ('report ethnicity pay', 0.67),
#   ('bame report ethnicity', 0.6408),
#   ('employees split bame', 0.6371),
#   ('ethnic non bame', 0.5439)],
#  [],
#  [('ceo pay ratio', 0.5939),
#   ('fourth year reporting', 0.5933),
#   ('reporting initiative gri', 0.5634),
#   ('gri fourth year', 0.5467),
#   ('median employee ceo', 0.5255)],
#  [('ceo pay data', 0.7893),
#   ('data includes salary', 0.5739),
#   ('includes salary benefits', 0.4777),
#   ('pay data includes', 0.4563),
#   ('salary benefits pension', 0.3915)],
#  [('figure reported 2022', 0.6308),
#   ('single figure reported', 0.6156),
#   ('reported 2022 annual', 0.598),
#   ('2022 annual report', 0.5767),
#   ('annual report accounts', 0.5438)],
#  [('total remuneration uk', 0.7362),
#   ('remuneration uk employees', 0.6942),
#   ('equivalent total remuneration', 0.6427),
#   ('uk employees financial', 0.5322),
#   ('employees financial year', 0.5094)],
#  [('ethnicity data captured', 0.7408),
#   ('2016 ethnicity data', 0.6782),
#   ('request human resources', 0.5728),
#   ('human resources systems', 0.5554),
#   ('captured human resources', 0.5346)],
#  [('given voluntarily employees', 0.6804), ('data given voluntarily', 0.6743)],
#  [('statistics ethnicity categories', 0.8045),
#   ('ethnicity categories shown', 0.73),
#   ('national statistics ethnicity', 0.6957),
#   ('office national statistics', 0.4924),
#   ('categories shown table', 0.4591)],
#  [('employee diversity sexual', 0.5955),
#   ('white includes employees', 0.5881),
#   ('hr identify lgbt', 0.5869),
#   ('diversity sexual orientation', 0.5475),
#   ('ethnic groups white', 0.5412)],
#  [('non executive directors', 0.7686),
#   ('excludes non executive', 0.7585),
#   ('data excludes non', 0.5711)],
#  [('employee diversity disability', 0.7278),
#   ('diversity disability proportion', 0.6982),
#   ('recording hr disability', 0.6549),
#   ('disability proportion employees', 0.6432),
#   ('52 employee diversity', 0.5961)],
#  [('categories disclosing disability', 0.6762),
#   ('disability data excludes', 0.6518),
#   ('disclosing disability data', 0.5822),
#   ('excludes non executive', 0.5564),
#   ('employees select categories', 0.5512)],
#  [('hidden disability hearing', 0.5804),
#   ('disability hearing disability', 0.5529),
#   ('visual disability mobility', 0.5292),
#   ('hearing disability visual', 0.5152),
#   ('disability mobility physical', 0.5049)],
#  [('non executive directors', 0.7686),
#   ('excludes non executive', 0.7585),
#   ('data excludes non', 0.5711)],
#  [],
#  [('weeks complete training', 0.5976),
#   ('excludes new starters', 0.5779),
#   ('training reported financial', 0.5678),
#   ('complete training reported', 0.5148),
#   ('starters weeks complete', 0.5127)],
#  [('mandatory training modules', 0.6667),
#   ('anti corruption bribery', 0.5865),
#   ('training mandatory training', 0.5687),
#   ('safety training mandatory', 0.5637),
#   ('corruption bribery information', 0.5601)],
#  [('employees complete training', 0.6061),
#   ('training modules employed', 0.5344),
#   ('complete training modules', 0.5247),
#   ('modules employed british', 0.5159),
#   ('employed british land', 0.4821)],
#  [('non executive directors', 0.7686),
#   ('excludes non executive', 0.7585),
#   ('data excludes non', 0.5711)],
#  [],
#  [('proportion calculated employees', 0.6319),
#   ('calculated employees employed', 0.5434),
#   ('performance review year', 0.5083),
#   ('employed british land', 0.4967),
#   ('employees employed british', 0.4943)],
#  [('non executive directors', 0.7686),
#   ('excludes non executive', 0.7585),
#   ('data excludes non', 0.5711)],
#  [('korn ferry uk', 0.7382),
#   ('limited korn ferry', 0.7189),
#   ('engaged korn ferry', 0.7002),
#   ('korn ferry conduct', 0.6972),
#   ('uk limited korn', 0.6581)],
#  [('estates gender ethnicity', 0.6132),
#   ('broadgate estates gender', 0.5832),
#   ('gender ethnicity pay', 0.5588),
#   ('ethnicity pay gaps', 0.5547),
#   ('ethnicity pay gap', 0.5355)],
#  [('gender ethnicity pay', 0.5767),
#   ('ethnicity pay gap', 0.5621),
#   ('review based 2022', 0.5434),
#   ('pay gap reports', 0.5285),
#   ('2022 data presented', 0.4841)],
#  [('gender pay gap', 0.7199),
#   ('review gender pay', 0.617),
#   ('regulations gender pay', 0.6092),
#   ('proportion employees receiving', 0.5834),
#   ('female employees quartile', 0.5795)],
#  [('ethnicity pay gap', 0.7514),
#   ('pay gap calculations', 0.597),
#   ('gap calculations reviewed', 0.3973),
#   ('calculations reviewed basis', 0.2794)],
#  [('employees receiving bonus', 0.615),
#   ('bonus pay review', 0.6109),
#   ('receiving bonus pay', 0.5714),
#   ('proportion employees receiving', 0.5712),
#   ('calculate proportion employees', 0.5256)],
#  [('ferry confirms resolved', 0.7167),
#   ('korn ferry confirms', 0.7043),
#   ('appropriate british land', 0.5181),
#   ('confirmed appropriate british', 0.5179),
#   ('resolved confirmed appropriate', 0.434)],
#  [('korn ferry independent', 0.6599),
#   ('ferry independent adviser', 0.6305),
#   ('control korn ferry', 0.604),
#   ('remuneration committee british', 0.5055),
#   ('independent adviser remuneration', 0.5026)],
#  [('korn ferry policies', 0.7911),
#   ('ferry policies procedures', 0.6957),
#   ('policies procedures designed', 0.5441),
#   ('procedures designed ensure', 0.4206),
#   ('objective independent advice', 0.3991)],
#  [('review relevant regulations', 0.6561),
#   ('pay governance specialists', 0.6476),
#   ('independent review carried', 0.612),
#   ('governance specialists experienced', 0.5719),
#   ('team pay governance', 0.5546)],
#  [('inherent limitations assurance', 0.7949),
#   ('limitations assurance assurance', 0.707),
#   ('inherent limitations data', 0.6152),
#   ('subject inherent limitations', 0.578),
#   ('assurance engagements subject', 0.5657)],
#  [('assurance relies premise', 0.6049),
#   ('furthermore assurance relies', 0.5988),
#   ('provided british land', 0.4663),
#   ('premise data information', 0.4612),
#   ('british land provided', 0.4475)],
#  [('ferry expressly disclaims', 0.7221),
#   ('disclaims liability responsibility', 0.668),
#   ('expressly disclaims liability', 0.6394),
#   ('liability responsibility decision', 0.5246),
#   ('korn ferry expressly', 0.5174)],
#  [('dnv business assurance', 0.7197),
#   ('uk limited dnv', 0.6846),
#   ('commissioned dnv business', 0.6269),
#   ('land commissioned dnv', 0.6225),
#   ('land company plc', 0.6062)],
#  [('conclusion based procedures', 0.5513),
#   ('performed evidence obtained', 0.5495),
#   ('procedures performed evidence', 0.546),
#   ('evidence obtained come', 0.5092),
#   ('believe selected information', 0.4896)],
#  [('limitations explained overleaf', 0.7038),
#   ('limited assurance report', 0.6985),
#   ('assurance report particular', 0.5893),
#   ('independent limited assurance', 0.5733),
#   ('inherent limitations explained', 0.5189)],
#  [('report british lands', 0.6627),
#   ('british lands management', 0.6498),
#   ('areas improvement raised', 0.6103),
#   ('observations areas improvement', 0.586),
#   ('raised separate report', 0.584)],
#  [('restricted 2022 data', 0.6781),
#   ('2022 data presented', 0.601),
#   ('work restricted 2022', 0.5943),
#   ('scope boundary work', 0.5316),
#   ('data presented figures', 0.3976)],
#  [('summary figures listed', 0.7176)],
#  [('nzc targets greenhouse', 0.7199),
#   ('sbti nzc targets', 0.6589),
#   ('targets greenhouse gas', 0.6372),
#   ('greenhouse gas intensity', 0.5739)],
#  [('net zero carbon', 0.8892), ('zero carbon developments', 0.8569)],
#  [('scopes ghg emissions', 0.7342),
#   ('ghg emissions location', 0.6901),
#   ('emissions location market', 0.6877),
#   ('indirect scopes ghg', 0.5772),
#   ('direct indirect scopes', 0.4808)],
#  [('indirect scopes landlord', 0.6504),
#   ('scopes landlord influenced', 0.6362),
#   ('landlord influenced greenhouse', 0.6355),
#   ('greenhouse gas emissions', 0.5628),
#   ('influenced greenhouse gas', 0.5235)],
#  [('greenhouse gas emissions', 0.6601),
#   ('value chain greenhouse', 0.6293),
#   ('chain greenhouse gas', 0.6051),
#   ('indirect scope value', 0.5579),
#   ('scope value chain', 0.5114)],
#  [('greenhouse gas emissions', 0.7686),
#   ('total greenhouse gas', 0.7308),
#   ('gas emissions gas', 0.6307)],
#  [('energy target intensity', 0.8463), ('building energy target', 0.8405)],
#  [('internal carbon levy', 0.7988),
#   ('carbon levy transition', 0.7622),
#   ('levy transition vehicle', 0.7095),
#   ('transition vehicle 10', 0.5623)],
#  [('electricity consumption 11', 0.9208),
#   ('total electricity consumption', 0.833)],
#  [('fuel consumption 12', 0.9095), ('total fuel consumption', 0.8642)],
#  [('like total electricity', 0.7084),
#   ('fuel consumption 13', 0.6908),
#   ('electricity fuel consumption', 0.6746),
#   ('total electricity fuel', 0.6428),
#   ('like like total', 0.4273)],
#  [('total energy consumed', 0.7761),
#   ('energy consumed generated', 0.7276),
#   ('consumed generated site', 0.5575),
#   ('generated site 14', 0.4256)],
#  [('sustainability ratings 15', 0.985)],
#  [('energy performance certificates', 0.8916),
#   ('performance certificates epc', 0.7186),
#   ('certificates epc 16', 0.6061)],
#  [('water consumption 17', 0.9268), ('total water consumption', 0.8216)],
#  [('water consumption 18', 0.749),
#   ('total water consumption', 0.7052),
#   ('like total water', 0.6837),
#   ('like like total', 0.4703)],
#  [('building water target', 0.8415),
#   ('water target intensity', 0.8387),
#   ('target intensity 19', 0.6843)],
#  [('waste management managed', 0.7123),
#   ('portfolio corporate 20', 0.6753),
#   ('managed portfolio corporate', 0.6312),
#   ('management managed portfolio', 0.628)],
#  [('like waste management', 0.6471),
#   ('management managed portfolio', 0.627),
#   ('waste management managed', 0.6101),
#   ('managed portfolio 21', 0.6082),
#   ('like like waste', 0.5062)],
#  [('waste management developments', 0.9617),
#   ('management developments 23', 0.5302)],
#  [('environmental compliance 32', 0.6012),
#   ('health safety compliance', 0.5487),
#   ('compliance 32 community', 0.5288),
#   ('dnv personnel applicable', 0.5232),
#   ('safety compliance 40', 0.5215)],
#  [('sustainability assurance professionals', 0.733),
#   ('team sustainability assurance', 0.6875),
#   ('independent team sustainability', 0.6342),
#   ('engagement work carried', 0.4775),
#   ('work carried independent', 0.3744)],
#  [('dnv held audit', 0.5753),
#   ('contracts british land', 0.4619),
#   ('assurance contracts british', 0.4439),
#   ('audit assurance contracts', 0.3695),
#   ('british land conflict', 0.356)],
#  [('sustainability assurance experience', 0.7203),
#   ('professionals combination environmental', 0.7169),
#   ('environmental sustainability assurance', 0.6638),
#   ('combination environmental sustainability', 0.5949),
#   ('team consisted professionals', 0.5356)],
#  [('lands reporting criteria', 0.7483),
#   ('reporting criteria criteria', 0.6338),
#   ('british lands reporting', 0.6287),
#   ('material misstatement report', 0.5604),
#   ('information includes assessment', 0.5455)],
#  [('report british lands', 0.6159),
#   ('published report british', 0.5797),
#   ('british lands website', 0.4745),
#   ('information published report', 0.3695),
#   ('current reporting period', 0.3501)],
#  [('assurance engagements isae', 0.7774),
#   ('revised assurance engagements', 0.7451),
#   ('standard assurance engagements', 0.7377),
#   ('assurance engagements audits', 0.7133),
#   ('assurance engagement accordance', 0.7119)],
#  [('comply ethical requirements', 0.6702),
#   ('requires comply ethical', 0.6482),
#   ('perform assurance engagement', 0.6175),
#   ('ethical requirements plan', 0.6174),
#   ('standard requires comply', 0.6119)],
#  [('dnv applies management', 0.696),
#   ('management standards compliance', 0.5905),
#   ('quality control accordance', 0.583),
#   ('standards compliance policies', 0.5807),
#   ('compliance policies quality', 0.5522)],
#  [('limited assurance engagement', 0.7594),
#   ('reasonable assurance engagement', 0.7347),
#   ('assurance engagement level', 0.7317),
#   ('assurance engagement vary', 0.7249),
#   ('substantially lower assurance', 0.7099)],
#  [('evidence considered sufficient', 0.6338),
#   ('opinion risk conclusion', 0.5794),
#   ('risk conclusion error', 0.5607),
#   ('obtain evidence considered', 0.5605),
#   ('basis opinion risk', 0.5568)],
#  [('land management data', 0.5614),
#   ('british land management', 0.5582),
#   ('land selected information', 0.526),
#   ('consolidation data group', 0.4599),
#   ('level data consolidated', 0.4557)],
#  [('dnv free choose', 0.6328),
#   ('selected information regard', 0.4358),
#   ('free choose site', 0.4277),
#   ('site basis materiality', 0.4187),
#   ('information regard criteria', 0.4101)],
#  [('dnv business assurance', 0.6818),
#   ('inherent limitations assurance', 0.6696),
#   ('limitations assurance engagements', 0.6498),
#   ('limitations selective testing', 0.5691),
#   ('inherent limitations selective', 0.5645)],
#  [('non financial data', 0.7565),
#   ('uncertainty financial data', 0.7487),
#   ('inherent uncertainty financial', 0.6279),
#   ('financial data given', 0.5937),
#   ('financial data subject', 0.5773)],
#  [('quantifications different entities', 0.7023),
#   ('different quantifications different', 0.6861),
#   ('different acceptable measurement', 0.6371),
#   ('acceptable measurement techniques', 0.6364),
#   ('result different quantifications', 0.5548)],
#  [('assurance relies premise', 0.6113),
#   ('provided british land', 0.4604),
#   ('premise data information', 0.4602),
#   ('information provided british', 0.4464),
#   ('british land provided', 0.4427)],
#  [('dnv expressly disclaims', 0.839),
#   ('disclaims liability responsibility', 0.7206),
#   ('expressly disclaims liability', 0.7182),
#   ('liability responsibility decision', 0.5532),
#   ('independent limited assurance', 0.5364)],
#  [('responsibilities board directors', 0.6862),
#   ('land dnv directors', 0.6699),
#   ('land sole responsibility', 0.624),
#   ('directors british land', 0.6226),
#   ('board directors british', 0.6203)],
#  [('responsibility plan perform', 0.6029),
#   ('assurance selected information', 0.5734),
#   ('assurance conclusion based', 0.5566),
#   ('limited assurance conclusion', 0.5526),
#   ('information prepared accordance', 0.5345)],
#  [('responsible preparation report', 0.497)],
#  [('dnv business assurance', 0.8005),
#   ('business assurance dnv', 0.8002),
#   ('assurance dnv business', 0.7711),
#   ('uk limited dnv', 0.7405),
#   ('limited dnv business', 0.7306)]]

# %%
key = ['ghg', 'sbti', 'tcfd', 'sasb']

# %%
def func(kw, key):
    if any(any(w in word[0] for w in key) for word in kw):
        return True

# %%
df_w['kw'] = kw

# %%
df_filtered = df_w[df_w['kw'].apply(lambda x: func(x, key)) == True]

# %%
df_filtered
# Out:
#                                                  words  \
# 0    Our ESG journey Our 2030 commitments Performan...
# 278  Location based: Our use of the 2021 UK greenho...
# 385  Overview SASB table This is British Lands firs...
# 465  Scope 1 and 2 GHG emissions intensities for EP...
# 466  For the financial ratio, see GHG Emissions Sco...
# 471  Carbon intensity includes Scope 1, 2 and 3 GHG...
# 503  Scope 1 and 2 GHG emissions financial intensit...
# 504  Financial intensity ratio expresses absolute S...
# 505  Absolute Scope 1 and 2 GHG emissions relate to...
# 511  Includes 100% of GHG emissions from our develo...
# 517  GHG conversion emissions factors for 2022 (see...
# 521  This includes the seven main GHG emissions cov...
# 522  Emissions are grouped by Scope 1, 2 and 3 in a...
# 526  Scope 1 and 2 absolute target: this Science Ba...
# 527  The reporting years total Scope 1 and 2 GHG em...
# 532  For the SBTi numerator, the A1-A5 emissions ar...
# 536  B1-B5 emissions (embodied carbon from the oper...
# 567  We use the location-based method to report our...
# 568  The location-based method was also used for GH...
# 615  Table 4 shows the combined carbon-equivalent e...
# 946       SBTi NZC targets greenhouse gas intensity 2.
# 948  Total direct and indirect (Scopes 1 2 & 3) GHG...
#
#                                                     kw
# 0    [(esg journey 2030, 0.5345), (2022 epra index,...
# 278  [(2021 uk greenhouse, 0.7075), (uk greenhouse ...
# 385  [(lands sustainability accounts, 0.6194), (ove...
# 465  [(emissions intensities epra, 0.7542), (intens...
# 466  [(emissions scope financial, 0.7036), (ghg emi...
# 471  [(carbon intensity includes, 0.718), (scope gh...
# 503  [(scope ghg emissions, 0.7161), (emissions fin...
# 504  [(financial intensity ratio, 0.668), (intensit...
# 505  [(scope ghg emissions, 0.7984), (ghg emissions...
# 511  [(ghg emissions developments, 0.6352), (emissi...
# 517  [(ghg conversion emissions, 0.6797), (emission...
# 521  [(main ghg emissions, 0.7272), (ghg emissions ...
# 522  [(emissions grouped scope, 0.7891), (scope acc...
# 526  [(sbti target reported, 0.6401), (target initi...
# 527  [(scope ghg emissions, 0.7563), (ghg emissions...
# 532  [(a1 a5 emissions, 0.6903), (a5 emissions pro,...
# 536  [(b1 b5 emissions, 0.7128), (b5 emissions embo...
# 567  [(ghg emissions track, 0.6567), (total ghg emi...
# 568  [(used ghg emissions, 0.6599), (ghg emissions ...
# 615  [(carbon equivalent emission, 0.6725), (factor...
# 946  [(nzc targets greenhouse, 0.7199), (sbti nzc t...
# 948  [(scopes ghg emissions, 0.7342), (ghg emission...

# %%
df_audit = df_w[df_w['kw'].apply(lambda x: func(x, ['externally assured', 'independently assured', 'independent limited assurance'])) == True]

# %%
df_audit
# Out:
#                                                  words  \
# 263  Selected datahas been independently assured si...
# 418  Certain key data is independently assured (see...
# 942  This conclusion relates only to the Selected I...
# 983  DNV expressly disclaims any liability or co-re...
#
#                                                     kw
# 263  [(datahas independently assured, 0.7164), (sel...
# 418  [(data independently assured, 0.7789), (key da...
# 942  [(limitations explained overleaf, 0.7038), (li...
# 983  [(dnv expressly disclaims, 0.839), (disclaims ...

# %%
df_audit['words'].apply(lambda x: print(x))
# Out:
# Selected datahas been independently assured since 2007 (see earlier reports).
# Certain key data is independently assured (see below).
# This conclusion relates only to the Selected Information, and is to be read in the context of this Independent Limited Assurance Report, in particular the inherent limitations explained overleaf.
# DNV expressly disclaims any liability or co-responsibility for any decision a person or an entity may make based on this Independent Limited Assurance Report.
# 263    None
# 418    None
# 942    None
# 983    None
# Name: words, dtype: object

# %%
df_compensation = df_w[df_w['kw'].apply(lambda x: func(x, ['targets', 'sustainable practices'])) == True]

# %%
df_compensation
# Out:
#                                                  words  \
# 49   Our Bright Lights skills and employment progra...
# 55   Top 81st percentile Science Based Targets: app...
# 63   From 2021, the 2030 strategy upgraded our BREE...
# 264  SBTi, Net Zero targets and greenhouse gas inte...
# 460  These targets are based on improvements in who...
# 946       SBTi NZC targets greenhouse gas intensity 2.
#
#                                                     kw
# 49   [(carbon reduction targets, 0.6085), (lights s...
# 55   [(81st percentile science, 0.6119), (percentil...
# 63   [(2030 strategy upgraded, 0.7276), (2021 2030 ...
# 264  [(portfolios carbon intensity, 0.5917), (affec...
# 460  [(improvements building intensity, 0.8052), (t...
# 946  [(nzc targets greenhouse, 0.7199), (sbti nzc t...

# %%
df_compensation['words'].apply(lambda x: print(x))
# Out:
# Our Bright Lights skills and employment programme Science Based Targets initiative validated our carbon reduction targets.
# Top 81st percentile Science Based Targets: approval in 2021 Our Place Based approach means understanding the most important issues and opportunities in the communities around each of our places and focusing our efforts collaboratively to make the biggest impact at each place.
# From 2021, the 2030 strategy upgraded our BREEAM targets to Outstanding for Offices (from Excellent) and Excellent for Retail (from Very Good) 2.
# SBTi, Net Zero targets and greenhouse gas intensity For the second consecutive year, COVID-19 and related government restrictions has significantly affected our portfolios carbon intensity, representing the majority of the reduction.
# These targets are based on improvements in whole building intensity.
# SBTi NZC targets greenhouse gas intensity 2.
# 49     None
# 55     None
# 63     None
# 264    None
# 460    None
# 946    None
# Name: words, dtype: object

# %%
df_audit['words'].apply(lambda x: print(x))
# Out:
# On the standing portfolio, we completed our net zero audits and are working with our customers to invest into the energy efficient interventions that programme has identified.
# Net zero asset audits completed Working with third party experts, we completed 29 audits across the portfolio identifying opportunities to improve the energy efficiency of our standing portfolio.
# This year we completed 29 net zero audits of buildings across our portfolio identifying initiatives which would deliver at least a 25% improvement in whole building energy efficiency.
# Overview Net Zero Carbon Reducing operational carbon continued Increasing energy efficiency on the standing portfolio This year, third party consultants completed net zero audits covering 29 of our major assets.
# Through our partnership with anti-modern slavery charity Unseen, we also undertook independent audits of 10 of our suppliers operating in higher risk areas (with 11 more scheduled), reviewing compliance on 12 key areas of our Supplier Code of Conduct.
# Informed by risk and impact assessments, audits prioritised property management service providers at our assets and construction contractors on our developments.
# Our Net Zero and energy auditsassessed major assets representing 90% of landlord procured power.
# In 2022 we undertook a number of independent water audits in order to identify existing or potential issues.
# Following our Net Zero Audits programme we now have a pathway for each major asset.
# 9      None
# 23     None
# 105    None
# 113    None
# 254    None
# 256    None
# 298    None
# 392    None
# 400    None
# Name: words, dtype: object

# %%
def get_kw(df, key):
    kw = []
    for i in tqdm(df['words']):
        kw.append(bert.extract_keywords(i, stop_words='english'))
    
    df['kw'] = kw
    df_filtered = df_w[df_w['kw'].apply(lambda x: func(x, key)) == True]
    if not df_filtered.empty:
        print("True")
        print(df['words'])

# %%
get_kw(df_w, ['audited'])
# Out:
#   0%|          | 0/988 [00:00<?, ?it/s]

# %% [markdown]
# ### BERT Test

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\anaconda3\lib\site-packages (4.23.0)
# Requirement already satisfied: filelock in c:\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\anaconda3\lib\site-packages (from transformers) (0.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\anaconda3\lib\site-packages (from transformers) (0.10.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in c:\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)

# %%
import torch
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer

# %%
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
# Out:
# Downloading:   0%|          | 0.00/443 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
df_w
# Out:
#                                                  words  \
# 0    Our ESG journey Our 2030 commitments Performan...
# 1    As we go into a new year, with new uncertainti...
# 2    Introduction This year we celebrate 20 years o...
# 3    The climate emergency is high on everyones age...
# 4    This means progressing our pathway to net zero...
# ..                                                 ...
# 983  DNV expressly disclaims any liability or co-re...
# 984  Responsibilities of the Board of Directors of ...
# 985  Our responsibility is to plan and perform our ...
# 986  We have not been responsible for the preparati...
# 987  DNV Business Assurance DNV Business Assurance ...
#
#                                                     kw
# 0    [(overview kpis, 0.5098), (kpis net, 0.474), (...
# 1    [(dedication vital, 0.572), (horizon dedicatio...
# 2    [(years sustainability, 0.7121), (sustainabili...
# 3    [(climate emergency, 0.6627), (crisis impact, ...
# 4    [(positive impact, 0.4841), (net zero, 0.4431)...
# ..                                                 ...
# 983  [(disclaims liability, 0.7088), (expressly dis...
# 984  [(responsibilities board, 0.6026), (board dire...
# 985  [(responsibility plan, 0.565), (assurance conc...
# 986  [(preparation report, 0.4001), (responsible pr...
# 987  [(dnv business, 0.7238), (assurance dnv, 0.664...
#
# [988 rows x 2 columns]

# %%
question = "Which standard is used to measure carbon emissions? "

# %%
paragraph = """
We use internal methodology to measuer carbon emissions
"""

# %%
encoding = tokenizer.encode_plus(text=question,text_pair=paragraph)

# %%
inputs = encoding['input_ids']  #Token embeddings
sentence_embedding = encoding['token_type_ids']  #Segment embeddings
tokens = tokenizer.convert_ids_to_tokens(inputs) #input tokens

# %%
score = model(input_ids=torch.tensor([inputs]), token_type_ids=torch.tensor([sentence_embedding]))

# %%
start_index = torch.argmax(score.start_logits)

end_index = torch.argmax(score.end_logits)

answer = ' '.join(tokens[start_index:end_index+1])

# %%
corrected_answer = ''

for word in answer.split():
    
    #If it's a subword token
    if word[0:2] == '##':
        corrected_answer += word[2:]
    else:
        corrected_answer += ' ' + word

print(corrected_answer)
# Out:
#  internal methodology

# %%
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
tok = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %%
def test(question, paragraph, model, tokenizer):
    encoding = tokenizer.encode_plus(text=question,text_pair=paragraph)
    inputs = encoding['input_ids']  #Token embeddings
    sentence_embedding = encoding['token_type_ids']  #Segment embeddings
    tokens = tokenizer.convert_ids_to_tokens(inputs) #input tokens
    score = model(input_ids=torch.tensor([inputs]), token_type_ids=torch.tensor([sentence_embedding]))
    
    start_index = torch.argmax(score.start_logits)

    end_index = torch.argmax(score.end_logits)

    answer = ' '.join(tokens[start_index:end_index+1])
    
    corrected_answer = ''

    for word in answer.split():
    
        #If it's a subword token
        if word[0:2] == '##':
            corrected_answer += word[2:]
        else:
            corrected_answer += ' ' + word
    print(corrected_answer)
    return corrected_answer

# %%
df_new = df_w[['words']].drop_duplicates()

# %%
df_new
# Out:
#                                                  words
# 0    Our ESG journey Our 2030 commitments Performan...
# 1    As we go into a new year, with new uncertainti...
# 2    Introduction This year we celebrate 20 years o...
# 3    The climate emergency is high on everyones age...
# 4    This means progressing our pathway to net zero...
# ..                                                 ...
# 983  DNV expressly disclaims any liability or co-re...
# 984  Responsibilities of the Board of Directors of ...
# 985  Our responsibility is to plan and perform our ...
# 986  We have not been responsible for the preparati...
# 987  DNV Business Assurance DNV Business Assurance ...
#
# [932 rows x 1 columns]

# %%
df_new['kw2'] = df_new['words'].apply(lambda x: test("Are your emission reduction targets independently assured?", x, model, tok))
# Out:
#  criteria assurance reports
#  progressing our pathway to net zero and making a positive impact at our places is more important than ever
#  canada water
#  fully let ( or under option ) four years ahead of completion
#  we completed our net zero audits
#  one outcome will be to raise epc ratings across our portfolio to a or b by 2030 in line with expected mees legislation
#  gresb
#  our place based approach and our strong local relationships
#  this year marked ten years of our partnership with the national literacy trust
#  certified schemes
#  working with third party experts
#  whole building operational energy intensity improvement vs 2019 baseline for offices 3
#  breeam certification framework
#  one of londons biggest rehearsal and artist development complexes
#
#  sustainability brief for developments
#
#  signatory to the un global compact
#  independently assured
#  completed first whole life carbon assessments
#  our sustainability brief established the social and environmental requirements for our developments
#  ukgbc works to promote sustainability
#  launched community charter
#  regents place customer community fund
#  launched bright lights , our skills and employment programme
#  worked with happy city to establish seven core principles
#  2030 sustainability strategy commitment to be net zero by 2030
#  independently assured ? [SEP]
#
#  our bright lights skills and employment programme science based targets initiative validated our carbon reduction targets
#  our net zero pathway
#  we already offset embodied carbon in developments and from 2030 will offset operational carbon
#  have set out clear targets
#  we demonstrate the strong progress we are delivering by participating in leading international benchmarks
#  we are pleased to have achieved this two years ahead of target
#  top 81st percentile science based targets : approval in 2021
#  from 2021 , the 2030 strategy upgraded our breeam targets to outstanding for offices ( from excellent ) and excellent for retail ( from very good ) 2
#  we have pursued breeam certificates
#  while we target best - in - class certifications
#  we are currently pursuing a multi - stage rollout of breeam in use certifications including first - time pilots at retail assets
#  following socio - economic assessments
#  use the priority assets tables on pages 21 - 23 to report progress against this
#  have set out clear targets
#  we have a long track record of delivering sustainable space and this a clear competitive advantage for our business as more and more of our customers prioritise sustainability
#  delivering on our pathway last year we set out our pathway to net zero
#  we committed to undertaking whole life carbon assessments
#  we have adopted one click lca life cycle assessment software
#  this enables us to consolidate data so together with our consultants
#  we focus on reusing existing materials and structures as far as possible
#  all the timber joists were individually assessed
#  new materials focused on responsibly sourced and low carbon alternatives
#  as a result we currently expect embodied carbon to be 403 kg co2e per sqm ( 434 kg co2e per sqm for the whole redevelopment ) , ahead of our 2030 target
#  so operational energy intensity is expected to be in line with our trajectory to 2030
#  canada water case study
#  piloting more sustainable materials and processes
#  we are using more sustainable materials in the superstructure
#  we are using post tensioned concrete slabs
#  these innovations are in line with the commitment to pilot low carbon materials in our net zero pathway
#  our current projections are for embodied carbon to be 682 kg co2e per sqm which is above our 2030 target of 500kg co2e per sqm , but below the glidepath to 2030
#  prioritise the re - use of existing materials to minimise embodied carbon as far as possible
#  certified emission reduction projects
#
#  supporting the planting of 23 , 000 trees through the woodland carbon code
#
#  the chart below sets out the key opportunities we have to reduce carbon emissions across our portfolio
#  energy intensity is just one sixth of the previous building .
#  identifying initiatives which would deliver at least a 25 % improvement in whole building energy efficiency
#  a case study of exchange house
#  indicative view
#  the decarbonisation of the national grid will play a key role in the switch to renewable power across the uk
#  are now undertaking feasibility studies to identify further opportunities for rooftop and solar car port possibilities
#  third party consultants completed net zero audits
#  one of the most effective interventions we have already delivered is introducing co2 controls
#  most significant interventions are led lighting and heat pumps
#  making the building fully compliant with expected mees legislation
#  our local charter
#
#  together , we agree priority local themes
#  15 customers and local stakeholders pledged over 150 , 000 to our broadgate and paddington central community funds
#  primary school projects and secondary school workshops to college events and university challenges
#  ringfenced opportunities with businesses at our places
#  over 60 % of candidates have already gained employment
#  ndt broadgate
#  we are on track to achieve well platinum
#  we are targeting industry leading standards
#  our first two office developments at canada water , a1 and a2 , will both be well - ready
#  pre - certification
#  our place based approach goes far beyond those assets with programmes delivered across our portfolio
#  we have rolled out specific qr codes
#  our bright lights initiatives will focus many of their activities on those most affected
#  working with local partners
#  our partnership with environmental education charity global generation continues to grow .
#  global generation engaged over 600 local primary schoolchildren through workshops and worked with generator youth leaders .
#  constructed using circular economy principles
#  we engaged 47 schoolchildren local to broadgate through our collaboration with the national literacy trust and customers
#  students worked collaboratively on designs for the campus through the broadgate prize
#  prioritising se16 residents
#  self - sustaining local business network
#  british land authentically supports people in the community
#  mature birch trees will offer homes for birds
#  strong relationship with capital city partnership
#  capital city partnership is on site every day , so retailers know vulnerable candidates have a network of resources to draw on
#  we couldnt have done that without the support of british land
#  internal mentorship scheme
#  90 % of staff reporting that they were proud to work for british land and 85 % confirming that they would recommend british land as a great place to work .
#
#  we maintained our excellent standards for health and safety to ensure our people and places are safe
#  our health and safety management system is accredited to the international iso standard
#  british land offers up to six months of shared parental leave on full pay .
#  approved by our csr committee
#  aligned with the united nations sustainable development goals , this sets out our commitments to improve the diversity , equality and inclusivity of our business by 2030 , ensuring that we reflect and understand the people who work , shop , live and spend time at our places
#  all our employee feedback channels , including exit interviews and engagement surveys , include diversity demographics
#  we ensure hiring managers complete anti - bias training and receive blind cvs at the selection for interview stage
#  a strong relationship with our suppliers plays a key role in the successful delivery of our strategy which is governed by our supplier code of conduct
#  compliance is mandatory for all suppliers
#  we strongly encourage all suppliers to pay their uk employees at or above the real living wage
#  our london campuses are accredited living wage places and also comply with the mayors good work standard
#  we have been a signatory to the uk governments prompt payment code since 2010 and aim to pay 95 % of suppliers within 30 days
#  we introduced our contractor framework
#  supplier excellence awards
#  we also undertook independent audits of 10 of our suppliers operating in higher risk areas ( with 11 more scheduled ) , reviewing compliance on 12 key areas of our supplier code of conduct
#  by working with these suppliers improvement opportunities will be identified and agreed
#  our supplier excellence awards we are delighted to be recognised by british land in their first supplier awards
#  havent seen any other client take this approach to service partner recognition
#  british land sustainability
#  full assurance reports
#  selected datahas been independently assured since 2007
#  net zero targets
#  we have also delivered initiatives which enhance energy efficiency
#  independently assured
#  the embodied emissions are offset after the project achieves the practical completion
#  until the uk government specifies the long - term strategy for low - carbon heating ( including the role of hydrogen and all - electric buildings ) , y will include the use of renewable bio - gas .
#  exploring all electric option targeting < 80
#  not undertaken the full nabers accreditation
#  tbc data will be available in future years
#  estimated energy consumption in retail units assumes regular operations .
#  this will show a significant rise vs last year , where we assumed only 50 % operation in retail units
#  location based
#  renewable gas rose to 85 % this year , renewable power dropped to 93 % .
#  reduced from last year primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff
#  independently assured ? [SEP] retail : direct use in retail units ( occupier procured ) fri or non - landlord obtained energy at non - bl managed assets upstream emissions from landlord obtained water use indirect value chain greenhouse gas emissions in 2021 / 22 , our estimated energy consumption in retail units assumes regular operations .
#  independently assured
#  we have also delivered initiatives which enhance energy efficiency
#  the committed development figures are provisional
#  proportionally disclosed at share
#  investment this year included a chiller replacement at broadwalk house with a total capex of 552 , 000 .
#  our net zero and energy audit
#  independently assured
#  primarily due to the impact of onboarding new assets where it may take time to transfer these assets onto a renewable tariff
#  independently assured
#  revolving credit facility kpis exclude residential properties
#  breeam
#  10 exchange square completed its first assessment
#  we also piloted breeam in use ( part 2 ) assessments
#
#  incentivises us to prioritise the collection of retailer consumption data
#  building certifications
#  independently assured
#  2021 / 22
#  independently assured
#  independently assured
#  independently assured
#  assurance excludes waste diverted from landfill through re - use on site and landfilled tax costs
#  despite these efforts , a sizable proportion still had to be sent to landfill
#  we opted to install reclaimed tiles from a supplier that takes back used raised floor tiles , tests them and provides new warranties .
#  the flooring supplier they were purchased from did not hold an fsc certification
#  we are therefore choosing to report these as non - certified
#  installing reclaimed tiles
#
#
#  independently assured
#  independently assured
#  independently assured
#  [CLS]
#  community investment
#  this value reflects the cost the organisations would have to bear if space was not provided by british land
#  planning consents
#  considerate constructors scheme scoring for the considerate constructors scheme has been updated for fy22
#  british land company plc ( company number : ) is a signatory of the prompt payment code
#  a duty on the uks largest companies and llps to report on a half - yearly basis on their payment practices , policies and performance .
#  independently assured ? [SEP] overview health and safety
#  independently assured ? [SEP] overview health and safety
#  requiring resolution within a shorter timeframe than with the previous compliance partner
#  2020 resolved percentages are an indication of this transition to new service provider and the subsequent work required to integrate new classifications into our processes .
#  independently assured
#  turnover rates are based on the number of leavers divided by the total number of employees at 31 march 2022
#  compare the gender pay ratios of employees in the same employment level .
#  remuneration
#  not mandatory training
#  independently assured ? [SEP]
#  dse assessment were therefore not mandatory this year as employees could also undertake these other assessments which were more appropriate
#  participation levels for the dse assessment and training are expecting to return to a higher rate for 2023
#  our it team had a target of reaching 85 % trained , which has been exceeded .
#  as per epra best practice recommendations
#
#  water intensity data covers whole buildings for offices and common parts for retail .
#  per m2 comprises net internal areas for offices and common parts for retail
#  employee data has been restated using headcount rather than fte
#  sustainability accounting standards board ( sasb ) framework .
#  provides limited data on certain indicators which have not previously been reported against
#  we will continue to consider how our reporting can develop to meet the needs of our stakeholders
#  independent water audits
#  our pathway to net zero , our transition plan , is available online at 2
#  sustainability brief for developments and operations is available online
#  no cost recovery clauses
#  we will use our transition vehicle to fund gaps so that the most efficient equipment can be installed
#  sustainability
#
#  these pathways arebeing presented to occupiers
#  sustainability impacts are a standing agenda item at property management forums
#  it also sets out the overall principles , boundaries , scope and methodologies applied when reporting sustainability data in our 2022 annual report and accounts , sustainability accounts and corporate website
#  reporting sustainability data in our 2022 annual report and accounts , sustainability accounts ( the report ) and corporate website
#  reporting criteria
#  we report data on issues relevant to our sustainability strategy
#  dnvs
#  dnvs
#  dnvs third year as our assurance partner
#  data is as accurate and complete as practical and feasible
#  consistent boundaries and methodologies are used wherever possible to allow comparisons over time
#  certain key data
#  where updated or new data is available , we restate data for prior years where the restatement is material
#  reporting criteria
#  rounding may mean that some columns do not sum precisely .
#  we engaged dnv to perform independent limited assurance of a selection of our most material 2022 data
#  we have designed , implemented and maintained internal controls and processes over information relevant to the measurement and preparation of the assured data
#  broadgate estates data is now included within british land and group data
#  covid - 19 has had a significant impact on a number of reporting areas for both 2021 and 2022
#  refer to the relevant focus area section of the reporting criteria
#  residential units belonging to one estate reported jointly
#  scope changed in fy21 reporting to include only projects that are formally committed in line with financial reporting
#  overview exceptions are sustainability ratings , flood risk and greenhouse gases , where we report on 100 % of assets under management
#  where this is not feasible
#  we make this clear in the reporting criteria
#  since 2015 , all our developments and managed portfolio are in the uk
#  to enable clearer comparison of performance over time , we report like - for - like performance in line with guidelines from the european public real estate association ( epra )
#  we monitor our energy and carbon intensity against our 2019 baseline and assess progress towards our 2030 energy and net zero carbon intensity targets
#  these targets are based on improvements in whole building intensity
#  currently , robust whole building energy and water data is only available for offices
#  each property is classified and reported on by asset type
#  financial ratio
#  properties are only included in intensity calculations
#  the scope of our net zero related energy and carbon intensity reporting is in accordance with guidelines published by the uk green building council
#
#  must have been managed by british land for at least 18 months and have reached at least 80 % occupancy
#  any new acquisitions of fully operational properties must have reached at least 80 % occupancy
#  energy , carbon and water relate to the whole building including both landlord and occupier areas plus any vacant space .
#  net lettable areas ( nla ) .
#  in 2021 floor area figures were sourced from mid - year valuations
#  must have been managed by british land for at least 12 months and have reached at least 80 % occupancy
#  landlord common parts intensity only is reported until occupier data can be obtained
#  only is reported until occupier data can be obtained
#  independently assured ? [SEP]
#  it has both negligible landlord procured common parts consumption and no appropriate denominator
#  shopping villages and high street retail : energy and carbon intensity to be reported when further data is available
#  shopping villages have external walkways and common areas beyond car parks but which are not enclosed
#  neither common parts floor area nor car park spaces is an appropriate denominator in the absence of occupier data
#  we report progress against a 5 % absolute improvement target in total water consumption versus a 2020 baseline for like - for - like assets .
#  financial intensity measures
#  financial intensity ratio
#  absolute scope 1 and 2 ghg emissions relate to managed portfolio electricity
#  figs
#  independently assured ? [SEP] waste managed by british land
#  100 % of ghg emissions from our developments , joint venture developments and developments undertaken by others with our funding
#  independently assured
#  independently assured ? [SEP]
#  estimated
#  value chain : full details of our value chain reporting
#  uk government conversion factors for company reporting 2021
#  ghg conversion emissions factors for 2022 ( see table 4 ) are sourced from the uk department for business , energy & industrial strategys ( beis ) 2021 guidelines
#  similarly , conversion factors for 2021 and 2020 were sourced from beiss 2020 and 2019 guidelines
#  the global warming potential of each greenhouse gas is sourced from the ipcc fourth assessment report
#  in line with common practice
#
#
#  scope 3
#
#  the reporting years total scope 1 and 2 ghg emissions are prepared for and sourced from figure 4
#
#  whole life carbon assessment
#  a recalculation is performed to assess and report the remaining carbon emissions between the stage 4 and final / as built assessment at practical completion
#  pro - rated by the duration of the construction project
#  if the projects actual embodied carbon is higher or lower than the estimate
#  if the actual project only results in 9 , 000 tonnes co2e
#  currently , these ghg emissions are estimated using industry benchmarks developed by industry expert simon sturgis
#  british land intends to monitor the actual operational embodied emissions at managed assets
#  nla inflated by 25 % to approximate gia
#  the denominator of the intensity target is the sum of ( i ) the net lettable area of the managed portfolio , and ( ii ) the pro - rated net lettable area of the developments under construction or completed in the reporting year
#
#  nzc2020standard
#  nzc 2030 standard : as werolloutthefull2030 programme , british land will incorporate theadditional criteriaof advanced modelling of operational efficiency
#  all new developments refurbishments , where the carbon levy applies , which are subject to the carbon levy are required to report their embodied emissions and offset to zero at practical completion
#  breeam compliant whole life carbon software
#
#  modelled using enhanced building energy modelling
#  modelling
#  forecasted nabers energy star rating : indicates the completed : refer to projects that have achieved practical completion
#  committed
#  there is an intention to undertake development and internal certain conditions are satisfied
#  zero on - site fossil fuel combustion
#  on - site or additional ppa renewables
#
#  where developments do not achieve the mayors carbon reduction targets
#  this offsetting fund
#  committed projects : refer to projects approved by executive board
#  completed projects : refer to projects that have achieved practical completion
#  all new developments and refurbishments , where the carbon levy applies , are required to report their embodied emissions and offset to zero at practical completion
#
#  rics assessments
#  independently assured
#  scope 2 emissions : managed portfolio electricity use in common parts and shared services and our corporate electricity use , also reported in fig
#  according to a location - based and a market - based method
#  we use the location - based method to report our total ghg emissions and track performance against our 2019 baseline
#  location - based method
#  the location - based method
#  we use the beis uk grid average emissions factor for the location - based method
#  the market - based method
#  we use supplier specific emission rates where available and the residual mix emissions factor for the remaining supplies
#  renewable energy guarantees
#  this is based on electricity contracts and a report from our energy suppliers assurance provider
#  renewable gas guarantees of origin
#  this is based on gas contracts and a report from our energy suppliers assurance provider
#  market - based emissions of our office occupiers are reported in scope 3 market based
#  we have estimated retail electricity and fuel use
#  aligned with the rics whole life carbon assessment for the built environment
#  figures represent projects that reached practical completion during the reporting year
#  whole life emissions new builds acquired : as above , emissions from rics modules a1 - a5 for acquisitions completed during the reporting year
#  independently assured ? [SEP]
#  pro - rating these by changes in employee fte
#  employee commuting is calculated to cover the 7 months of fy22 when working from home was not required
#  estimated emissions for homeworking have been reported for fy21 and fy22
#  employee homeworking data is calculated to cover 5 months of fy22 when working from home was required
#  independently assured ? [SEP] value chain business travel : air travel : emissions from staff business travel by air
#  calculated using ( i ) the origin - destination codes and travel class provided by british lands two travel management companies , and ( ii ) great - circle distances from great circle mapper
#  air travel emissions were based only on emission factors for domestic average passenger
#  independently assured
#  where available , this is calculated using the kilometres travelled and travel class provided by british lands two travel management companies
#  where kilometres are unavailable , this is estimated using british lands average kilometres travelled per gbp spent
#  emissions from tube travel are excluded
#  this is calculated using exact claimed mileage through expenses
#  independently assured
#  estimated based on annual footfall , third - party surveys of visitors mode and duration of travel
#  estimated based on surveys of our office campus workers mode of transport and distance travelled
#  british land re - instituted the collection of water consumption data from retail assets .
#  assessed in accordancewithrics methodology and guidance
#  emissions are reported according to the location - based method
#  table 4 shows the combined carbon - equivalent emission factors
#
#  independently assured
#  internal carbon levy and transition vehicle data in this table is reported on a cumulative basis
#  british land applied an internal carbon levy of 60 per tonne co2e on embodied carbon from developments
#  british land will earmark 20 / tonne of the levy for the purchase of carbon offset credits
#  only 100 liverpool street was offset in fy21
#  st annes will not be offset until fy22
#  committed developments
#  the figures are adjusted to reflected equity share
#  british lands 50 % offset is matched by our jv partner
#
#  the transition vehicle
#  british land will invest 5m in the transition vehicle
#  the greenhouse gas emissions savings calculations are based on the direct energy savings from the initiative and the related upstream ( scope 3 ) emissions savings
#  where asset energy data was partially unavailable , we used data from adjacent periods to estimate data for missing periods
#  at our retail properties
#  where this is not possible
#  where an estimate is not available
#  sub - metered
#  where sub - metering is not available
#  measured
#  it is estimated based on methods that reflect what equipment is being used for
#  on - site renewables at our offices comprise photovoltaic panels
#  energy is used on site and included in common parts data .
#  low carbon technologies
#  independently assured ? [SEP]
#  on - site renewables in retail
#  we have assumed that all electricity generated at our retail sites has been exported to the grid
#
#
#
#  we have included energy consumption in our flexible workspace offices ( storey ) in our reporting
#  generation
#  where this occurs , it is acceptableto default to the higher rating
#  where multiple sustainability certifications are held for the same building , the following procedure is applied for determining which certification is reported
#  the default selection for reporting is the development certification
#  if a further operational certification is sought for the purpose of improving an existing development rating , it is permitted to substitute this new operational rating in place of the previous development certificates rating
#  operational certifications differ from development certifications
#  sustainable homes was withdrawn in march 2015
#  all current certificates are still valid
#  certification
#  from 2019 , we are reporting on residential developments on track to achieve the bre home quality mark
#  developments : developments hold pre - assessed ratings or certificates achieved at design stage ; these are provided by certified assessors
#  it is possible for development scores to change before final certification
#  final building certifications are reported as provided by certified assessors
#  we aim to achieve the most up to date version of breeam as appropriate for each development
#  we target breeam outstanding for offices , excellent for retail and home quality mark 3 * for residential .
#  we are meeting the local authoritys target rating
#  all major developments hold breeam completion or in - use certification
#  british land financial reporting .
#  any annual updates or adjustments will be undertaken with the intent to align with financial reporting
#  shopping centres floor areas represent net internal area ( nia ) , while retail parks floor areas represent gross internal area ( gia ) .
#  in 2021 the floor areas were primarily sourced from mid - year valuation reports
#  existence of zero values : for an asset with an exceptionally small valuation where british land holds the freehold interest only this may be reported as a zero floor area in financial reporting , which would be mirrored in sustainability reporting
#  british land completed a sustainability - linked revolving credit facility to incentivise both the coverage and quality of sustainability ratings across the portfolio
#  agreed sustainability kpis
#  percentage of development projects on track to achieve breeam excellent or above , and ( ii ) the percentage of assets under management with a breeam certificate of very good or above
#  kpis use the same data sets as the developments and assets sections , but residential properties are excluded from their scope
#  scope
#  assets with missing epcs do not currently have an epc lodged
#  assets which are planned to go into development but currently within the managed portfolio are included in scope
#  assets which do not require an epc to be lodged are excluded from scope
#  office sector includes all offices , except those that are a small part of retail assets .
#  epc is required
#  we only report whole building use
#  we only report common parts use
#  epra guidance
#  we used data from adjacent periods to estimate data for missing periods
#  independently assured
#  waste sent to a material recovery facility ( mrf ) is included in recycling , incineration and / or landfill figures
#  mrf output is calculated at a site level , monthly , based on each facilitys average performance
#  using data from the previous period and site team operational knowledge
#  data captured from our sites has been split into excavation , demolition and construction , hazardous and non hazardous categories .
#  landfill tax costs are indicative
#  waste data is estimated for some sites in march2022 , using data from the previous period and site team operational knowledge
#  independently assured
#  should have been reported to the relevant local authority or the environment agency
#  the proportion of iso coverage is at our major developments and in our managed portfolio
#  iso certification
#  independently assured
#  expert analysis
#  exposure
#  independently assured ? [SEP] the proportion of high flood risk assets with flood risk management plans is calculated as a proportion of asset value
#  resource efficiency metrics are sourced from figs
#  energy sources metrics are sourced from figs
#  portfolio with green building ratings is sourced from fig
#  proportion of gross rental income ( gri ) from breeam certified assets is the ratio of gri derived from assets with a breeam certification
#  biodiversity
#  information is based on formal ecologists reports or design team commitments
#  reporting on new construction and major renovation projects designed to achieve a 10 % net gain in biodiversity has been removed from fig
#  there is also a risk of double counting if both net improvements and 10 % net gain indicators are reported against
#  the sustainability brief is under review in fy23
#  a site specific biodiversity action plan
#  community engagement proportion of assets ( floorarea ) where community activity is implementedis reported in line with epra guidance
#  initiatives
#  they tend to be ongoing , or are scalable and / or can be repeated , and include pilot initiatives
#  if an initiative is run across multiple sites , it is counted per site
#  initiatives are only reported where outcomes against the initiative have been achieved within the reporting year
#  excluded from initiatives figures are one - off or ad hoc activities
#  if a series or programme of related activity took place at our group offices or at a site , the initiative has been counted just once per site
#  sustainability / society / bright - lights initiatives
#  ourapprenticeship programme , which is counted as one initiative
#  apprenticeships at our group offices
#  peoplereceiving employment related support or training we definepeople receiving employment related support or training as people who have received meaningful supportvia our programmes
#  not completed a programme
#
#  people that receive employment related support or training or who progress into jobs through our bright lights programme
#  fy20 and fy19 figures have beenredistributed inthe new table format but remain the same
#  cashcontributionsexcludevat
#  british land employee time ( direct )
#  in - kind contributions
#  separate average hourly costs are calculated for executive directors and applied accordingly , excluding share incentive costs
#  valued according to an average cost
#  separate values are attributed to retail and office property management
#  arevalued according to the latest office for national statistics uk average earnings data
#  activityfunded by british land
#  do not report beneficiary numbers
#
#  if we part fund an activity , weonlyreport the number of beneficiaries
#  thecommunitypartner has accessed up to 50 % of the cost from other sources
#  if british landemployeesorsupplierpartners support a session / workshop and volunteers from other organisationsareinvolved , we record the total number of beneficiaries attending
#  we commissionedplace based reviews
#  aresocio economic impact assessments
#  these reports provide baseline data on deprivation , population and employment and will be reviewedat intervals over the coming years , 5years
#  long term space donation : the value of long term space provided to community organisations is outside of the scope of the b4si methodology
#  community benefit
#  full - time equivalent figures were used
#  volunteeringdata ( % ) includesbritish landsproperty managementarm
#
#  this is undertaken during work hours , except for some expert volunteering
#  expertvolunteering
#  if itis directly linked withour community investment programme
#  expert volunteering does not include support of industry bodies or chambers of commerce
#  affordable housing : constructing affordable housing , not including design fees
#  public space and environment : environmental or art enhancements with a clear community benefit , regardless of land ownership
#  accessibility and transport : contributions to highways , roads or public spaces outside our ownership boundary , including payments made to local authorities
#  not captured in our community investment programme
#  figures are based on spend in the financial year
#  data is estimated by our cost consultants based on their professional knowledge and project understanding , and pro - rated monthly across the construction period .
#  scope
#  scoring changed to out of 45 , with 5 points available for innovation
#  target score for all projects remains 40
#  independently assured
#  spend data is cumulative
#  an organisation with a postcode within the defined s106 agreement
#  local branches of national firms are included if within the defined area
#  an organisation employing fewer than 250 people
#  corporate data is normalised
#  health and safety figs
#  british land , our managing agents or development project managers are required to report all fatalities and specified injuries that occur to anyone ( including employees , contractors and visitors ) in the common parts and the vacant space of our multi - let properties to the health and safety executive ( hse ) or the relevant local authority
#  this requirement is set out under the reporting of injuries , diseases and dangerous occurrences regulations 2013
#  according to riddor reporting guidance
#  independently assured ? [SEP] thefollowing are reported asriddorincidents in british lands health and safety reporting
#  independently assured
#  overview accidents that result in someone being unable to work for more than seven days
#  the health and safety reporting
#  thie includes incidents involving british land employees , members of the public , occupier employees and contractors .
#  data for total people working in each office building is calculated as an average fte for a period
#
#  rates are calculated using the number of incidents involving british land employees only
#  injury frequency rate
#  number of hours worked data is estimated for developments without a digital security system
#
#  risks controlled at annual audit
#  we target our management agents to ensure that 90 % of all risks are deemed to be under control during the annual assessment
#  statutory document compliance
#  legionella risk assessments
#  a risk assessment audit is undertaken within two weeks
#  this risk assessment
#  lost day rate
#  all lost days are calculated from the moment an employee leaves work ( half day , for example ) or does not arrive at work
#  independently assured
#  employment type is defined as shown in table 10
#  new hires includes permanent and ftcs who joined within the year even if left during the year
#  employees who left under tupe or at the end of their agreed fixed term employment contract are excluded
#  turnover rates are based on the number of leavers divided by the total number of number of employees at the end of the year
#  proportion of leavers by gender , employment level and age is based on the number of leavers in each category divided by total number of leavers within the year
#  had not been determined when data was compiled
#  pro - rated to their fte data
#  non - executive directors are not included in this table
#  we are reporting on the 2022 pay gap ahead of the 2023 deadline set by the government
#  comply with the mandatory government criteria for gender pay gap reporting
#  any bonus received in the year preceding 5 april 2022 is included in the bonus calculations
#  in line with recommendations from the global reporting initiative
#  it is consistent with the single figure reported in our 2022 annual report and accounts
#  the data follows method a of the governments reporting criteria
#  from 2016 , ethnicity data has been captured through the human resources systems upon request from human resources
#  fig 52 : employee diversity disability proportion of employees voluntarily recording on our hr system
#  prefer not to say
#  this proportion is calculated for employees employed by british land group since the beginning of the performance review year
#  limited
#  have not been prepared , in all material respects , in accordance with the applicable criteria
#  the ethnicity pay gap calculations were also reviewed on the same basis
#  these were resolved or confirmed as appropriate by british land
#  korn ferry policies and procedures are designed to ensure the provision of objective and independent advice
#  all assurance engagements are subject to inherent limitations such as data sampling and may not detect errors , fraud or other irregularities
#  korn ferry expressly disclaims any liability or co - responsibility
#  independent limited assurance report to the board of directors of the british land company plc
#  independent limited assurance report
#  our observations and areas for improvement will be raised in a separate report to british lands management
#  the scope and boundary of our work is restricted to the 2022 data presented in figures marked with a ( the selected information ) in the report
#  sbti nzc targets greenhouse gas intensity 2
#  net zero carbon developments
#  indirect ( scope 3 ) value chain greenhouse gas emissions 7
#  independently assured
#  independently assured
#  internal carbon levy and transition vehicle 10
#  independently assured
#  independently assured
#  sustainability
#  energy performance certificates
#  independently assured
#  like - for - like total water consumption 18
#  independently assured
#  waste management - managed portfolio and corporate 20
#  independently assured
#  independent team of sustainability assurance professionals
#  none of which conflict with the scope of this work
#  sustainability assurance
#  an assessment of the risk of material misstatement in the report , we have used british lands reporting criteria
#  we have not performed any work , and do not express any conclusion
#
#  limited assurance
#  dnv
#  the level of assurance obtained is substantially lower than the assurance that would have been obtained had a reasonable assurance engagement been performed
#
#  dnv were free to choose the site on the basis of materiality to the group level figures ; assessing the appropriateness of the criteria for the selected information ; and reading the report and narrative accompanying the selected information within it with regard to the criteria
#  selective testing ( sampling ) may not detect errors , fraud or other irregularities
#  the selection of different , but acceptable , measurement techniques
#  our assurance relies on the premise that the data and information provided to us by british land have been provided in good faith
#  dnv expressly disclaims any liability or co - responsibility for any decision a person or an entity may make based on this independent limited assurance report
#  designing , implementing and maintaining effective internal controls over the information and data , resulting in the preparation of the selected information that is free from material misstatements
#  to report to british land in the form of an independent limited assurance conclusion , based on the work performed and the evidence obtained
#  dnv business assurance

# %%
df_audit['kw2'] = df_audit['words'].apply(lambda x: test('Are your emission reduction targets independently assured?', x, model, tok))
# Out:
#  selected datahas been independently assured since 2007
#  certain key data
#  independent limited assurance report
#  dnv expressly disclaims any liability or co - responsibility for any decision a person or an entity may make based on this independent limited assurance report

# %%
df_new = df_new[~df_new['kw2'].str.contains('SEP')]

# %%
df_d = df_new[df_new['kw2'].str.contains('independent|externally|external')]

# %%
df_d['words'].apply(lambda x: print(x))
# Out:
# Selected datahas been independently assured since 2007 (see earlier reports).
# Overview Carbon emissions (continued) Fig.
# Overview Energy use Fig.
# Overview Energy use (continued) Fig.
# Overview Water use Fig.
# Overview Water use (continued) Fig.
# Overview Overview Waste and materials Fig.
# Overview Waste and materials (continued) Fig.
# Overview Biodiversity Fig.
# Overview Community Fig.
# Overview Contributions and investment Fig.
# Overview Health and safety Fig.
# Overview Health and safety (continued) Fig.
# Employee training proportion by category DSE Assessment and Training (previously referred to as Health and Safety training), fell significantly during the year due to an alternative focus on working from home and returning to the office assessments.
# In 2022 we undertook a number of independent water audits in order to identify existing or potential issues.
# It also sets out the overall principles, boundaries, scope and methodologies applied when reporting sustainability data in our 2022 Annual Report and Accounts, Sustainability Accounts and corporate website.
# The following sets out the overall principles, boundaries, scope and methodologies applied when reporting sustainability data in our 2022 Annual Report and Accounts, Sustainability Accounts (The Report) and corporate website.
# Certain key data is independently assured (see below).
# We engaged DNV to perform independent limited assurance of a selection of our most material 2022 data.
# Shopping villages have external walkways and common areas beyond car parks but which are not enclosed.
# Overview Greenhouse gas emissions Fig.
# Overview Fig 9.
# The heat and power output from CHP is reported in Fig.
# Note: mains water refers to municipal water in the EPRA guidance, borehole water to ground water, and on-site harvesting to rainwater harvesting.
# Extreme weather (flood risk) metrics cover all assets under management High flood risk is defined as assets located in areas withaflood frequency of a 100 year return period.
# Thefollowing are reported asRIDDORincidents in British Lands health and safety reporting: A specified injury is defined as: Fractures, other than to fingers, thumbs and toes.
# Korn Ferry policies and procedures are designed to ensure the provision of objective and independent advice.
# This conclusion relates only to the Selected Information, and is to be read in the context of this Independent Limited Assurance Report, in particular the inherent limitations explained overleaf.
# Total greenhouse gas emissions by gas 8.
# Building energy target and intensity 9.
# Total electricity consumption 11.
# Building water target and intensity 19.
# Overview Standard and level of assurance We performed a limited assurance engagement in accordance with the International Standard on Assurance Engagements (ISAE) 3000 revised Assurance Engagements other than Audits and Reviews of Historical Financial Information (revised), issued by the International Auditing and Assurance Standards Board.
# DNV expressly disclaims any liability or co-responsibility for any decision a person or an entity may make based on this Independent Limited Assurance Report.
# Our responsibility is to plan and perform our work to obtain limited assurance about whether the Selected Information has been prepared in accordance with the Criteria and to report to British Land in the form of an independent limited assurance conclusion, based on the work performed and the evidence obtained.
# 263    None
# 266    None
# 299    None
# 302    None
# 318    None
# 321    None
# 322    None
# 323    None
# 338    None
# 340    None
# 344    None
# 355    None
# 356    None
# 375    None
# 392    None
# 406    None
# 407    None
# 418    None
# 423    None
# 495    None
# 564    None
# 617    None
# 652    None
# 705    None
# 725    None
# 828    None
# 935    None
# 942    None
# 951    None
# 952    None
# 954    None
# 962    None
# 972    None
# 983    None
# 985    None
# Name: words, dtype: object

# %%
df_c = df_new[df_new['kw'].str.contains('ghg')]

# %%
df_c['words'].apply(lambda x: print(x))
# Out:
# For the financial ratio, see GHG Emissions Scope 1 and 2 Financial Intensity Measures.
# Table 4 shows the combined carbon-equivalent emission factors for the different GHGs considered.
# 466    None
# 615    None
# Name: words, dtype: object
